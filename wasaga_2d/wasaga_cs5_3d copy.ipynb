# %%
# %%
# ## Getting Started
from pathlib import Path
from tempfile import TemporaryDirectory
from tempfile import mkdtemp

import numpy as np
import matplotlib.pyplot as plt
import flopy
import pandas as pd
import shutil
import pickle
import subprocess
import os
# %% [markdown]

# %%

# %%
################### Model Parameters   ##############################
my_params = {}
my_params['name'] = 'test_wasaga_2'
## mt3dGcg
cclose=my_params['cclose'] = 1e-5
## RCT

my_params['hk'] = 6.9
my_params['vk'] = 0.1

my_params['porosity'] = 0.35
my_params['sy'] = 0.33
my_params['ss'] = 0.0002
my_params['la'] = 0.2
my_params['trpt'] = 0.1
my_params['trpv'] = 0.1
my_params['dmcoef'] = 3.7E-10 ####
my_params['sconc'] = 0.01

#Species ID
sp_ID = {}
#sp_ID['Cl-'] = 1
sp_ID['SRP'] = 1
my_params['sp_ID'] = sp_ID

#Species Name
sp_name = {}
#sp_name[1] = 'Cl-'
sp_name[1] = 'SRP'
my_params['sp_name'] = sp_name


## P lens
my_params['perlen'] = [1]+[30,92,31,212]*25 +[365]*5+[365*5]*5+[365*4]+[185,30,30,120]


## Wel data
wel_data = {}
#last_wel_id = len(my_params['perlen'])-1
for y in range(25):
    p = (y)*4 +2
    wel_data[p] = [[50,0,15,0.0075]]
    p += 1
    wel_data[p] = [[50,0,15,0.075]]
    p += 1
    wel_data[p] = [[50,0,15,0.0075]]
    p += 1
    wel_data[p] = [[50,0,15,0.0]]
    p += 1

wel_data[p] = [[50,0,15,0]]
my_params['wel_data'] = wel_data


# Mt3dSsm 
ssm_data = {}
itype = flopy.mt3d.Mt3dSsm.itype_dict()

for y in range(25):
    p = (y)*4 +2
    ssm_data[p] = [(50, 0, 15, 3000.0, itype['WEL'])]
    p += 1
    ssm_data[p] = [(50, 0, 15, 3000.0, itype['WEL'])]
    p += 1
    ssm_data[p] = [(50, 0, 15, 3000.0, itype['WEL'])]
    p += 1
    ssm_data[p] = [(50, 0, 15, 3000.0, itype['WEL'])]
    p += 1
ssm_data[p] = [(50, 0, 15, 0.0, itype['WEL'])]
my_params['ssm_data'] = ssm_data


#Mt3dBtn
mixelm=my_params['mixelm'] = 0 # 0 = FDM 3 =HMOC
my_params['isothm'] = 3 # Langmuir
my_params['sp1'] = 0.0001 ##  0.1 mg/L  => 1e5 ug/m3
my_params['sp2'] = 0.0001  ##  maximum soil adsorption value = 100 ug/g => 1e5 ug/kg

# Rch
my_params['rech'] = 0.5/365 #0.5/365 ## 500mm/year

# dt0
my_params['dt0'] = 0.1
################################################################

base_model_my_params = my_params

# %%
my_params['sp1'] = 0.0002
my_params['la'] = 5
my_params['hk'] = 6.9
base_model_my_params = my_params.copy()

my_params['vk'] = 0.1
trpv=my_params['trpv'] = 0.01

# %%
my_params['la']
# Out:
# 5

# %%
# bed size 10x10
# row: 25-35 (1m), col 12-17 (2m)
#  50 cells

# %%
mytop =np.loadtxt('_imports/top')
mybot = np.loadtxt('_imports/bot')
myibound = np.loadtxt('_imports/ibound')
mystrt = np.loadtxt('_imports/strt')
myicbund = np.loadtxt('_imports/icbund')

# %%
mytop = np.tile(mytop.reshape([74,1,110]),(1,60,1))
mybot = np.tile(mybot.reshape([74,1,110]),(1,60,1))
myibound= np.tile(myibound.reshape([74,1,110]),(1,60,1))
mystrt = np.tile(mystrt.reshape([74,1,110]),(1,60,1))
myicbund = np.tile(myicbund.reshape([74,1,110]),(1,60,1))

# %%
# mytop = np.tile(mytop.reshape([74,1,110]),(1,1,1))
# mybot = np.tile(mybot.reshape([74,1,110]),(1,1,1))
# myibound= np.tile(myibound.reshape([74,1,110]),(1,1,1))
# mystrt = np.tile(mystrt.reshape([74,1,110]),(1,1,1))
# myicbund = np.tile(myicbund.reshape([74,1,110]),(1,1,1))

# %%
from random_name import generate_random_name
from datetime import datetime
import platform

# %%
# ## Import
Lx = 150
Lz = 1
nlay = 74
nrow = 60
ncol = 110
delr = np.concatenate([np.repeat(2,25),np.repeat(1,70),np.repeat(2,15)])
delc = 1.0
delv = mytop[:,0] - mybot[:,0]

# %%
# Control variable to decide the location of the temp folder
use_d_drive = True  # Set to True to use the custom location

# Define model workspace
myt = datetime.now().strftime('%m%d%H%M%S')
name = 'wasaga'
adj_non = '_' + generate_random_name()

if use_d_drive and platform.system() == 'Windows':  # Check if on Windows
    temp_dir = 'H:/mf/_T{}_{}'.format(myt, adj_non)  # Path for D drive
elif use_d_drive and platform.system() == 'Darwin':  # Check if on macOS
    temp_dir = '/Volumes/Public/mf/_T{}_{}'.format(myt, adj_non)
else:
    temp_dir = mkdtemp(prefix='_T{}_'.format(myt), suffix=adj_non)

os.makedirs(Path(temp_dir) / '_output', exist_ok=True)
workspace = temp_dir

# %%
# ## Workspace

swt = flopy.seawat.Seawat(name, exe_name="swtv4", model_ws=workspace)

# %%
##

import os
import platform
import subprocess

def open_file(path):
    if platform.system() == "Windows":
        os.startfile(path)
    elif platform.system() == "Darwin":
        subprocess.Popen(["open", path])
    else:
        subprocess.Popen(["xdg-open", path])

open_file(workspace)

# %%
# %%
def create_time_table():
    time_table = pd.DataFrame()

    perlen = pd.Series(my_params['perlen'])
    perlen.index = perlen.index+1

    time_table['perlen'] = perlen
    time_table['Time'] = time_table['perlen'].cumsum()

    #time_table = pd.DataFrame()
    for key,value in wel_data.items():
        key
        time_table.loc[key,'wel_data'] = value[0][3]

    #time_table = pd.DataFrame()
    for key,value in ssm_data.items():
        key
        time_table.loc[key,'ssm'] = value[0][3]
    return time_table

# %%
# ## DIS

# %%
ipakcb = 53

# %%

perlen = my_params['perlen']
nper = len(perlen)
nstp = np.repeat(1,nper)
steady = np.append(np.array([True]),np.repeat(False,nper-1))



# %%
dis = flopy.modflow.ModflowDis(
    swt,
    nlay,
    nrow,
    ncol,
    nper=nper,
    delr=delr,
    delc=delc,
    laycbd=0,
    top=182.2,
    botm=mybot,
    perlen=perlen,
    nstp=nstp, #Number of time steps in each stress period
    steady = steady
)

# %% [markdown]
# ## WEL

# %%
# #last_wel_id = len(my_params['perlen'])-1

# ## Wel data
# wel_data = {}
# # Mt3dSsm 
# ssm_data = {}
# for per in range(nper):
#     wel_data[per]= []
#     ssm_data[per] = []


# for row in range(25,35+1):
#     for col in range(12,17+1):
#         for y in range(25):

#             p = (y)*4 +2
#             wel_data[p].append([50,row,col,0.5/50])
#             p += 1
#             wel_data[p].append([50,row,col,0.5/50])
#             p += 1
#             wel_data[p].append([50,row,col,0.5/50])
#             p += 1
#             wel_data[p].append([50,row,col,0.5/50])
#             p += 1


#             wel_data[p].append([50,row,col,0.5/50])




# itype = flopy.mt3d.Mt3dSsm.itype_dict()



# for row in range(25,35+1):
#     for col in range(12,17+1):
#         for y in range(25):
#             p = (y)*4 +2
#             ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))
#             p += 1
#             ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))
#             p += 1
#             ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))
#             p += 1
#             ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))
#             p += 1
#         ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))


# my_params['ssm_data'] = ssm_data

# %% [markdown]
# ## RCH

# %%
rch_dict = {}

rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_dict[0] = rch_array

rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
#rch_array[int(nrow/2),int(ncol/2)] = 0.51/delr/delc
#rch_array[int(nrow/2),int(ncol/3)] = 0.51/delr/delc

for row in range(25,35+1):
    for col in range(12,17+1):
        rch_array[row,col] = 0.51/10/10
        rch_array[row,col] = 0.51/10/10

rch_dict[1] = rch_array 


rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_dict[int(25*4+1)] = rch_array

# %%
crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)
crch_dict = {}
crch_dict[0] = crch_array

crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)

# crch_array[int(nrow/2),int(ncol/2)] =5000
# crch_array[int(nrow/2),int(ncol/3)] =5000

for row in range(25,35+1):
    for col in range(12,17+1):
        crch_array[row, col] =5000
        crch_array[row, col]= 5000


crch_dict[1] = crch_array


crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)
crch_dict[int(25*4+1)] = crch_array

# %%
bas = flopy.modflow.ModflowBas(swt, myibound, mystrt)


lpf = flopy.modflow.ModflowLpf(swt, hk=my_params['hk'], vka=my_params['vk'],
                            ss= my_params['ss'],sy=my_params['sy'],
                            ipakcb=ipakcb,laytyp=1)

pcg = flopy.modflow.ModflowPcg(swt, hclose=1e-4)

# %%
stress_period_data = {}
for kper in range(nper):
    for kstp in range(nstp[kper]):
        stress_period_data[(kper, kstp)] = [
            "save head",
            "save drawdown",
            "save budget",
            "print head",
            "print budget",
        ]

# OC - Output Control Option
oc = flopy.modflow.ModflowOc(
    swt,
    stress_period_data= stress_period_data,
    compact=True,
)

# ## Well

# wel_data = my_params['wel_data']
# wel = flopy.modflow.ModflowWel(swt, stress_period_data=wel_data, ipakcb=ipakcb)

# # ModflowRch

# rch = flopy.modflow.ModflowRch(model = swt, rech = my_params['rech'])

rch = flopy.modflow.ModflowRch(model = swt, rech = rch_dict)

# # ## SSM
# ssm_data = my_params['ssm_data']



# ## BTN

#timprs = my_params['perlen'][:5]*5 +np.arange(365,np.sum(my_params['perlen']),5*355).tolist()
timprs = np.cumsum(my_params['perlen'])
timprs = [1]




btn = flopy.mt3d.Mt3dBtn(
    swt,
    nprs=len(timprs),
    timprs=timprs,
    prsity=my_params['porosity'],
    sconc=my_params['sconc'], # starting concentration
    ifmtcn=0,
    chkmas=False,
    nprobs=10,
    nprmas=10,
    dt0=my_params['dt0'],  # The user-specified initial transport step size
    ttsmult=1.1,
    mxstrn = 50000,
    icbund = myicbund
)
adv = flopy.mt3d.Mt3dAdv(swt, mixelm=my_params['mixelm'],percel=0.4,mxpart=400000,nadvfd=0)
dsp = flopy.mt3d.Mt3dDsp(swt, al=my_params['la'], trpt=my_params['trpt'], 
                        trpv=my_params['trpv'], 
                        dmcoef=my_params['dmcoef'])
gcg = flopy.mt3d.Mt3dGcg(swt, iter1=50, mxiter=1, isolve=2, cclose=my_params['cclose'])

ssm = flopy.mt3d.Mt3dSsm(swt, crch=crch_dict)

# %% [markdown]
# ## RCT


rct = flopy.mt3d.Mt3dRct(model=swt, isothm=my_params['isothm'],sp1=my_params['sp1'],sp2=my_params['sp2'],igetsc=0,rhob= 1.65E+09)





# %%
#Pht3d
#phc = flopy.mt3d.Mt3dPhc(swt,mine=[1],ie=[1],surf=[1],mobkin=[1],minkin=[1],surfkin=[1],imobkin=[1])
#phc.write_file()

# %% [markdown]
# # Write File

# %% [markdown]
# # RUN

# %%
# %%
swt.write_input()

# %%


# %% [markdown]
# ## ################   Run      ########################

# %%

success, buff = swt.run_model(silent=False, report=True)
assert success, "SEAWAT did not terminate normally."

# %%  dump
swt.my_params = my_params
swt.delv =  delv
swt.delr = delr
pickle.dump( swt, open( Path(workspace) / '_output' / 'model.pickle',"wb" ) )

# %%


# %% [markdown]
# # Summarize Parameters
# Out:
# Util2d rech_1: locat is None, but model does not support free format and how is internal... resetting how = external
# Util2d rech_2: locat is None, but model does not support free format and how is internal... resetting how = external
# Util2d rech_102: locat is None, but model does not support free format and how is internal... resetting how = external
# FloPy is using the following executable to run the model: C:\Users\Administrator\AppData\Local\flopy\bin\swtv4.exe
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: wasaga.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2024/02/21  0:23:19
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:  0.10000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    2   Step Size:  0.1100     Total Elapsed Time:  0.21000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    3   Step Size:  0.1210     Total Elapsed Time:  0.33100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    4   Step Size:  0.1331     Total Elapsed Time:  0.46410
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    5   Step Size:  0.1464     Total Elapsed Time:  0.61051
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    6   Step Size:  0.1611     Total Elapsed Time:  0.77156
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    7   Step Size:  0.1772     Total Elapsed Time:  0.94872
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    8   Step Size:  5.1283E-02 Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    2
#
#   STRESS PERIOD    2 TIME STEP    1 FROM TIME =   1.0000     TO    31.000
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   1.1000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   76.36      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5929E-04  [K,I,J]   51   25   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9722E-10  [K,I,J]   51   35   15
#  Transport Step:    2   Step Size:  0.1100     Total Elapsed Time:   1.2100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   1.085      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1018E-05  [K,I,J]   51   25   15
#  Transport Step:    3   Step Size:  0.1210     Total Elapsed Time:   1.3310
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5716      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6479E-06  [K,I,J]   51   25   15
#  Transport Step:    4   Step Size:  0.1331     Total Elapsed Time:   1.4641
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3995      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5471E-06  [K,I,J]   51   25   15
#  Transport Step:    5   Step Size:  0.1464     Total Elapsed Time:   1.6105
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3136      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5185E-06  [K,I,J]   51   25   15
#  Transport Step:    6   Step Size:  0.1611     Total Elapsed Time:   1.7716
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2622      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5235E-06  [K,I,J]   51   25   15
#  Transport Step:    7   Step Size:  0.1772     Total Elapsed Time:   1.9487
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2281      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5498E-06  [K,I,J]   51   25   15
#  Transport Step:    8   Step Size:  0.1949     Total Elapsed Time:   2.1436
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2039      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5991E-06  [K,I,J]   51   35   15
#  Transport Step:    9   Step Size:  0.2144     Total Elapsed Time:   2.3579
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1859      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6765E-06  [K,I,J]   51   35   15
#  Transport Step:   10   Step Size:  0.2358     Total Elapsed Time:   2.5937
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1720      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7766E-06  [K,I,J]   51   35   15
#  Transport Step:   11   Step Size:  0.2594     Total Elapsed Time:   2.8531
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1610      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8593E-05  [K,I,J]   52   27   15
#  Transport Step:   12   Step Size:  0.2853     Total Elapsed Time:   3.1384
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1521      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-04  [K,I,J]   52   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6421E-08  [K,I,J]   52   26   15
#  Transport Step:   13   Step Size:  0.3138     Total Elapsed Time:   3.4523
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1448      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2071E-04  [K,I,J]   52   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1175E-07  [K,I,J]   52   26   15
#  Transport Step:   14   Step Size:  0.3452     Total Elapsed Time:   3.7975
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1386      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2618E-04  [K,I,J]   52   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1785E-07  [K,I,J]   52   26   15
#  Transport Step:   15   Step Size:  0.3797     Total Elapsed Time:   4.1772
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1334      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3165E-04  [K,I,J]   52   33   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2280E-07  [K,I,J]   52   26   15
#  Transport Step:   16   Step Size:  0.4177     Total Elapsed Time:   4.5950
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1290      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3753E-04  [K,I,J]   52   33   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2594E-07  [K,I,J]   52   26   15
#  Transport Step:   17   Step Size:  0.4595     Total Elapsed Time:   5.0545
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1251      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2419E-03  [K,I,J]   53   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2638E-05  [K,I,J]   52   31   15
#  Transport Step:   18   Step Size:  0.5054     Total Elapsed Time:   5.5599
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1217      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1157E-03  [K,I,J]   53   36   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2739E-05  [K,I,J]   52   31   15
#  Transport Step:   19   Step Size:  0.5560     Total Elapsed Time:   6.1159
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1187      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8810E-04  [K,I,J]   53   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3478E-05  [K,I,J]   53   31   15
#  Transport Step:   20   Step Size:  0.6116     Total Elapsed Time:   6.7275
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1160      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2326E-03  [K,I,J]   51   37   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6465E-05  [K,I,J]   53   31   15
#  Transport Step:   21   Step Size:  0.6727     Total Elapsed Time:   7.4002
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1136      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2783E-03  [K,I,J]   53   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6157E-05  [K,I,J]   53   31   15
#  Transport Step:   22   Step Size:  0.7400     Total Elapsed Time:   8.1403
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1114      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3728E-03  [K,I,J]   53   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5973E-05  [K,I,J]   52   26   15
#  Transport Step:   23   Step Size:  0.8140     Total Elapsed Time:   8.9543
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1094      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8694E-04  [K,I,J]   51   37   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8487E-06  [K,I,J]   51   36   12
#  Transport Step:   24   Step Size:  0.8954     Total Elapsed Time:   9.8497
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1075      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2405E-03  [K,I,J]   53   31   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2697E-05  [K,I,J]   52   25   12
#  Transport Step:   25   Step Size:  0.9850     Total Elapsed Time:   10.835
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1058      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2430E-03  [K,I,J]   53   28   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3115E-05  [K,I,J]   52   36   12
#  Transport Step:   26   Step Size:   1.083     Total Elapsed Time:   11.918
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1041      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1729E-03  [K,I,J]   53   26   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4136E-05  [K,I,J]   52   36   12
#  Transport Step:   27   Step Size:   1.192     Total Elapsed Time:   13.110
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1026      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1327E-03  [K,I,J]   51   37   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3904E-05  [K,I,J]   50   25   12
#  Transport Step:   28   Step Size:   1.311     Total Elapsed Time:   14.421
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1011      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2978E-03  [K,I,J]   51   37   11
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8203E-05  [K,I,J]   52   29   11
#  Transport Step:   29   Step Size:   1.442     Total Elapsed Time:   15.863
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9964E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2053E-03  [K,I,J]   54   28   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1043E-04  [K,I,J]   52   36   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7153E-06  [K,I,J]   52   36   12
#  Transport Step:   30   Step Size:   1.586     Total Elapsed Time:   17.449
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9821E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1826E-03  [K,I,J]   51   37   11
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1224E-04  [K,I,J]   52   36   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1188E-05  [K,I,J]   52   36   12
#  Transport Step:   31   Step Size:   1.745     Total Elapsed Time:   19.194
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9680E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3048E-03  [K,I,J]   51   25   11
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1757E-04  [K,I,J]   52   36   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4002E-05  [K,I,J]   52   36   12
#  Transport Step:   32   Step Size:   1.919     Total Elapsed Time:   21.114
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9540E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2581E-03  [K,I,J]   51   25   11
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2491E-04  [K,I,J]   52   36   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4619E-05  [K,I,J]   52   36   12
#  Transport Step:   33   Step Size:   2.111     Total Elapsed Time:   23.225
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9400E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2513E-03  [K,I,J]   51   37   11
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3348E-04  [K,I,J]   52   36   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5896E-05  [K,I,J]   52   36   12
#  Transport Step:   34   Step Size:   2.323     Total Elapsed Time:   25.548
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9258E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2762E-03  [K,I,J]   51   37   11
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4428E-04  [K,I,J]   52   36   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8933E-05  [K,I,J]   52   36   12
#  Transport Step:   35   Step Size:   2.555     Total Elapsed Time:   28.102
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9114E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3345E-03  [K,I,J]   52   36   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5141E-04  [K,I,J]   52   36   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1141E-04  [K,I,J]   52   36   12
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4727E-06  [K,I,J]   51   25   11
#  Transport Step:   36   Step Size:   2.810     Total Elapsed Time:   30.913
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8968E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4102E-03  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4886E-04  [K,I,J]   52   36   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1510E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7432E-06  [K,I,J]   51   25   11
#  Transport Step:   37   Step Size:  8.7319E-02 Total Elapsed Time:   31.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2576E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4054E-06  [K,I,J]   51   25   11
#
#  STRESS PERIOD NO.    3
#
#   STRESS PERIOD    3 TIME STEP    1 FROM TIME =   31.000     TO    123.00
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   31.100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2938E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5619E-06  [K,I,J]   51   37   11
#  Transport Step:    2   Step Size:  0.1100     Total Elapsed Time:   31.210
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3219E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6888E-06  [K,I,J]   51   37   11
#  Transport Step:    3   Step Size:  0.1210     Total Elapsed Time:   31.331
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3526E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8474E-06  [K,I,J]   51   37   11
#  Transport Step:    4   Step Size:  0.1331     Total Elapsed Time:   31.464
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3860E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1045E-05  [K,I,J]   51   37   11
#  Transport Step:    5   Step Size:  0.1464     Total Elapsed Time:   31.611
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4225E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1292E-05  [K,I,J]   51   37   11
#  Transport Step:    6   Step Size:  0.1611     Total Elapsed Time:   31.772
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4621E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1599E-05  [K,I,J]   51   37   11
#  Transport Step:    7   Step Size:  0.1772     Total Elapsed Time:   31.949
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5051E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1977E-05  [K,I,J]   51   37   11
#  Transport Step:    8   Step Size:  0.1949     Total Elapsed Time:   32.144
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5519E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2439E-05  [K,I,J]   51   37   11
#  Transport Step:    9   Step Size:  0.2144     Total Elapsed Time:   32.358
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6026E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2999E-05  [K,I,J]   51   37   11
#  Transport Step:   10   Step Size:  0.2358     Total Elapsed Time:   32.594
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6575E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3671E-05  [K,I,J]   51   37   11
#  Transport Step:   11   Step Size:  0.2594     Total Elapsed Time:   32.853
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7168E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4468E-05  [K,I,J]   51   37   11
#  Transport Step:   12   Step Size:  0.2853     Total Elapsed Time:   33.138
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7809E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5402E-05  [K,I,J]   51   37   11
#  Transport Step:   13   Step Size:  0.3138     Total Elapsed Time:   33.452
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8500E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6484E-05  [K,I,J]   51   37   11
#  Transport Step:   14   Step Size:  0.3452     Total Elapsed Time:   33.797
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9242E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7724E-05  [K,I,J]   51   37   11
#  Transport Step:   15   Step Size:  0.3797     Total Elapsed Time:   34.177
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1004E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9126E-05  [K,I,J]   51   37   11
#  Transport Step:   16   Step Size:  0.4177     Total Elapsed Time:   34.595
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1089E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1071E-04  [K,I,J]   51   25   11
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4158E-06  [K,I,J]   52   36   12
#  Transport Step:   17   Step Size:  0.4595     Total Elapsed Time:   35.054
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1181E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1246E-04  [K,I,J]   51   25   11
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6248E-06  [K,I,J]   52   36   12
#  Transport Step:   18   Step Size:  0.5054     Total Elapsed Time:   35.560
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1278E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1438E-04  [K,I,J]   51   25   11
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9168E-06  [K,I,J]   52   36   12
#  Transport Step:   19   Step Size:  0.5560     Total Elapsed Time:   36.116
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1381E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1813E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1302E-05  [K,I,J]   52   36   12
#  Transport Step:   20   Step Size:  0.6116     Total Elapsed Time:   36.727
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1490E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2383E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1965E-05  [K,I,J]   52   36   12
#  Transport Step:   21   Step Size:  0.6727     Total Elapsed Time:   37.400
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1606E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3108E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2801E-05  [K,I,J]   52   36   12
#  Transport Step:   22   Step Size:  0.7400     Total Elapsed Time:   38.140
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1727E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3997E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3899E-05  [K,I,J]   52   26   12
#  Transport Step:   23   Step Size:  0.8140     Total Elapsed Time:   38.954
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1855E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5096E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5476E-05  [K,I,J]   52   35   12
#  Transport Step:   24   Step Size:  0.8954     Total Elapsed Time:   39.850
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1988E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6506E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8138E-05  [K,I,J]   52   35   12
#  Transport Step:   25   Step Size:  0.9850     Total Elapsed Time:   40.835
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2126E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8158E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1144E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5505E-06  [K,I,J]   52   26   12
#  Transport Step:   26   Step Size:   1.083     Total Elapsed Time:   41.918
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2269E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1016E-03  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1681E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1519E-05  [K,I,J]   52   35   12
#  Transport Step:   27   Step Size:   1.192     Total Elapsed Time:   43.110
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2416E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1259E-03  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2859E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8471E-05  [K,I,J]   52   35   12
#  Transport Step:   28   Step Size:   1.311     Total Elapsed Time:   44.421
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2566E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1518E-03  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1554E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7186E-05  [K,I,J]   52   35   12
#  Transport Step:   29   Step Size:   1.442     Total Elapsed Time:   45.863
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2720E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1856E-03  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2146E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7343E-05  [K,I,J]   52   35   12
#  Transport Step:   30   Step Size:   1.586     Total Elapsed Time:   47.449
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2875E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2150E-03  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2299E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6192E-05  [K,I,J]   52   35   12
#  Transport Step:   31   Step Size:   1.745     Total Elapsed Time:   49.194
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3030E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2364E-03  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1017E-04  [K,I,J]   52   31   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6920E-05  [K,I,J]   52   35   12
#  Transport Step:   32   Step Size:   1.919     Total Elapsed Time:   51.114
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3186E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2527E-03  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1664E-04  [K,I,J]   53   27   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7012E-05  [K,I,J]   52   35   12
#  Transport Step:   33   Step Size:   2.111     Total Elapsed Time:   53.225
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3340E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2936E-03  [K,I,J]   52   27   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2246E-04  [K,I,J]   53   27   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1428E-04  [K,I,J]   52   27   12
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8202E-05  [K,I,J]   52   27   12
#  Transport Step:   34   Step Size:   2.323     Total Elapsed Time:   55.548
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3491E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3304E-03  [K,I,J]   52   27   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3193E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8840E-05  [K,I,J]   52   27   12
#  Transport Step:   35   Step Size:   2.555     Total Elapsed Time:   58.102
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3638E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3807E-03  [K,I,J]   52   27   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3671E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8994E-05  [K,I,J]   53   29   11
#  Transport Step:   36   Step Size:   2.810     Total Elapsed Time:   60.913
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3783E-01  [K,I,J]   50   28   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4279E-03  [K,I,J]   52   27   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3849E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2026E-04  [K,I,J]   53   27   12
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2065E-05  [K,I,J]   53   31   11
#  Transport Step:   37   Step Size:   3.091     Total Elapsed Time:   64.004
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3923E-01  [K,I,J]   50   28   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4875E-03  [K,I,J]   52   27   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5396E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2228E-04  [K,I,J]   53   27   12
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3454E-05  [K,I,J]   53   35   11
#  Transport Step:   38   Step Size:   3.400     Total Elapsed Time:   67.404
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4057E-01  [K,I,J]   50   34   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5566E-03  [K,I,J]   52   27   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6732E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2754E-04  [K,I,J]   53   27   12
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5372E-05  [K,I,J]   53   35   11
#  Transport Step:   39   Step Size:   3.740     Total Elapsed Time:   71.145
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4184E-01  [K,I,J]   50   34   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6384E-03  [K,I,J]   52   27   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8703E-04  [K,I,J]   52   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3273E-04  [K,I,J]   53   35   11
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1126E-04  [K,I,J]   53   35   11
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5589E-06  [K,I,J]   55   27   11
#  Transport Step:   40   Step Size:   4.114     Total Elapsed Time:   75.259
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4303E-01  [K,I,J]   50   34   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7319E-03  [K,I,J]   52   27   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1149E-03  [K,I,J]   53   27   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1328E-04  [K,I,J]   54   27   11
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1029E-04  [K,I,J]   54   27   11
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1949E-05  [K,I,J]   55   27   11
#  Transport Step:   41   Step Size:   4.526     Total Elapsed Time:   79.785
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4413E-01  [K,I,J]   50   34   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7388E-03  [K,I,J]   52   33   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1463E-03  [K,I,J]   52   33   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1698E-04  [K,I,J]   54   29   11
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1234E-04  [K,I,J]   55   29   11
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3522E-05  [K,I,J]   55   29   11
#  Transport Step:   42   Step Size:   4.979     Total Elapsed Time:   84.764
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4513E-01  [K,I,J]   50   34   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8345E-03  [K,I,J]   52   33   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1941E-03  [K,I,J]   52   33   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2856E-04  [K,I,J]   54   29   11
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4406E-05  [K,I,J]   55   32   10
#  Transport Step:   43   Step Size:   5.476     Total Elapsed Time:   90.240
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4603E-01  [K,I,J]   50   34   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8947E-03  [K,I,J]   52   32   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2518E-03  [K,I,J]   52   32   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3747E-04  [K,I,J]   54   31   11
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5560E-05  [K,I,J]   55   31   10
#  Transport Step:   44   Step Size:   6.024     Total Elapsed Time:   96.264
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4711E-01  [K,I,J]   50   34   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1004E-02  [K,I,J]   52   32   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3031E-03  [K,I,J]   52   31   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4806E-04  [K,I,J]   54   31   11
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7542E-05  [K,I,J]   56   31   10
#  Transport Step:   45   Step Size:   6.626     Total Elapsed Time:   102.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4814E-01  [K,I,J]   50   34   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6394E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2088E-03  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3651E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4041E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3104E-05  [K,I,J]   51   25   12
#  Transport Step:   46   Step Size:   7.289     Total Elapsed Time:   110.18
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4907E-01  [K,I,J]   50   34   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7703E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3688E-03  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1821E-03  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3513E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1036E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.9300E-06  [K,I,J]   51   25   12
#  Transport Step:   47   Step Size:   8.018     Total Elapsed Time:   118.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4995E-01  [K,I,J]   50   34   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9267E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1352E-03  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1163E-03  [K,I,J]   54   34   12
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5547E-04  [K,I,J]   54   34   12
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4237E-05  [K,I,J]   55   34   11
#  Transport Step:   48   Step Size:   4.803     Total Elapsed Time:   123.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2819E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2302E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6089E-04  [K,I,J]   53   35   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5544E-05  [K,I,J]   51   25   12
#
#  STRESS PERIOD NO.    4
#
#   STRESS PERIOD    4 TIME STEP    1 FROM TIME =   123.00     TO    154.00
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   123.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5734E-03  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1245E-06  [K,I,J]   51   37   12
#  Transport Step:    2   Step Size:  0.1100     Total Elapsed Time:   123.21
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6301E-03  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1426E-06  [K,I,J]   51   37   12
#  Transport Step:    3   Step Size:  0.1210     Total Elapsed Time:   123.33
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6925E-03  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1665E-06  [K,I,J]   51   24   12
#  Transport Step:    4   Step Size:  0.1331     Total Elapsed Time:   123.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7609E-03  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2051E-06  [K,I,J]   51   24   12
#  Transport Step:    5   Step Size:  0.1464     Total Elapsed Time:   123.61
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8361E-03  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2507E-06  [K,I,J]   51   24   12
#  Transport Step:    6   Step Size:  0.1611     Total Elapsed Time:   123.77
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9185E-03  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3039E-06  [K,I,J]   51   24   12
#  Transport Step:    7   Step Size:  0.1772     Total Elapsed Time:   123.95
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1009E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3651E-06  [K,I,J]   51   24   12
#  Transport Step:    8   Step Size:  0.1949     Total Elapsed Time:   124.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1108E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4345E-06  [K,I,J]   51   24   12
#  Transport Step:    9   Step Size:  0.2144     Total Elapsed Time:   124.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1217E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5120E-06  [K,I,J]   51   24   12
#  Transport Step:   10   Step Size:  0.2358     Total Elapsed Time:   124.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1336E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5968E-06  [K,I,J]   51   24   12
#  Transport Step:   11   Step Size:  0.2594     Total Elapsed Time:   124.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1467E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7174E-06  [K,I,J]   53   35   12
#  Transport Step:   12   Step Size:  0.2853     Total Elapsed Time:   125.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1610E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1071E-05  [K,I,J]   53   35   12
#  Transport Step:   13   Step Size:  0.3138     Total Elapsed Time:   125.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1767E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1544E-05  [K,I,J]   53   35   12
#  Transport Step:   14   Step Size:  0.3452     Total Elapsed Time:   125.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1938E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2163E-05  [K,I,J]   53   35   12
#  Transport Step:   15   Step Size:  0.3797     Total Elapsed Time:   126.18
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2126E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2958E-05  [K,I,J]   53   35   12
#  Transport Step:   16   Step Size:  0.4177     Total Elapsed Time:   126.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2331E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3945E-05  [K,I,J]   53   35   12
#  Transport Step:   17   Step Size:  0.4595     Total Elapsed Time:   127.05
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2555E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5154E-05  [K,I,J]   53   35   12
#  Transport Step:   18   Step Size:  0.5054     Total Elapsed Time:   127.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2799E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6614E-05  [K,I,J]   53   35   12
#  Transport Step:   19   Step Size:  0.5560     Total Elapsed Time:   128.12
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3066E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8361E-05  [K,I,J]   53   35   12
#  Transport Step:   20   Step Size:  0.6116     Total Elapsed Time:   128.73
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3357E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1046E-04  [K,I,J]   53   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3446E-06  [K,I,J]   51   25   12
#  Transport Step:   21   Step Size:  0.6727     Total Elapsed Time:   129.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3674E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1300E-04  [K,I,J]   53   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3691E-06  [K,I,J]   51   25   12
#  Transport Step:   22   Step Size:  0.7400     Total Elapsed Time:   130.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4019E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1603E-04  [K,I,J]   53   35   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3918E-06  [K,I,J]   51   25   12
#  Transport Step:   23   Step Size:  0.8140     Total Elapsed Time:   130.95
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4394E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1971E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4535E-06  [K,I,J]   51   25   12
#  Transport Step:   24   Step Size:  0.8954     Total Elapsed Time:   131.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4801E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2432E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6100E-06  [K,I,J]   54   35   11
#  Transport Step:   25   Step Size:  0.9850     Total Elapsed Time:   132.83
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5243E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2977E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8380E-06  [K,I,J]   54   35   11
#  Transport Step:   26   Step Size:   1.083     Total Elapsed Time:   133.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5722E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3619E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1139E-05  [K,I,J]   54   35   11
#  Transport Step:   27   Step Size:   1.192     Total Elapsed Time:   135.11
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6239E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4273E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1304E-05  [K,I,J]   54   30   11
#  Transport Step:   28   Step Size:   1.311     Total Elapsed Time:   136.42
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6799E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5083E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1783E-05  [K,I,J]   54   30   11
#  Transport Step:   29   Step Size:   1.442     Total Elapsed Time:   137.86
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7402E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5995E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2320E-05  [K,I,J]   54   31   11
#  Transport Step:   30   Step Size:   1.586     Total Elapsed Time:   139.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8051E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7053E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3102E-05  [K,I,J]   54   31   11
#  Transport Step:   31   Step Size:   1.745     Total Elapsed Time:   141.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8748E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8215E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4117E-05  [K,I,J]   54   31   11
#  Transport Step:   32   Step Size:   1.919     Total Elapsed Time:   143.11
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9496E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9488E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5318E-05  [K,I,J]   54   29   12
#  Transport Step:   33   Step Size:   2.111     Total Elapsed Time:   145.23
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1030E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1093E-03  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7314E-05  [K,I,J]   54   29   12
#  Transport Step:   34   Step Size:   2.323     Total Elapsed Time:   147.55
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1115E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1253E-03  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9923E-05  [K,I,J]   54   29   12
#  Transport Step:   35   Step Size:   2.555     Total Elapsed Time:   150.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1206E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1428E-03  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1338E-04  [K,I,J]   54   33   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3037E-05  [K,I,J]   51   25   12
#  Transport Step:   36   Step Size:   2.810     Total Elapsed Time:   152.91
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1302E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1622E-03  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1786E-04  [K,I,J]   54   33   12
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4136E-05  [K,I,J]   51   25   12
#  Transport Step:   37   Step Size:   1.087     Total Elapsed Time:   154.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4971E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2698E-04  [K,I,J]   51   25   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1540E-05  [K,I,J]   51   25   12
#
#  STRESS PERIOD NO.    5
#
#   STRESS PERIOD    5 TIME STEP    1 FROM TIME =   154.00     TO    366.00
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   154.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4554E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6883E-07  [K,I,J]   53   33   12
#  Transport Step:    2   Step Size:  0.1100     Total Elapsed Time:   154.21
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5006E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9307E-07  [K,I,J]   53   33   12
#  Transport Step:    3   Step Size:  0.1210     Total Elapsed Time:   154.33
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5502E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1260E-06  [K,I,J]   53   33   12
#  Transport Step:    4   Step Size:  0.1331     Total Elapsed Time:   154.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6047E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1704E-06  [K,I,J]   53   33   12
#  Transport Step:    5   Step Size:  0.1464     Total Elapsed Time:   154.61
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6646E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2300E-06  [K,I,J]   53   33   12
#  Transport Step:    6   Step Size:  0.1611     Total Elapsed Time:   154.77
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7303E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3096E-06  [K,I,J]   53   33   12
#  Transport Step:    7   Step Size:  0.1772     Total Elapsed Time:   154.95
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8024E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4170E-06  [K,I,J]   53   29   12
#  Transport Step:    8   Step Size:  0.1949     Total Elapsed Time:   155.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8815E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5586E-06  [K,I,J]   53   29   12
#  Transport Step:    9   Step Size:  0.2144     Total Elapsed Time:   155.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9684E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7448E-06  [K,I,J]   53   29   12
#  Transport Step:   10   Step Size:  0.2358     Total Elapsed Time:   155.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1064E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9773E-06  [K,I,J]   53   29   12
#  Transport Step:   11   Step Size:  0.2594     Total Elapsed Time:   155.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1168E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1284E-05  [K,I,J]   53   29   12
#  Transport Step:   12   Step Size:  0.2853     Total Elapsed Time:   156.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1283E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1672E-05  [K,I,J]   53   29   12
#  Transport Step:   13   Step Size:  0.3138     Total Elapsed Time:   156.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1408E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2163E-05  [K,I,J]   53   29   12
#  Transport Step:   14   Step Size:  0.3452     Total Elapsed Time:   156.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1545E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2777E-05  [K,I,J]   53   29   12
#  Transport Step:   15   Step Size:  0.3797     Total Elapsed Time:   157.18
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1696E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3555E-05  [K,I,J]   53   32   12
#  Transport Step:   16   Step Size:  0.4177     Total Elapsed Time:   157.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1861E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4524E-05  [K,I,J]   53   32   12
#  Transport Step:   17   Step Size:  0.4595     Total Elapsed Time:   158.05
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2041E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5718E-05  [K,I,J]   53   32   12
#  Transport Step:   18   Step Size:  0.5054     Total Elapsed Time:   158.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2238E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7180E-05  [K,I,J]   53   32   12
#  Transport Step:   19   Step Size:  0.5560     Total Elapsed Time:   159.12
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2453E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8962E-05  [K,I,J]   53   32   12
#  Transport Step:   20   Step Size:  0.6116     Total Elapsed Time:   159.73
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2688E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1112E-04  [K,I,J]   53   32   12
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1921E-06  [K,I,J]   54   30   11
# ...
#  Transport Step:   35   Step Size:   2.555     Total Elapsed Time:   21778.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2560E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2017E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2075E-05  [K,I,J]   58   31   70
#  Transport Step:   36   Step Size:   2.810     Total Elapsed Time:   21781.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2816E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2364E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2701E-05  [K,I,J]   58   31   70
#  Transport Step:   37   Step Size:  8.7319E-02 Total Elapsed Time:   21781.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8735E-05  [K,I,J]   53   31   29
#
#  STRESS PERIOD NO.  116
#
#   STRESS PERIOD  116 TIME STEP    1 FROM TIME =   21781.     TO    21901.
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   21781.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1000E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7465E-08  [K,I,J]   58   31   70
#  Transport Step:    2   Step Size:  0.1100     Total Elapsed Time:   21781.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1100E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9817E-08  [K,I,J]   58   31   70
#  Transport Step:    3   Step Size:  0.1210     Total Elapsed Time:   21781.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1210E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1290E-07  [K,I,J]   58   31   70
#  Transport Step:    4   Step Size:  0.1331     Total Elapsed Time:   21781.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1332E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1692E-07  [K,I,J]   58   31   70
#  Transport Step:    5   Step Size:  0.1464     Total Elapsed Time:   21782.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1465E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2217E-07  [K,I,J]   58   31   70
#  Transport Step:    6   Step Size:  0.1611     Total Elapsed Time:   21782.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1611E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2902E-07  [K,I,J]   58   31   70
#  Transport Step:    7   Step Size:  0.1772     Total Elapsed Time:   21782.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1772E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3792E-07  [K,I,J]   58   31   70
#  Transport Step:    8   Step Size:  0.1949     Total Elapsed Time:   21782.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1949E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4947E-07  [K,I,J]   58   31   70
#  Transport Step:    9   Step Size:  0.2144     Total Elapsed Time:   21782.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2144E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6444E-07  [K,I,J]   58   31   70
#  Transport Step:   10   Step Size:  0.2358     Total Elapsed Time:   21783.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2359E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8377E-07  [K,I,J]   58   31   70
#  Transport Step:   11   Step Size:  0.2594     Total Elapsed Time:   21783.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2595E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1087E-06  [K,I,J]   58   31   70
#  Transport Step:   12   Step Size:  0.2853     Total Elapsed Time:   21783.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2854E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1407E-06  [K,I,J]   58   31   70
#  Transport Step:   13   Step Size:  0.3138     Total Elapsed Time:   21783.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3140E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1818E-06  [K,I,J]   58   31   70
#  Transport Step:   14   Step Size:  0.3452     Total Elapsed Time:   21784.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3453E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2342E-06  [K,I,J]   58   31   70
#  Transport Step:   15   Step Size:  0.3797     Total Elapsed Time:   21784.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3799E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3010E-06  [K,I,J]   58   31   70
#  Transport Step:   16   Step Size:  0.4177     Total Elapsed Time:   21785.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4179E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3858E-06  [K,I,J]   58   31   70
#  Transport Step:   17   Step Size:  0.4595     Total Elapsed Time:   21785.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4596E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4929E-06  [K,I,J]   58   31   70
#  Transport Step:   18   Step Size:  0.5054     Total Elapsed Time:   21786.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5056E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6277E-06  [K,I,J]   58   31   70
#  Transport Step:   19   Step Size:  0.5560     Total Elapsed Time:   21786.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5562E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7967E-06  [K,I,J]   58   31   70
#  Transport Step:   20   Step Size:  0.6116     Total Elapsed Time:   21787.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6118E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1008E-05  [K,I,J]   58   31   70
#  Transport Step:   21   Step Size:  0.6727     Total Elapsed Time:   21787.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6730E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1270E-05  [K,I,J]   58   31   70
#  Transport Step:   22   Step Size:  0.7400     Total Elapsed Time:   21788.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7403E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1594E-05  [K,I,J]   58   31   70
#  Transport Step:   23   Step Size:  0.8140     Total Elapsed Time:   21789.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8143E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1992E-05  [K,I,J]   58   31   70
#  Transport Step:   24   Step Size:  0.8954     Total Elapsed Time:   21790.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8957E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2479E-05  [K,I,J]   58   31   70
#  Transport Step:   25   Step Size:  0.9850     Total Elapsed Time:   21791.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9853E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3072E-05  [K,I,J]   58   31   70
#  Transport Step:   26   Step Size:   1.083     Total Elapsed Time:   21792.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1084E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3790E-05  [K,I,J]   58   31   70
#  Transport Step:   27   Step Size:   1.192     Total Elapsed Time:   21793.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1192E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4654E-05  [K,I,J]   58   31   70
#  Transport Step:   28   Step Size:   1.311     Total Elapsed Time:   21794.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1312E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5688E-05  [K,I,J]   58   31   70
#  Transport Step:   29   Step Size:   1.442     Total Elapsed Time:   21796.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1443E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6919E-05  [K,I,J]   58   31   70
#  Transport Step:   30   Step Size:   1.586     Total Elapsed Time:   21797.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1587E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8374E-05  [K,I,J]   58   31   70
#  Transport Step:   31   Step Size:   1.745     Total Elapsed Time:   21799.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1746E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1009E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6670E-06  [K,I,J]   58   31   70
#  Transport Step:   32   Step Size:   1.919     Total Elapsed Time:   21801.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1921E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1206E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8952E-06  [K,I,J]   58   31   70
#  Transport Step:   33   Step Size:   2.111     Total Elapsed Time:   21803.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2113E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1435E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1192E-05  [K,I,J]   58   31   70
#  Transport Step:   34   Step Size:   2.323     Total Elapsed Time:   21806.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2324E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1700E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1576E-05  [K,I,J]   58   31   70
#  Transport Step:   35   Step Size:   2.555     Total Elapsed Time:   21808.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2557E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2003E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2066E-05  [K,I,J]   58   31   70
#  Transport Step:   36   Step Size:   2.810     Total Elapsed Time:   21811.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2813E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2348E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2689E-05  [K,I,J]   58   31   70
#  Transport Step:   37   Step Size:   3.091     Total Elapsed Time:   21814.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3094E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2770E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3474E-05  [K,I,J]   58   31   70
#  Transport Step:   38   Step Size:   3.400     Total Elapsed Time:   21817.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3404E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3251E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4460E-05  [K,I,J]   58   31   70
#  Transport Step:   39   Step Size:   3.740     Total Elapsed Time:   21821.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3745E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3793E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5692E-05  [K,I,J]   58   31   70
#  Transport Step:   40   Step Size:   4.114     Total Elapsed Time:   21825.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4120E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4398E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7230E-05  [K,I,J]   58   31   70
#  Transport Step:   41   Step Size:   4.526     Total Elapsed Time:   21830.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4533E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5069E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9146E-05  [K,I,J]   58   31   70
#  Transport Step:   42   Step Size:   4.979     Total Elapsed Time:   21835.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4987E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5849E-04  [K,I,J]   58   31   72
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1153E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2470E-05  [K,I,J]   58   31   70
#  Transport Step:   43   Step Size:   5.476     Total Elapsed Time:   21840.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5486E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6730E-04  [K,I,J]   58   31   72
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1446E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3331E-05  [K,I,J]   58   31   70
#  Transport Step:   44   Step Size:   6.024     Total Elapsed Time:   21846.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6036E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7682E-04  [K,I,J]   58   31   72
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1811E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4423E-05  [K,I,J]   58   31   70
#  Transport Step:   45   Step Size:   6.626     Total Elapsed Time:   21853.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6641E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8698E-04  [K,I,J]   58   31   72
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2262E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5781E-05  [K,I,J]   58   31   70
#  Transport Step:   46   Step Size:   7.289     Total Elapsed Time:   21860.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7307E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9767E-04  [K,I,J]   58   31   72
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2817E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7445E-05  [K,I,J]   58   31   70
#  Transport Step:   47   Step Size:   8.018     Total Elapsed Time:   21868.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8040E-03  [K,I,J]   53   31   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1087E-03  [K,I,J]   58   31   72
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3495E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9454E-05  [K,I,J]   58   31   70
#  Transport Step:   48   Step Size:   8.820     Total Elapsed Time:   21877.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8848E-03  [K,I,J]   53   31   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1208E-03  [K,I,J]   58   31   73
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4314E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1186E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2211E-05  [K,I,J]   58   31   70
#  Transport Step:   49   Step Size:   9.702     Total Elapsed Time:   21887.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9736E-03  [K,I,J]   53   31   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1338E-03  [K,I,J]   58   31   73
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5282E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1470E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3109E-05  [K,I,J]   58   31   70
#  Transport Step:   50   Step Size:   10.67     Total Elapsed Time:   21897.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1071E-02  [K,I,J]   53   31   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1468E-03  [K,I,J]   58   31   73
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6423E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1807E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4306E-05  [K,I,J]   58   31   70
#  Transport Step:   51   Step Size:   3.609     Total Elapsed Time:   21901.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3600E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3507E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5119E-05  [K,I,J]   58   31   70
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2024/02/21  0:34:25
#  Elapsed run time: 11 Minutes,  5.462 Seconds
#
#  Normal termination of SEAWAT

# %%
# %%

def plot_my_params():

    time_table = create_time_table()

    fig,ax = plt.subplots(figsize=(8,5))

    xs = time_table['Time']
    ax.scatter(xs,np.repeat(10,len(xs)),s=200,marker='|')
    ax.annotate('Stress Period:   {}'.format([n for n in time_table['perlen'].dropna().unique()]),(0,10.2))


    mask = time_table['wel_data'].isna()
    xs = time_table[~mask]['Time']
    ax.scatter(xs,np.repeat(9,len(xs)),s=200,marker='|',c=time_table[~mask]['wel_data'],cmap='coolwarm_r')
    ax.annotate('Well Input:   {}'.format([n for n in time_table['wel_data'].dropna().unique()]),(0,9.2))


    mask = time_table['ssm'].isna()
    xs = time_table[~mask]['Time']
    ax.scatter(xs,np.repeat(8,len(xs)),s=200,marker='|',c=time_table[~mask]['ssm'],cmap='coolwarm_r')
    ax.annotate('Input Concentration:   {}'.format([n for n in time_table['ssm'].dropna().unique()]),(0,8.2))


    ax.annotate('Aquifer:',(11000,9.2),weight="bold")
    ax.annotate(('hk={0:.3g} '.format(my_params['hk']) + 'vk={0:.3g}'.format(my_params['vk'])),(11000,9))
    ax.annotate('ss= {} sy={}'.format(my_params['ss'],my_params['sy']),(11000,8.8))
    ax.annotate('porosity={}'.format(my_params['porosity']),(11000,8.6))

    ax.annotate('Dispersion:',(16400,9.2),weight="bold")
    ax.annotate('la={}, trpt={}, trpv={}'.format(my_params['la'],my_params['trpt'],my_params['trpv']),(16400,9))


    ax.annotate('Advection:',(16400,8.7),weight="bold")
    d = {0:'FDM',3:'HMOC'}
    ax.annotate('Solution: {}'.format(d[my_params['mixelm']]),(16400,8.5))


    ax.annotate('Sorption:',(11000,8.3),weight="bold")
    d = {0:'No Sorption',1:'Linear',3:'Langmuir'}
    ax.annotate('{},'.format(d[my_params['isothm']]),(11000,8.1))
    if my_params['isothm']==1:
        ax.annotate('sp1={}'.format(my_params['sp1']),(11000,7.9))
        
    elif my_params['isothm']==3:
        ax.annotate('sp1={}'.format(my_params['sp1']),(11000,7.9))
        ax.annotate('sp2={}'.format(my_params['sp2']),(11000,7.7))
        


    ax.annotate('Recharge:',(16400,8.3),weight="bold")
    #d = {0:'No Sorption',1:'Linear'}
    ax.annotate('{0:.3g}'.format(my_params['rech']),(16000,8.1))


    ax.annotate('{}'.format(os.path.basename(os.path.normpath(workspace))),(200,7.3),weight="bold")

    ax.axes.get_yaxis().set_visible(False)
    plt.ylim(7,10.5)
    plt.xlim(-1000,65*365)
    plt.tight_layout()
    plt.savefig(Path(workspace) /'_output/_my_params.png')


## Run
plot_my_params()


# %% [markdown]
# ## JSON
# %%
import json

with open(Path(workspace) /'_output/my_params.json', 'w') as fp:
    json.dump(my_params,fp)



# %%
create_time_table().to_csv(Path(workspace) /'_output/time_table.csv')   
shutil.copytree('_imports',Path(workspace)/'_output/_imports',dirs_exist_ok =True)
#shutil.copyfile(__file__,Path(workspace) /'_output/{}'.format(os.path.basename(__file__)))

# %%
# Out:
# WindowsPath('H:/mf/_T0221002315__Foolish_Map/_output/_imports')

# %%
### read data
col = int(24)
ibound = swt.bas6.ibound.array
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace)/ 'MT3D001.UCN')

times = ucnobj.get_times()

    # Read the concentration data from the UCN file
    
concentration_array = ucnobj.get_data(totim=times[-1])# (time step, stress period)

# Mask the inactive cells
mask = ((ibound== 0)|(concentration_array>=1e30))
masked_conc_data = np.ma.masked_where(mask, concentration_array)

### plotting# ##
fig = plt.figure(figsize=(15, 4))
line = {"Column": col}

# Create a PlotCrossSection object for the model
xsect = flopy.plot.PlotCrossSection(model=swt, line=line)

# Plot the concentration results
cs = xsect.plot_array(masked_conc_data, cmap='coolwarm', vmin=0.1, vmax=300)
plt.colorbar(cs)
ibd = xsect.plot_ibound(color_noflow='grey')
plt.title('col:{:03}, kper:{:02}'.format(col,kper))
plt.gcf().set_size_inches(10,5)
plt.ylim(mybot.min(),177)

#plt.savefig(Path(workspace)/'_output/conc_{:02}.png'.format(kper))
#plt.clf()

##--------
# Out:
# (172.2, 177.0)

# %%
### read data
col = int(44)
ibound = swt.bas6.ibound.array
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace)/ 'MT3D001.UCN')

times = ucnobj.get_times()

    # Read the concentration data from the UCN file
    
concentration_array = ucnobj.get_data(totim=times[-1])# (time step, stress period)

# Mask the inactive cells
mask = ((ibound== 0)|(concentration_array>=1e30))
masked_conc_data = np.ma.masked_where(mask, concentration_array)

### plotting# ##
fig = plt.figure(figsize=(15, 4))
line = {"Column": col}

# Create a PlotCrossSection object for the model
xsect = flopy.plot.PlotCrossSection(model=swt, line=line)

# Plot the concentration results
cs = xsect.plot_array(masked_conc_data, cmap='coolwarm', vmin=0.1, vmax=300)
plt.colorbar(cs)
ibd = xsect.plot_ibound(color_noflow='grey')
plt.title('col:{:03}, kper:{:02}'.format(col,kper))
plt.gcf().set_size_inches(10,5)
plt.ylim(mybot.min(),177)

#plt.savefig(Path(workspace)/'_output/conc_{:02}.png'.format(kper))
#plt.clf()

##--------
# Out:
# (172.2, 177.0)

# %%
### read data
col = int(64)
ibound = swt.bas6.ibound.array
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace)/ 'MT3D001.UCN')

times = ucnobj.get_times()

    # Read the concentration data from the UCN file
    
concentration_array = ucnobj.get_data(totim=times[-1])# (time step, stress period)

# Mask the inactive cells
mask = ((ibound== 0)|(concentration_array>=1e30))
masked_conc_data = np.ma.masked_where(mask, concentration_array)

### plotting# ##
fig = plt.figure(figsize=(15, 4))
line = {"Column": col}

# Create a PlotCrossSection object for the model
xsect = flopy.plot.PlotCrossSection(model=swt, line=line)

# Plot the concentration results
cs = xsect.plot_array(masked_conc_data, cmap='coolwarm', vmin=0.1, vmax=300)
plt.colorbar(cs)
ibd = xsect.plot_ibound(color_noflow='grey')
plt.title('col:{:03}, kper:{:02}'.format(col,kper))
plt.gcf().set_size_inches(10,5)
plt.ylim(mybot.min(),177)

#plt.savefig(Path(workspace)/'_output/conc_{:02}.png'.format(kper))
#plt.clf()
##--------
# Out:
# (172.2, 177.0)

# %%
concentration_array[np.isclose(concentration_array,1e30)]  =0

concentration_array[:,:,50].shape
# Out:
# (74, 60)

# %%
# Out:
# (74, 110)

# %%
import os  # Make sure to import os module

row = int(30)
ibound = swt.bas6.ibound.array
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace)/ 'MT3D001.UCN')

for time in [times[4],times[83],times[115]]:
    concentration_array = ucnobj.get_data(totim=time)  # Read concentration data

    # Mask inactive cells
    mask = ((ibound == 0)|(concentration_array >= 1e30))
    masked_conc_data = np.ma.masked_where(mask, concentration_array)

    # Plotting
    fig = plt.figure(figsize=(15, 4))
    line = {"Row": row}

    # Create PlotCrossSection object
    xsect = flopy.plot.PlotCrossSection(model=swt, line=line)

    # Plot concentration results
    cs = xsect.plot_array(masked_conc_data, cmap='coolwarm', vmin=0.1, vmax=300)
    plt.colorbar(cs)
    ibd = xsect.plot_ibound(color_noflow='grey')
    plt.title('col:{:03}, year:{:.1f}'.format(col, int(time/365)))
    plt.axvline(50, c='k')
    plt.axvline(70, c='k')
    plt.axvline(90, c='k')

    # Check if output folder exists, create if not
    output_folder = Path(workspace) / '_output/xsect_'
    os.makedirs(output_folder, exist_ok=True)  # This will create the directory if it does not exist

    # Save the figure
    plt.savefig(output_folder / f'conc_{times.index(time):02}.png')
    plt.clf()

# %%
open_file(workspace)

# %%
find_closest_value = lambda target_value: min(delr.cumsum(), key=lambda x: abs(target_value- x))
find_closest_value(140)
# Out:
# 140

# %%
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace) / 'MT3D001.UCN')
times = ucnobj.get_times()
conc = ucnobj.get_data(totim=times[-1])  # get the concentration data for the last time step
conc[np.where(conc==1e30)] = 0
conc_sum = np.sum(conc, axis=0)
mapview = flopy.plot.PlotMapView(model=swt)
fig = mapview.plot_array(conc_sum,cmap='coolwarm')
plt.axvline(50,c='k')
plt.axvline(70,c='k')
plt.axvline(90,c='k')
plt.gcf().set_size_inches(15,8)
plt.colorbar(fig,orientation='horizontal')
plt.title('SRP (sum of all layers)')
plt.show()

# %%
def execute_wasaga_draw(ws):
    # Define the path to the script and its folder
    script_path = Path(ws) / "wasaga_draw.py"
    #script_path = os.path.join("workspace", "wasaga_draw.py")
    script_folder = os.path.dirname(script_path)

    # Save the current working directory
    original_dir = os.getcwd()

    try:
        # Change the working directory to the script's folder
        os.chdir(script_folder)

        # Define the command to execute the script
        command = ["python", script_path]

        # Execute the command and capture the output
        output = subprocess.check_output(command, universal_newlines=True)
        print("Script executed successfully.")
        print("Output:")
        print(output)
    except subprocess.CalledProcessError as e:
        print("Error executing the script:")
        print(e)
    finally:
        # Change the working directory back to the original
        os.chdir(original_dir)

# %%
shutil.copy('wasaga_draw.py',Path(workspace) / 'wasaga_draw.py')
execute_wasaga_draw(ws = workspace)
# Out:
# Error executing the script:
# Command '['python', WindowsPath('H:/mf/_T0221002315__Foolish_Map/wasaga_draw.py')]' returned non-zero exit status 1.

# %%
# %%


if (__name__ == '__main__'):
    ################### Model Parameters  #########################




def execute_wasaga_draw(ws):
    # Define the path to the script and its folder
    script_path = Path(ws) / "wasaga_draw.py"
    #script_path = os.path.join("workspace", "wasaga_draw.py")
    script_folder = os.path.dirname(script_path)

    # Save the current working directory
    original_dir = os.getcwd()

    try:
        # Change the working directory to the script's folder
        os.chdir(script_folder)

        # Define the command to execute the script
        command = ["python", script_path]

        # Execute the command and capture the output
        output = subprocess.check_output(command, universal_newlines=True)
        print("Script executed successfully.")
        print("Output:")
        print(output)
    except subprocess.CalledProcessError as e:
        print("Error executing the script:")
        print(e)
    finally:
        # Change the working directory back to the original
        os.chdir(original_dir)


# %%
if (__name__ == '__main__'):

    
    run_wasaga(my_params)
# Out:
#   Cell In[64], line 10
#     def execute_wasaga_draw(ws):
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4
