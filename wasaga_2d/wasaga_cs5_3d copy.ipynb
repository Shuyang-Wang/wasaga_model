# %%
# %%
# ## Getting Started
from pathlib import Path
from tempfile import TemporaryDirectory
from tempfile import mkdtemp

import numpy as np
import matplotlib.pyplot as plt
import flopy
import pandas as pd
import shutil
import pickle
import subprocess
import os
# %% [markdown]

# %%

# %%
################### Model Parameters   ##############################
my_params = {}
my_params['name'] = 'test_wasaga_2'
## mt3dGcg
cclose=my_params['cclose'] = 1e-5
## RCT

my_params['hk'] = 6.9
my_params['vk'] = 0.1

my_params['porosity'] = 0.35
my_params['sy'] = 0.33
my_params['ss'] = 0.0002
my_params['la'] = 0.2
my_params['trpt'] = 0.1
my_params['trpv'] = 0.1
my_params['dmcoef'] = 3.7E-10 ####
my_params['sconc'] = 0.01

#Species ID
sp_ID = {}
#sp_ID['Cl-'] = 1
sp_ID['SRP'] = 1
my_params['sp_ID'] = sp_ID

#Species Name
sp_name = {}
#sp_name[1] = 'Cl-'
sp_name[1] = 'SRP'
my_params['sp_name'] = sp_name


## P lens
my_params['perlen'] = [1]+[30,92,31,212]*25 +[365]*5+[365*5]*5+[365*4]+[185,30,30,120]


## Wel data
wel_data = {}
#last_wel_id = len(my_params['perlen'])-1
for y in range(25):
    p = (y)*4 +2
    wel_data[p] = [[50,0,15,0.0075]]
    p += 1
    wel_data[p] = [[50,0,15,0.075]]
    p += 1
    wel_data[p] = [[50,0,15,0.0075]]
    p += 1
    wel_data[p] = [[50,0,15,0.0]]
    p += 1

wel_data[p] = [[50,0,15,0]]
my_params['wel_data'] = wel_data


# Mt3dSsm 
ssm_data = {}
itype = flopy.mt3d.Mt3dSsm.itype_dict()

for y in range(25):
    p = (y)*4 +2
    ssm_data[p] = [(50, 0, 15, 3000.0, itype['WEL'])]
    p += 1
    ssm_data[p] = [(50, 0, 15, 3000.0, itype['WEL'])]
    p += 1
    ssm_data[p] = [(50, 0, 15, 3000.0, itype['WEL'])]
    p += 1
    ssm_data[p] = [(50, 0, 15, 3000.0, itype['WEL'])]
    p += 1
ssm_data[p] = [(50, 0, 15, 0.0, itype['WEL'])]
my_params['ssm_data'] = ssm_data


#Mt3dBtn
mixelm=my_params['mixelm'] = 3 # 0 = FDM 3 =HMOC
my_params['isothm'] = 3 # Langmuir
my_params['sp1'] = 0.0001 ##  0.1 mg/L  => 1e5 ug/m3
my_params['sp2'] = 0.0001  ##  maximum soil adsorption value = 100 ug/g => 1e5 ug/kg

# Rch
my_params['rech'] = 0.5/365 #0.5/365 ## 500mm/year

# dt0
my_params['dt0'] = 0.1
################################################################

base_model_my_params = my_params

# %%
my_params['sp1'] = 0.0002
my_params['la'] = 5
my_params['hk'] = 6.9
base_model_my_params = my_params.copy()

my_params['vk'] = 0.1
trpv=my_params['trpv'] = 0.01

# %%
my_params['la']
# Out:
# 5

# %%
# bed size 10x10
# row: 25-35 (1m), col 12-17 (2m)
#  50 cells

# %%
mytop =np.loadtxt('_imports/top')
mybot = np.loadtxt('_imports/bot')
myibound = np.loadtxt('_imports/ibound')
mystrt = np.loadtxt('_imports/strt')
myicbund = np.loadtxt('_imports/icbund')

# %%
mytop = np.tile(mytop.reshape([74,1,110]),(1,60,1))
mybot = np.tile(mybot.reshape([74,1,110]),(1,60,1))
myibound= np.tile(myibound.reshape([74,1,110]),(1,60,1))
mystrt = np.tile(mystrt.reshape([74,1,110]),(1,60,1))
myicbund = np.tile(myicbund.reshape([74,1,110]),(1,60,1))

# %%
# mytop = np.tile(mytop.reshape([74,1,110]),(1,1,1))
# mybot = np.tile(mybot.reshape([74,1,110]),(1,1,1))
# myibound= np.tile(myibound.reshape([74,1,110]),(1,1,1))
# mystrt = np.tile(mystrt.reshape([74,1,110]),(1,1,1))
# myicbund = np.tile(myicbund.reshape([74,1,110]),(1,1,1))

# %%
from random_name import generate_random_name
from datetime import datetime
import platform

# %%
# ## Import
Lx = 150
Lz = 1
nlay = 74
nrow = 60
ncol = 110
delr = np.concatenate([np.repeat(2,25),np.repeat(1,70),np.repeat(2,15)])
delc = 1.0
delv = mytop[:,0] - mybot[:,0]

# %%
# Control variable to decide the location of the temp folder
use_d_drive = True  # Set to True to use the custom location

# Define model workspace
myt = datetime.now().strftime('%m%d%H%M%S')
name = 'wasaga'
adj_non = '_' + generate_random_name()

if use_d_drive and platform.system() == 'Windows':  # Check if on Windows
    temp_dir = 'H:/mf/_T{}_{}'.format(myt, adj_non)  # Path for D drive
elif use_d_drive and platform.system() == 'Darwin':  # Check if on macOS
    temp_dir = '/Volumes/Public/mf/_T{}_{}'.format(myt, adj_non)
else:
    temp_dir = mkdtemp(prefix='_T{}_'.format(myt), suffix=adj_non)

os.makedirs(Path(temp_dir) / '_output', exist_ok=True)
workspace = temp_dir

# %%
# ## Workspace

swt = flopy.seawat.Seawat(name, exe_name="swtv4", model_ws=workspace)

# %%
##

import os
import platform
import subprocess

def open_file(path):
    if platform.system() == "Windows":
        os.startfile(path)
    elif platform.system() == "Darwin":
        subprocess.Popen(["open", path])
    else:
        subprocess.Popen(["xdg-open", path])

open_file(workspace)

# %%
# %%
def create_time_table():
    time_table = pd.DataFrame()

    perlen = pd.Series(my_params['perlen'])
    perlen.index = perlen.index+1

    time_table['perlen'] = perlen
    time_table['Time'] = time_table['perlen'].cumsum()

    #time_table = pd.DataFrame()
    for key,value in wel_data.items():
        key
        time_table.loc[key,'wel_data'] = value[0][3]

    #time_table = pd.DataFrame()
    for key,value in ssm_data.items():
        key
        time_table.loc[key,'ssm'] = value[0][3]
    return time_table

# %%
# ## DIS

# %%
ipakcb = 53

# %%

perlen = my_params['perlen']
nper = len(perlen)
nstp = np.repeat(1,nper)
steady = np.append(np.array([True]),np.repeat(False,nper-1))



# %%
dis = flopy.modflow.ModflowDis(
    swt,
    nlay,
    nrow,
    ncol,
    nper=nper,
    delr=delr,
    delc=delc,
    laycbd=0,
    top=182.2,
    botm=mybot,
    perlen=perlen,
    nstp=nstp, #Number of time steps in each stress period
    steady = steady
)

# %% [markdown]
# ## WEL

# %%
# #last_wel_id = len(my_params['perlen'])-1

# ## Wel data
# wel_data = {}
# # Mt3dSsm 
# ssm_data = {}
# for per in range(nper):
#     wel_data[per]= []
#     ssm_data[per] = []


# for row in range(25,35+1):
#     for col in range(12,17+1):
#         for y in range(25):

#             p = (y)*4 +2
#             wel_data[p].append([50,row,col,0.5/50])
#             p += 1
#             wel_data[p].append([50,row,col,0.5/50])
#             p += 1
#             wel_data[p].append([50,row,col,0.5/50])
#             p += 1
#             wel_data[p].append([50,row,col,0.5/50])
#             p += 1


#             wel_data[p].append([50,row,col,0.5/50])




# itype = flopy.mt3d.Mt3dSsm.itype_dict()



# for row in range(25,35+1):
#     for col in range(12,17+1):
#         for y in range(25):
#             p = (y)*4 +2
#             ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))
#             p += 1
#             ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))
#             p += 1
#             ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))
#             p += 1
#             ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))
#             p += 1
#         ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))


# my_params['ssm_data'] = ssm_data

# %% [markdown]
# ## RCH

# %%
rch_dict = {}

rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_dict[0] = rch_array

rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
#rch_array[int(nrow/2),int(ncol/2)] = 0.51/delr/delc
#rch_array[int(nrow/2),int(ncol/3)] = 0.51/delr/delc

for row in range(25,35+1):
    for col in range(12,17+1):
        rch_array[row,col] = 0.51/10/10
        rch_array[row,col] = 0.51/10/10

rch_dict[1] = rch_array 


rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_dict[int(25*4+1)] = rch_array

# %%
crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)
crch_dict = {}
crch_dict[0] = crch_array

crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)

# crch_array[int(nrow/2),int(ncol/2)] =5000
# crch_array[int(nrow/2),int(ncol/3)] =5000

for row in range(25,35+1):
    for col in range(12,17+1):
        crch_array[row, col] =5000
        crch_array[row, col]= 5000


crch_dict[1] = crch_array


crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)
crch_dict[int(25*4+1)] = crch_array

# %%
bas = flopy.modflow.ModflowBas(swt, myibound, mystrt)


lpf = flopy.modflow.ModflowLpf(swt, hk=my_params['hk'], vka=my_params['vk'],
                            ss= my_params['ss'],sy=my_params['sy'],
                            ipakcb=ipakcb,laytyp=1)

pcg = flopy.modflow.ModflowPcg(swt, hclose=1e-4)

# %%
stress_period_data = {}
for kper in range(nper):
    for kstp in range(nstp[kper]):
        stress_period_data[(kper, kstp)] = [
            "save head",
            "save drawdown",
            "save budget",
            "print head",
            "print budget",
        ]

# OC - Output Control Option
oc = flopy.modflow.ModflowOc(
    swt,
    stress_period_data= stress_period_data,
    compact=True,
)

# ## Well

# wel_data = my_params['wel_data']
# wel = flopy.modflow.ModflowWel(swt, stress_period_data=wel_data, ipakcb=ipakcb)

# # ModflowRch

# rch = flopy.modflow.ModflowRch(model = swt, rech = my_params['rech'])

rch = flopy.modflow.ModflowRch(model = swt, rech = rch_dict)

# # ## SSM
# ssm_data = my_params['ssm_data']



# ## BTN

#timprs = my_params['perlen'][:5]*5 +np.arange(365,np.sum(my_params['perlen']),5*355).tolist()
timprs = np.cumsum(my_params['perlen'])
timprs = [1]




btn = flopy.mt3d.Mt3dBtn(
    swt,
    nprs=len(timprs),
    timprs=timprs,
    prsity=my_params['porosity'],
    sconc=my_params['sconc'], # starting concentration
    ifmtcn=0,
    chkmas=False,
    nprobs=10,
    nprmas=10,
    dt0=my_params['dt0'],  # The user-specified initial transport step size
    ttsmult=1.1,
    mxstrn = 50000,
    icbund = myicbund
)
adv = flopy.mt3d.Mt3dAdv(swt, mixelm=my_params['mixelm'],percel=0.4,mxpart=400000,nadvfd=0)
dsp = flopy.mt3d.Mt3dDsp(swt, al=my_params['la'], trpt=my_params['trpt'], 
                        trpv=my_params['trpv'], 
                        dmcoef=my_params['dmcoef'])
gcg = flopy.mt3d.Mt3dGcg(swt, iter1=50, mxiter=1, isolve=2, cclose=my_params['cclose'])

ssm = flopy.mt3d.Mt3dSsm(swt, crch=crch_dict)

# %% [markdown]
# ## RCT


rct = flopy.mt3d.Mt3dRct(model=swt, isothm=my_params['isothm'],sp1=my_params['sp1'],sp2=my_params['sp2'],igetsc=0,rhob= 1.65E+09)





# %%
#Pht3d
#phc = flopy.mt3d.Mt3dPhc(swt,mine=[1],ie=[1],surf=[1],mobkin=[1],minkin=[1],surfkin=[1],imobkin=[1])
#phc.write_file()

# %% [markdown]
# # Write File

# %% [markdown]
# # RUN

# %%
# %%
swt.write_input()

# %%


# %% [markdown]
# ## ################   Run      ########################

# %%

success, buff = swt.run_model(silent=False, report=True)
assert success, "SEAWAT did not terminate normally."

# %%  dump
swt.my_params = my_params
swt.delv =  delv
swt.delr = delr
pickle.dump( swt, open( Path(workspace) / '_output' / 'model.pickle',"wb" ) )

# %%


# %% [markdown]
# # Summarize Parameters
# Out:
# Util2d rech_1: locat is None, but model does not support free format and how is internal... resetting how = external
# Util2d rech_2: locat is None, but model does not support free format and how is internal... resetting how = external
# Util2d rech_102: locat is None, but model does not support free format and how is internal... resetting how = external
# FloPy is using the following executable to run the model: C:\Users\Administrator\AppData\Local\flopy\bin\swtv4.exe
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: wasaga.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2024/02/20 22:33:52
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  1.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    2   Step Size:  0.1000     Total Elapsed Time:  0.11000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    3   Step Size:  0.1000     Total Elapsed Time:  0.21000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    4   Step Size:  0.1000     Total Elapsed Time:  0.31000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    5   Step Size:  0.1000     Total Elapsed Time:  0.41000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    6   Step Size:  0.1000     Total Elapsed Time:  0.51000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    7   Step Size:  0.1000     Total Elapsed Time:  0.61000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    8   Step Size:  0.1000     Total Elapsed Time:  0.71000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    9   Step Size:  0.1000     Total Elapsed Time:  0.81000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:   10   Step Size:  0.1000     Total Elapsed Time:  0.91000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:   11   Step Size:  9.0000E-02 Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    2
#
#   STRESS PERIOD    2 TIME STEP    1 FROM TIME =   1.0000     TO    31.000
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   1.1000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   76.36      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4709E-04  [K,I,J]   51   35   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8039E-10  [K,I,J]   51   35   15
#  Transport Step:    2   Step Size:  0.1000     Total Elapsed Time:   1.2000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9861      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6161E-06  [K,I,J]   51   35   15
#  Transport Step:    3   Step Size:  0.1000     Total Elapsed Time:   1.3000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4960      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3139E-06  [K,I,J]   51   35   15
#  Transport Step:    4   Step Size:  0.1000     Total Elapsed Time:   1.4000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3313      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2123E-06  [K,I,J]   51   35   15
#  Transport Step:    5   Step Size:  0.1000     Total Elapsed Time:   1.5000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2486      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1613E-06  [K,I,J]   51   35   15
#  Transport Step:    6   Step Size:  0.1000     Total Elapsed Time:   1.6000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1989      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1306E-06  [K,I,J]   51   35   15
#  Transport Step:    7   Step Size:  0.1000     Total Elapsed Time:   1.7000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1658      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1102E-06  [K,I,J]   51   35   15
#  Transport Step:    8   Step Size:  0.1000     Total Elapsed Time:   1.8000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1421      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9554E-07  [K,I,J]   51   35   15
#  Transport Step:    9   Step Size:  0.1000     Total Elapsed Time:   1.9000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1243      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8455E-07  [K,I,J]   51   35   15
#  Transport Step:   10   Step Size:  0.1000     Total Elapsed Time:   2.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1104      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7600E-07  [K,I,J]   51   35   15
#  Transport Step:   11   Step Size:  0.1000     Total Elapsed Time:   2.1000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9935E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6916E-07  [K,I,J]   51   35   15
#  Transport Step:   12   Step Size:  0.1000     Total Elapsed Time:   2.2000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9029E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6355E-07  [K,I,J]   51   35   15
#  Transport Step:   13   Step Size:  0.1000     Total Elapsed Time:   2.3000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8273E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5888E-07  [K,I,J]   51   35   15
#  Transport Step:   14   Step Size:  0.1000     Total Elapsed Time:   2.4000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7634E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5492E-07  [K,I,J]   51   35   15
#  Transport Step:   15   Step Size:  0.1000     Total Elapsed Time:   2.5000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7086E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2113E-06  [K,I,J]   52   30   15
#  Transport Step:   16   Step Size:  0.1000     Total Elapsed Time:   2.6000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6611E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4491E-06  [K,I,J]   52   28   15
#  Transport Step:   17   Step Size:  0.1000     Total Elapsed Time:   2.7000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6195E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4372E-06  [K,I,J]   52   32   15
#  Transport Step:   18   Step Size:  0.1000     Total Elapsed Time:   2.8000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5828E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6011E-06  [K,I,J]   52   32   15
#  Transport Step:   19   Step Size:  0.1000     Total Elapsed Time:   2.9000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5502E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7092E-06  [K,I,J]   52   32   15
#  Transport Step:   20   Step Size:  0.1000     Total Elapsed Time:   3.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5210E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7797E-06  [K,I,J]   52   31   15
#  Transport Step:   21   Step Size:  0.1000     Total Elapsed Time:   3.1000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4948E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8233E-06  [K,I,J]   52   31   15
#  Transport Step:   22   Step Size:  0.1000     Total Elapsed Time:   3.2000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4710E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8482E-06  [K,I,J]   52   31   15
#  Transport Step:   23   Step Size:  0.1000     Total Elapsed Time:   3.3000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4494E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8602E-06  [K,I,J]   52   31   15
#  Transport Step:   24   Step Size:  0.1000     Total Elapsed Time:   3.4000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4297E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8635E-06  [K,I,J]   52   31   15
#  Transport Step:   25   Step Size:  0.1000     Total Elapsed Time:   3.5000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4116E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8608E-06  [K,I,J]   52   31   15
#  Transport Step:   26   Step Size:  0.1000     Total Elapsed Time:   3.6000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3949E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8541E-06  [K,I,J]   52   31   15
#  Transport Step:   27   Step Size:  0.1000     Total Elapsed Time:   3.7000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3796E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8449E-06  [K,I,J]   52   31   15
#  Transport Step:   28   Step Size:  0.1000     Total Elapsed Time:   3.8000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3654E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8342E-06  [K,I,J]   52   31   15
#  Transport Step:   29   Step Size:  0.1000     Total Elapsed Time:   3.9000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3521E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8225E-06  [K,I,J]   52   31   15
#  Transport Step:   30   Step Size:  0.1000     Total Elapsed Time:   4.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3399E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7884E-06  [K,I,J]   52   34   15
#  Transport Step:   31   Step Size:  0.1000     Total Elapsed Time:   4.1000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3284E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2713E-04  [K,I,J]   53   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7354E-08  [K,I,J]   52   31   15
#  Transport Step:   32   Step Size:  0.1000     Total Elapsed Time:   4.2000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3176E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2319E-04  [K,I,J]   53   34   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1276E-07  [K,I,J]   53   28   15
#  Transport Step:   33   Step Size:  0.1000     Total Elapsed Time:   4.3000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3076E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1990E-04  [K,I,J]   53   35   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1842E-07  [K,I,J]   53   27   15
#  Transport Step:   34   Step Size:  0.1000     Total Elapsed Time:   4.4000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2981E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1572E-04  [K,I,J]   53   27   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1478E-07  [K,I,J]   53   27   15
#  Transport Step:   35   Step Size:  0.1000     Total Elapsed Time:   4.5000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2892E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1254E-04  [K,I,J]   53   27   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1191E-07  [K,I,J]   53   27   15
#  Transport Step:   36   Step Size:  0.1000     Total Elapsed Time:   4.6000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2808E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1005E-04  [K,I,J]   53   27   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9630E-08  [K,I,J]   53   27   15
#  Transport Step:   37   Step Size:  0.1000     Total Elapsed Time:   4.7000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2729E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1414E-04  [K,I,J]   53   26   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1560E-07  [K,I,J]   53   26   15
#  Transport Step:   38   Step Size:  0.1000     Total Elapsed Time:   4.8000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2654E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1106E-04  [K,I,J]   53   26   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1261E-07  [K,I,J]   53   26   15
#  Transport Step:   39   Step Size:  0.1000     Total Elapsed Time:   4.9000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2583E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8676E-05  [K,I,J]   53   26   15
#  Transport Step:   40   Step Size:  0.1000     Total Elapsed Time:   5.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2516E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6807E-05  [K,I,J]   53   26   15
#  Transport Step:   41   Step Size:  0.1000     Total Elapsed Time:   5.1000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2452E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6251E-05  [K,I,J]   53   30   15
#  Transport Step:   42   Step Size:  0.1000     Total Elapsed Time:   5.2000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2391E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4596E-05  [K,I,J]   53   30   15
#  Transport Step:   43   Step Size:  0.1000     Total Elapsed Time:   5.3000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2333E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6110E-05  [K,I,J]   53   34   15
#  Transport Step:   44   Step Size:  0.1000     Total Elapsed Time:   5.4000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2277E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4576E-05  [K,I,J]   53   28   15
#  Transport Step:   45   Step Size:  0.1000     Total Elapsed Time:   5.5000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2225E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3533E-05  [K,I,J]   53   28   15
#  Transport Step:   46   Step Size:  0.1000     Total Elapsed Time:   5.6000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2174E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4549E-05  [K,I,J]   53   35   15
#  Transport Step:   47   Step Size:  0.1000     Total Elapsed Time:   5.7000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2126E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4575E-05  [K,I,J]   52   31   12
#  Transport Step:   48   Step Size:  0.1000     Total Elapsed Time:   5.8000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2080E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4351E-05  [K,I,J]   52   34   12
#  Transport Step:   49   Step Size:  0.1000     Total Elapsed Time:   5.9000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2036E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3778E-05  [K,I,J]   52   28   12
#  Transport Step:   50   Step Size:  0.1000     Total Elapsed Time:   6.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1992E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5309E-05  [K,I,J]   51   37   12
#  Transport Step:   51   Step Size:  0.1000     Total Elapsed Time:   6.1000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1951E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4542E-05  [K,I,J]   51   37   12
#  Transport Step:   52   Step Size:  0.1000     Total Elapsed Time:   6.2000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1912E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4711E-05  [K,I,J]   53   36   15
#  Transport Step:   53   Step Size:  0.1000     Total Elapsed Time:   6.3000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1875E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3987E-05  [K,I,J]   53   26   15
#  Transport Step:   54   Step Size:  0.1000     Total Elapsed Time:   6.4000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1838E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7641E-05  [K,I,J]   54   31   15
#  Transport Step:   55   Step Size:  0.1000     Total Elapsed Time:   6.5000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1803E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7786E-05  [K,I,J]   54   30   15
#  Transport Step:   56   Step Size:  0.1000     Total Elapsed Time:   6.6000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1770E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6794E-05  [K,I,J]   54   34   15
#  Transport Step:   57   Step Size:  0.1000     Total Elapsed Time:   6.7000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1738E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5416E-05  [K,I,J]   54   28   15
#  Transport Step:   58   Step Size:  0.1000     Total Elapsed Time:   6.8000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1706E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4337E-05  [K,I,J]   54   28   15
#  Transport Step:   59   Step Size:  0.1000     Total Elapsed Time:   6.9000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1676E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5796E-05  [K,I,J]   54   27   15
#  Transport Step:   60   Step Size:  0.1000     Total Elapsed Time:   7.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1647E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4613E-05  [K,I,J]   54   27   15
#  Transport Step:   61   Step Size:  0.1000     Total Elapsed Time:   7.1000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1619E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3679E-05  [K,I,J]   54   27   15
#  Transport Step:   62   Step Size:  0.1000     Total Elapsed Time:   7.2000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1591E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2839E-05  [K,I,J]   54   27   15
#  Transport Step:   63   Step Size:  0.1000     Total Elapsed Time:   7.3000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1565E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2517E-05  [K,I,J]   53   26   15
#  Transport Step:   64   Step Size:  0.1000     Total Elapsed Time:   7.4000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1540E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2406E-05  [K,I,J]   53   26   15
#  Transport Step:   65   Step Size:  0.1000     Total Elapsed Time:   7.5000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1515E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5121E-05  [K,I,J]   53   31   15
#  Transport Step:   66   Step Size:  0.1000     Total Elapsed Time:   7.6000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1491E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5127E-05  [K,I,J]   53   29   15
#  Transport Step:   67   Step Size:  0.1000     Total Elapsed Time:   7.7000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1468E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4535E-05  [K,I,J]   53   29   15
#  Transport Step:   68   Step Size:  0.1000     Total Elapsed Time:   7.8000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1445E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4157E-05  [K,I,J]   53   29   15
#  Transport Step:   69   Step Size:  0.1000     Total Elapsed Time:   7.9000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1423E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4526E-05  [K,I,J]   53   28   15
#  Transport Step:   70   Step Size:  0.1000     Total Elapsed Time:   8.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1402E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4095E-05  [K,I,J]   53   28   15
#  Transport Step:   71   Step Size:  0.1000     Total Elapsed Time:   8.1000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1381E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3721E-05  [K,I,J]   53   28   15
#  Transport Step:   72   Step Size:  0.1000     Total Elapsed Time:   8.2000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1361E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3716E-05  [K,I,J]   53   31   15
#  Transport Step:   73   Step Size:  0.1000     Total Elapsed Time:   8.3000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1342E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4451E-05  [K,I,J]   53   35   15
#  Transport Step:   74   Step Size:  0.1000     Total Elapsed Time:   8.4000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1323E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4024E-05  [K,I,J]   53   35   15
#  Transport Step:   75   Step Size:  0.1000     Total Elapsed Time:   8.5000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1304E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3874E-05  [K,I,J]   53   31   15
#  Transport Step:   76   Step Size:  0.1000     Total Elapsed Time:   8.6000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1286E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3939E-05  [K,I,J]   53   31   15
#  Transport Step:   77   Step Size:  0.1000     Total Elapsed Time:   8.7000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1269E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5453E-05  [K,I,J]   54   30   15
#  Transport Step:   78   Step Size:  0.1000     Total Elapsed Time:   8.8000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1252E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5559E-05  [K,I,J]   54   31   15
#  Transport Step:   79   Step Size:  0.1000     Total Elapsed Time:   8.9000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1235E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4596E-05  [K,I,J]   54   27   15
#  Transport Step:   80   Step Size:  0.1000     Total Elapsed Time:   9.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1219E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4487E-05  [K,I,J]   53   31   15
#  Transport Step:   81   Step Size:  0.1000     Total Elapsed Time:   9.1000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1203E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5233E-05  [K,I,J]   53   31   15
#  Transport Step:   82   Step Size:  0.1000     Total Elapsed Time:   9.2000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1188E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5061E-05  [K,I,J]   53   31   15
#  Transport Step:   83   Step Size:  0.1000     Total Elapsed Time:   9.3000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1173E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4948E-05  [K,I,J]   53   31   15
#  Transport Step:   84   Step Size:  0.1000     Total Elapsed Time:   9.4000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1158E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4883E-05  [K,I,J]   53   31   15
#  Transport Step:   85   Step Size:  0.1000     Total Elapsed Time:   9.5000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1144E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4851E-05  [K,I,J]   53   31   15
#  Transport Step:   86   Step Size:  0.1000     Total Elapsed Time:   9.6000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1130E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4841E-05  [K,I,J]   53   31   15
#  Transport Step:   87   Step Size:  0.1000     Total Elapsed Time:   9.7000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1116E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4847E-05  [K,I,J]   53   31   15
#  Transport Step:   88   Step Size:  0.1000     Total Elapsed Time:   9.8000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1103E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4861E-05  [K,I,J]   53   31   15
#  Transport Step:   89   Step Size:  0.1000     Total Elapsed Time:   9.9000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1090E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4884E-05  [K,I,J]   53   31   15
#  Transport Step:   90   Step Size:  0.1000     Total Elapsed Time:   10.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1077E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4843E-05  [K,I,J]   53   30   15
#  Transport Step:   91   Step Size:  0.1000     Total Elapsed Time:   10.100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1065E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4725E-05  [K,I,J]   53   33   15
#  Transport Step:   92   Step Size:  0.1000     Total Elapsed Time:   10.200
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1052E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4765E-05  [K,I,J]   53   33   15
#  Transport Step:   93   Step Size:  0.1000     Total Elapsed Time:   10.300
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1040E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4614E-05  [K,I,J]   53   34   15
#  Transport Step:   94   Step Size:  0.1000     Total Elapsed Time:   10.400
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1029E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4548E-05  [K,I,J]   53   34   15
#  Transport Step:   95   Step Size:  0.1000     Total Elapsed Time:   10.500
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1017E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4386E-05  [K,I,J]   53   34   15
#  Transport Step:   96   Step Size:  0.1000     Total Elapsed Time:   10.600
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1006E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3498E-05  [K,I,J]   53   27   15
#  Transport Step:   97   Step Size:  0.1000     Total Elapsed Time:   10.700
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9952E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3530E-05  [K,I,J]   53   35   15
#  Transport Step:   98   Step Size:  0.1000     Total Elapsed Time:   10.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9845E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9348E-06  [K,I,J]   52   27   12
#  Transport Step:   99   Step Size:  0.1000     Total Elapsed Time:   10.900
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9729E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7821E-06  [K,I,J]   54   34   15
#  Transport Step:  100   Step Size:  0.1000     Total Elapsed Time:   11.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9627E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6667E-06  [K,I,J]   54   27   15
#  Transport Step:  101   Step Size:  0.1000     Total Elapsed Time:   11.100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9526E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9170E-06  [K,I,J]   52   35   12
#  Transport Step:  102   Step Size:  0.1000     Total Elapsed Time:   11.200
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9425E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6170E-06  [K,I,J]   52   35   12
#  Transport Step:  103   Step Size:  0.1000     Total Elapsed Time:   11.300
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9329E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6618E-06  [K,I,J]   51   37   12
#  Transport Step:  104   Step Size:  0.1000     Total Elapsed Time:   11.400
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9234E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7373E-06  [K,I,J]   51   37   12
#  Transport Step:  105   Step Size:  0.1000     Total Elapsed Time:   11.500
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9141E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7919E-06  [K,I,J]   51   37   12
#  Transport Step:  106   Step Size:  0.1000     Total Elapsed Time:   11.600
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9050E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8317E-06  [K,I,J]   51   37   12
#  Transport Step:  107   Step Size:  0.1000     Total Elapsed Time:   11.700
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8961E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8566E-06  [K,I,J]   51   37   12
#  Transport Step:  108   Step Size:  0.1000     Total Elapsed Time:   11.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8873E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8712E-06  [K,I,J]   51   37   12
#  Transport Step:  109   Step Size:  0.1000     Total Elapsed Time:   11.900
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8787E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2259E-05  [K,I,J]   51   37   11
#  Transport Step:  110   Step Size:  0.1000     Total Elapsed Time:   12.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8703E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2147E-05  [K,I,J]   51   37   11
#  Transport Step:  111   Step Size:  0.1000     Total Elapsed Time:   12.100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8620E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1910E-05  [K,I,J]   51   37   11
#  Transport Step:  112   Step Size:  0.1000     Total Elapsed Time:   12.200
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8538E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1731E-05  [K,I,J]   51   37   11
#  Transport Step:  113   Step Size:  0.1000     Total Elapsed Time:   12.300
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8458E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1571E-05  [K,I,J]   51   37   11
#  Transport Step:  114   Step Size:  0.1000     Total Elapsed Time:   12.400
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8380E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1484E-05  [K,I,J]   53   36   12
#  Transport Step:  115   Step Size:  0.1000     Total Elapsed Time:   12.500
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8303E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1487E-05  [K,I,J]   52   34   11
#  Transport Step:  116   Step Size:  0.1000     Total Elapsed Time:   12.600
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8227E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2602E-05  [K,I,J]   52   31   12
#  Transport Step:  117   Step Size:  0.1000     Total Elapsed Time:   12.700
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8152E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2508E-05  [K,I,J]   52   32   12
#  Transport Step:  118   Step Size:  0.1000     Total Elapsed Time:   12.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8079E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1863E-05  [K,I,J]   52   30   12
#  Transport Step:  119   Step Size:  0.1000     Total Elapsed Time:   12.900
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8007E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2347E-05  [K,I,J]   52   29   12
#  Transport Step:  120   Step Size:  0.1000     Total Elapsed Time:   13.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7936E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1850E-05  [K,I,J]   52   29   12
#  Transport Step:  121   Step Size:  0.1000     Total Elapsed Time:   13.100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7867E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1452E-05  [K,I,J]   52   29   12
#  Transport Step:  122   Step Size:  0.1000     Total Elapsed Time:   13.200
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7798E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1132E-05  [K,I,J]   52   29   12
#  Transport Step:  123   Step Size:  0.1000     Total Elapsed Time:   13.300
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7731E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1275E-05  [K,I,J]   54   27   12
#  Transport Step:  124   Step Size:  0.1000     Total Elapsed Time:   13.400
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7665E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1763E-05  [K,I,J]   52   28   12
#  Transport Step:  125   Step Size:  0.1000     Total Elapsed Time:   13.500
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7599E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1375E-05  [K,I,J]   52   28   12
#  Transport Step:  126   Step Size:  0.1000     Total Elapsed Time:   13.600
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7535E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3396E-05  [K,I,J]   51   37   12
#  Transport Step:  127   Step Size:  0.1000     Total Elapsed Time:   13.700
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7472E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2915E-05  [K,I,J]   51   37   12
#  Transport Step:  128   Step Size:  0.1000     Total Elapsed Time:   13.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7410E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2520E-05  [K,I,J]   51   37   12
#  Transport Step:  129   Step Size:  0.1000     Total Elapsed Time:   13.900
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7349E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2202E-05  [K,I,J]   51   37   12
#  Transport Step:  130   Step Size:  0.1000     Total Elapsed Time:   14.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7289E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2733E-05  [K,I,J]   52   31   12
#  Transport Step:  131   Step Size:  0.1000     Total Elapsed Time:   14.100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7229E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2851E-05  [K,I,J]   52   29   12
#  Transport Step:  132   Step Size:  0.1000     Total Elapsed Time:   14.200
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7171E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2360E-05  [K,I,J]   52   29   12
#  Transport Step:  133   Step Size:  0.1000     Total Elapsed Time:   14.300
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7113E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1912E-05  [K,I,J]   52   28   12
#  Transport Step:  134   Step Size:  0.1000     Total Elapsed Time:   14.400
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7057E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2060E-05  [K,I,J]   52   27   12
#  Transport Step:  135   Step Size:  0.1000     Total Elapsed Time:   14.500
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7001E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1650E-05  [K,I,J]   52   35   12
#  Transport Step:  136   Step Size:  0.1000     Total Elapsed Time:   14.600
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6946E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1787E-05  [K,I,J]   52   28   12
#  Transport Step:  137   Step Size:  0.1000     Total Elapsed Time:   14.700
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6892E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1398E-05  [K,I,J]   52   34   11
#  Transport Step:  138   Step Size:  0.1000     Total Elapsed Time:   14.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6838E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1509E-05  [K,I,J]   52   27   12
#  Transport Step:  139   Step Size:  0.1000     Total Elapsed Time:   14.900
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6785E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1248E-05  [K,I,J]   52   27   12
#  Transport Step:  140   Step Size:  0.1000     Total Elapsed Time:   15.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6733E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1265E-05  [K,I,J]   52   35   11
#  Transport Step:  141   Step Size:  0.1000     Total Elapsed Time:   15.100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6682E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1100E-05  [K,I,J]   52   35   11
#  Transport Step:  142   Step Size:  0.1000     Total Elapsed Time:   15.200
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6632E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9628E-06  [K,I,J]   52   35   11
#  Transport Step:  143   Step Size:  0.1000     Total Elapsed Time:   15.300
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6582E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9613E-06  [K,I,J]   51   25   12
#  Transport Step:  144   Step Size:  0.1000     Total Elapsed Time:   15.400
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6528E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1678E-05  [K,I,J]   53   35   12
#  Transport Step:  145   Step Size:  0.1000     Total Elapsed Time:   15.500
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6480E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9592E-06  [K,I,J]   51   25   12
#  Transport Step:  146   Step Size:  0.1000     Total Elapsed Time:   15.600
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6432E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1714E-05  [K,I,J]   53   34   12
#  Transport Step:  147   Step Size:  0.1000     Total Elapsed Time:   15.700
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6384E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1232E-05  [K,I,J]   52   25   11
#  Transport Step:  148   Step Size:  0.1000     Total Elapsed Time:   15.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6338E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1198E-05  [K,I,J]   52   36   11
#  Transport Step:  149   Step Size:  0.1000     Total Elapsed Time:   15.900
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6292E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1270E-05  [K,I,J]   52   26   12
#  Transport Step:  150   Step Size:  0.1000     Total Elapsed Time:   16.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6247E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1237E-05  [K,I,J]   51   24   12
#  Transport Step:  151   Step Size:  0.1000     Total Elapsed Time:   16.100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6203E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1028E-05  [K,I,J]   53   33   11
#  Transport Step:  152   Step Size:  0.1000     Total Elapsed Time:   16.200
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6159E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1005E-05  [K,I,J]   51   37   11
#  Transport Step:  153   Step Size:  0.1000     Total Elapsed Time:   16.300
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6116E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9847E-06  [K,I,J]   51   37   11
#  Transport Step:  154   Step Size:  0.1000     Total Elapsed Time:   16.400
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6074E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1079E-05  [K,I,J]   53   28   11
#  Transport Step:  155   Step Size:  0.1000     Total Elapsed Time:   16.500
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6032E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9678E-06  [K,I,J]   53   28   11
#  Transport Step:  156   Step Size:  0.1000     Total Elapsed Time:   16.600
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5990E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9250E-06  [K,I,J]   51   25   12
#  Transport Step:  157   Step Size:  0.1000     Total Elapsed Time:   16.700
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5949E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9070E-06  [K,I,J]   51   25   12
#  Transport Step:  158   Step Size:  0.1000     Total Elapsed Time:   16.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5909E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9969E-06  [K,I,J]   55   31   12
#  Transport Step:  159   Step Size:  0.1000     Total Elapsed Time:   16.900
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5869E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1227E-05  [K,I,J]   53   29   13
#  Transport Step:  160   Step Size:  0.1000     Total Elapsed Time:   17.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5829E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1007E-05  [K,I,J]   53   35   11
#  Transport Step:  161   Step Size:  0.1000     Total Elapsed Time:   17.100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5790E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2063E-05  [K,I,J]   53   31   13
#  Transport Step:  162   Step Size:  0.1000     Total Elapsed Time:   17.200
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5752E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1940E-05  [K,I,J]   52   25   12
#  Transport Step:  163   Step Size:  0.1000     Total Elapsed Time:   17.300
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5714E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2915E-05  [K,I,J]   51   37   12
#  Transport Step:  164   Step Size:  0.1000     Total Elapsed Time:   17.400
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5676E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2538E-05  [K,I,J]   51   25   12
#  Transport Step:  165   Step Size:  0.1000     Total Elapsed Time:   17.500
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5639E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2242E-05  [K,I,J]   51   25   12
#  Transport Step:  166   Step Size:  0.1000     Total Elapsed Time:   17.600
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5602E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2134E-05  [K,I,J]   53   31   12
#  Transport Step:  167   Step Size:  0.1000     Total Elapsed Time:   17.700
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5566E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2046E-05  [K,I,J]   53   32   12
#  Transport Step:  168   Step Size:  0.1000     Total Elapsed Time:   17.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5531E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2072E-05  [K,I,J]   53   33   12
#  Transport Step:  169   Step Size:  0.1000     Total Elapsed Time:   17.900
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5495E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1786E-05  [K,I,J]   53   33   12
#  Transport Step:  170   Step Size:  0.1000     Total Elapsed Time:   18.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5460E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2635E-05  [K,I,J]   52   33   12
#  Transport Step:  171   Step Size:  0.1000     Total Elapsed Time:   18.100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5426E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2368E-05  [K,I,J]   52   30   12
#  Transport Step:  172   Step Size:  0.1000     Total Elapsed Time:   18.200
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5392E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2172E-05  [K,I,J]   52   34   12
#  Transport Step:  173   Step Size:  0.1000     Total Elapsed Time:   18.300
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5358E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1902E-05  [K,I,J]   52   34   12
#  Transport Step:  174   Step Size:  0.1000     Total Elapsed Time:   18.400
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5325E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1652E-05  [K,I,J]   52   34   12
#  Transport Step:  175   Step Size:  0.1000     Total Elapsed Time:   18.500
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5292E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2119E-05  [K,I,J]   53   36   12
#  Transport Step:  176   Step Size:  0.1000     Total Elapsed Time:   18.600
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5259E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2598E-05  [K,I,J]   52   27   12
#  Transport Step:  177   Step Size:  0.1000     Total Elapsed Time:   18.700
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5227E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1799E-05  [K,I,J]   52   27   12
#  Transport Step:  178   Step Size:  0.1000     Total Elapsed Time:   18.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5194E-02  [K,I,J]   50   27   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1070E-05  [K,I,J]   52   31   11
#  Transport Step:  179   Step Size:  0.1000     Total Elapsed Time:   18.900
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5163E-02  [K,I,J]   50   27   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9665E-06  [K,I,J]   52   31   11
#  Transport Step:  180   Step Size:  0.1000     Total Elapsed Time:   19.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5132E-02  [K,I,J]   50   27   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8854E-06  [K,I,J]   52   31   11
#  Transport Step:  181   Step Size:  0.1000     Total Elapsed Time:   19.100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5101E-02  [K,I,J]   50   27   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9306E-06  [K,I,J]   52   29   11
#  Transport Step:  182   Step Size:  0.1000     Total Elapsed Time:   19.200
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5071E-02  [K,I,J]   50   27   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8565E-06  [K,I,J]   51   37   12
#  Transport Step:  183   Step Size:  0.1000     Total Elapsed Time:   19.300
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5041E-02  [K,I,J]   50   27   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1188E-05  [K,I,J]   51   24   12
# ...
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5135E-06  [K,I,J]   51   38   12
#  Transport Step:   66   Step Size:  0.1000     Total Elapsed Time:   890.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2137E-03  [K,I,J]   50   33   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4520E-06  [K,I,J]   51   37   12
#  Transport Step:   67   Step Size:  0.1000     Total Elapsed Time:   890.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2128E-03  [K,I,J]   50   33   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4573E-06  [K,I,J]   51   37   12
#  Transport Step:   68   Step Size:  0.1000     Total Elapsed Time:   890.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2118E-03  [K,I,J]   50   33   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4018E-06  [K,I,J]   51   37   12
#  Transport Step:   69   Step Size:  0.1000     Total Elapsed Time:   890.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3922E-03  [K,I,J]   56   39   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5611E-06  [K,I,J]   51   37   12
#  Transport Step:   70   Step Size:  0.1000     Total Elapsed Time:   891.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2538E-03  [K,I,J]   50   25   12
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4786E-06  [K,I,J]   51   37   12
#  Transport Step:   71   Step Size:  0.1000     Total Elapsed Time:   891.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2113E-03  [K,I,J]   50   25   12
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4577E-06  [K,I,J]   51   24   12
#  Transport Step:   72   Step Size:  0.1000     Total Elapsed Time:   891.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9700E-03  [K,I,J]   52   37   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7322E-06  [K,I,J]   51   37   12
#  Transport Step:   73   Step Size:  0.1000     Total Elapsed Time:   891.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8815E-03  [K,I,J]   55   37   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8707E-06  [K,I,J]   56   37   13
#  Transport Step:   74   Step Size:  0.1000     Total Elapsed Time:   891.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2065E-03  [K,I,J]   50   33   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5752E-06  [K,I,J]   51   37   12
#  Transport Step:   75   Step Size:  0.1000     Total Elapsed Time:   891.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2514E-03  [K,I,J]   50   25   12
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4908E-06  [K,I,J]   51   37   12
#  Transport Step:   76   Step Size:  0.1000     Total Elapsed Time:   891.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2207E-03  [K,I,J]   50   37   12
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5252E-06  [K,I,J]   51   38   13
#  Transport Step:   77   Step Size:  0.1000     Total Elapsed Time:   891.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6103E-03  [K,I,J]   53   24   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5414E-06  [K,I,J]   54   24   13
#  Transport Step:   78   Step Size:  0.1000     Total Elapsed Time:   891.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2029E-03  [K,I,J]   50   33   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4864E-06  [K,I,J]   51   25   12
#  Transport Step:   79   Step Size:  0.1000     Total Elapsed Time:   891.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5535E-03  [K,I,J]   51   26   12
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4702E-06  [K,I,J]   51   37   11
#  Transport Step:   80   Step Size:  0.1000     Total Elapsed Time:   892.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2012E-03  [K,I,J]   50   33   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6468E-06  [K,I,J]   51   38   13
#  Transport Step:   81   Step Size:  0.1000     Total Elapsed Time:   892.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2003E-03  [K,I,J]   50   33   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6795E-06  [K,I,J]   51   38   13
#  Transport Step:   82   Step Size:  0.1000     Total Elapsed Time:   892.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4980E-03  [K,I,J]   51   36   12
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5536E-06  [K,I,J]   51   38   13
#  Transport Step:   83   Step Size:  0.1000     Total Elapsed Time:   892.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8442E-03  [K,I,J]   53   38   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8413E-06  [K,I,J]   54   38   13
#  Transport Step:   84   Step Size:  0.1000     Total Elapsed Time:   892.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2924E-03  [K,I,J]   56   38   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4709E-06  [K,I,J]   51   37   11
#  Transport Step:   85   Step Size:  0.1000     Total Elapsed Time:   892.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4511E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1404E-05  [K,I,J]   51   38   13
#  Transport Step:   86   Step Size:  0.1000     Total Elapsed Time:   892.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3649E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1181E-05  [K,I,J]   51   38   13
#  Transport Step:   87   Step Size:  0.1000     Total Elapsed Time:   892.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3283E-03  [K,I,J]   56   24   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9921E-06  [K,I,J]   51   38   13
#  Transport Step:   88   Step Size:  0.1000     Total Elapsed Time:   892.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2196E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7450E-06  [K,I,J]   51   38   13
#  Transport Step:   89   Step Size:  0.1000     Total Elapsed Time:   892.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2321E-03  [K,I,J]   50   37   12
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6582E-06  [K,I,J]   51   38   13
#  Transport Step:   90   Step Size:  0.1000     Total Elapsed Time:   893.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2150E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7361E-06  [K,I,J]   51   38   13
#  Transport Step:   91   Step Size:  0.1000     Total Elapsed Time:   893.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2532E-03  [K,I,J]   50   37   12
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7495E-06  [K,I,J]   51   38   13
#  Transport Step:   92   Step Size:  0.1000     Total Elapsed Time:   893.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2479E-03  [K,I,J]   50   25   12
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6266E-06  [K,I,J]   51   38   13
#  Transport Step:   93   Step Size:  0.1000     Total Elapsed Time:   893.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2273E-03  [K,I,J]   50   25   12
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4995E-06  [K,I,J]   51   38   13
#  Transport Step:   94   Step Size:  0.1000     Total Elapsed Time:   893.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2497E-03  [K,I,J]   54   39   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4912E-06  [K,I,J]   51   37   12
#  Transport Step:   95   Step Size:  0.1000     Total Elapsed Time:   893.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1946E-03  [K,I,J]   50   37   12
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4707E-06  [K,I,J]   52   25   12
#  Transport Step:   96   Step Size:  0.1000     Total Elapsed Time:   893.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1880E-03  [K,I,J]   50   33   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4847E-06  [K,I,J]   51   38   13
#  Transport Step:   97   Step Size:  0.1000     Total Elapsed Time:   893.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2000E-03  [K,I,J]   50   25   12
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4414E-06  [K,I,J]   51   24   13
#  Transport Step:   98   Step Size:  0.1000     Total Elapsed Time:   893.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1865E-03  [K,I,J]   50   33   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5385E-06  [K,I,J]   52   25   12
#  Transport Step:   99   Step Size:  0.1000     Total Elapsed Time:   893.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1857E-03  [K,I,J]   50   33   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5883E-06  [K,I,J]   52   38   13
#  Transport Step:  100   Step Size:  0.1000     Total Elapsed Time:   894.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2630E-03  [K,I,J]   54   39   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5164E-06  [K,I,J]   51   38   13
#  Transport Step:  101   Step Size:  0.1000     Total Elapsed Time:   894.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2846E-03  [K,I,J]   56   38   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6189E-06  [K,I,J]   51   38   13
#  Transport Step:  102   Step Size:  0.1000     Total Elapsed Time:   894.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3660E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1188E-05  [K,I,J]   51   38   13
#  Transport Step:  103   Step Size:  0.1000     Total Elapsed Time:   894.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3083E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1012E-05  [K,I,J]   51   38   13
#  Transport Step:  104   Step Size:  0.1000     Total Elapsed Time:   894.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2997E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9962E-06  [K,I,J]   51   38   13
#  Transport Step:  105   Step Size:  0.1000     Total Elapsed Time:   894.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1424E-02  [K,I,J]   52   25   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1453E-05  [K,I,J]   51   38   13
#  Transport Step:  106   Step Size:  0.1000     Total Elapsed Time:   894.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3654E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1197E-05  [K,I,J]   51   38   13
#  Transport Step:  107   Step Size:  0.1000     Total Elapsed Time:   894.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5719E-03  [K,I,J]   53   24   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9649E-06  [K,I,J]   51   38   13
#  Transport Step:  108   Step Size:  0.1000     Total Elapsed Time:   894.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2499E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8537E-06  [K,I,J]   51   38   13
#  Transport Step:  109   Step Size:  0.1000     Total Elapsed Time:   894.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2137E-03  [K,I,J]   53   22   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7278E-06  [K,I,J]   51   38   13
#  Transport Step:  110   Step Size:  0.1000     Total Elapsed Time:   895.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2170E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7413E-06  [K,I,J]   51   38   13
#  Transport Step:  111   Step Size:  0.1000     Total Elapsed Time:   895.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5821E-03  [K,I,J]   53   24   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1202E-05  [K,I,J]   51   38   13
#  Transport Step:  112   Step Size:  0.1000     Total Elapsed Time:   895.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3153E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1021E-05  [K,I,J]   51   38   13
#  Transport Step:  113   Step Size:  0.1000     Total Elapsed Time:   895.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8350E-03  [K,I,J]   53   38   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8883E-06  [K,I,J]   51   38   13
#  Transport Step:  114   Step Size:  0.1000     Total Elapsed Time:   895.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4162E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1341E-05  [K,I,J]   51   38   13
#  Transport Step:  115   Step Size:  0.1000     Total Elapsed Time:   895.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3489E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1146E-05  [K,I,J]   51   38   13
#  Transport Step:  116   Step Size:  0.1000     Total Elapsed Time:   895.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2842E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9556E-06  [K,I,J]   51   38   13
#  Transport Step:  117   Step Size:  0.1000     Total Elapsed Time:   895.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6373E-03  [K,I,J]   53   24   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8407E-06  [K,I,J]   51   38   13
#  Transport Step:  118   Step Size:  0.1000     Total Elapsed Time:   895.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2131E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7215E-06  [K,I,J]   51   38   13
#  Transport Step:  119   Step Size:  0.1000     Total Elapsed Time:   895.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1787E-03  [K,I,J]   51   38   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6260E-06  [K,I,J]   51   38   13
#  Transport Step:  120   Step Size:  0.1000     Total Elapsed Time:   896.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1086E-02  [K,I,J]   52   37   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8909E-06  [K,I,J]   54   38   13
#  Transport Step:  121   Step Size:  0.1000     Total Elapsed Time:   896.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7804E-03  [K,I,J]   50   24   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7583E-06  [K,I,J]   51   25   12
#  Transport Step:  122   Step Size:  0.1000     Total Elapsed Time:   896.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7046E-03  [K,I,J]   50   24   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5183E-06  [K,I,J]   51   24   13
#  Transport Step:  123   Step Size:  0.1000     Total Elapsed Time:   896.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1109E-02  [K,I,J]   52   37   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7950E-06  [K,I,J]   53   37   12
#  Transport Step:  124   Step Size:  0.1000     Total Elapsed Time:   896.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6820E-03  [K,I,J]   50   24   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7150E-06  [K,I,J]   51   24   13
#  Transport Step:  125   Step Size:  0.1000     Total Elapsed Time:   896.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6172E-03  [K,I,J]   50   24   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7365E-06  [K,I,J]   51   24   13
#  Transport Step:  126   Step Size:  0.1000     Total Elapsed Time:   896.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5602E-03  [K,I,J]   50   24   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7439E-06  [K,I,J]   51   24   13
#  Transport Step:  127   Step Size:  0.1000     Total Elapsed Time:   896.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5155E-03  [K,I,J]   50   24   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4914E-06  [K,I,J]   51   24   13
#  Transport Step:  128   Step Size:  0.1000     Total Elapsed Time:   896.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4585E-03  [K,I,J]   50   24   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5249E-06  [K,I,J]   51   24   13
#  Transport Step:  129   Step Size:  0.1000     Total Elapsed Time:   896.90
#
#  ERROR: MAXIMUM NUMBER OF PARTICLES ALLOWED [MXPART] IS    400000
#         ACTUAL NUMBER OF PARTICLES NEEDED AT THIS POINT    400016
#  INCREASE VALUE OF [MXPART] IN ADVECTION INPUT FILE
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[32], line 13
#       4 # %%
#       5
#       6
#    (...)
#       9
#      10 # %%
#      12 success, buff = swt.run_model(silent=False, report=True)
# ---> 13 assert success, "SEAWAT did not terminate normally."
#      15 # %%  dump
#      16 swt.my_params = my_params
#
# AssertionError: SEAWAT did not terminate normally.

# %%
# %%

def plot_my_params():

    time_table = create_time_table()

    fig,ax = plt.subplots(figsize=(8,5))

    xs = time_table['Time']
    ax.scatter(xs,np.repeat(10,len(xs)),s=200,marker='|')
    ax.annotate('Stress Period:   {}'.format([n for n in time_table['perlen'].dropna().unique()]),(0,10.2))


    mask = time_table['wel_data'].isna()
    xs = time_table[~mask]['Time']
    ax.scatter(xs,np.repeat(9,len(xs)),s=200,marker='|',c=time_table[~mask]['wel_data'],cmap='coolwarm_r')
    ax.annotate('Well Input:   {}'.format([n for n in time_table['wel_data'].dropna().unique()]),(0,9.2))


    mask = time_table['ssm'].isna()
    xs = time_table[~mask]['Time']
    ax.scatter(xs,np.repeat(8,len(xs)),s=200,marker='|',c=time_table[~mask]['ssm'],cmap='coolwarm_r')
    ax.annotate('Input Concentration:   {}'.format([n for n in time_table['ssm'].dropna().unique()]),(0,8.2))


    ax.annotate('Aquifer:',(11000,9.2),weight="bold")
    ax.annotate(('hk={0:.3g} '.format(my_params['hk']) + 'vk={0:.3g}'.format(my_params['vk'])),(11000,9))
    ax.annotate('ss= {} sy={}'.format(my_params['ss'],my_params['sy']),(11000,8.8))
    ax.annotate('porosity={}'.format(my_params['porosity']),(11000,8.6))

    ax.annotate('Dispersion:',(16400,9.2),weight="bold")
    ax.annotate('la={}, trpt={}, trpv={}'.format(my_params['la'],my_params['trpt'],my_params['trpv']),(16400,9))


    ax.annotate('Advection:',(16400,8.7),weight="bold")
    d = {0:'FDM',3:'HMOC'}
    ax.annotate('Solution: {}'.format(d[my_params['mixelm']]),(16400,8.5))


    ax.annotate('Sorption:',(11000,8.3),weight="bold")
    d = {0:'No Sorption',1:'Linear',3:'Langmuir'}
    ax.annotate('{},'.format(d[my_params['isothm']]),(11000,8.1))
    if my_params['isothm']==1:
        ax.annotate('sp1={}'.format(my_params['sp1']),(11000,7.9))
        
    elif my_params['isothm']==3:
        ax.annotate('sp1={}'.format(my_params['sp1']),(11000,7.9))
        ax.annotate('sp2={}'.format(my_params['sp2']),(11000,7.7))
        


    ax.annotate('Recharge:',(16400,8.3),weight="bold")
    #d = {0:'No Sorption',1:'Linear'}
    ax.annotate('{0:.3g}'.format(my_params['rech']),(16000,8.1))


    ax.annotate('{}'.format(os.path.basename(os.path.normpath(workspace))),(200,7.3),weight="bold")

    ax.axes.get_yaxis().set_visible(False)
    plt.ylim(7,10.5)
    plt.xlim(-1000,65*365)
    plt.tight_layout()
    plt.savefig(Path(workspace) /'_output/_my_params.png')


## Run
plot_my_params()


# %% [markdown]
# ## JSON
# %%
import json

with open(Path(workspace) /'_output/my_params.json', 'w') as fp:
    json.dump(my_params,fp)



# %%
create_time_table().to_csv(Path(workspace) /'_output/time_table.csv')   
shutil.copytree('_imports',Path(workspace)/'_output/_imports',dirs_exist_ok =True)
#shutil.copyfile(__file__,Path(workspace) /'_output/{}'.format(os.path.basename(__file__)))

# %%

# %%
### read data
col = int(24)
ibound = swt.bas6.ibound.array
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace)/ 'MT3D001.UCN')

times = ucnobj.get_times()

    # Read the concentration data from the UCN file
    
concentration_array = ucnobj.get_data(totim=times[-1])# (time step, stress period)

# Mask the inactive cells
mask = ((ibound== 0)|(concentration_array>=1e30))
masked_conc_data = np.ma.masked_where(mask, concentration_array)

### plotting# ##
fig = plt.figure(figsize=(15, 4))
line = {"Column": col}

# Create a PlotCrossSection object for the model
xsect = flopy.plot.PlotCrossSection(model=swt, line=line)

# Plot the concentration results
cs = xsect.plot_array(masked_conc_data, cmap='coolwarm', vmin=0.1, vmax=300)
plt.colorbar(cs)
ibd = xsect.plot_ibound(color_noflow='grey')
plt.title('col:{:03}, kper:{:02}'.format(col,kper))
plt.gcf().set_size_inches(10,5)
plt.ylim(mybot.min(),177)

#plt.savefig(Path(workspace)/'_output/conc_{:02}.png'.format(kper))
#plt.clf()

##--------

# %%
### read data
col = int(44)
ibound = swt.bas6.ibound.array
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace)/ 'MT3D001.UCN')

times = ucnobj.get_times()

    # Read the concentration data from the UCN file
    
concentration_array = ucnobj.get_data(totim=times[-1])# (time step, stress period)

# Mask the inactive cells
mask = ((ibound== 0)|(concentration_array>=1e30))
masked_conc_data = np.ma.masked_where(mask, concentration_array)

### plotting# ##
fig = plt.figure(figsize=(15, 4))
line = {"Column": col}

# Create a PlotCrossSection object for the model
xsect = flopy.plot.PlotCrossSection(model=swt, line=line)

# Plot the concentration results
cs = xsect.plot_array(masked_conc_data, cmap='coolwarm', vmin=0.1, vmax=300)
plt.colorbar(cs)
ibd = xsect.plot_ibound(color_noflow='grey')
plt.title('col:{:03}, kper:{:02}'.format(col,kper))
plt.gcf().set_size_inches(10,5)
plt.ylim(mybot.min(),177)

#plt.savefig(Path(workspace)/'_output/conc_{:02}.png'.format(kper))
#plt.clf()

##--------

# %%
### read data
col = int(64)
ibound = swt.bas6.ibound.array
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace)/ 'MT3D001.UCN')

times = ucnobj.get_times()

    # Read the concentration data from the UCN file
    
concentration_array = ucnobj.get_data(totim=times[-1])# (time step, stress period)

# Mask the inactive cells
mask = ((ibound== 0)|(concentration_array>=1e30))
masked_conc_data = np.ma.masked_where(mask, concentration_array)

### plotting# ##
fig = plt.figure(figsize=(15, 4))
line = {"Column": col}

# Create a PlotCrossSection object for the model
xsect = flopy.plot.PlotCrossSection(model=swt, line=line)

# Plot the concentration results
cs = xsect.plot_array(masked_conc_data, cmap='coolwarm', vmin=0.1, vmax=300)
plt.colorbar(cs)
ibd = xsect.plot_ibound(color_noflow='grey')
plt.title('col:{:03}, kper:{:02}'.format(col,kper))
plt.gcf().set_size_inches(10,5)
plt.ylim(mybot.min(),177)

#plt.savefig(Path(workspace)/'_output/conc_{:02}.png'.format(kper))
#plt.clf()

##--------

# %%
import os  # Make sure to import os module

row = int(30)
ibound = swt.bas6.ibound.array
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace)/ 'MT3D001.UCN')

for time in [times[4],times[83],times[115]]:
    concentration_array = ucnobj.get_data(totim=time)  # Read concentration data

    # Mask inactive cells
    mask = ((ibound == 0)|(concentration_array >= 1e30))
    masked_conc_data = np.ma.masked_where(mask, concentration_array)

    # Plotting
    fig = plt.figure(figsize=(15, 4))
    line = {"Row": row}

    # Create PlotCrossSection object
    xsect = flopy.plot.PlotCrossSection(model=swt, line=line)

    # Plot concentration results
    cs = xsect.plot_array(masked_conc_data, cmap='coolwarm', vmin=0.1, vmax=300)
    plt.colorbar(cs)
    ibd = xsect.plot_ibound(color_noflow='grey')
    plt.title('col:{:03}, year:{:.1f}'.format(col, int(time/365)))
    plt.axvline(50, c='k')
    plt.axvline(70, c='k')
    plt.axvline(90, c='k')

    # Check if output folder exists, create if not
    output_folder = Path(workspace) / '_output/xsect_'
    os.makedirs(output_folder, exist_ok=True)  # This will create the directory if it does not exist

    # Save the figure
    plt.savefig(output_folder / f'conc_{times.index(time):02}.png')
    plt.clf()

# %%
open_file(workspace)

# %%
find_closest_value = lambda target_value: min(delr.cumsum(), key=lambda x: abs(target_value- x))
find_closest_value(140)

# %%
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace) / 'MT3D001.UCN')
times = ucnobj.get_times()
conc = ucnobj.get_data(totim=times[-1])  # get the concentration data for the last time step
conc[np.where(conc==1e30)] = 0
conc_sum = np.sum(conc, axis=0)
mapview = flopy.plot.PlotMapView(model=swt)
fig = mapview.plot_array(conc_sum,cmap='coolwarm')
plt.axvline(50,c='k')
plt.axvline(70,c='k')
plt.axvline(90,c='k')
plt.gcf().set_size_inches(15,8)
plt.colorbar(fig,orientation='horizontal')
plt.title('SRP (sum of all layers)')
plt.show()

# %%
def execute_wasaga_draw(ws):
    # Define the path to the script and its folder
    script_path = Path(ws) / "wasaga_draw.py"
    #script_path = os.path.join("workspace", "wasaga_draw.py")
    script_folder = os.path.dirname(script_path)

    # Save the current working directory
    original_dir = os.getcwd()

    try:
        # Change the working directory to the script's folder
        os.chdir(script_folder)

        # Define the command to execute the script
        command = ["python", script_path]

        # Execute the command and capture the output
        output = subprocess.check_output(command, universal_newlines=True)
        print("Script executed successfully.")
        print("Output:")
        print(output)
    except subprocess.CalledProcessError as e:
        print("Error executing the script:")
        print(e)
    finally:
        # Change the working directory back to the original
        os.chdir(original_dir)

# %%
shutil.copy('wasaga_draw.py',Path(workspace) / 'wasaga_draw.py')
execute_wasaga_draw(ws = workspace)

# %%
# %%


if (__name__ == '__main__'):
    ################### Model Parameters  #########################




def execute_wasaga_draw(ws):
    # Define the path to the script and its folder
    script_path = Path(ws) / "wasaga_draw.py"
    #script_path = os.path.join("workspace", "wasaga_draw.py")
    script_folder = os.path.dirname(script_path)

    # Save the current working directory
    original_dir = os.getcwd()

    try:
        # Change the working directory to the script's folder
        os.chdir(script_folder)

        # Define the command to execute the script
        command = ["python", script_path]

        # Execute the command and capture the output
        output = subprocess.check_output(command, universal_newlines=True)
        print("Script executed successfully.")
        print("Output:")
        print(output)
    except subprocess.CalledProcessError as e:
        print("Error executing the script:")
        print(e)
    finally:
        # Change the working directory back to the original
        os.chdir(original_dir)


# %%
if (__name__ == '__main__'):

    
    run_wasaga(my_params)
