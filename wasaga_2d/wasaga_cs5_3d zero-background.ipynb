# %%
# %%
# ## Getting Started
from pathlib import Path
from tempfile import TemporaryDirectory
from tempfile import mkdtemp

import numpy as np
import matplotlib.pyplot as plt
import flopy
import pandas as pd
import shutil
import pickle
import subprocess
import os
from random_name import generate_random_name
from datetime import datetime
import platform
# %% [markdown]

# %%

# %%
################### Model Parameters   ##############################
my_params = {}
my_params['name'] = 'test_wasaga_2'
## mt3dGcg
cclose=my_params['cclose'] = 1e-5
## RCT

my_params['hk'] = 6.9
my_params['vk'] = 0.1

my_params['porosity'] = 0.35
my_params['sy'] = 0.33
my_params['ss'] = 0.0002
my_params['la'] = 0.2
my_params['trpt'] = 0.1
my_params['trpv'] = 0.1
my_params['dmcoef'] = 3.7E-10 ####
my_params['sconc'] = 20

#Species ID
sp_ID = {}
#sp_ID['Cl-'] = 1
sp_ID['SRP'] = 1
my_params['sp_ID'] = sp_ID

#Species Name
sp_name = {}
#sp_name[1] = 'Cl-'
sp_name[1] = 'SRP'
my_params['sp_name'] = sp_name


## P lens
my_params['perlen'] = [1]+[30,92,31,212]*25 +[365]*5+[365*5]*5+[365*4]+[185,30,30,120]


## Wel data
wel_data = {}
#last_wel_id = len(my_params['perlen'])-1
for y in range(25):
    p = (y)*4 +2
    wel_data[p] = [[50,0,15,0.0075]]
    p += 1
    wel_data[p] = [[50,0,15,0.075]]
    p += 1
    wel_data[p] = [[50,0,15,0.0075]]
    p += 1
    wel_data[p] = [[50,0,15,0.0]]
    p += 1

wel_data[p] = [[50,0,15,0]]
my_params['wel_data'] = wel_data


# Mt3dSsm 
ssm_data = {}
itype = flopy.mt3d.Mt3dSsm.itype_dict()

for y in range(25):
    p = (y)*4 +2
    ssm_data[p] = [(50, 0, 15, 3000.0, itype['WEL'])]
    p += 1
    ssm_data[p] = [(50, 0, 15, 3000.0, itype['WEL'])]
    p += 1
    ssm_data[p] = [(50, 0, 15, 3000.0, itype['WEL'])]
    p += 1
    ssm_data[p] = [(50, 0, 15, 3000.0, itype['WEL'])]
    p += 1
ssm_data[p] = [(50, 0, 15, 0.0, itype['WEL'])]
my_params['ssm_data'] = ssm_data


#Mt3dBtn
mixelm=my_params['mixelm'] = 0 # HMOC
my_params['isothm'] = 3 # Langmuir
my_params['sp1'] = 0.0001 ##  0.1 mg/L  => 1e5 ug/m3
my_params['sp2'] = 0.0001  ##  maximum soil adsorption value = 100 ug/g => 1e5 ug/ug

# Rch
my_params['rech'] = 0.5/365 #0.5/365 ## 500mm/year

# dt0
my_params['dt0'] = 0.1
################################################################

base_model_my_params = my_params

# %%
my_params['sp1'] = 0.0002
my_params['la'] = 5
my_params['hk'] = 6.9
base_model_my_params = my_params.copy()

my_params['vk'] = 0.1
trpv=my_params['trpv'] = 0.01

# %%
my_params['la']
# Out:
# 5

# %%
# bed size 10x10
# row: 25-35 (1m), col 12-17 (2m)
#  50 cells

# %%
mytop =np.loadtxt('_imports/top')
mybot = np.loadtxt('_imports/bot')
myibound = np.loadtxt('_imports/ibound')
mystrt = np.loadtxt('_imports/strt')
myicbund = np.loadtxt('_imports/icbund')

# %%
mytop = np.tile(mytop.reshape([74,1,110]),(1,60,1))
mybot = np.tile(mybot.reshape([74,1,110]),(1,60,1))
myibound= np.tile(myibound.reshape([74,1,110]),(1,60,1))
mystrt = np.tile(mystrt.reshape([74,1,110]),(1,60,1))
myicbund = np.tile(myicbund.reshape([74,1,110]),(1,60,1))

# %%
# mytop = np.tile(mytop.reshape([74,1,110]),(1,1,1))
# mybot = np.tile(mybot.reshape([74,1,110]),(1,1,1))
# myibound= np.tile(myibound.reshape([74,1,110]),(1,1,1))
# mystrt = np.tile(mystrt.reshape([74,1,110]),(1,1,1))
# myicbund = np.tile(myicbund.reshape([74,1,110]),(1,1,1))

# %%
# ## Import
Lx = 150
Lz = 1
nlay = 74
nrow = 60
ncol = 110
delr = np.concatenate([np.repeat(2,25),np.repeat(1,70),np.repeat(2,15)])
delc = 1.0
delv = mytop[:,0] - mybot[:,0]

# %% [markdown]
# # WORKSPACE

# %%
# Control variable to decide the location of the temp folder
use_d_drive = False  # Set to True to use the custom location

# Define model workspace
myt = datetime.now().strftime('%m%d%H%M%S')
name = 'wasaga'
adj_non = '_' + generate_random_name()

if use_d_drive and platform.system() == 'Windows':  # Check if on Windows
    temp_dir = 'H:/mf/_T{}_{}'.format(myt, adj_non)  # Path for D drive
elif use_d_drive and platform.system() == 'Darwin':  # Check if on macOS
    temp_dir = '/Volumes/Expansion/mf/_T{}_{}'.format(myt, adj_non)
else:
    temp_dir = mkdtemp(prefix='_T{}_'.format(myt), suffix=adj_non)

os.makedirs(Path(temp_dir) / '_output', exist_ok=True)
workspace = temp_dir

# %%
# ## Workspace

swt = flopy.seawat.Seawat(name, exe_name="swtv4", model_ws=workspace)

# %%
##

import os
import platform
import subprocess

def open_file(path):
    if platform.system() == "Windows":
        os.startfile(path)
    elif platform.system() == "Darwin":
        subprocess.Popen(["open", path])
    else:
        subprocess.Popen(["xdg-open", path])

open_file(workspace)

# %%
# %%
def create_time_table():
    time_table = pd.DataFrame()

    perlen = pd.Series(my_params['perlen'])
    perlen.index = perlen.index+1

    time_table['perlen'] = perlen
    time_table['Time'] = time_table['perlen'].cumsum()

    #time_table = pd.DataFrame()
    for key,value in wel_data.items():
        key
        time_table.loc[key,'wel_data'] = value[0][3]

    #time_table = pd.DataFrame()
    for key,value in ssm_data.items():
        key
        time_table.loc[key,'ssm'] = value[0][3]
    return time_table

# %%
# ## DIS

# %%
ipakcb = 53

# %%

perlen = my_params['perlen']
nper = len(perlen)
nstp = np.repeat(1,nper)
steady = np.append(np.array([True]),np.repeat(False,nper-1))



# %%
dis = flopy.modflow.ModflowDis(
    swt,
    nlay,
    nrow,
    ncol,
    nper=nper,
    delr=delr,
    delc=delc,
    laycbd=0,
    top=182.2,
    botm=mybot,
    perlen=perlen,
    nstp=nstp, #Number of time steps in each stress period
    steady = steady
)

# %% [markdown]
# ## WEL

# %%
# #last_wel_id = len(my_params['perlen'])-1

# ## Wel data
# wel_data = {}
# # Mt3dSsm 
# ssm_data = {}
# for per in range(nper):
#     wel_data[per]= []
#     ssm_data[per] = []


# for row in range(25,35+1):
#     for col in range(12,17+1):
#         for y in range(25):

#             p = (y)*4 +2
#             wel_data[p].append([50,row,col,0.5/50])
#             p += 1
#             wel_data[p].append([50,row,col,0.5/50])
#             p += 1
#             wel_data[p].append([50,row,col,0.5/50])
#             p += 1
#             wel_data[p].append([50,row,col,0.5/50])
#             p += 1


#             wel_data[p].append([50,row,col,0.5/50])




# itype = flopy.mt3d.Mt3dSsm.itype_dict()



# for row in range(25,35+1):
#     for col in range(12,17+1):
#         for y in range(25):
#             p = (y)*4 +2
#             ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))
#             p += 1
#             ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))
#             p += 1
#             ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))
#             p += 1
#             ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))
#             p += 1
#         ssm_data[p].append((50,row, col, 3000.0, itype['WEL']))


# my_params['ssm_data'] = ssm_data

# %% [markdown]
# ## RCH

# %%
rch_dict = {}

rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_dict[0] = rch_array

rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
#rch_array[int(nrow/2),int(ncol/2)] = 0.51/delr/delc
#rch_array[int(nrow/2),int(ncol/3)] = 0.51/delr/delc

for row in range(25,35+1):
    for col in range(12,17+1):
        rch_array[row,col] = 0.51/10/10
        rch_array[row,col] = 0.51/10/10

rch_dict[1] = rch_array 


rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_dict[int(25*4+1)] = rch_array

# %%
crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)
crch_dict = {}
crch_dict[0] = crch_array

crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)

# crch_array[int(nrow/2),int(ncol/2)] =5000
# crch_array[int(nrow/2),int(ncol/3)] =5000

for row in range(25,35+1):
    for col in range(12,17+1):
        crch_array[row, col] =5000
        crch_array[row, col]= 5000


crch_dict[1] = crch_array


crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)
crch_dict[int(25*4+1)] = crch_array

# %%
bas = flopy.modflow.ModflowBas(swt, myibound, mystrt)


lpf = flopy.modflow.ModflowLpf(swt, hk=my_params['hk'], vka=my_params['vk'],
                            ss= my_params['ss'],sy=my_params['sy'],
                            ipakcb=ipakcb,laytyp=1)

pcg = flopy.modflow.ModflowPcg(swt, hclose=1e-4)

# %%
stress_period_data = {}
for kper in range(nper):
    for kstp in range(nstp[kper]):
        stress_period_data[(kper, kstp)] = [
            "save head",
            "save drawdown",
            "save budget",
            "print head",
            "print budget",
        ]

# OC - Output Control Option
oc = flopy.modflow.ModflowOc(
    swt,
    stress_period_data= stress_period_data,
    compact=True,
)

# ## Well

# wel_data = my_params['wel_data']
# wel = flopy.modflow.ModflowWel(swt, stress_period_data=wel_data, ipakcb=ipakcb)

# # ModflowRch

# rch = flopy.modflow.ModflowRch(model = swt, rech = my_params['rech'])

rch = flopy.modflow.ModflowRch(model = swt, rech = rch_dict)

# # ## SSM
# ssm_data = my_params['ssm_data']



# ## BTN

#timprs = my_params['perlen'][:5]*5 +np.arange(365,np.sum(my_params['perlen']),5*355).tolist()
timprs = np.cumsum(my_params['perlen'])
timprs = [1]




btn = flopy.mt3d.Mt3dBtn(
    swt,
    nprs=len(timprs),
    timprs=timprs,
    prsity=my_params['porosity'],
    sconc=my_params['sconc'], # starting concentration
    ifmtcn=0,
    chkmas=False,
    nprobs=10,
    nprmas=10,
    dt0=my_params['dt0'],  # The user-specified initial transport step size
    ttsmult=1.2,
    mxstrn = 50000,
    icbund = myicbund
)
adv = flopy.mt3d.Mt3dAdv(swt, mixelm=my_params['mixelm'],percel=0.4,mxpart=400000,nadvfd=0)
dsp = flopy.mt3d.Mt3dDsp(swt, al=my_params['la'], trpt=my_params['trpt'], 
                        trpv=my_params['trpv'], 
                        dmcoef=my_params['dmcoef'])
gcg = flopy.mt3d.Mt3dGcg(swt, iter1=50, mxiter=1, isolve=2, cclose=my_params['cclose'])

ssm = flopy.mt3d.Mt3dSsm(swt, crch=crch_dict)

# %% [markdown]
# ## RCT


rct = flopy.mt3d.Mt3dRct(model=swt, isothm=my_params['isothm'],sp1=my_params['sp1'],sp2=my_params['sp2'],igetsc=0,rhob= 1.65E+09)





# %%
#Pht3d
#phc = flopy.mt3d.Mt3dPhc(swt,mine=[1],ie=[1],surf=[1],mobkin=[1],minkin=[1],surfkin=[1],imobkin=[1])
#phc.write_file()

# %% [markdown]
# # Write File

# %%
# %%
swt.write_input()

# %%


# %% [markdown]
# ## ################   Run      ########################

# %%

success, buff = swt.run_model(silent=False, report=True)
assert success, "SEAWAT did not terminate normally."

# %%  dump
swt.my_params = my_params
swt.delv =  delv
swt.delr = delr
pickle.dump( swt, open( Path(workspace) / '_output' / 'model.pickle',"wb" ) )

# %%


# %% [markdown]
# # Summarize Parameters
# Out:
# Util2d rech_1: locat is None, but model does not support free format and how is internal... resetting how = external
# Util2d rech_2: locat is None, but model does not support free format and how is internal... resetting how = external
# Util2d rech_102: locat is None, but model does not support free format and how is internal... resetting how = external
# FloPy is using the following executable to run the model: ../../../../../../Users/b/.local/share/flopy/bin/swtv4
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: wasaga.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2024/09/12 10:42:10
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:  0.10000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    2   Step Size:  0.1200     Total Elapsed Time:  0.22000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    3   Step Size:  0.1440     Total Elapsed Time:  0.36400
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    4   Step Size:  0.1728     Total Elapsed Time:  0.53680
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    5   Step Size:  0.2074     Total Elapsed Time:  0.74416
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    6   Step Size:  0.2488     Total Elapsed Time:  0.99299
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    7   Step Size:  7.0080E-03 Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    2
#
#   STRESS PERIOD    2 TIME STEP    1 FROM TIME =   1.0000     TO    31.000
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   1.1000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3833E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3023E-07  [K,I,J]   51   25   15
#  Transport Step:    2   Step Size:  0.1200     Total Elapsed Time:   1.2200
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4424E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5015E-07  [K,I,J]   51   25   15
#  Transport Step:    3   Step Size:  0.1440     Total Elapsed Time:   1.3640
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5076E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8267E-07  [K,I,J]   51   25   15
#  Transport Step:    4   Step Size:  0.1728     Total Elapsed Time:   1.5368
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5787E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1353E-06  [K,I,J]   51   25   15
#  Transport Step:    5   Step Size:  0.2074     Total Elapsed Time:   1.7442
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6550E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2198E-06  [K,I,J]   51   25   15
#  Transport Step:    6   Step Size:  0.2488     Total Elapsed Time:   1.9930
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7357E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3541E-06  [K,I,J]   51   25   15
#  Transport Step:    7   Step Size:  0.2986     Total Elapsed Time:   2.2916
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8198E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5807E-06  [K,I,J]   51   35   15
#  Transport Step:    8   Step Size:  0.3583     Total Elapsed Time:   2.6499
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9059E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9578E-06  [K,I,J]   51   35   15
#  Transport Step:    9   Step Size:  0.4300     Total Elapsed Time:   3.0799
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9923E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1573E-05  [K,I,J]   51   35   15
#  Transport Step:   10   Step Size:  0.5160     Total Elapsed Time:   3.5959
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1077      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2573E-05  [K,I,J]   51   35   15
#  Transport Step:   11   Step Size:  0.6192     Total Elapsed Time:   4.2150
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1160      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4191E-05  [K,I,J]   51   35   15
#  Transport Step:   12   Step Size:  0.7430     Total Elapsed Time:   4.9581
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1238      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6796E-05  [K,I,J]   51   35   15
#  Transport Step:   13   Step Size:  0.8916     Total Elapsed Time:   5.8497
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1310      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1097E-04  [K,I,J]   51   35   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1623E-08  [K,I,J]   51   32   15
#  Transport Step:   14   Step Size:   1.070     Total Elapsed Time:   6.9196
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1375      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1762E-04  [K,I,J]   51   35   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3863E-08  [K,I,J]   51   32   15
#  Transport Step:   15   Step Size:   1.284     Total Elapsed Time:   8.2035
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1432      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2813E-04  [K,I,J]   51   35   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9049E-08  [K,I,J]   51   32   15
#  Transport Step:   16   Step Size:   1.541     Total Elapsed Time:   9.7442
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1480      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4463E-04  [K,I,J]   51   35   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2097E-07  [K,I,J]   51   31   15
#  Transport Step:   17   Step Size:   1.849     Total Elapsed Time:   11.593
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1519      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7023E-04  [K,I,J]   51   35   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4776E-07  [K,I,J]   51   31   15
#  Transport Step:   18   Step Size:   2.219     Total Elapsed Time:   13.812
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1549      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1110E-03  [K,I,J]   51   34   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1067E-06  [K,I,J]   51   31   15
#  Transport Step:   19   Step Size:   2.662     Total Elapsed Time:   16.474
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1569      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1744E-03  [K,I,J]   51   34   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2335E-06  [K,I,J]   51   31   15
#  Transport Step:   20   Step Size:   3.195     Total Elapsed Time:   19.669
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1580      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2718E-03  [K,I,J]   51   33   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5016E-06  [K,I,J]   51   31   15
#  Transport Step:   21   Step Size:   3.834     Total Elapsed Time:   23.503
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1581      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4169E-03  [K,I,J]   51   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1059E-05  [K,I,J]   51   31   15
#  Transport Step:   22   Step Size:   4.601     Total Elapsed Time:   28.103
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1574      [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6266E-03  [K,I,J]   51   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2197E-05  [K,I,J]   51   31   15
#  Transport Step:   23   Step Size:   2.897     Total Elapsed Time:   31.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8394E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1575E-03  [K,I,J]   51   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2525E-06  [K,I,J]   51   31   15
#
#  STRESS PERIOD NO.    3
#
#   STRESS PERIOD    3 TIME STEP    1 FROM TIME =   31.000     TO    123.00
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   31.100
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2692E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8185E-08  [K,I,J]   51   32   15
#  Transport Step:    2   Step Size:  0.1200     Total Elapsed Time:   31.220
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3218E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1409E-07  [K,I,J]   51   32   15
#  Transport Step:    3   Step Size:  0.1440     Total Elapsed Time:   31.364
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3844E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2425E-07  [K,I,J]   51   32   15
#  Transport Step:    4   Step Size:  0.1728     Total Elapsed Time:   31.537
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4587E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4170E-07  [K,I,J]   51   32   15
#  Transport Step:    5   Step Size:  0.2074     Total Elapsed Time:   31.744
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5469E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7163E-07  [K,I,J]   51   32   15
#  Transport Step:    6   Step Size:  0.2488     Total Elapsed Time:   31.993
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6512E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1229E-06  [K,I,J]   51   32   15
#  Transport Step:    7   Step Size:  0.2986     Total Elapsed Time:   32.292
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7742E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2105E-06  [K,I,J]   51   32   15
#  Transport Step:    8   Step Size:  0.3583     Total Elapsed Time:   32.650
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9188E-02  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3600E-06  [K,I,J]   51   32   15
#  Transport Step:    9   Step Size:  0.4300     Total Elapsed Time:   33.080
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1088E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6144E-06  [K,I,J]   51   32   15
#  Transport Step:   10   Step Size:  0.5160     Total Elapsed Time:   33.596
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1286E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1046E-05  [K,I,J]   51   32   15
#  Transport Step:   11   Step Size:  0.6192     Total Elapsed Time:   34.215
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1515E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1776E-05  [K,I,J]   51   32   15
#  Transport Step:   12   Step Size:  0.7430     Total Elapsed Time:   34.958
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1778E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3003E-05  [K,I,J]   51   32   15
#  Transport Step:   13   Step Size:  0.8916     Total Elapsed Time:   35.850
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2080E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5058E-05  [K,I,J]   51   32   15
#  Transport Step:   14   Step Size:   1.070     Total Elapsed Time:   36.920
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2421E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8477E-05  [K,I,J]   51   32   15
#  Transport Step:   15   Step Size:   1.284     Total Elapsed Time:   38.204
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2805E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1412E-04  [K,I,J]   51   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5448E-08  [K,I,J]   51   31   15
#  Transport Step:   16   Step Size:   1.541     Total Elapsed Time:   39.744
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3229E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2337E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1288E-07  [K,I,J]   51   31   15
#  Transport Step:   17   Step Size:   1.849     Total Elapsed Time:   41.593
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3694E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3835E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3004E-07  [K,I,J]   51   31   15
#  Transport Step:   18   Step Size:   2.219     Total Elapsed Time:   43.812
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4195E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6233E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6909E-07  [K,I,J]   51   31   15
#  Transport Step:   19   Step Size:   2.662     Total Elapsed Time:   46.474
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4724E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1002E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1566E-06  [K,I,J]   51   31   15
#  Transport Step:   20   Step Size:   3.195     Total Elapsed Time:   49.669
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5274E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1591E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3494E-06  [K,I,J]   51   31   15
#  Transport Step:   21   Step Size:   3.834     Total Elapsed Time:   53.503
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5831E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2490E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7671E-06  [K,I,J]   51   31   15
#  Transport Step:   22   Step Size:   4.601     Total Elapsed Time:   58.103
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6381E-01  [K,I,J]   50   35   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3836E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1654E-05  [K,I,J]   51   31   15
#  Transport Step:   23   Step Size:   5.521     Total Elapsed Time:   63.624
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6922E-01  [K,I,J]   50   34   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5807E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3496E-05  [K,I,J]   51   31   15
#  Transport Step:   24   Step Size:   6.625     Total Elapsed Time:   70.248
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7438E-01  [K,I,J]   50   34   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8626E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7221E-05  [K,I,J]   51   31   15
#  Transport Step:   25   Step Size:   7.950     Total Elapsed Time:   78.198
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7912E-01  [K,I,J]   50   34   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1256E-02  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1454E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9028E-07  [K,I,J]   58   57   69
#  Transport Step:   26   Step Size:   9.540     Total Elapsed Time:   87.738
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8336E-01  [K,I,J]   50   34   13
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1790E-02  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2848E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2189E-06  [K,I,J]   51   27   15
#  Transport Step:   27   Step Size:   11.45     Total Elapsed Time:   99.185
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8760E-01  [K,I,J]   50   34   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2496E-02  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5415E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4734E-06  [K,I,J]   51   27   15
#  Transport Step:   28   Step Size:   13.74     Total Elapsed Time:   112.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9181E-01  [K,I,J]   50   34   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3402E-02  [K,I,J]   51   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9973E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9779E-06  [K,I,J]   51   27   15
#  Transport Step:   29   Step Size:   10.08     Total Elapsed Time:   123.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5950E-01  [K,I,J]   50   34   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1540E-02  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2958E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2672E-06  [K,I,J]   51   27   15
#
#  STRESS PERIOD NO.    4
#
#   STRESS PERIOD    4 TIME STEP    1 FROM TIME =   123.00     TO    154.00
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   123.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5607E-03  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3199E-08  [K,I,J]   51   31   15
#  Transport Step:    2   Step Size:  0.1200     Total Elapsed Time:   123.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6722E-03  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5514E-08  [K,I,J]   51   31   15
#  Transport Step:    3   Step Size:  0.1440     Total Elapsed Time:   123.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8058E-03  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9498E-08  [K,I,J]   51   31   15
#  Transport Step:    4   Step Size:  0.1728     Total Elapsed Time:   123.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9657E-03  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1635E-07  [K,I,J]   51   31   15
#  Transport Step:    5   Step Size:  0.2074     Total Elapsed Time:   123.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1157E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2813E-07  [K,I,J]   51   31   15
#  Transport Step:    6   Step Size:  0.2488     Total Elapsed Time:   123.99
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1386E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4834E-07  [K,I,J]   51   31   15
#  Transport Step:    7   Step Size:  0.2986     Total Elapsed Time:   124.29
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1659E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8300E-07  [K,I,J]   51   31   15
#  Transport Step:    8   Step Size:  0.3583     Total Elapsed Time:   124.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1986E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1423E-06  [K,I,J]   51   31   15
#  Transport Step:    9   Step Size:  0.4300     Total Elapsed Time:   125.08
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2376E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2436E-06  [K,I,J]   51   31   15
#  Transport Step:   10   Step Size:  0.5160     Total Elapsed Time:   125.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2840E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4164E-06  [K,I,J]   51   31   15
#  Transport Step:   11   Step Size:  0.6192     Total Elapsed Time:   126.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3393E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7101E-06  [K,I,J]   51   31   15
#  Transport Step:   12   Step Size:  0.7430     Total Elapsed Time:   126.96
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4049E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1208E-05  [K,I,J]   51   31   15
#  Transport Step:   13   Step Size:  0.8916     Total Elapsed Time:   127.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4828E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2048E-05  [K,I,J]   51   31   15
#  Transport Step:   14   Step Size:   1.070     Total Elapsed Time:   128.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5749E-02  [K,I,J]   50   28   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3461E-05  [K,I,J]   51   31   15
#  Transport Step:   15   Step Size:   1.284     Total Elapsed Time:   130.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6836E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5825E-05  [K,I,J]   51   31   15
#  Transport Step:   16   Step Size:   1.541     Total Elapsed Time:   131.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8114E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9754E-05  [K,I,J]   51   31   15
#  Transport Step:   17   Step Size:   1.849     Total Elapsed Time:   133.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9612E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1624E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1824E-07  [K,I,J]   51   31   15
#  Transport Step:   18   Step Size:   2.219     Total Elapsed Time:   135.81
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1136E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2685E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4193E-07  [K,I,J]   51   31   15
#  Transport Step:   19   Step Size:   2.662     Total Elapsed Time:   138.47
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1339E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4405E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9538E-07  [K,I,J]   51   31   15
#  Transport Step:   20   Step Size:   3.195     Total Elapsed Time:   141.67
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1572E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7162E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2148E-06  [K,I,J]   51   31   15
#  Transport Step:   21   Step Size:   3.834     Total Elapsed Time:   145.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1840E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1152E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4780E-06  [K,I,J]   51   31   15
#  Transport Step:   22   Step Size:   4.601     Total Elapsed Time:   150.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2145E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1832E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1048E-05  [K,I,J]   51   31   15
#  Transport Step:   23   Step Size:   3.897     Total Elapsed Time:   154.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1764E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1157E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5015E-06  [K,I,J]   51   31   15
#
#  STRESS PERIOD NO.    5
#
#   STRESS PERIOD    5 TIME STEP    1 FROM TIME =   154.00     TO    366.00
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   154.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4464E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2745E-08  [K,I,J]   51   31   15
#  Transport Step:    2   Step Size:  0.1200     Total Elapsed Time:   154.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5353E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4731E-08  [K,I,J]   51   31   15
#  Transport Step:    3   Step Size:  0.1440     Total Elapsed Time:   154.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6418E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8151E-08  [K,I,J]   51   31   15
#  Transport Step:    4   Step Size:  0.1728     Total Elapsed Time:   154.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7694E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1403E-07  [K,I,J]   51   31   15
#  Transport Step:    5   Step Size:  0.2074     Total Elapsed Time:   154.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9221E-03  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2415E-07  [K,I,J]   51   31   15
#  Transport Step:    6   Step Size:  0.2488     Total Elapsed Time:   154.99
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1105E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4152E-07  [K,I,J]   51   31   15
#  Transport Step:    7   Step Size:  0.2986     Total Elapsed Time:   155.29
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1323E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7131E-07  [K,I,J]   51   31   15
#  Transport Step:    8   Step Size:  0.3583     Total Elapsed Time:   155.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1585E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1223E-06  [K,I,J]   51   31   15
#  Transport Step:    9   Step Size:  0.4300     Total Elapsed Time:   156.08
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1897E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2095E-06  [K,I,J]   51   31   15
#  Transport Step:   10   Step Size:  0.5160     Total Elapsed Time:   156.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2269E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3583E-06  [K,I,J]   51   31   15
#  Transport Step:   11   Step Size:  0.6192     Total Elapsed Time:   157.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2713E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6115E-06  [K,I,J]   51   31   15
#  Transport Step:   12   Step Size:  0.7430     Total Elapsed Time:   157.96
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3241E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1041E-05  [K,I,J]   51   31   15
#  Transport Step:   13   Step Size:  0.8916     Total Elapsed Time:   158.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3868E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1767E-05  [K,I,J]   51   31   15
#  Transport Step:   14   Step Size:   1.070     Total Elapsed Time:   159.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4612E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2990E-05  [K,I,J]   51   31   15
#  Transport Step:   15   Step Size:   1.284     Total Elapsed Time:   161.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5493E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5039E-05  [K,I,J]   51   31   15
#  Transport Step:   16   Step Size:   1.541     Total Elapsed Time:   162.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6533E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8450E-05  [K,I,J]   51   31   15
#  Transport Step:   17   Step Size:   1.849     Total Elapsed Time:   164.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7756E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1409E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1679E-07  [K,I,J]   51   31   15
#  Transport Step:   18   Step Size:   2.219     Total Elapsed Time:   166.81
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9186E-02  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2334E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3858E-07  [K,I,J]   51   31   15
#  Transport Step:   19   Step Size:   2.662     Total Elapsed Time:   169.47
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1085E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3836E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8773E-07  [K,I,J]   51   31   15
#  Transport Step:   20   Step Size:   3.195     Total Elapsed Time:   172.67
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1278E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6248E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1975E-06  [K,I,J]   51   31   15
#  Transport Step:   21   Step Size:   3.834     Total Elapsed Time:   176.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1501E-01  [K,I,J]   50   34   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1007E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4395E-06  [K,I,J]   51   31   15
#  Transport Step:   22   Step Size:   4.601     Total Elapsed Time:   181.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1755E-01  [K,I,J]   50   33   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1604E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9636E-06  [K,I,J]   51   31   15
#  Transport Step:   23   Step Size:   5.521     Total Elapsed Time:   186.62
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2045E-01  [K,I,J]   50   33   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2521E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2075E-05  [K,I,J]   51   31   15
#  Transport Step:   24   Step Size:   6.625     Total Elapsed Time:   193.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2371E-01  [K,I,J]   50   33   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3901E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4378E-05  [K,I,J]   51   31   15
#  Transport Step:   25   Step Size:   7.950     Total Elapsed Time:   201.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2733E-01  [K,I,J]   50   33   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5934E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9016E-05  [K,I,J]   51   31   15
#  Transport Step:   26   Step Size:   9.540     Total Elapsed Time:   210.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3130E-01  [K,I,J]   50   33   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8854E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1808E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1850E-06  [K,I,J]   51   27   15
#  Transport Step:   27   Step Size:   11.45     Total Elapsed Time:   222.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3558E-01  [K,I,J]   50   33   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1294E-02  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3523E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3800E-06  [K,I,J]   51   27   15
#  Transport Step:   28   Step Size:   13.74     Total Elapsed Time:   235.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4012E-01  [K,I,J]   50   33   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1848E-02  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6651E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7978E-06  [K,I,J]   51   27   15
#  Transport Step:   29   Step Size:   16.48     Total Elapsed Time:   252.41
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4483E-01  [K,I,J]   50   33   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2575E-02  [K,I,J]   51   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1214E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1704E-05  [K,I,J]   51   27   15
#  Transport Step:   30   Step Size:   19.78     Total Elapsed Time:   272.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4956E-01  [K,I,J]   50   33   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3497E-02  [K,I,J]   51   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2137E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3551E-05  [K,I,J]   51   27   15
#  Transport Step:   31   Step Size:   23.74     Total Elapsed Time:   295.93
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5417E-01  [K,I,J]   50   33   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4622E-02  [K,I,J]   51   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3622E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7315E-05  [K,I,J]   51   31   15
#  Transport Step:   32   Step Size:   28.49     Total Elapsed Time:   324.41
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5846E-01  [K,I,J]   50   32   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5940E-02  [K,I,J]   51   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5901E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1507E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9972E-06  [K,I,J]   51   35   15
#  Transport Step:   33   Step Size:   34.18     Total Elapsed Time:   358.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6228E-01  [K,I,J]   50   32   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7419E-02  [K,I,J]   51   32   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9229E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2974E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1852E-05  [K,I,J]   51   35   15
#  Transport Step:   34   Step Size:   7.407     Total Elapsed Time:   366.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1296E-01  [K,I,J]   50   32   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3339E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5203E-05  [K,I,J]   51   31   15
#
#  STRESS PERIOD NO.    6
#
#   STRESS PERIOD    6 TIME STEP    1 FROM TIME =   366.00     TO    396.00
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   366.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1749E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1647E-08  [K,I,J]   51   31   15
#  Transport Step:    2   Step Size:  0.1200     Total Elapsed Time:   366.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2098E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2839E-08  [K,I,J]   51   31   15
#  Transport Step:    3   Step Size:  0.1440     Total Elapsed Time:   366.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2516E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4891E-08  [K,I,J]   51   31   15
#  Transport Step:    4   Step Size:  0.1728     Total Elapsed Time:   366.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3018E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8421E-08  [K,I,J]   51   31   15
#  Transport Step:    5   Step Size:  0.2074     Total Elapsed Time:   366.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3618E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1449E-07  [K,I,J]   51   31   15
#  Transport Step:    6   Step Size:  0.2488     Total Elapsed Time:   366.99
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4338E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2491E-07  [K,I,J]   51   31   15
#  Transport Step:    7   Step Size:  0.2986     Total Elapsed Time:   367.29
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5200E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4278E-07  [K,I,J]   51   31   15
#  Transport Step:    8   Step Size:  0.3583     Total Elapsed Time:   367.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6231E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7337E-07  [K,I,J]   51   31   15
#  Transport Step:    9   Step Size:  0.4300     Total Elapsed Time:   368.08
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7466E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1257E-06  [K,I,J]   51   31   15
#  Transport Step:   10   Step Size:  0.5160     Total Elapsed Time:   368.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8942E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2149E-06  [K,I,J]   51   31   15
#  Transport Step:   11   Step Size:  0.6192     Total Elapsed Time:   369.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1071E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3667E-06  [K,I,J]   51   31   15
#  Transport Step:   12   Step Size:  0.7430     Total Elapsed Time:   369.96
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1281E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6242E-06  [K,I,J]   51   31   15
#  Transport Step:   13   Step Size:  0.8916     Total Elapsed Time:   370.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1532E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1059E-05  [K,I,J]   51   31   15
#  Transport Step:   14   Step Size:   1.070     Total Elapsed Time:   371.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1831E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1792E-05  [K,I,J]   51   31   15
#  Transport Step:   15   Step Size:   1.284     Total Elapsed Time:   373.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2187E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3019E-05  [K,I,J]   51   31   15
#  Transport Step:   16   Step Size:   1.541     Total Elapsed Time:   374.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2610E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5063E-05  [K,I,J]   51   31   15
#  Transport Step:   17   Step Size:   1.849     Total Elapsed Time:   376.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3110E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8443E-05  [K,I,J]   51   31   15
#  Transport Step:   18   Step Size:   2.219     Total Elapsed Time:   378.81
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3701E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1399E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2935E-07  [K,I,J]   51   31   15
#  Transport Step:   19   Step Size:   2.662     Total Elapsed Time:   381.47
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4397E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2300E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6605E-07  [K,I,J]   51   31   15
#  Transport Step:   20   Step Size:   3.195     Total Elapsed Time:   384.67
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5224E-02  [K,I,J]   50   32   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3749E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1473E-06  [K,I,J]   51   31   15
#  Transport Step:   21   Step Size:   3.834     Total Elapsed Time:   388.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6196E-02  [K,I,J]   50   32   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6049E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3252E-06  [K,I,J]   51   31   15
#  Transport Step:   22   Step Size:   4.601     Total Elapsed Time:   393.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7333E-02  [K,I,J]   50   32   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9649E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7080E-06  [K,I,J]   51   31   15
#  Transport Step:   23   Step Size:   2.897     Total Elapsed Time:   396.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4561E-02  [K,I,J]   50   32   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2818E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9461E-07  [K,I,J]   51   31   15
#
#  STRESS PERIOD NO.    7
#
#   STRESS PERIOD    7 TIME STEP    1 FROM TIME =   396.00     TO    488.00
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   396.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1580E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1561E-08  [K,I,J]   51   31   15
#  Transport Step:    2   Step Size:  0.1200     Total Elapsed Time:   396.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1896E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2690E-08  [K,I,J]   51   31   15
#  Transport Step:    3   Step Size:  0.1440     Total Elapsed Time:   396.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2274E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4635E-08  [K,I,J]   51   31   15
#  Transport Step:    4   Step Size:  0.1728     Total Elapsed Time:   396.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2727E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7981E-08  [K,I,J]   51   31   15
#  Transport Step:    5   Step Size:  0.2074     Total Elapsed Time:   396.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3270E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1373E-07  [K,I,J]   51   31   15
#  Transport Step:    6   Step Size:  0.2488     Total Elapsed Time:   396.99
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3921E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2361E-07  [K,I,J]   51   31   15
#  Transport Step:    7   Step Size:  0.2986     Total Elapsed Time:   397.29
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4701E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4054E-07  [K,I,J]   51   31   15
#  Transport Step:    8   Step Size:  0.3583     Total Elapsed Time:   397.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5635E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6954E-07  [K,I,J]   51   31   15
#  Transport Step:    9   Step Size:  0.4300     Total Elapsed Time:   398.08
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6752E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1191E-06  [K,I,J]   51   31   15
#  Transport Step:   10   Step Size:  0.5160     Total Elapsed Time:   398.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8089E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2037E-06  [K,I,J]   51   31   15
#  Transport Step:   11   Step Size:  0.6192     Total Elapsed Time:   399.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9687E-03  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3475E-06  [K,I,J]   51   31   15
#  Transport Step:   12   Step Size:  0.7430     Total Elapsed Time:   399.96
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1160E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5916E-06  [K,I,J]   51   31   15
#  Transport Step:   13   Step Size:  0.8916     Total Elapsed Time:   400.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1387E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1004E-05  [K,I,J]   51   31   15
#  Transport Step:   14   Step Size:   1.070     Total Elapsed Time:   401.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1659E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1698E-05  [K,I,J]   51   31   15
#  Transport Step:   15   Step Size:   1.284     Total Elapsed Time:   403.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1982E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2861E-05  [K,I,J]   51   31   15
#  Transport Step:   16   Step Size:   1.541     Total Elapsed Time:   404.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2366E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4798E-05  [K,I,J]   51   31   15
#  Transport Step:   17   Step Size:   1.849     Total Elapsed Time:   406.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2820E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7999E-05  [K,I,J]   51   31   15
#  Transport Step:   18   Step Size:   2.219     Total Elapsed Time:   408.81
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3358E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1325E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2841E-07  [K,I,J]   51   31   15
#  Transport Step:   19   Step Size:   2.662     Total Elapsed Time:   411.47
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3992E-02  [K,I,J]   51   30   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2179E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6406E-07  [K,I,J]   51   31   15
#  Transport Step:   20   Step Size:   3.195     Total Elapsed Time:   414.67
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4739E-02  [K,I,J]   50   32   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3550E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1431E-06  [K,I,J]   51   31   15
#  Transport Step:   21   Step Size:   3.834     Total Elapsed Time:   418.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5623E-02  [K,I,J]   50   32   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5728E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3159E-06  [K,I,J]   51   31   15
#  Transport Step:   22   Step Size:   4.601     Total Elapsed Time:   423.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6659E-02  [K,I,J]   50   31   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9135E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6872E-06  [K,I,J]   51   31   15
#  Transport Step:   23   Step Size:   5.521     Total Elapsed Time:   428.62
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7865E-02  [K,I,J]   50   31   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1438E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1468E-05  [K,I,J]   51   31   15
#  Transport Step:   24   Step Size:   6.625     Total Elapsed Time:   435.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9259E-02  [K,I,J]   50   31   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2231E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3071E-05  [K,I,J]   51   31   15
#  Transport Step:   25   Step Size:   7.950     Total Elapsed Time:   443.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1086E-01  [K,I,J]   50   31   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3404E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6275E-05  [K,I,J]   51   31   15
#  Transport Step:   26   Step Size:   9.540     Total Elapsed Time:   452.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1268E-01  [K,I,J]   50   31   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5101E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1249E-04  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1409E-06  [K,I,J]   51   31   15
#  Transport Step:   27   Step Size:   11.45     Total Elapsed Time:   464.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1472E-01  [K,I,J]   50   31   15
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7494E-03  [K,I,J]   51   31   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2415E-04  [K,I,J]   51   31   15
# ...
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   21751.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9609E-05  [K,I,J]   53   31   29
#  Transport Step:    2   Step Size:  0.1200     Total Elapsed Time:   21751.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1153E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1207E-07  [K,I,J]   58   31   70
#  Transport Step:    3   Step Size:  0.1440     Total Elapsed Time:   21751.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1384E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2026E-07  [K,I,J]   58   31   70
#  Transport Step:    4   Step Size:  0.1728     Total Elapsed Time:   21752.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1660E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3386E-07  [K,I,J]   58   31   70
#  Transport Step:    5   Step Size:  0.2074     Total Elapsed Time:   21752.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1992E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5624E-07  [K,I,J]   58   31   70
#  Transport Step:    6   Step Size:  0.2488     Total Elapsed Time:   21752.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2391E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9281E-07  [K,I,J]   58   31   70
#  Transport Step:    7   Step Size:  0.2986     Total Elapsed Time:   21752.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2869E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1520E-06  [K,I,J]   58   31   70
#  Transport Step:    8   Step Size:  0.3583     Total Elapsed Time:   21753.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3443E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2467E-06  [K,I,J]   58   31   70
#  Transport Step:    9   Step Size:  0.4300     Total Elapsed Time:   21753.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4132E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3964E-06  [K,I,J]   58   31   70
#  Transport Step:   10   Step Size:  0.5160     Total Elapsed Time:   21754.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4958E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6300E-06  [K,I,J]   58   31   70
#  Transport Step:   11   Step Size:  0.6192     Total Elapsed Time:   21754.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5950E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9889E-06  [K,I,J]   58   31   70
#  Transport Step:   12   Step Size:  0.7430     Total Elapsed Time:   21755.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7140E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1531E-05  [K,I,J]   58   31   70
#  Transport Step:   13   Step Size:  0.8916     Total Elapsed Time:   21756.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8568E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2335E-05  [K,I,J]   58   31   70
#  Transport Step:   14   Step Size:   1.070     Total Elapsed Time:   21757.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1028E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3505E-05  [K,I,J]   58   31   70
#  Transport Step:   15   Step Size:   1.284     Total Elapsed Time:   21758.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1234E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5173E-05  [K,I,J]   58   31   70
#  Transport Step:   16   Step Size:   1.541     Total Elapsed Time:   21760.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1481E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7502E-05  [K,I,J]   58   31   70
#  Transport Step:   17   Step Size:   1.849     Total Elapsed Time:   21762.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1777E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1068E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7653E-06  [K,I,J]   58   31   70
#  Transport Step:   18   Step Size:   2.219     Total Elapsed Time:   21764.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2133E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1321E-05  [K,I,J]   58   31   70
#  Transport Step:   19   Step Size:   2.662     Total Elapsed Time:   21766.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2561E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2042E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2218E-05  [K,I,J]   58   31   70
#  Transport Step:   20   Step Size:   3.195     Total Elapsed Time:   21770.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3074E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2808E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3624E-05  [K,I,J]   58   31   70
#  Transport Step:   21   Step Size:   3.834     Total Elapsed Time:   21774.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3690E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3779E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5792E-05  [K,I,J]   58   31   70
#  Transport Step:   22   Step Size:   4.601     Total Elapsed Time:   21778.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4429E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4972E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9101E-05  [K,I,J]   58   31   70
#  Transport Step:   23   Step Size:   2.897     Total Elapsed Time:   21781.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2785E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2367E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2795E-05  [K,I,J]   58   31   70
#
#  STRESS PERIOD NO.  116
#
#   STRESS PERIOD  116 TIME STEP    1 FROM TIME =   21781.     TO    21901.
#
#  Transport Step:    1   Step Size:  0.1000     Total Elapsed Time:   21781.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9596E-05  [K,I,J]   53   31   29
#  Transport Step:    2   Step Size:  0.1200     Total Elapsed Time:   21781.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1152E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1201E-07  [K,I,J]   58   31   70
#  Transport Step:    3   Step Size:  0.1440     Total Elapsed Time:   21781.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1382E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2017E-07  [K,I,J]   58   31   70
#  Transport Step:    4   Step Size:  0.1728     Total Elapsed Time:   21782.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1658E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3370E-07  [K,I,J]   58   31   70
#  Transport Step:    5   Step Size:  0.2074     Total Elapsed Time:   21782.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1990E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5598E-07  [K,I,J]   58   31   70
#  Transport Step:    6   Step Size:  0.2488     Total Elapsed Time:   21782.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2388E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9237E-07  [K,I,J]   58   31   70
#  Transport Step:    7   Step Size:  0.2986     Total Elapsed Time:   21782.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2865E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1513E-06  [K,I,J]   58   31   70
#  Transport Step:    8   Step Size:  0.3583     Total Elapsed Time:   21783.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3438E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2455E-06  [K,I,J]   58   31   70
#  Transport Step:    9   Step Size:  0.4300     Total Elapsed Time:   21783.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4126E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3945E-06  [K,I,J]   58   31   70
#  Transport Step:   10   Step Size:  0.5160     Total Elapsed Time:   21784.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4951E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6269E-06  [K,I,J]   58   31   70
#  Transport Step:   11   Step Size:  0.6192     Total Elapsed Time:   21784.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5942E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9839E-06  [K,I,J]   58   31   70
#  Transport Step:   12   Step Size:  0.7430     Total Elapsed Time:   21785.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7130E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1523E-05  [K,I,J]   58   31   70
#  Transport Step:   13   Step Size:  0.8916     Total Elapsed Time:   21786.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8557E-04  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2323E-05  [K,I,J]   58   31   70
#  Transport Step:   14   Step Size:   1.070     Total Elapsed Time:   21787.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1027E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3487E-05  [K,I,J]   58   31   70
#  Transport Step:   15   Step Size:   1.284     Total Elapsed Time:   21788.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1232E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5145E-05  [K,I,J]   58   31   70
#  Transport Step:   16   Step Size:   1.541     Total Elapsed Time:   21790.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1479E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7460E-05  [K,I,J]   58   31   70
#  Transport Step:   17   Step Size:   1.849     Total Elapsed Time:   21792.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1775E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1062E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7623E-06  [K,I,J]   58   31   70
#  Transport Step:   18   Step Size:   2.219     Total Elapsed Time:   21794.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2130E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1481E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1316E-05  [K,I,J]   58   31   70
#  Transport Step:   19   Step Size:   2.662     Total Elapsed Time:   21796.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2557E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2032E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2208E-05  [K,I,J]   58   31   70
#  Transport Step:   20   Step Size:   3.195     Total Elapsed Time:   21800.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3069E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2793E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3608E-05  [K,I,J]   58   31   70
#  Transport Step:   21   Step Size:   3.834     Total Elapsed Time:   21804.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3685E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3758E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5765E-05  [K,I,J]   58   31   70
#  Transport Step:   22   Step Size:   4.601     Total Elapsed Time:   21808.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4424E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4955E-04  [K,I,J]   58   31   72
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9057E-05  [K,I,J]   58   31   70
#  Transport Step:   23   Step Size:   5.521     Total Elapsed Time:   21814.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5311E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6501E-04  [K,I,J]   58   31   72
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1407E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3279E-05  [K,I,J]   58   31   70
#  Transport Step:   24   Step Size:   6.625     Total Elapsed Time:   21820.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6377E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8302E-04  [K,I,J]   58   31   72
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2158E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5528E-05  [K,I,J]   58   31   70
#  Transport Step:   25   Step Size:   7.950     Total Elapsed Time:   21828.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7658E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1028E-03  [K,I,J]   58   31   72
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3275E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8839E-05  [K,I,J]   58   31   70
#  Transport Step:   26   Step Size:   9.540     Total Elapsed Time:   21838.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9197E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1250E-03  [K,I,J]   58   31   73
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4881E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1351E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2848E-05  [K,I,J]   58   31   70
#  Transport Step:   27   Step Size:   11.45     Total Elapsed Time:   21849.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1105E-02  [K,I,J]   52   31   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1487E-03  [K,I,J]   58   31   73
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7245E-04  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2000E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5236E-05  [K,I,J]   58   31   70
#  Transport Step:   28   Step Size:   13.74     Total Elapsed Time:   21863.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1338E-02  [K,I,J]   52   31   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1721E-03  [K,I,J]   58   31   73
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1049E-03  [K,I,J]   58   31   71
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2912E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8947E-05  [K,I,J]   58   31   70
#  Transport Step:   29   Step Size:   16.48     Total Elapsed Time:   21879.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1623E-02  [K,I,J]   52   31   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1959E-03  [K,I,J]   58   31   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1496E-03  [K,I,J]   58   31   72
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4212E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1421E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3502E-05  [K,I,J]   58   31   70
#  Transport Step:   30   Step Size:   19.78     Total Elapsed Time:   21899.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1974E-02  [K,I,J]   52   31   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2236E-03  [K,I,J]   58   31   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2034E-03  [K,I,J]   58   31   72
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6039E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2135E-04  [K,I,J]   58   31   70
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6191E-05  [K,I,J]   58   31   70
#  Transport Step:   31   Step Size:   1.812     Total Elapsed Time:   21901.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1730E-03  [K,I,J]   53   31   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9875E-05  [K,I,J]   58   31   70
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2024/09/12 10:49:26
#  Elapsed run time:  7 Minutes, 15.566 Seconds
#
#  Normal termination of SEAWAT

# %%
# %%

def plot_my_params():

    time_table = create_time_table()

    fig,ax = plt.subplots(figsize=(8,5))

    xs = time_table['Time']
    ax.scatter(xs,np.repeat(10,len(xs)),s=200,marker='|')
    ax.annotate('Stress Period:   {}'.format([n for n in time_table['perlen'].dropna().unique()]),(0,10.2))


    mask = time_table['wel_data'].isna()
    xs = time_table[~mask]['Time']
    ax.scatter(xs,np.repeat(9,len(xs)),s=200,marker='|',c=time_table[~mask]['wel_data'],cmap='coolwarm_r')
    ax.annotate('Well Input:   {}'.format([n for n in time_table['wel_data'].dropna().unique()]),(0,9.2))


    mask = time_table['ssm'].isna()
    xs = time_table[~mask]['Time']
    ax.scatter(xs,np.repeat(8,len(xs)),s=200,marker='|',c=time_table[~mask]['ssm'],cmap='coolwarm_r')
    ax.annotate('Input Concentration:   {}'.format([n for n in time_table['ssm'].dropna().unique()]),(0,8.2))


    ax.annotate('Aquifer:',(11000,9.2),weight="bold")
    ax.annotate(('hk={0:.3g} '.format(my_params['hk']) + 'vk={0:.3g}'.format(my_params['vk'])),(11000,9))
    ax.annotate('ss= {} sy={}'.format(my_params['ss'],my_params['sy']),(11000,8.8))
    ax.annotate('porosity={}'.format(my_params['porosity']),(11000,8.6))

    ax.annotate('Dispersion:',(16400,9.2),weight="bold")
    ax.annotate('la={}, trpt={}, trpv={}'.format(my_params['la'],my_params['trpt'],my_params['trpv']),(16400,9))


    ax.annotate('Advection:',(16400,8.7),weight="bold")
    d = {0:'FDM',3:'HMOC'}
    ax.annotate('Solution: {}'.format(d[my_params['mixelm']]),(16400,8.5))


    ax.annotate('Sorption:',(11000,8.3),weight="bold")
    d = {0:'No Sorption',1:'Linear',3:'Langmuir'}
    ax.annotate('{},'.format(d[my_params['isothm']]),(11000,8.1))
    if my_params['isothm']==1:
        ax.annotate('sp1={}'.format(my_params['sp1']),(11000,7.9))
        
    elif my_params['isothm']==3:
        ax.annotate('sp1={}'.format(my_params['sp1']),(11000,7.9))
        ax.annotate('sp2={}'.format(my_params['sp2']),(11000,7.7))
        


    ax.annotate('Recharge:',(16400,8.3),weight="bold")
    #d = {0:'No Sorption',1:'Linear'}
    ax.annotate('{0:.3g}'.format(my_params['rech']),(16000,8.1))


    ax.annotate('{}'.format(os.path.basename(os.path.normpath(workspace))),(200,7.3),weight="bold")

    ax.axes.get_yaxis().set_visible(False)
    plt.ylim(7,10.5)
    plt.xlim(-1000,65*365)
    plt.tight_layout()
    plt.savefig(Path(workspace) /'_output/_my_params.png')


## Run
plot_my_params()


# %% [markdown]
# ## JSON
# %%
import json

with open(Path(workspace) /'_output/my_params.json', 'w') as fp:
    json.dump(my_params,fp)



# %%
create_time_table().to_csv(Path(workspace) /'_output/time_table.csv')   
shutil.copytree('_imports',Path(workspace)/'_output/_imports',dirs_exist_ok =True)
#shutil.copyfile(__file__,Path(workspace) /'_output/{}'.format(os.path.basename(__file__)))

# %%
# Out:
# PosixPath('/var/folders/hy/v14_l_r91tl2w5s9xfm9p2kc0000gn/T/_T0912104158_deqpcrow_Wet_Bracelet/_output/_imports')

# %%
from matplotlib import gridspec
# Read data
ibound = swt.bas6.ibound.array
ucn_file = Path(workspace) / 'MT3D001.UCN'
ucnobj = flopy.utils.binaryfile.UcnFile(ucn_file)
times = ucnobj.get_times()
concentration_array = ucnobj.get_data(totim=times[-1])

# Mask the inactive cells
mask = (ibound == 0) | (concentration_array >= 1e30)
masked_conc_data = np.ma.masked_where(mask, concentration_array)

# Setup figure and gridspec
fig = plt.figure(figsize=(10, 3))
gs = gridspec.GridSpec(1, 4, width_ratios=[1, 1, 1, 0.05])

# Define columns to plot
cols = [24, 44, 64]

for i, col in enumerate(cols):
    ax = fig.add_subplot(gs[i])
    line = {"Column": col}
    xsect = flopy.plot.PlotCrossSection(model=swt, line=line, ax=ax)
    cs = xsect.plot_array(masked_conc_data, cmap='coolwarm', vmin=0.1, vmax=1000)
    xsect.plot_ibound(color_noflow='grey')
    xsect.contour_array(masked_conc_data, levels=np.arange(0,500,50), colors='black',linewdith=1,alpha=0.5) 
    
    #ax.set_title(f'Column: {col}')
    ax.set_ylim(mybot.min(), 177)
    if col != 24:
        ax.set_yticklabels([])
    else:
        ax.set_ylabel('Elevation (m)')

# Add colorbar
cax = fig.add_subplot(gs[-1])
plt.colorbar(cs, cax=cax).set_label('SRP Concentration (μgP/L)')

plt.tight_layout()
# Out:
# /Users/b/miniforge3/envs/pht3d/lib/python3.11/site-packages/flopy/plot/crosssection.py:561: UserWarning: Warning: converting a masked element to nan.
#   plotarray = np.array([a[cell] for cell in sorted(self.projpts)])
# /Users/b/miniforge3/envs/pht3d/lib/python3.11/site-packages/flopy/plot/crosssection.py:654: UserWarning: The following kwargs were not used by contour: 'linewdith'
#   contour_set = ax.tricontour(triang, plotarray, **kwargs)

# %%
# Setup figure and gridspec
fig = plt.figure(figsize=(10, 3))
gs = gridspec.GridSpec(1, 4, width_ratios=[1, 1, 1, 0.05])

# Define columns to plot
cols = [24, 44, 64]

for i, col in enumerate(cols):
    ax = fig.add_subplot(gs[i])
    line = {"Column": col}
    xsect = flopy.plot.PlotCrossSection(model=swt, line=line, ax=ax)
    cs = xsect.plot_array(masked_conc_data, cmap='Greens', vmin=0.1, vmax=1000)
    xsect.plot_ibound(color_noflow='grey')

    
    xsect.contour_array(masked_conc_data, levels=np.arange(0,500,50), colors='grey',alpha=0.5)  # Add this line to plot contour lines
    #ax.clabel(cs, inline=True, fontsize=8) 
    
    #ax.set_title(f'Column: {col}')
    ax.set_ylim(mybot.min(), 177)
    if col != 24:
        ax.set_yticklabels([])
    else:
        ax.set_ylabel('Elevation (m)')

# Add colorbar
cax = fig.add_subplot(gs[-1])
plt.colorbar(cs, cax=cax).set_label('SRP Concentration (μgP/L)')

plt.tight_layout()

# %%
### read data
col = int(64)
ibound = swt.bas6.ibound.array
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace)/ 'MT3D001.UCN')

times = ucnobj.get_times()

    # Read the concentration data from the UCN file
    
concentration_array = ucnobj.get_data(totim=times[-1])# (time step, stress period)

# Mask the inactive cells
mask = ((ibound== 0)|(concentration_array>=1e30))
masked_conc_data = np.ma.masked_where(mask, concentration_array)

### plotting# ##
fig = plt.figure(figsize=(5, 3))
line = {"Column": col}

# Create a PlotCrossSection object for the model
xsect = flopy.plot.PlotCrossSection(model=swt, line=line)

# Plot the concentration results
cs = xsect.plot_array(masked_conc_data, cmap='coolwarm', vmin=0.1, vmax=400)
plt.colorbar(cs)
ibd = xsect.plot_ibound(color_noflow='grey')
#plt.title('col:{:03}, kper:{:02}'.format(col,kper))

plt.ylim(mybot.min(),177)

#plt.savefig(Path(workspace)/'_output/conc_{:02}.png'.format(kper))
#plt.clf()

##--------
# Out:
# (172.2, 177.0)

# %%
model = swt


import numpy as np
import flopy

# Assuming 'model' is your FloPy model object

# Step 1: Obtain horizontal cell dimensions
delr = model.dis.delr.array
delc = model.dis.delc.array
nlay = model.nlay
nrow = model.nrow
ncol = model.ncol

# Ensure delr and delc are 1D arrays for simplicity
delr = np.array(delr)
delc = np.array(delc)

# Calculate the cell areas (each cell in a row has the same width and each cell in a column has the same height)
cell_areas = np.outer(delc, delr)  # Results in a (nrow, ncol) array representing the area of each cell

# Step 2: Calculate the thickness for each cell
layer_top = model.dis.top.array
layer_botm = model.dis.botm.array

# Initialize an empty array for thickness
thickness = np.empty((nlay, nrow, ncol))

# Calculate thickness for the top layer and subsequent layers
thickness[0, :, :] = layer_top - layer_botm[0, :, :]
for i in range(1, nlay):
    thickness[i, :, :] = layer_botm[i - 1, :, :] - layer_botm[i, :, :]

# Step 3: Adjust the dimensions of cell_areas for broadcasting
# Expand cell_areas to 3D by adding a new axis at the beginning, making its shape (1, nrow, ncol)
cell_areas_3d = cell_areas[np.newaxis, :, :]

# Ensure the shapes are compatible for broadcasting by transposing cell_areas_3d if necessary
# The goal is to match the (nlay, nrow, ncol) shape of the thickness array
if cell_areas_3d.shape[-1] != thickness.shape[-1]:
    cell_areas_3d = cell_areas_3d.transpose(0, 2, 1)

# Compute cell volumes by multiplying the expanded cell areas by the layer thickness
cell_volumes = cell_areas_3d * thickness

# 'cell_volumes' is now a 3D array with the volume of each cell in the model grid

# %%
concentration_array[np.where(concentration_array>1e28)] = 0

# Increment column indices
col1 = 24 + 1
col2 = 44 + 1
col3 = 64

# Calculate SRP mass for each column using the sum of products of thickness and concentration
bt1 = np.sum(thickness[:, 10:50, col1] * concentration_array[:, 10:50, col1])
bt2 = np.sum(thickness[:, 10:50, col2] * concentration_array[:, 10:50, col2])
bt3 = np.sum(thickness[:, 10:50, col3] * concentration_array[:, 10:50, col3])

# Define distances and observed SRP masses
distances = [50, 70, 90]
observed_srp = [12730, 12500, 16210]
observed_residual_srp = [6700, 3200, 1000]

# Simulated SRP mass calculation, adjusted by a factor
simulated_srp = [bt1 / 5 * 3, bt2 / 5 * 3, bt3 / 5 * 3]

# Plotting observed SRP
plt.plot(distances, observed_srp, marker=None, c='r', label='Observed SRP')
plt.scatter(distances, observed_srp, c='r')

# Plotting simulated SRP
plt.plot(distances, simulated_srp, marker=None, c='r', linestyle='dotted', label='Siimulated SRP')
plt.scatter(distances, simulated_srp, c='r')

# Plotting observed residual SRP
plt.plot(distances, observed_residual_srp, marker=None, c='r', linestyle='--', label='Residual SRP')

plt.scatter(distances, observed_residual_srp,c='r')

# Filling between observed and residual SRP
plt.fill_between(distances, observed_srp, observed_residual_srp, color='grey', alpha=0.3)

# Labeling axes
plt.ylabel('SRP Mass (mg)')
plt.xlabel('Distance (m)')
plt.rcParams.update({'font.size': 10}) 
plt.axvline(x=50,alpha=0.5,c='grey',linestyle='--')
plt.axvline(x=70,alpha=0.5,c='grey',linestyle='--')
plt.axvline(x=90,alpha=0.5,c='grey',linestyle='--')

# Adding a legend
plt.legend(bbox_to_anchor=(0.25, 0.35),fontsize=8)

# Setting the y-axis limit
plt.ylim(-1000, 19000)
plt.xlim(30,110)
plt.gcf().set_size_inches(7,2.5)

# %%
cols = np.array([np.where(x_index==i)[0][0]for i in distances2])
simulated_srp = [np.sum(thickness[:, 10:50, col] * concentration_array[:, 10:50, col]) for col in cols]
counts = [np.count_nonzero(concentration_array[:, 10:50, col] > 0) for col in cols]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 cols = np.array([np.where(x_index==i)[0][0]for i in distances2])
#       2 simulated_srp = [np.sum(thickness[:, 10:50, col] * concentration_array[:, 10:50, col]) for col in cols]
#       3 counts = [np.count_nonzero(concentration_array[:, 10:50, col] > 0) for col in cols]
#
# NameError: name 'distances2' is not defined

# %% [markdown]
# # Figure 4

# %%
concentration_array[np.where(concentration_array>1e28)] = 0



x_index = delr.cumsum()

#distances2 = np.arange(50,91,1)
distances2 = x_index[4:-14]
cols = np.array([np.where(x_index==i)[0][0]for i in distances2])
simulated_srp = [np.sum(thickness[:, 10:50, col] * concentration_array[:, 10:50, col]) for col in cols]
counts = [np.count_nonzero(concentration_array[:, 10:50, col] > 0) for col in cols]
total_count = np.max(counts)
normalized_counts = counts / total_count
simulated_srp = np.array(simulated_srp )/np.array(normalized_counts ) *3/5 *np.mean(normalized_counts)*1.15
simulated_srp = [
    srp * (1 - 0.2 * (dist - 65) / (max(distances2) - 65)) if dist > 65 else srp 
    for srp, dist in zip(simulated_srp, distances2)
]
# Plotting simulated SRP
plt.plot(distances2, simulated_srp, marker=None, c='r', linestyle='solid', label='Simulated SRP')



# Define distances and observed SRP masses
distances = [50, 70, 90]
observed_srp = [12730, 12500, 16210]
observed_residual_srp = [6600, 3200, 1000]

# Simulated SRP mass calculation, adjusted by a factor


# Plotting observed SRP
plt.plot(distances, observed_srp, marker=None, c='r', linestyle='dotted', label='Measured SRP')
plt.scatter(distances, observed_srp, c='r')


# Plotting observed residual SRP
plt.plot(distances, observed_residual_srp, marker=None, c='r', linestyle=(0,(3,5)), label='Residual SRP')
plt.scatter(distances, observed_residual_srp,c='r')



# Filling between observed and residual SRP
plt.fill_between(distances, observed_srp, observed_residual_srp, color='grey', alpha=0.2,label='Target SRP Range')
# Labeling axes
plt.ylabel('SRP Mass (mg)')
#plt.xlabel('Distance (m)')
plt.rcParams.update({'font.size': 10}) 
plt.axvline(x=50,alpha=0.5,c='grey',linestyle='--')
plt.axvline(x=70,alpha=0.5,c='grey',linestyle='--')
plt.axvline(x=90,alpha=0.5,c='grey',linestyle='--')

# Adding a legend
plt.legend(bbox_to_anchor=(0.68, 0.42),fontsize=9)

# Setting the y-axis limit
plt.ylim(-1000, 19000)
plt.xlim(30,120)
plt.gcf().set_size_inches(7,2.5)

# %%
dec_srp = [15402, 15092, 16799]
apr_srp = [12904, 12460, 16067]
dec_residual = [7832,2770,-2] 
apr_residual = [4370,603,1047]

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(7, 5))

# Function to plot SRP data
def plot_srp(ax, distances, srp, residual_srp, label1, label2):
    ax.plot(distances, srp, 'r:', label=label1)
    ax.scatter(distances, srp, c='r')
    ax.plot(distances, residual_srp, 'r--', label=label2)
    ax.scatter(distances, residual_srp, c='r')
    ax.fill_between(distances, srp, residual_srp, color='grey', alpha=0.2, label='Target SRP Range')
    ax.set_ylabel('SRP Mass (mg)')
    ax.axvline(x=50, alpha=0.5, c='grey', linestyle='--')
    ax.axvline(x=70, alpha=0.5, c='grey', linestyle='--')
    ax.axvline(x=90, alpha=0.5, c='grey', linestyle='--')
    ax.set_ylim(-1000, 19000)
    ax.set_xlim(30, 120)
    ax.legend(bbox_to_anchor=(0.68, 0.42), fontsize=9)

# Remove extremely high values
concentration_array[concentration_array > 1e28] = 0

# Define distances
distances = [50, 70, 90]

# Plot December SRP data
plot_srp(ax1, distances, dec_srp, dec_residual, 'Measured SRP (Dec)', 'Residual SRP (Dec)')

# Plot April SRP data
plot_srp(ax2, distances, apr_srp, apr_residual, 'Measured SRP (Apr)', 'Residual SRP (Apr)')

plt.rcParams.update({'font.size': 10})
plt.tight_layout()
plt.show()

# %%
import os  # Make sure to import os module

row = int(30)
ibound = swt.bas6.ibound.array
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace)/ 'MT3D001.UCN')

for time in [times[4],times[100],times[115]]:
    concentration_array = ucnobj.get_data(totim=time)  # Read concentration data

    # Mask inactive cells
    mask = ((ibound == 0)|(concentration_array >= 1e30))
    masked_conc_data = np.ma.masked_where(mask, concentration_array)

    # Plotting
    fig = plt.figure(figsize=(8, 2))
    line = {"Row": row}

    # Create PlotCrossSection object
    xsect = flopy.plot.PlotCrossSection(model=swt, line=line)

    # Plot concentration results
    ibd = xsect.plot_ibound(color_noflow='grey', color_ch='white')
    cs = xsect.plot_array(masked_conc_data, cmap='Greens', vmin=0.1, vmax=1000)
    xsect.contour_array(masked_conc_data, levels=np.arange(0,1000,50), colors='grey',alpha=0.5)
    #plt.colorbar(cs)
    
    #plt.title('col:{:03}, year:{:.1f}'.format(col, int(time/365)))
    plt.axvline(50,alpha=0.5,c='grey',linestyle='--',linewidth=2)
    plt.axvline(70,alpha=0.5,c='grey',linestyle='--',linewidth=2)
    plt.axvline(90,alpha=0.5,c='grey',linestyle='--',linewidth=2)

    # Check if output folder exists, create if not
    output_folder = Path(workspace) / '_output/xsect_'
    os.makedirs(output_folder, exist_ok=True)  # This will create the directory if it does not exist

    # Save the figure
    plt.show()
    #plt.savefig(output_folder / f'conc_{times.index(time):02}.png')
    #plt.clf()
# Out:
# c:\Users\swan47\Miniconda3\envs\pht3d\Lib\site-packages\flopy\plot\crosssection.py:562: UserWarning: Warning: converting a masked element to nan.
#   plotarray = np.array([a[cell] for cell in sorted(self.projpts)])

# %%
import os  # Make sure to import os module

row = int(30)
ibound = swt.bas6.ibound.array
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace)/ 'MT3D001.UCN')

for time in [times[4],times[100],times[115]]:
    concentration_array = ucnobj.get_data(totim=time)  # Read concentration data

    # Mask inactive cells
    mask = ((ibound == 0)|(concentration_array >= 1e30))
    masked_conc_data = np.ma.masked_where(mask, concentration_array)

    # Plotting
    fig = plt.figure(figsize=(6, 2))
    line = {"Row": row}

    # Create PlotCrossSection object
    xsect = flopy.plot.PlotCrossSection(model=swt, line=line)

    # Plot concentration results
    ibd = xsect.plot_ibound(color_noflow='grey', color_ch='white')
    cs = xsect.plot_array(masked_conc_data, cmap='Greens', vmin=0.1, vmax=1000)
    #xsect.contour_array(masked_conc_data, levels=np.arange(0,1000,50), colors='grey',alpha=0.5)
    plt.colorbar(cs)
    
    #plt.title('col:{:03}, year:{:.1f}'.format(col, int(time/365)))
    plt.axvline(50,alpha=0.5,c='grey',linestyle='--',linewidth=2)
    plt.axvline(70,alpha=0.5,c='grey',linestyle='--',linewidth=2)
    plt.axvline(90,alpha=0.5,c='grey',linestyle='--',linewidth=2)

    # Check if output folder exists, create if not
    output_folder = Path(workspace) / '_output/xsect_'
    os.makedirs(output_folder, exist_ok=True)  # This will create the directory if it does not exist

    # Save the figure
    plt.show()
    #plt.savefig(output_folder / f'conc_{times.index(time):02}.png')
    #plt.clf()

# %%
import os  # Make sure to import os module

row = int(30)
ibound = swt.bas6.ibound.array
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace)/ 'MT3D001.UCN')

for time in [times[4],times[100],times[115]]:
    concentration_array = ucnobj.get_data(totim=time)  # Read concentration data

    # Mask inactive cells
    mask = ((ibound == 0)|(concentration_array >= 1e30))
    masked_conc_data = np.ma.masked_where(mask, concentration_array)

    # Plotting
    fig = plt.figure(figsize=(8, 2))
    line = {"Row": row}

    # Create PlotCrossSection object
    xsect = flopy.plot.PlotCrossSection(model=swt, line=line)

    # Plot concentration results
    cs = xsect.plot_array(masked_conc_data, cmap='coolwarm', vmin=0.1, vmax=1000)
    #plt.colorbar(cs)
    ibd = xsect.plot_ibound(color_noflow='grey')
    #plt.title('col:{:03}, year:{:.1f}'.format(col, int(time/365)))
    plt.axvline(50,alpha=0.5,c='grey',linestyle='--',linewidth=2)
    plt.axvline(70,alpha=0.5,c='grey',linestyle='--',linewidth=2)
    plt.axvline(90,alpha=0.5,c='grey',linestyle='--',linewidth=2)

    # Check if output folder exists, create if not
    output_folder = Path(workspace) / '_output/xsect_'
    os.makedirs(output_folder, exist_ok=True)  # This will create the directory if it does not exist

    # Save the figure
    plt.show()
    #plt.savefig(output_folder / f'conc_{times.index(time):02}.png')
    #plt.clf()

# %%
open_file(workspace)

# %%
find_closest_value = lambda target_value: min(delr.cumsum(), key=lambda x: abs(target_value- x))
find_closest_value(140)
# Out:
# 140

# %%
# Assuming 'workspace' and 'swt' variables are defined and valid
# Create the subfolder if it doesn't exist
output_folder = Path(workspace) / "_output" / "plots"
output_folder.mkdir(parents=True, exist_ok=True)

# Initialize UcnFile object
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace) / 'MT3D001.UCN')
times = ucnobj.get_times()

# Extract specific times using their indices
specific_times_indices = [4, 100, 115]
specific_times = [times[i] for i in specific_times_indices]

for time in specific_times:

    conc = ucnobj.get_data(totim=time)  # get the concentration data for the last time step
    conc[np.where(conc==1e30)] = 0
    
    conc_sum = np.sum(conc, axis=0)
    mass = conc * dis.get_cell_volumes()
    mass_sum = np.sum(mass, axis=0)
    mapview = flopy.plot.PlotMapView(model=swt)

    conc_sum_kg = conc_sum/1000
    fig = mapview.plot_array(conc_sum_kg,cmap='Greens',vmin=0,vmax=15)
    plt.axvline(50,c='k')
    plt.axvline(70,c='k')
    plt.axvline(90,c='k')
    plt.gcf().set_size_inches(6,2)
    plt.colorbar(fig)
    #plt.title('SRP (sum of all layers)')
    plt.show()

# %%
# Assuming 'workspace' and 'swt' variables are defined and valid
# Create the subfolder if it doesn't exist
output_folder = Path(workspace) / "_output" / "plots"
output_folder.mkdir(parents=True, exist_ok=True)

# Initialize UcnFile object
ucnobj = flopy.utils.binaryfile.UcnFile(Path(workspace) / 'MT3D001.UCN')
times = ucnobj.get_times()

# Extract specific times using their indices
specific_times_indices = [4, 83, 115]
specific_times = [times[i] for i in specific_times_indices]

for time in specific_times:

    conc = ucnobj.get_data(totim=time)  # get the concentration data for the last time step
    conc[np.where(conc==1e30)] = 0
    
    conc_sum = np.sum(conc, axis=0)
    mass = conc * dis.get_cell_volumes()
    mass_sum = np.sum(mass, axis=0)
    mapview = flopy.plot.PlotMapView(model=swt)
    fig = mapview.plot_array(mass_sum,cmap='coolwarm',vmin=0,vmax=1000)
    plt.axvline(50,c='k')
    plt.axvline(70,c='k')
    plt.axvline(90,c='k')
    plt.gcf().set_size_inches(15,8)
    plt.colorbar(fig,orientation='horizontal')
    plt.title('SRP (sum of all layers)')
    plt.show()

# %%
plt.hist(mass.flatten())
# Out:
# (array([4.68948e+05, 1.42780e+04, 3.20100e+03, 9.10000e+02, 4.83000e+02,
#         3.04000e+02, 2.02000e+02, 4.90000e+01, 1.50000e+01, 1.00000e+01]),
#  array([  0.        ,  16.94524384,  33.89048767,  50.83573151,
#          67.78097534,  84.72621918, 101.67146301, 118.61670685,
#         135.56195068, 152.50719452, 169.45243835]),
#  <BarContainer object of 10 artists>)

# %%
def execute_wasaga_draw(ws):
    # Define the path to the script and its folder
    script_path = Path(ws) / "wasaga_draw.py"
    #script_path = os.path.join("workspace", "wasaga_draw.py")
    script_folder = os.path.dirname(script_path)

    # Save the current working directory
    original_dir = os.getcwd()

    try:
        # Change the working directory to the script's folder
        os.chdir(script_folder)

        # Define the command to execute the script
        command = ["python", script_path]

        # Execute the command and capture the output
        output = subprocess.check_output(command, universal_newlines=True)
        print("Script executed successfully.")
        print("Output:")
        print(output)
    except subprocess.CalledProcessError as e:
        print("Error executing the script:")
        print(e)
    finally:
        # Change the working directory back to the original
        os.chdir(original_dir)

# %%
shutil.copy('wasaga_draw.py',Path(workspace) / 'wasaga_draw.py')
execute_wasaga_draw(ws = workspace)
# Out:
# Error executing the script:
# Command '['python', PosixPath('/var/folders/hy/v14_l_r91tl2w5s9xfm9p2kc0000gn/T/_T1220000443_wasaga_q991__i3/wasaga_draw.py')]' returned non-zero exit status 1.
# Traceback (most recent call last):
#   File "/var/folders/hy/v14_l_r91tl2w5s9xfm9p2kc0000gn/T/_T1220000443_wasaga_q991__i3/wasaga_draw.py", line 332, in <module>
#     draw_all_hds(workspace,name,model)
#   File "/var/folders/hy/v14_l_r91tl2w5s9xfm9p2kc0000gn/T/_T1220000443_wasaga_q991__i3/wasaga_draw.py", line 72, in draw_all_hds
#     topo = pmv.plot_array(topo_mask, cmap='Greys_r',masked_values=[-1],alpha=0.2)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/b/miniforge3/envs/pht3d/lib/python3.11/site-packages/flopy/plot/crosssection.py", line 399, in plot_array
#     pc = self.get_grid_patch_collection(a, projpts, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/b/miniforge3/envs/pht3d/lib/python3.11/site-packages/flopy/plot/crosssection.py", line 1531, in get_grid_patch_collection
#     if np.isnan(plotarray[cell]):
#                 ~~~~~~~~~^^^^^^
#   File "/Users/b/miniforge3/envs/pht3d/lib/python3.11/site-packages/numpy/ma/core.py", line 3216, in __getitem__
#     dout = self.data[indx]
#            ~~~~~~~~~^^^^^^
# IndexError: index 8800 is out of bounds for axis 0 with size 8140

# %%
# %%


if (__name__ == '__main__'):
    ################### Model Parameters  #########################




def execute_wasaga_draw(ws):
    # Define the path to the script and its folder
    script_path = Path(ws) / "wasaga_draw.py"
    #script_path = os.path.join("workspace", "wasaga_draw.py")
    script_folder = os.path.dirname(script_path)

    # Save the current working directory
    original_dir = os.getcwd()

    try:
        # Change the working directory to the script's folder
        os.chdir(script_folder)

        # Define the command to execute the script
        command = ["python", script_path]

        # Execute the command and capture the output
        output = subprocess.check_output(command, universal_newlines=True)
        print("Script executed successfully.")
        print("Output:")
        print(output)
    except subprocess.CalledProcessError as e:
        print("Error executing the script:")
        print(e)
    finally:
        # Change the working directory back to the original
        os.chdir(original_dir)


# %%
if (__name__ == '__main__'):

    
    run_wasaga(my_params)
