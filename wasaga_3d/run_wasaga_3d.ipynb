# %%
import flopy
import numpy as np
import matplotlib.pyplot as plt
import shutil
from pathlib import Path

from datetime import datetime
from tempfile import TemporaryDirectory
from tempfile import mkdtemp

import os
import platform
import subprocess
from shapely.geometry import Polygon, Point
from scipy.interpolate import make_interp_spline

# %%
def locate_ground_surface_lay(row=150):
    cross_section = ibound[:,:,0]
    lay = np.where(cross_section[:,row]==1)[0][0]
    return lay

def meter_to_col(col_meter):
    return int(np.round(col_meter/delc,0))

def meter_to_row(row_meter):
    return int(np.round(row_meter/delc,0))

def meter_to_lay(lay_meter):
    return int(np.round((top_elev-lay_meter)/layer_thickness,0))

def col_to_meter(col):
    return col*delc

def row_to_meter(row):
    return row*delc

def lay_to_meter(row):
    return 190.0-row*layer_thickness

# %%
def change_array_within_polygon(array, row_coords, col_coords, value):

    # Create a polygon object from the row and column coordinates
    polygon = Polygon(zip(col_coords, row_coords))

    # Create a boolean mask indicating which points fall within the polygon
    mask = np.zeros_like(array, dtype=bool)
    for row in range(array.shape[0]):
        for col in range(array.shape[1]):
            point = Point(col, row)
            if polygon.contains(point) or polygon.intersects(point):
                mask[row, col] = True

    # Set the values of the array that fall within the polygon to the new value
    array[mask] = value

    return array

# %% [markdown]
# # Workspace

# %%
# Define model workspace

myt = datetime.now().strftime('%m%d%H%M%S')
name = 'wasaga'
temp_dir = mkdtemp(prefix='_T{}_{}_'.format(myt,name))
os.makedirs(Path(temp_dir) / '_output')

#model_ws = "./modflow_model_2"
model_ws = temp_dir

def open_file(path):
    if platform.system() == "Windows":
        os.startfile(path)
    elif platform.system() == "Darwin":
        subprocess.Popen(["open", path])
    else:
        subprocess.Popen(["xdg-open", path])

open_file(model_ws)

# %% [markdown]
# # Model

# %%
# # Create a MODFLOW model instance
# model = flopy.modflow.Modflow(modelname="example_model",version='mf2005',
#                               exe_name='mf2005', 
#                               model_ws=model_ws)

# %%
# Create a MODFLOW model instance
model = flopy.seawat.Seawat(modelname="example_model",
                            exe_name='swtv4', 
                              model_ws=model_ws)

# %% [markdown]
# # DIS

# %%
# Define model dimensions
nlay = int(60 * 2)
nrow = int(220 * 1)
ncol = int(220 * 1)
delr = 2200/nrow  # Cell width along rows (extend 2200 / 220)
delc = 2200/ncol  # Cell width along columns (extend 2200 / 220)

# Define top elevation
layer_thickness = 30.0 / nlay

top_elev = 190.0
botm_elev = [top_elev - (i * layer_thickness) for i in range(1, nlay + 1)]
# Define layer thickness (uniform thickness)


perlen = 365
nper = int(70)

steady = np.append(np.array([True]),np.repeat(False,nper-1))
#steady=[False,False,True]
#steady = True

# Create DIS package

# %%
dis = flopy.modflow.ModflowDis(model, nlay=nlay, nrow=nrow, ncol=ncol, 
                               delr=delr, delc=delc,top=top_elev, 
                               botm=botm_elev,
                               nper = nper, perlen = perlen,
                               nstp = 1, steady = steady)

# %% [markdown]
# # Ibound

# %%
x = np.array([0, 100, 340, 600, 750, 850, 1100, 1350, 1450, 1530, 1650, 1750, 1850, 2050, 2200])
y_topo = np.array([190,190,187,184,184,184,183,182,179,175.5,175,173.8,173.5,172,171])#topo
y_clay = np.array([185,184,180,175,174,174,173,170,169,168.5,167.5,166.8,166.5,165,164]) #clay


# Interpolate the data using smoothing splines
spl = make_interp_spline(x, y_topo)
x_smooth_topo = np.linspace(x.min(), x.max(), 30)
y_smooth_topo = spl(x_smooth_topo)

col_coords = (x_smooth_topo/delr).round(0)
col_coords_topo = list(col_coords) +[nrow,0]

row_coords = ((top_elev - y_smooth_topo)/layer_thickness).round(0)
row_coords_topo  =  list(row_coords) +[0,0]



# Interpolate the data using smoothing splines
spl = make_interp_spline(x, y_clay)
x_smooth = np.linspace(x.min(), x.max(), 30)
y_smooth = spl(x_smooth)

col_coords = (x_smooth/delr).round(0)
col_coords_clay = list(col_coords) +[nrow,0]
row_coords = ((top_elev - y_smooth)/layer_thickness).round(0)
row_coords_clay  =  list(row_coords) +[nlay,nlay]

# %% [markdown]
# # Ibound & Strt

# %%
# Define ibound and initial conditionsa
ibound = np.ones((nlay, nrow, ncol), dtype=int)
initial_head = np.full((nlay, nrow, ncol), 200.0, dtype=float)

# Set constant head boundary conditions for the first and last rows
array = change_array_within_polygon(ibound, row_coords_topo, col_coords_topo, 0)
plt.scatter(col_coords_topo,row_coords_topo,c='r')


array = change_array_within_polygon(ibound, row_coords_clay, col_coords_clay, 0)
plt.scatter(col_coords,row_coords,c='r')

for c in range(0,2):
    i = np.where(ibound[:,c,-1]==1)[0][-1]
    head = top_elev-i*layer_thickness
    #print('head {}'.format(head))
    
    while head<187:
        ibound[i,c,:] = -1
        #print(i,c)
        #initial_head[i,c,:] = head+0.5
        print(head)
        initial_head[i,c,:] = 187
        head+=layer_thickness
        i-=1


lay = np.where(ibound[:,int(1700/delr),-1])[0][0]
elv = lay_to_meter(lay)
head = elv

for c in range(int(1700/delr),int(2200/delr)):
    lay = np.where(ibound[:,c,-1]==1)[0][0]
    #print(lay,lay_to_meter(lay))
    ibound[lay,c,:] = -1
    initial_head[lay,c,:] = elv




# Your existing code
im = plt.imshow(ibound[:,:,2], origin='upper', aspect=1)
plt.axvline(x=meter_to_col(1700))# shoreline
plt.gcf().set_size_inches(15,10)

# Set the y-axis tick positions and labels
#plt.yticks([0, 10,20, 30,40, 50,60], ['190m (0L)','185m (10L)', '180m (20L)','175m (30L)', '170m (40L)', '165m (50L)','160m (60L)'])

# Add a horizontal colorbar
cbar = plt.colorbar(im, orientation='horizontal')
cbar.ax.tick_params(labelsize=16)
cbar.set_label('Colorbar Label', fontsize=16)

# Display the plot
plt.title('ibound')
plt.grid()
plt.show()


fig, ax = plt.subplots(figsize=(15, 10))
im = ax.imshow(initial_head[:, :, 0], origin='upper')

# Add a horizontal colorbar
cbar = plt.colorbar(im, orientation='horizontal')
cbar.ax.tick_params(labelsize=18)
plt.title('initial head')
plt.show()
# Out:
# 185.25
# 185.5
# 185.75
# 186.0
# 186.25
# 186.5
# 186.75
# 185.0
# 185.25
# 185.5
# 185.75
# 186.0
# 186.25
# 186.5
# 186.75

# %% [markdown]
# # BAS LPF  PCG

# %%
# Create BAS package
bas = flopy.modflow.ModflowBas(model, ibound=ibound, strt=initial_head)

# Define hydraulic properties
horizontal_k = 2.3  # Horizontal hydraulic conductivity (m/day)
vertical_ka = 0.1   # Vertical hydraulic conductivity (m/day)
porosity = 0.25     # Porosity

# Create LPF package (Layer Property Flow package)
lpf = flopy.modflow.ModflowLpf(model, hk=horizontal_k, 
                               vka=vertical_ka, laytyp=1, 
                               ipakcb=None,ss=0.0002,sy=0.33,
                               laywet=1,iwetit=1,wetfct=0.1,ihdwet=1)

# #ss=0.0002,sy=0.33
# upw = flopy.modflow.ModflowUpw(model, laytyp=1, hk=horizontal_k)

pcg = flopy.modflow.ModflowPcg(model, hclose=1e-3,npcond=1,
                               relax=0.99,rclose=1e-3,mutpcg=0,nbpol=1,iprpcg=1)

# %% [markdown]
# # Heterogeneity

# %%
# hk_mean = 2.3  # mean hydraulic conductivity
# hk_std = 2  # standard deviation of hydraulic conductivity
# hk= np.random.normal(hk_mean, hk_std, size=[nlay,nrow,ncol])
# hk[np.where(hk<0)]=0.001

# model.lpf.hk = hk

# %%
# hk_mean = np.log10(2.3)  # mean hydraulic conductivity
# hk_std = 0.4  # standard deviation of hydraulic conductivity
# hk= np.random.normal(hk_mean, hk_std, size=[nlay,nrow,ncol])
# hk = 10**hk
# #hk[np.where(hk<0)]=0.001
# hk.mean()
# model.lpf.hk = hk

# %%
# plt.hist(hk.flatten(),bins=np.linspace(0,30,50))
# plt.show()

# plt.imshow(hk[0,:,:])
# plt.show()

# %% [markdown]
# # DRN

# %%
locate_ground_surface_lay(meter_to_row(160))
#drn_cell = [(0, 150, 28), -10, 100]

beach_drns = np.arange(1520,1600+1,delr).astype(int)
river_drns = np.arange(595,605+1,delr).astype(int)

drn_list = []
drn_ys= list(beach_drns)+list(river_drns)

for y in drn_ys:
   row = meter_to_row(y)
   lay = locate_ground_surface_lay(row=row)
   elv = lay_to_meter(lay)
   #print(lay)
   for col in range(ncol):

      drn_list.append([lay, row, col, elv, 100])
      #drn_list.append([12*2, meter_to_row(600), col, 184.0-0.5, 100])
      
drn_cell = {0:drn_list} 

#drn_cell={0:[[31, 160, 0, 174.5-0.5, 0],[12, 60, 0, 184.0-0.5, 0]]}
drn = flopy.modflow.ModflowDrn(model=model, stress_period_data=drn_cell,)

# %%
lays_with_drn = np.unique([i[0] for i in drn.stress_period_data.data[0]])
for lay in lays_with_drn:
    pmv = flopy.plot.PlotMapView(model=model, layer=lay)
    pmv.plot_bc('DRN',color='r')

# %% [markdown]
# # BTN ICBOUND

# %%
icbund = np.full((nlay, nrow, ncol),0, dtype=float)
icbund = ibound.copy()

btn = flopy.mt3d.Mt3dBtn(
    model,
    nprs=5,
    timprs=np.cumsum([200]*7),
    prsity=0.25,
    sconc= 0.1, # starting concentration
    ifmtcn=0, chkmas=False, nprobs=10, nprmas=10,
    dt0=5,  # The user-specified initial 
    ttsmult=1.4,
    mxstrn = 50000,
    icbund = icbund
)

# %%
adv = flopy.mt3d.Mt3dAdv(model, mixelm=0,percel=0.4,mxpart=50000000,nadvfd=0)
dsp = flopy.mt3d.Mt3dDsp(model, al=0.2, trpt=0.1, 
                        trpv=0.1, 
                        dmcoef=3.7E-10 )
gcg = flopy.mt3d.Mt3dGcg(model, iter1=50, mxiter=1, isolve=2, cclose= 1e-5)

# %% [markdown]
# # RCH

# %%
# crch_array =  np.full(( nrow, ncol), 0.1, dtype=float)
# crch_dict = {}
# crch_dict[0] = crch_array
# ssm = flopy.mt3d.Mt3dSsm(model, crch=crch_dict)

# rch_dict = {}
# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# rch_dict[0] = rch_array
# rch = flopy.modflow.ModflowRch(model = model, rech = rch_dict)


# ## [row, col, rch(m3), crch, start, end]
# rch_data = [[1100,1100,0.51,5000,1,20]]

# %%
crch_array =  np.full(( nrow, ncol), 0.1, dtype=float)
crch_dict = {}
crch_dict[0] = crch_array

crch_array =  np.full(( nrow, ncol), 0.1, dtype=float)
crch_array[int(nrow/2),int(ncol/2)] =5000
crch_array[int(nrow/2),int(ncol/3)] =5000
crch_dict = {}
crch_dict[1] = crch_array

ssm = flopy.mt3d.Mt3dSsm(model, crch=crch_dict)

# %%
rch_dict = {}

rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_dict[0] = rch_array

rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_array[int(nrow/2),int(ncol/2)] = 0.51/delr/delc
rch_array[int(nrow/2),int(ncol/3)] = 0.51/delr/delc

rch_dict[1] = rch_array
rch = flopy.modflow.ModflowRch(model = model, rech = rch_dict)

# %% [markdown]
# # RCT

# %%
#rct = flopy.mt3d.Mt3dRct(model=model, isothm=3,sp1=1e-5,sp2=0.0001,igetsc=0,rhob= 1.65E+09)

# %% [markdown]
# # OC

# %%
# OC
spd = {}
for kper in range(nper):
    for kstp in range(1):
        spd[(kper, kstp)] = [
            "save head",
            "save drawdown",
            "save budget",
            "print head",
            "print budget",
        ]

oc = flopy.modflow.ModflowOc(
    model,
    stress_period_data= spd,
    compact=True
    ,extension=['oc', 'hds', 'ddn', 'cbc', 'ibo']
    ,unitnumber = [14, 51, 52, 53, 0]
)

oc.reset_budgetunit(budgetunit=1053, fname='test.cbc')
oc.reset_budgetunit(budgetunit=53, fname='example_model.cbc')

# %% [markdown]
# # Write and Run

# %%
# Write MODFLOW input files
model.write_input()
# Out:
# Util2d rech_1: locat is None, but model does not support free format and how is internal... resetting how = external
# Util2d rech_2: locat is None, but model does not support free format and how is internal... resetting how = external

# %%
open_file(model_ws)

# %%
# Run the MODFLOW model
model.run_model()
# Out:
# FloPy is using the following executable to run the model: ..\..\flopy\bin\swtv4.exe
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: example_model.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2023/11/14 16:44:32
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    365.00
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   5.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1505      [K,I,J]   15   16  189
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2051E-03  [K,I,J]   57  151    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4176E-05  [K,I,J]   63  160  147
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   12.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6869E-01  [K,I,J]   15   16  190
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5143E-03  [K,I,J]   57  151    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1069E-04  [K,I,J]   63  160  145
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6504E-06  [K,I,J]   63  160  145
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   21.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3396E-01  [K,I,J]   62  167  107
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8977E-03  [K,I,J]   51  138  159
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3293E-04  [K,I,J]   51  138   45
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1547E-05  [K,I,J]   63  160  142
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   35.520
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3037E-01  [K,I,J]   24   56    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1415E-02  [K,I,J]   51  138  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8531E-04  [K,I,J]   51  138   45
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3720E-05  [K,I,J]   63  160  138
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   54.728
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3514E-01  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2983E-02  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1965E-03  [K,I,J]   51  138   45
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1127E-04  [K,I,J]   63  160   65
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1640E-05  [K,I,J]   63  160   66
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   81.619
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4725E-01  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6540E-02  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4207E-03  [K,I,J]   51  138   45
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3443E-04  [K,I,J]   57  151    4
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5564E-05  [K,I,J]   63  160  104
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   119.27
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6266E-01  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1302E-01  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9485E-03  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1291E-03  [K,I,J]   63  163  125
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1591E-04  [K,I,J]   63  163    1
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2331E-05  [K,I,J]   63  162  105
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   171.97
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8141E-01  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2384E-01  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2314E-02  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4274E-03  [K,I,J]   63  163   46
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6385E-04  [K,I,J]   63  162  125
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1481E-04  [K,I,J]   63  162  104
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2781E-05  [K,I,J]   63  163   90
#  Transport Step:    9   Step Size:   28.03     Total Elapsed Time:   200.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3464E-01  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5936E-02  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5126E-03  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4635E-04  [K,I,J]   63  160  102
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7171E-05  [K,I,J]   63  160   99
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   303.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1383      [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6638E-01  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7856E-02  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2998E-02  [K,I,J]   63  163  220
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8957E-03  [K,I,J]   63  162  145
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1751E-03  [K,I,J]   63  165  124
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1158E-03  [K,I,J]   63  163    1
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2789E-04  [K,I,J]   63  163    1
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1267E-03  [K,I,J]   61  158  218
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1122E-03  [K,I,J]   61  158  218
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1909E-05  [K,I,J]   61  158  218
#  Transport Step:   11   Step Size:   61.69     Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5718E-01  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2160E-01  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3339E-02  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4713E-03  [K,I,J]   63  163  219
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9416E-04  [K,I,J]   63  162  144
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2234E-04  [K,I,J]   63  162  208
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1077E-04  [K,I,J]   63  163   45
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.7192E-05  [K,I,J]   63  163   45
#
#  STRESS PERIOD NO.    2
#
#   STRESS PERIOD    2 TIME STEP    1 FROM TIME =   365.00     TO    730.00
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   370.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1576E+05  [K,I,J]   39  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   247.9      [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =   1.429      [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1945E-01  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4210E-03  [K,I,J]   41  111   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2114E-05  [K,I,J]   43  111   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   377.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7476      [K,I,J]   39  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2205E-01  [K,I,J]   39  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4117E-03  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9371E-05  [K,I,J]   40  112  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   386.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3276      [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1993E-01  [K,I,J]   39  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6815E-03  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1767E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1866E-06  [K,I,J]   41  111   73
#  Transport Step:    4   Step Size:   13.20     Total Elapsed Time:   400.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2182      [K,I,J]   41  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1436E-01  [K,I,J]   39  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1057E-02  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2323E-04  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4002E-06  [K,I,J]   41  111   73
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   419.21
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1861      [K,I,J]   41  111   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9961E-02  [K,I,J]   39  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2108E-02  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5171E-04  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1670E-05  [K,I,J]   43  111   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   446.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1545      [K,I,J]   42  111   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5533E-02  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3470E-02  [K,I,J]   42  111   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1618E-03  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1743E-04  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5859E-05  [K,I,J]   41  114  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   483.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1352      [K,I,J]   42  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5157E-02  [K,I,J]   41  113  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6513E-02  [K,I,J]   43  111   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3460E-03  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1108E-03  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7871E-05  [K,I,J]   42  116  111
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   536.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1355      [K,I,J]   42  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5919E-02  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1173E-01  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2322E-02  [K,I,J]   42  116  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1248E-02  [K,I,J]   42  115  111
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2786E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2250E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4203E-05  [K,I,J]   43  119  111
#  Transport Step:    9   Step Size:   63.55     Total Elapsed Time:   600.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1213      [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8341E-02  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1057E-01  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1451E-02  [K,I,J]   42  116  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1786E-03  [K,I,J]   43  118  111
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4498E-04  [K,I,J]   43  118  111
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5434E-04  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4655E-05  [K,I,J]   43  119  111
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   703.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1416      [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1309E-01  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1868E-01  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3947E-02  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8645E-03  [K,I,J]   43  118  111
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4606E-03  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4271E-03  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4585E-04  [K,I,J]   44  121  111
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2873E-04  [K,I,J]   43  118  111
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.8128E-03  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.7965E-03  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.3011E-05  [K,I,J]   46  126  111
#  Transport Step:   11   Step Size:   26.69     Total Elapsed Time:   730.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3011E-01  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2486E-02  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5117E-03  [K,I,J]   42  116  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4089E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3144E-05  [K,I,J]   43  119  111
#
#  STRESS PERIOD NO.    3
#
#   STRESS PERIOD    3 TIME STEP    1 FROM TIME =   730.00     TO    1095.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   735.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5609E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7868E-04  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2044E-05  [K,I,J]   40  112  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   742.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7739E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1611E-03  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5832E-05  [K,I,J]   40  112  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   751.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1059E-01  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3278E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1894E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5141E-06  [K,I,J]   41  114   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   765.52
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1433E-01  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6714E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6107E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1747E-05  [K,I,J]   41  114   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   784.73
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1902E-01  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1296E-02  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1881E-03  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1281E-04  [K,I,J]   42  116   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1913E-06  [K,I,J]   41  114   74
#  Transport Step:    6   Step Size:   15.27     Total Elapsed Time:   800.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1455E-01  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8505E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8879E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2513E-05  [K,I,J]   41  114   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   837.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3591E-01  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3950E-02  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1129E-02  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6868E-04  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2582E-04  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9698E-06  [K,I,J]   44  121   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   890.35
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4654E-01  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6136E-02  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2302E-02  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2164E-03  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4859E-04  [K,I,J]   44  121   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5881E-05  [K,I,J]   43  118   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   964.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5642E-01  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8525E-02  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4332E-02  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6815E-03  [K,I,J]   42  116   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2538E-03  [K,I,J]   44  121   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1190E-03  [K,I,J]   44  121   74
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2905E-04  [K,I,J]   45  123   74
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1736E-05  [K,I,J]   46  126   74
#  Transport Step:   10   Step Size:   35.86     Total Elapsed Time:   1000.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2361E-01  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3013E-02  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7336E-03  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5169E-04  [K,I,J]   42  116   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5413E-05  [K,I,J]   44  121   74
#  Transport Step:   11   Step Size:   95.00     Total Elapsed Time:   1095.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5454E-01  [K,I,J]   45  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8781E-02  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6211E-02  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1288E-02  [K,I,J]   42  116   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1535E-03  [K,I,J]   45  123   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4552E-03  [K,I,J]   45  124   74
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6364E-03  [K,I,J]   45  124   74
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1219E-04  [K,I,J]   46  126   74
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.8340E-05  [K,I,J]   46  126   74
#
#  STRESS PERIOD NO.    4
#
#   STRESS PERIOD    4 TIME STEP    1 FROM TIME =   1095.0     TO    1460.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1100.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2809E-02  [K,I,J]   45  117   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6028E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1404E-05  [K,I,J]   42  117   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1107.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3899E-02  [K,I,J]   45  117   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1169E-03  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4492E-05  [K,I,J]   42  117   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1116.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5387E-02  [K,I,J]   45  117  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2100E-03  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1326E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1402E-06  [K,I,J]   42  116   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1130.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7393E-02  [K,I,J]   45  117  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3467E-03  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3536E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7342E-06  [K,I,J]   42  116   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1149.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1004E-01  [K,I,J]   45  117  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6269E-03  [K,I,J]   41  115  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9952E-04  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2441E-05  [K,I,J]   42  116   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1176.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1371E-01  [K,I,J]   45  118   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1077E-02  [K,I,J]   41  115  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2559E-03  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1108E-04  [K,I,J]   42  116   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4351E-05  [K,I,J]   45  124   74
#  Transport Step:    7   Step Size:   23.38     Total Elapsed Time:   1200.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1164E-01  [K,I,J]   46  118   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7550E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1636E-03  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5654E-05  [K,I,J]   42  116   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1252.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2480E-01  [K,I,J]   46  118   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2430E-02  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1320E-02  [K,I,J]   44  121   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1120E-03  [K,I,J]   42  116  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2169E-04  [K,I,J]   45  124   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3226E-05  [K,I,J]   43  116  111
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   1326.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3175E-01  [K,I,J]   46  119   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3253E-02  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2511E-02  [K,I,J]   44  121   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3279E-03  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7479E-04  [K,I,J]   46  126   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1330E-04  [K,I,J]   44  118  111
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.9727E-05  [K,I,J]   47  128   74
#  Transport Step:   10   Step Size:   73.50     Total Elapsed Time:   1400.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3036E-01  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3486E-02  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2222E-02  [K,I,J]   45  124   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3187E-03  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6326E-04  [K,I,J]   46  126   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9255E-05  [K,I,J]   44  118  111
#  Transport Step:   11   Step Size:   60.00     Total Elapsed Time:   1460.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2312E-01  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2834E-02  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1427E-02  [K,I,J]   45  124   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1511E-03  [K,I,J]   43  119  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2683E-04  [K,I,J]   46  126   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3396E-05  [K,I,J]   44  119  111
#
#  STRESS PERIOD NO.    5
#
#   STRESS PERIOD    5 TIME STEP    1 FROM TIME =   1460.0     TO    1825.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1465.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2015E-02  [K,I,J]   43  122  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2927E-04  [K,I,J]   44  122   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7294E-06  [K,I,J]   43  122  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1472.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2543E-02  [K,I,J]   47  120   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5828E-04  [K,I,J]   44  121   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2423E-05  [K,I,J]   45  124  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1481.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3525E-02  [K,I,J]   47  121   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1238E-03  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8242E-05  [K,I,J]   45  124  111
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1495.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4893E-02  [K,I,J]   47  121   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2520E-03  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2587E-04  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1947E-06  [K,I,J]   44  121  111
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1514.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6754E-02  [K,I,J]   47  121   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4814E-03  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7424E-04  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1603E-05  [K,I,J]   44  121  111
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1541.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9265E-02  [K,I,J]   48  121   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8583E-03  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1924E-03  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7483E-05  [K,I,J]   44  121   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   1579.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1255E-01  [K,I,J]   48  121   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1419E-02  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4529E-03  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2990E-04  [K,I,J]   44  121   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4999E-05  [K,I,J]   48  131   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1632.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1685E-01  [K,I,J]   48  122   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2161E-02  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9467E-03  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1013E-03  [K,I,J]   44  121   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1377E-04  [K,I,J]   48  131   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3092E-05  [K,I,J]   45  121   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   1705.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2228E-01  [K,I,J]   49  122   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3010E-02  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1716E-02  [K,I,J]   45  124   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2907E-03  [K,I,J]   44  121   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4436E-04  [K,I,J]   48  131   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1074E-04  [K,I,J]   45  121   74
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4684E-05  [K,I,J]   49  133   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   1809.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2873E-01  [K,I,J]   49  123   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3810E-02  [K,I,J]   43  120   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2805E-02  [K,I,J]   47  128   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6968E-03  [K,I,J]   44  121   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1266E-03  [K,I,J]   47  124  111
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3896E-04  [K,I,J]   45  121   74
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2112E-04  [K,I,J]   49  133   74
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3147E-05  [K,I,J]   50  135   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   1825.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4269E-02  [K,I,J]   49  124   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2318E-03  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3323E-04  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5332E-06  [K,I,J]   45  123  111
#
#  STRESS PERIOD NO.    6
#
#   STRESS PERIOD    6 TIME STEP    1 FROM TIME =   1825.0     TO    2190.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1830.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1630E-02  [K,I,J]   43  122  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2516E-04  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6156E-06  [K,I,J]   45  124  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1837.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1862E-02  [K,I,J]   49  124   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5129E-04  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2112E-05  [K,I,J]   45  124  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1846.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2592E-02  [K,I,J]   49  124   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9801E-04  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6807E-05  [K,I,J]   45  124  111
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1860.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3599E-02  [K,I,J]   50  124   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1739E-03  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1993E-04  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2622E-06  [K,I,J]   45  123  111
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1879.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4976E-02  [K,I,J]   50  124   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2845E-03  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5217E-04  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1147E-05  [K,I,J]   45  123  111
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1906.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6831E-02  [K,I,J]   50  124   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5160E-03  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1204E-03  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5025E-05  [K,I,J]   45  123  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   1944.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9342E-02  [K,I,J]   50  125   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8906E-03  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2799E-03  [K,I,J]   47  129   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1789E-04  [K,I,J]   45  123  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2750E-05  [K,I,J]   48  131   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1997.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1267E-01  [K,I,J]   50  125   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-02  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6077E-03  [K,I,J]   47  129   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6207E-04  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9467E-05  [K,I,J]   49  133   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   2070.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1680E-01  [K,I,J]   51  125   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2261E-02  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1200E-02  [K,I,J]   48  131   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1882E-03  [K,I,J]   45  124  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3149E-04  [K,I,J]   49  133   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6828E-05  [K,I,J]   46  123  111
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   2174.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2292E-01  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3343E-02  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2297E-02  [K,I,J]   48  131   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5103E-03  [K,I,J]   47  128   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9261E-04  [K,I,J]   50  135   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2616E-04  [K,I,J]   46  123  111
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1505E-04  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.7364E-05  [K,I,J]   52  140   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   2190.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3321E-02  [K,I,J]   52  127   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2104E-03  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2575E-04  [K,I,J]   47  129   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4404E-06  [K,I,J]   46  126   74
#
#  STRESS PERIOD NO.    7
#
#   STRESS PERIOD    7 TIME STEP    1 FROM TIME =   2190.0     TO    2555.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   2195.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1037E-02  [K,I,J]   52  127   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2143E-04  [K,I,J]   47  129   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6223E-06  [K,I,J]   47  129   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   2202.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1446E-02  [K,I,J]   52  127   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4226E-04  [K,I,J]   47  129   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1974E-05  [K,I,J]   47  129   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   2211.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2013E-02  [K,I,J]   52  127   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7825E-04  [K,I,J]   47  129   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5946E-05  [K,I,J]   47  129   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   2225.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2795E-02  [K,I,J]   52  127   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1536E-03  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1658E-04  [K,I,J]   47  129   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2336E-06  [K,I,J]   46  126   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   2244.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3870E-02  [K,I,J]   52  128   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2977E-03  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4238E-04  [K,I,J]   47  129   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9698E-06  [K,I,J]   47  128   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   2271.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5352E-02  [K,I,J]   52  128   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5403E-03  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1185E-03  [K,I,J]   48  131   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1538E-04  [K,I,J]   47  129   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3419E-05  [K,I,J]   48  131   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   2309.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7344E-02  [K,I,J]   52  128   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9151E-03  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2481E-03  [K,I,J]   48  131   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1868E-04  [K,I,J]   47  128   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2183E-05  [K,I,J]   51  138   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   2362.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9957E-02  [K,I,J]   53  128   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1444E-02  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5143E-03  [K,I,J]   48  131   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6050E-04  [K,I,J]   47  128   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7510E-05  [K,I,J]   51  138   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   2435.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1345E-01  [K,I,J]   53  129   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2118E-02  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9496E-03  [K,I,J]   48  131   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1785E-03  [K,I,J]   47  128   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2428E-04  [K,I,J]   52  140   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1186E-04  [K,I,J]   48  128   74
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6609E-05  [K,I,J]   48  128   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   2539.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1775E-01  [K,I,J]   54  130   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2877E-02  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1658E-02  [K,I,J]   50  135   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4627E-03  [K,I,J]   47  128   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7586E-04  [K,I,J]   49  129   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3625E-04  [K,I,J]   48  128   74
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1077E-04  [K,I,J]   48  128   74
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3317E-05  [K,I,J]   54  144   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   2555.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2671E-02  [K,I,J]   54  131   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1483E-03  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1940E-04  [K,I,J]   48  131  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4196E-06  [K,I,J]   51  138   74
#
#  STRESS PERIOD NO.    8
#
#   STRESS PERIOD    8 TIME STEP    1 FROM TIME =   2555.0     TO    2920.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   2560.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8368E-03  [K,I,J]   54  131   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1576E-04  [K,I,J]   47  129   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4439E-06  [K,I,J]   47  129   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   2567.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1169E-02  [K,I,J]   54  131   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3055E-04  [K,I,J]   47  129   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1378E-05  [K,I,J]   47  129   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   2576.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1630E-02  [K,I,J]   54  131   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5689E-04  [K,I,J]   48  131  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3998E-05  [K,I,J]   47  129   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   2590.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2268E-02  [K,I,J]   54  131   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1031E-03  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1175E-04  [K,I,J]   48  131  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2379E-06  [K,I,J]   51  138   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   2609.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3147E-02  [K,I,J]   54  131   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1989E-03  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3114E-04  [K,I,J]   48  131  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8454E-06  [K,I,J]   51  138   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   2636.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4345E-02  [K,I,J]   54  131   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3572E-03  [K,I,J]   46  127   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6945E-04  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8158E-05  [K,I,J]   51  138   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   2674.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5976E-02  [K,I,J]   55  132   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5974E-03  [K,I,J]   49  134   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1798E-03  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1369E-04  [K,I,J]   47  128   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1968E-05  [K,I,J]   52  140   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   2727.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8186E-02  [K,I,J]   55  132   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9744E-03  [K,I,J]   49  134   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3958E-03  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3927E-04  [K,I,J]   47  128   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6353E-05  [K,I,J]   52  140   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   2800.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1103E-01  [K,I,J]   55  132   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1511E-02  [K,I,J]   49  134   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8081E-03  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1117E-03  [K,I,J]   48  131   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1995E-04  [K,I,J]   53  142   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2318E-05  [K,I,J]   48  128   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   2904.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1470E-01  [K,I,J]   56  133   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2231E-02  [K,I,J]   49  134   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1510E-02  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3122E-03  [K,I,J]   50  135   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5886E-04  [K,I,J]   49  131  111
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9590E-05  [K,I,J]   48  128   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   2920.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2228E-02  [K,I,J]   56  134   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1383E-03  [K,I,J]   49  134   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1827E-04  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3251E-06  [K,I,J]   51  138   74
#
#  STRESS PERIOD NO.    9
#
#   STRESS PERIOD    9 TIME STEP    1 FROM TIME =   2920.0     TO    3285.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   2925.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6967E-03  [K,I,J]   56  134   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1275E-04  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3681E-06  [K,I,J]   51  138   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   2932.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9723E-03  [K,I,J]   56  134   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2594E-04  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1273E-05  [K,I,J]   51  138   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   2941.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1355E-02  [K,I,J]   56  134   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4960E-04  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4033E-05  [K,I,J]   51  138   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   2955.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1884E-02  [K,I,J]   56  134   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1014E-03  [K,I,J]   49  134   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1168E-04  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1922E-06  [K,I,J]   51  138   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   2974.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2619E-02  [K,I,J]   57  135   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1959E-03  [K,I,J]   49  134   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3094E-04  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6059E-06  [K,I,J]   79  133   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   3001.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3632E-02  [K,I,J]   57  135   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3551E-03  [K,I,J]   49  134   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7342E-04  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3021E-05  [K,I,J]   51  138   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   3039.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5007E-02  [K,I,J]   57  135   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6032E-03  [K,I,J]   49  134   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1744E-03  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1508E-04  [K,I,J]   50  135   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1664E-05  [K,I,J]   57  150   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   3092.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6845E-02  [K,I,J]   58  136   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9586E-03  [K,I,J]   49  134   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3510E-03  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4108E-04  [K,I,J]   50  135   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5647E-05  [K,I,J]   57  150   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   3165.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9326E-02  [K,I,J]   58  136   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1426E-02  [K,I,J]   49  134   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6531E-03  [K,I,J]   52  140   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1117E-03  [K,I,J]   50  135   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1892E-04  [K,I,J]   57  150   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3206E-05  [K,I,J]   58  152   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   3269.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1247E-01  [K,I,J]   59  137   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1985E-02  [K,I,J]   49  134   74
# ...
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9185E-04  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7664E-07  [K,I,J]   42  111   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   23415.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1285E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1396E-06  [K,I,J]   69  177   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   23442.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1797E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3529E-06  [K,I,J]   69  177   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   23479.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2513E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8722E-06  [K,I,J]   69  177   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   23532.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3510E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2117E-05  [K,I,J]   69  177   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   23606.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4897E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5014E-05  [K,I,J]   69  177   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   23709.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6820E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1145E-04  [K,I,J]   69  177   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3746E-06  [K,I,J]   69  176   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   23725.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1054E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7595E-07  [K,I,J]   69  177   74
#
#  STRESS PERIOD NO.   66
#
#   STRESS PERIOD   66 TIME STEP    1 FROM TIME =   23725.     TO    24090.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   23730.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3307E-04  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2795E-07  [K,I,J]   40  111   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   23737.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4628E-04  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4368E-07  [K,I,J]   40  111   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   23747.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6477E-04  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6162E-07  [K,I,J]   41  111   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   23761.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9062E-04  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8504E-07  [K,I,J]   42  111   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   23780.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1268E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1329E-06  [K,I,J]   69  177   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   23807.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1773E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3354E-06  [K,I,J]   69  177   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   23844.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2477E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8262E-06  [K,I,J]   69  177   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   23897.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3459E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2000E-05  [K,I,J]   69  177   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   23971.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4824E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4730E-05  [K,I,J]   69  177   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   24074.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6714E-03  [K,I,J]   73  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1079E-04  [K,I,J]   69  177   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3380E-06  [K,I,J]   69  176   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   24090.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1038E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7181E-07  [K,I,J]   69  177   74
#
#  STRESS PERIOD NO.   67
#
#   STRESS PERIOD   67 TIME STEP    1 FROM TIME =   24090.     TO    24455.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   24095.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3258E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1887E-07  [K,I,J]   40  111   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   24102.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4560E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3537E-07  [K,I,J]   40  111   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   24112.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6382E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5404E-07  [K,I,J]   41  111   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   24126.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8930E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7715E-07  [K,I,J]   42  111   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   24145.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1249E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1256E-06  [K,I,J]   69  177   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   24172.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1747E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3172E-06  [K,I,J]   69  177   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   24209.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2442E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7804E-06  [K,I,J]   69  177   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   24262.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3409E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1885E-05  [K,I,J]   69  177   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   24336.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4754E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4451E-05  [K,I,J]   69  177   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   24439.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6614E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1014E-04  [K,I,J]   69  177   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3053E-06  [K,I,J]   69  176   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   24455.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1023E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6780E-07  [K,I,J]   69  177   74
#
#  STRESS PERIOD NO.   68
#
#   STRESS PERIOD   68 TIME STEP    1 FROM TIME =   24455.     TO    24820.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   24460.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3212E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2788E-07  [K,I,J]   40  111   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   24467.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4495E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4361E-07  [K,I,J]   40  111   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   24477.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6290E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6162E-07  [K,I,J]   41  111   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   24491.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8801E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8535E-07  [K,I,J]   42  111   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   24510.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1231E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1189E-06  [K,I,J]   69  177   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   24537.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1721E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3000E-06  [K,I,J]   69  177   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   24574.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2405E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7357E-06  [K,I,J]   69  177   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   24627.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3357E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1773E-05  [K,I,J]   69  177   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   24701.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4679E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4177E-05  [K,I,J]   69  177   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   24804.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6505E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9507E-05  [K,I,J]   69  177   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   24820.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1007E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6386E-07  [K,I,J]   69  177   74
#
#  STRESS PERIOD NO.   69
#
#   STRESS PERIOD   69 TIME STEP    1 FROM TIME =   24820.     TO    25185.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   24825.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3159E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1901E-07  [K,I,J]   40  111   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   24832.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4421E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3549E-07  [K,I,J]   40  111   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   24842.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6187E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5425E-07  [K,I,J]   41  111   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   24856.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8655E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7777E-07  [K,I,J]   42  111   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   24875.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1211E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1119E-06  [K,I,J]   69  177   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   24902.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1692E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2830E-06  [K,I,J]   69  177   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   24939.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2364E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6928E-06  [K,I,J]   69  177   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   24992.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3299E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1664E-05  [K,I,J]   69  177   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   25066.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4595E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3914E-05  [K,I,J]   69  177   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   25169.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6384E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8895E-05  [K,I,J]   69  177   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   25185.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9882E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6006E-07  [K,I,J]   69  177   74
#
#  STRESS PERIOD NO.   70
#
#   STRESS PERIOD   70 TIME STEP    1 FROM TIME =   25185.     TO    25550.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   25190.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3101E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2782E-07  [K,I,J]   40  111   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   25197.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4340E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4354E-07  [K,I,J]   40  111   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   25207.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6072E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6164E-07  [K,I,J]   41  111   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   25221.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8494E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8577E-07  [K,I,J]   42  111   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   25240.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1188E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1106E-06  [K,I,J]   43  111   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   25267.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1660E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2668E-06  [K,I,J]   69  177   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   25304.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2319E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6513E-06  [K,I,J]   69  177   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   25357.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3235E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1559E-05  [K,I,J]   69  177   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   25431.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4504E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3659E-05  [K,I,J]   69  177   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   25534.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6254E-03  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8306E-05  [K,I,J]   69  177   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   25550.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9681E-04  [K,I,J]   72  178   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5630E-07  [K,I,J]   69  177   74
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2023/11/14 17:11:32
#  Elapsed run time: 26 Minutes, 59.914 Seconds
#
#  Normal termination of SEAWAT
# (True, [])
