# %%
import flopy
import numpy as np
import matplotlib.pyplot as plt
import shutil
from pathlib import Path

from datetime import datetime
from tempfile import TemporaryDirectory
from tempfile import mkdtemp

import os
import platform
import subprocess
from shapely.geometry import Polygon, Point
from scipy.interpolate import make_interp_spline

# %%
def locate_ground_surface_lay(row=150):
    cross_section = ibound[:,:,0]
    lay = np.where(cross_section[:,row]==1)[0][0]
    return lay

def meter_to_col(col_meter):
    return int(np.round(col_meter/delc,0))

def meter_to_row(row_meter):
    return int(np.round(row_meter/delc,0))

def meter_to_lay(lay_meter):
    return int(np.round((top_elev-lay_meter)/layer_thickness,0))

def col_to_meter(col):
    return col*delc

def row_to_meter(row):
    return row*delc

def lay_to_meter(row):
    return 190.0-row*layer_thickness

# %%
def change_array_within_polygon(array, row_coords, col_coords, value):

    # Create a polygon object from the row and column coordinates
    polygon = Polygon(zip(col_coords, row_coords))

    # Create a boolean mask indicating which points fall within the polygon
    mask = np.zeros_like(array, dtype=bool)
    for row in range(array.shape[0]):
        for col in range(array.shape[1]):
            point = Point(col, row)
            if polygon.contains(point) or polygon.intersects(point):
                mask[row, col] = True

    # Set the values of the array that fall within the polygon to the new value
    array[mask] = value

    return array

# %% [markdown]
# # Workspace

# %%
# Define model workspace

myt = datetime.now().strftime('%m%d%H%M%S')
name = 'wasaga'
temp_dir = mkdtemp(prefix='_T{}_{}_'.format(myt,name))
os.makedirs(Path(temp_dir) / '_output')

#model_ws = "./modflow_model_2"
model_ws = temp_dir

def open_file(path):
    if platform.system() == "Windows":
        os.startfile(path)
    elif platform.system() == "Darwin":
        subprocess.Popen(["open", path])
    else:
        subprocess.Popen(["xdg-open", path])

open_file(model_ws)

# %% [markdown]
# # Model

# %%
# Create a MODFLOW model instance
model = flopy.modflow.Modflow(modelname="example_model",version='mf2005',
                              exe_name='mf2005', 
                              model_ws=model_ws)

# %%
# Create a MODFLOW model instance
model = flopy.seawat.Seawat(modelname="example_model",
                            exe_name='swtv4', 
                              model_ws=model_ws)

# %% [markdown]
# # DIS

# %%
# Define model dimensions
nlay = int(60 * 2)
nrow = int(220 * 1)
ncol = int(220 * 1)
delr = 2200/nrow  # Cell width along rows (extend 2200 / 220)
delc = 2200/ncol  # Cell width along columns (extend 2200 / 220)

# Define top elevation
layer_thickness = 30.0 / nlay

top_elev = 190.0
botm_elev = [top_elev - (i * layer_thickness) for i in range(1, nlay + 1)]
# Define layer thickness (uniform thickness)


perlen = 365
nper = int(70)

steady = np.append(np.array([True]),np.repeat(False,nper-1))
#steady=[False,False,True]
#steady = True

# Create DIS package

# %%
dis = flopy.modflow.ModflowDis(model, nlay=nlay, nrow=nrow, ncol=ncol, 
                               delr=delr, delc=delc,top=top_elev, 
                               botm=botm_elev,
                               nper = nper, perlen = perlen,
                               nstp = 1, steady = steady)

# %% [markdown]
# # Ibound

# %%
x = np.array([0, 100, 340, 600, 750, 850, 1100, 1350, 1450, 1530, 1650, 1750, 1850, 2050, 2200])
y_topo = np.array([190,190,187,184,184,184,183,182,179,175.5,175,173.8,173.5,172,171])#topo
y_clay = np.array([185,184,180,175,174,174,173,170,169,168.5,167.5,166.8,166.5,165,164]) #clay


# Interpolate the data using smoothing splines
spl = make_interp_spline(x, y_topo)
x_smooth_topo = np.linspace(x.min(), x.max(), 30)
y_smooth_topo = spl(x_smooth_topo)

col_coords = (x_smooth_topo/delr).round(0)
col_coords_topo = list(col_coords) +[nrow,0]

row_coords = ((top_elev - y_smooth_topo)/layer_thickness).round(0)
row_coords_topo  =  list(row_coords) +[0,0]



# Interpolate the data using smoothing splines
spl = make_interp_spline(x, y_clay)
x_smooth = np.linspace(x.min(), x.max(), 30)
y_smooth = spl(x_smooth)

col_coords = (x_smooth/delr).round(0)
col_coords_clay = list(col_coords) +[nrow,0]
row_coords = ((top_elev - y_smooth)/layer_thickness).round(0)
row_coords_clay  =  list(row_coords) +[nlay,nlay]

# %% [markdown]
# # Ibound & Strt

# %%
# Define ibound and initial conditionsa
ibound = np.ones((nlay, nrow, ncol), dtype=int)
initial_head = np.full((nlay, nrow, ncol), 200.0, dtype=float)

# Set constant head boundary conditions for the first and last rows
array = change_array_within_polygon(ibound, row_coords_topo, col_coords_topo, 0)
plt.scatter(col_coords_topo,row_coords_topo,c='r')


array = change_array_within_polygon(ibound, row_coords_clay, col_coords_clay, 0)
plt.scatter(col_coords,row_coords,c='r')

for c in range(0,2):
    i = np.where(ibound[:,c,-1]==1)[0][-1]
    head = top_elev-i*layer_thickness
    #print('head {}'.format(head))
    
    while head<187:
        ibound[i,c,:] = -1
        #print(i,c)
        #initial_head[i,c,:] = head+0.5
        print(head)
        initial_head[i,c,:] = 187
        head+=layer_thickness
        i-=1


lay = np.where(ibound[:,int(1700/delr),-1])[0][0]
elv = lay_to_meter(lay)
head = elv

for c in range(int(1700/delr),int(2200/delr)):
    lay = np.where(ibound[:,c,-1]==1)[0][0]
    #print(lay,lay_to_meter(lay))
    ibound[lay,c,:] = -1
    initial_head[lay,c,:] = elv




# Your existing code
im = plt.imshow(ibound[:,:,2], origin='upper', aspect=1)
plt.axvline(x=meter_to_col(1700))# shoreline
plt.gcf().set_size_inches(15,10)

# Set the y-axis tick positions and labels
#plt.yticks([0, 10,20, 30,40, 50,60], ['190m (0L)','185m (10L)', '180m (20L)','175m (30L)', '170m (40L)', '165m (50L)','160m (60L)'])

# Add a horizontal colorbar
cbar = plt.colorbar(im, orientation='horizontal')
cbar.ax.tick_params(labelsize=16)
cbar.set_label('Colorbar Label', fontsize=16)

# Display the plot
plt.title('ibound')
plt.grid()
plt.show()


fig, ax = plt.subplots(figsize=(15, 10))
im = ax.imshow(initial_head[:, :, 0], origin='upper')

# Add a horizontal colorbar
cbar = plt.colorbar(im, orientation='horizontal')
cbar.ax.tick_params(labelsize=18)
plt.title('initial head')
plt.show()
# Out:
# 185.25
# 185.5
# 185.75
# 186.0
# 186.25
# 186.5
# 186.75
# 185.0
# 185.25
# 185.5
# 185.75
# 186.0
# 186.25
# 186.5
# 186.75

# %% [markdown]
# # BAS LPF  PCG

# %%
# Create BAS package
bas = flopy.modflow.ModflowBas(model, ibound=ibound, strt=initial_head)

# Define hydraulic properties
horizontal_k = 2.3  # Horizontal hydraulic conductivity (m/day)
vertical_ka = 0.1   # Vertical hydraulic conductivity (m/day)
porosity = 0.25     # Porosity

# Create LPF package (Layer Property Flow package)
lpf = flopy.modflow.ModflowLpf(model, hk=horizontal_k, 
                               vka=vertical_ka, laytyp=1, 
                               ipakcb=None,ss=0.0002,sy=0.33,
                               laywet=1,iwetit=1,wetfct=0.1,ihdwet=1)

# #ss=0.0002,sy=0.33
# upw = flopy.modflow.ModflowUpw(model, laytyp=1, hk=horizontal_k)

pcg = flopy.modflow.ModflowPcg(model, hclose=1e-3,npcond=1,
                               relax=0.99,rclose=1e-3,mutpcg=0,nbpol=1,iprpcg=1)

# %% [markdown]
# # Heterogeneity

# %%
# hk_mean = 2.3  # mean hydraulic conductivity
# hk_std = 2  # standard deviation of hydraulic conductivity
# hk= np.random.normal(hk_mean, hk_std, size=[nlay,nrow,ncol])
# hk[np.where(hk<0)]=0.001

# model.lpf.hk = hk

# %%
# hk_mean = np.log10(2.3)  # mean hydraulic conductivity
# hk_std = 0.4  # standard deviation of hydraulic conductivity
# hk= np.random.normal(hk_mean, hk_std, size=[nlay,nrow,ncol])
# hk = 10**hk
# #hk[np.where(hk<0)]=0.001
# hk.mean()
# model.lpf.hk = hk

# %%
# plt.hist(hk.flatten(),bins=np.linspace(0,30,50))
# plt.show()

# plt.imshow(hk[0,:,:])
# plt.show()

# %% [markdown]
# # DRN

# %%
locate_ground_surface_lay(meter_to_row(160))
#drn_cell = [(0, 150, 28), -10, 100]

beach_drns = np.arange(1520,1600+1,delr).astype(int)
river_drns = np.arange(595,605+1,delr).astype(int)

drn_list = []
drn_ys= list(beach_drns)+list(river_drns)

for y in drn_ys:
   row = meter_to_row(y)
   lay = locate_ground_surface_lay(row=row)
   elv = lay_to_meter(lay)
   #print(lay)
   for col in range(ncol):

      drn_list.append([lay, row, col, elv, 100])
      #drn_list.append([12*2, meter_to_row(600), col, 184.0-0.5, 100])
      
drn_cell = {0:drn_list} 

#drn_cell={0:[[31, 160, 0, 174.5-0.5, 0],[12, 60, 0, 184.0-0.5, 0]]}
drn = flopy.modflow.ModflowDrn(model=model, stress_period_data=drn_cell,)

# %%
lays_with_drn = np.unique([i[0] for i in drn.stress_period_data.data[0]])
for lay in lays_with_drn:
    pmv = flopy.plot.PlotMapView(model=model, layer=lay)
    pmv.plot_bc('DRN',color='r')

# %% [markdown]
# # BTN ICBOUND

# %%
icbund = np.full((nlay, nrow, ncol),0, dtype=float)
icbund = ibound.copy()

btn = flopy.mt3d.Mt3dBtn(
    model,
    nprs=5,
    timprs=np.cumsum([200]*7),
    prsity=0.25,
    sconc= 0.1, # starting concentration
    ifmtcn=0, chkmas=False, nprobs=10, nprmas=10,
    dt0=5,  # The user-specified initial 
    ttsmult=1.4,
    mxstrn = 50000,
    icbund = icbund
)

# %%
adv = flopy.mt3d.Mt3dAdv(model, mixelm=0,percel=0.4,mxpart=50000000,nadvfd=0)
dsp = flopy.mt3d.Mt3dDsp(model, al=0.2, trpt=0.1, 
                        trpv=0.1, 
                        dmcoef=3.7E-10 )
gcg = flopy.mt3d.Mt3dGcg(model, iter1=50, mxiter=1, isolve=2, cclose= 1e-5)

# %% [markdown]
# # RCH

# %%
crch_array =  np.full(( nrow, ncol), 0.1, dtype=float)
crch_dict = {}
crch_dict[0] = crch_array
ssm = flopy.mt3d.Mt3dSsm(model, crch=crch_dict)

rch_dict = {}
rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_dict[0] = rch_array
rch = flopy.modflow.ModflowRch(model = model, rech = rch_dict)

# %%
## [row, col, rch(m3), crch, start, end]
rch_data = [[1100,1100,0.51,5000,1,20]]

# %%
crch_array =  np.full(( nrow, ncol), 0.1, dtype=float)
crch_dict = {}
crch_dict[0] = crch_array

crch_array =  np.full(( nrow, ncol), 0.1, dtype=float)
crch_array[int(nrow/2),int(ncol/2)] =5000
crch_array[int(nrow/2),int(ncol/3)] =5000
crch_dict = {}
crch_dict[1] = crch_array

ssm = flopy.mt3d.Mt3dSsm(model, crch=crch_dict)

# %%
rch_dict = {}

rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_dict[0] = rch_array

rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_array[int(nrow/2),int(ncol/2)] = 0.51/delr/delc
rch_array[int(nrow/2),int(ncol/3)] = 0.51/delr/delc

rch_dict[1] = rch_array
rch = flopy.modflow.ModflowRch(model = model, rech = rch_dict)

# %% [markdown]
# # RCT

# %%
rct = flopy.mt3d.Mt3dRct(model=model, isothm=3,sp1=1e-5,sp2=0.0001,igetsc=0,rhob= 1.65E+09)

# %% [markdown]
# # OC

# %%
oc = flopy.modflow.ModflowOc(
    model,
    stress_period_data= None,
    compact=True,
    extension=['oc', 'hds', 'ddn', 'cbc', 'ibo']
)

# %% [markdown]
# # Write and Run

# %%
# Write MODFLOW input files
model.write_input()
# Out:
# Util2d rech_1: locat is None, but model does not support free format and how is internal... resetting how = external
# Util2d rech_2: locat is None, but model does not support free format and how is internal... resetting how = external

# %%
open_file(model_ws)

# %%
# Run the MODFLOW model
model.run_model()
# Out:
# FloPy is using the following executable to run the model: ../../../../../../Users/b/.local/share/flopy/bin/swtv4
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: example_model.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2023/10/27 23:51:44
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    365.00
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   5.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4257E-01  [K,I,J]   15   16  188
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3952E-06  [K,I,J]   50  136   45
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   12.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4563E-01  [K,I,J]   15   16  189
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1920E-05  [K,I,J]   57  151    6
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   21.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4491E-01  [K,I,J]   15   16  189
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7048E-05  [K,I,J]   57  151    6
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   35.520
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3988E-01  [K,I,J]   15   16  189
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2124E-04  [K,I,J]   57  151    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1804E-06  [K,I,J]   63  160    8
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   54.728
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3163E-01  [K,I,J]   15   16  190
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5465E-04  [K,I,J]   57  151    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6264E-06  [K,I,J]   63  160  147
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   81.619
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2358E-01  [K,I,J]   26   67    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1219E-03  [K,I,J]   57  151    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1743E-05  [K,I,J]   63  160  146
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   119.27
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2015E-01  [K,I,J]   62  167  107
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2394E-03  [K,I,J]   57  151    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3950E-05  [K,I,J]   57  151    5
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   171.97
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2032E-01  [K,I,J]   23   51  110
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4291E-03  [K,I,J]   51  138  159
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1136E-04  [K,I,J]   57  151    5
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5085E-06  [K,I,J]   63  160  143
#  Transport Step:    9   Step Size:   28.03     Total Elapsed Time:   200.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9325E-02  [K,I,J]   24   56    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9924E-04  [K,I,J]   57  151    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1351E-05  [K,I,J]   57  151    5
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   303.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2648E-01  [K,I,J]   64  170    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1306E-02  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8177E-04  [K,I,J]   51  138   45
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3604E-05  [K,I,J]   63  160   63
#  Transport Step:   11   Step Size:   61.69     Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1429E-01  [K,I,J]   13    1  188
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4217E-03  [K,I,J]   51  138   45
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1625E-04  [K,I,J]   51  138   45
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7050E-06  [K,I,J]   63  160  138
#
#  STRESS PERIOD NO.    2
#
#   STRESS PERIOD    2 TIME STEP    1 FROM TIME =   365.00     TO    730.00
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   370.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   3226.      [K,I,J]   39  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5629      [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3899E-03  [K,I,J]   40  111   73
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1341E-06  [K,I,J]   40  111   73
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   377.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   1.220      [K,I,J]   39  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8888E-03  [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4952E-06  [K,I,J]   40  111   73
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   386.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6419      [K,I,J]   39  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1376E-02  [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8399E-06  [K,I,J]   40  111   73
#  Transport Step:    4   Step Size:   13.20     Total Elapsed Time:   400.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4205      [K,I,J]   39  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1993E-02  [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1469E-05  [K,I,J]   40  111   73
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   419.21
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3223      [K,I,J]   39  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3103E-02  [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5234E-05  [K,I,J]   40  112  111
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   446.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2406      [K,I,J]   39  111   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4129E-02  [K,I,J]   39  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1939E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1540E-05  [K,I,J]   40  112  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   483.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2058      [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5793E-02  [K,I,J]   39  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6192E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1060E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3861E-05  [K,I,J]   40  112  111
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   536.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1845      [K,I,J]   40  111   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6686E-02  [K,I,J]   39  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1663E-03  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2071E-04  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1409E-05  [K,I,J]   40  112  111
#  Transport Step:    9   Step Size:   63.55     Total Elapsed Time:   600.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1486      [K,I,J]   41  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5113E-02  [K,I,J]   39  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2037E-03  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2319E-04  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6489E-06  [K,I,J]   40  112  111
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   703.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1599      [K,I,J]   41  111   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6044E-02  [K,I,J]   39  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8746E-03  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2352E-03  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4375E-05  [K,I,J]   41  111  111
#  Transport Step:   11   Step Size:   26.69     Total Elapsed Time:   730.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3467E-01  [K,I,J]   42  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3817E-03  [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5227E-05  [K,I,J]   39  112   74
#
#  STRESS PERIOD NO.    3
#
#   STRESS PERIOD    3 TIME STEP    1 FROM TIME =   730.00     TO    1095.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   735.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6412E-02  [K,I,J]   42  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6699E-05  [K,I,J]   40  111  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   742.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8829E-02  [K,I,J]   42  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1589E-04  [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2479E-07  [K,I,J]   39  112  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   751.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1206E-01  [K,I,J]   42  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3589E-04  [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1068E-06  [K,I,J]   39  112  111
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   765.52
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1626E-01  [K,I,J]   42  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7609E-04  [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4290E-06  [K,I,J]   39  112  111
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   784.73
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2152E-01  [K,I,J]   42  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1491E-03  [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1598E-05  [K,I,J]   39  112   74
#  Transport Step:    6   Step Size:   15.27     Total Elapsed Time:   800.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1629E-01  [K,I,J]   42  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8460E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6300E-06  [K,I,J]   39  112  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   837.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3562E-01  [K,I,J]   42  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6453E-03  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1759E-04  [K,I,J]   39  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4194E-06  [K,I,J]   39  112   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   890.35
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4293E-01  [K,I,J]   43  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1179E-02  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4793E-04  [K,I,J]   39  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3717E-06  [K,I,J]   41  113  111
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   964.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5090E-01  [K,I,J]   43  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1931E-02  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1176E-03  [K,I,J]   39  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1745E-05  [K,I,J]   41  113  111
#  Transport Step:   10   Step Size:   35.86     Total Elapsed Time:   1000.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2248E-01  [K,I,J]   41  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5005E-03  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1154E-04  [K,I,J]   39  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4726E-07  [K,I,J]   40  111  111
#  Transport Step:   11   Step Size:   95.00     Total Elapsed Time:   1095.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5345E-01  [K,I,J]   42  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2378E-02  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1935E-03  [K,I,J]   39  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4459E-05  [K,I,J]   41  113  111
#
#  STRESS PERIOD NO.    4
#
#   STRESS PERIOD    4 TIME STEP    1 FROM TIME =   1095.0     TO    1460.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1100.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2782E-02  [K,I,J]   42  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3451E-05  [K,I,J]   40  112  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1107.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3870E-02  [K,I,J]   42  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8651E-05  [K,I,J]   40  112  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1116.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5368E-02  [K,I,J]   42  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2102E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5326E-07  [K,I,J]   39  112   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1130.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7416E-02  [K,I,J]   42  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4906E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2232E-06  [K,I,J]   39  112   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1149.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1018E-01  [K,I,J]   42  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1089E-03  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8699E-06  [K,I,J]   39  112   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1176.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1386E-01  [K,I,J]   42  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2272E-03  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3107E-05  [K,I,J]   39  112   74
#  Transport Step:    7   Step Size:   23.38     Total Elapsed Time:   1200.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1174E-01  [K,I,J]   42  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1619E-03  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1731E-05  [K,I,J]   39  112   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1252.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2492E-01  [K,I,J]   42  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7924E-03  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2944E-04  [K,I,J]   39  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3739E-06  [K,I,J]   41  114  111
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   1326.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3191E-01  [K,I,J]   42  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1258E-02  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7360E-04  [K,I,J]   39  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1677E-05  [K,I,J]   41  114  111
#  Transport Step:   10   Step Size:   73.50     Total Elapsed Time:   1400.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2945E-01  [K,I,J]   43  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1140E-02  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6583E-04  [K,I,J]   39  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1711E-05  [K,I,J]   41  114  111
#  Transport Step:   11   Step Size:   60.00     Total Elapsed Time:   1460.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2246E-01  [K,I,J]   43  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7643E-03  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3305E-04  [K,I,J]   39  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7205E-06  [K,I,J]   41  114  111
#
#  STRESS PERIOD NO.    5
#
#   STRESS PERIOD    5 TIME STEP    1 FROM TIME =   1460.0     TO    1825.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1465.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1858E-02  [K,I,J]   43  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2194E-05  [K,I,J]   40  112  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1472.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2580E-02  [K,I,J]   43  112   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5506E-05  [K,I,J]   40  112  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1481.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3572E-02  [K,I,J]   43  112  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1339E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2772E-07  [K,I,J]   39  112  111
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1495.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4920E-02  [K,I,J]   43  112  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3126E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1193E-06  [K,I,J]   40  112  111
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1514.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6733E-02  [K,I,J]   43  112  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6932E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4845E-06  [K,I,J]   40  112  111
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1541.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9126E-02  [K,I,J]   43  112  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1442E-03  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1825E-05  [K,I,J]   40  112  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   1579.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1220E-01  [K,I,J]   43  112  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2775E-03  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6286E-05  [K,I,J]   40  112  111
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1632.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1673E-01  [K,I,J]   42  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4867E-03  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1943E-04  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3991E-06  [K,I,J]   41  114  111
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   1705.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2275E-01  [K,I,J]   42  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7925E-03  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5270E-04  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1828E-05  [K,I,J]   41  114  111
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   1809.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3031E-01  [K,I,J]   42  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1515E-02  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1221E-03  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7015E-05  [K,I,J]   41  114  111
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   1825.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4641E-02  [K,I,J]   42  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2886E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1929E-06  [K,I,J]   40  112  111
#
#  STRESS PERIOD NO.    6
#
#   STRESS PERIOD    6 TIME STEP    1 FROM TIME =   1825.0     TO    2190.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1830.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1453E-02  [K,I,J]   42  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1315E-05  [K,I,J]   40  112  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1837.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2027E-02  [K,I,J]   42  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3306E-05  [K,I,J]   40  112  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1846.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2823E-02  [K,I,J]   42  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8057E-05  [K,I,J]   40  112  111
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1860.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3924E-02  [K,I,J]   42  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1884E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1011E-06  [K,I,J]   40  112  111
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1879.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5437E-02  [K,I,J]   42  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4182E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4053E-06  [K,I,J]   40  112  111
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1906.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7498E-02  [K,I,J]   42  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8697E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1495E-05  [K,I,J]   40  112  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   1944.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1027E-01  [K,I,J]   42  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1671E-03  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4984E-05  [K,I,J]   40  112  111
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1997.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1392E-01  [K,I,J]   42  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3209E-03  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1472E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3510E-06  [K,I,J]   41  114  111
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   2070.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1868E-01  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6550E-03  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3775E-04  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1580E-05  [K,I,J]   41  114  111
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   2174.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2459E-01  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1252E-02  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8322E-04  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6328E-05  [K,I,J]   41  114  111
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   2190.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3733E-02  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1703E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1495E-06  [K,I,J]   40  112  111
#
#  STRESS PERIOD NO.    7
#
#   STRESS PERIOD    7 TIME STEP    1 FROM TIME =   2190.0     TO    2555.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   2195.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1168E-02  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7699E-06  [K,I,J]   40  112  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   2202.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1627E-02  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1940E-05  [K,I,J]   40  112  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   2211.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2263E-02  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4737E-05  [K,I,J]   40  112  111
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   2225.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3140E-02  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1110E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7748E-07  [K,I,J]   40  112  111
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   2244.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4339E-02  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2467E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3046E-06  [K,I,J]   40  112  111
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   2271.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5964E-02  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5133E-04  [K,I,J]   40  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1093E-05  [K,I,J]   40  112  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   2309.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8134E-02  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1138E-03  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3520E-05  [K,I,J]   40  112  111
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   2362.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1112E-01  [K,I,J]   42  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2465E-03  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9985E-05  [K,I,J]   40  112  111
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   2435.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1523E-01  [K,I,J]   42  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5042E-03  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2456E-04  [K,I,J]   40  112   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1174E-05  [K,I,J]   41  114  111
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   2539.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2072E-01  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9639E-03  [K,I,J]   40  113   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7299E-04  [K,I,J]   42  116  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4858E-05  [K,I,J]   41  114  111
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   2555.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3198E-02  [K,I,J]   42  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1209E-04  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1025E-06  [K,I,J]   40  112  111
#
#  STRESS PERIOD NO.    8
#
#   STRESS PERIOD    8 TIME STEP    1 FROM TIME =   2555.0     TO    2920.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   2560.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1003E-02  [K,I,J]   42  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4767E-06  [K,I,J]   41  114  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   2567.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1400E-02  [K,I,J]   42  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1242E-05  [K,I,J]   41  114  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   2576.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1955E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3175E-05  [K,I,J]   41  114  111
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   2590.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2726E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7915E-05  [K,I,J]   41  114  111
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   2609.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3795E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1910E-04  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2033E-06  [K,I,J]   40  112  111
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   2636.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5269E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4419E-04  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7149E-06  [K,I,J]   40  112  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   2674.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7285E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9688E-04  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2246E-05  [K,I,J]   40  112  111
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   2727.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1001E-01  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1986E-03  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6528E-05  [K,I,J]   42  117   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   2800.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1362E-01  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4020E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2338E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7778E-06  [K,I,J]   41  114  111
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   2904.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1826E-01  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8291E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7916E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3169E-05  [K,I,J]   41  114  111
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   2920.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2798E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1007E-04  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6331E-07  [K,I,J]   40  112  111
#
#  STRESS PERIOD NO.    9
#
#   STRESS PERIOD    9 TIME STEP    1 FROM TIME =   2920.0     TO    3285.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   2925.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8764E-03  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4040E-06  [K,I,J]   41  114  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   2932.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1223E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1050E-05  [K,I,J]   41  114  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   2941.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1705E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2674E-05  [K,I,J]   41  114  111
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   2955.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2372E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6633E-05  [K,I,J]   41  114  111
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   2974.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3291E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1589E-04  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1365E-06  [K,I,J]   42  117  111
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   3001.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4549E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3639E-04  [K,I,J]   41  114  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5587E-06  [K,I,J]   42  117  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   3039.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6254E-02  [K,I,J]   43  114   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8564E-04  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2153E-05  [K,I,J]   42  117   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   3092.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8529E-02  [K,I,J]   43  114  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1953E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7792E-05  [K,I,J]   42  117   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   3165.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1159E-01  [K,I,J]   43  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4244E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2646E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5589E-06  [K,I,J]   42  116   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   3269.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1603E-01  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8718E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8441E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2412E-05  [K,I,J]   42  116   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   3285.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2455E-02  [K,I,J]   43  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1067E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6978E-07  [K,I,J]   42  117  111
#
#  STRESS PERIOD NO.   10
#
#   STRESS PERIOD   10 TIME STEP    1 FROM TIME =   3285.0     TO    3650.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   3290.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7698E-03  [K,I,J]   43  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4579E-06  [K,I,J]   42  117  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   3297.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1076E-02  [K,I,J]   43  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1182E-05  [K,I,J]   42  117  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   3306.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1504E-02  [K,I,J]   43  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2986E-05  [K,I,J]   42  117  111
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   3320.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2100E-02  [K,I,J]   43  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7348E-05  [K,I,J]   42  117  111
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   3339.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2928E-02  [K,I,J]   43  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1750E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1579E-06  [K,I,J]   42  117  111
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   3366.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4076E-02  [K,I,J]   43  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4008E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6346E-06  [K,I,J]   42  117  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   3404.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5656E-02  [K,I,J]   43  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8780E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2393E-05  [K,I,J]   42  117  111
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   3457.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7816E-02  [K,I,J]   43  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1919E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8433E-05  [K,I,J]   42  117   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   3530.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1073E-01  [K,I,J]   43  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4163E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2773E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3307E-06  [K,I,J]   42  116   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   3634.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1456E-01  [K,I,J]   43  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8516E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8496E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1960E-05  [K,I,J]   42  116   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   3650.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2231E-02  [K,I,J]   43  115   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1192E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7309E-07  [K,I,J]   42  117  111
#
#  STRESS PERIOD NO.   11
#
#   STRESS PERIOD   11 TIME STEP    1 FROM TIME =   3650.0     TO    4015.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   3655.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6991E-03  [K,I,J]   43  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5149E-06  [K,I,J]   42  117  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   3662.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9765E-03  [K,I,J]   43  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1325E-05  [K,I,J]   42  117  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   3671.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1363E-02  [K,I,J]   43  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3334E-05  [K,I,J]   42  117  111
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   3685.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1899E-02  [K,I,J]   44  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8158E-05  [K,I,J]   42  117  111
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   3704.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2644E-02  [K,I,J]   44  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1928E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1618E-06  [K,I,J]   42  117  111
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   3731.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3670E-02  [K,I,J]   44  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4373E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6457E-06  [K,I,J]   42  117  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   3769.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5077E-02  [K,I,J]   44  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9454E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2411E-05  [K,I,J]   42  117   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   3822.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6986E-02  [K,I,J]   44  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1937E-03  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8378E-05  [K,I,J]   42  117   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   3895.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9535E-02  [K,I,J]   44  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3867E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2702E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3387E-06  [K,I,J]   42  116   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   3999.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1286E-01  [K,I,J]   44  115  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7866E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8055E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1686E-05  [K,I,J]   42  116   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   4015.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1981E-02  [K,I,J]   44  116  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1251E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7120E-07  [K,I,J]   42  117  111
#
#  STRESS PERIOD NO.   12
#
#   STRESS PERIOD   12 TIME STEP    1 FROM TIME =   4015.0     TO    4380.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   4020.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6214E-03  [K,I,J]   44  116  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5423E-06  [K,I,J]   42  117  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   4027.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8692E-03  [K,I,J]   44  116  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1393E-05  [K,I,J]   42  117  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   4036.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1215E-02  [K,I,J]   44  116  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3498E-05  [K,I,J]   42  117  111
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   4050.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1699E-02  [K,I,J]   44  116  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8532E-05  [K,I,J]   42  117  111
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   4069.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2372E-02  [K,I,J]   44  116  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2007E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1575E-06  [K,I,J]   42  117  111
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   4096.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3309E-02  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4519E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6275E-06  [K,I,J]   42  117  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   4134.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4605E-02  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9671E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2334E-05  [K,I,J]   42  117  111
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   4187.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6389E-02  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1954E-03  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8050E-05  [K,I,J]   42  117   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   4260.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8816E-02  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3702E-03  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2562E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3192E-06  [K,I,J]   42  116   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   4364.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1206E-01  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6931E-03  [K,I,J]   41  115   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7479E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1488E-05  [K,I,J]   42  116   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   4380.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1857E-02  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1252E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6754E-07  [K,I,J]   42  117  111
#
#  STRESS PERIOD NO.   13
#
#   STRESS PERIOD   13 TIME STEP    1 FROM TIME =   4380.0     TO    4745.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   4385.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5824E-03  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5458E-06  [K,I,J]   42  117  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   4392.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8140E-03  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1399E-05  [K,I,J]   42  117  111
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   4401.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1137E-02  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3503E-05  [K,I,J]   42  117  111
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   4415.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1587E-02  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8510E-05  [K,I,J]   42  117  111
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   4434.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2211E-02  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1991E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1485E-06  [K,I,J]   42  117  111
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   4461.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3075E-02  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4452E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5902E-06  [K,I,J]   42  117  111
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   4499.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4263E-02  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9437E-04  [K,I,J]   42  117  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2185E-05  [K,I,J]   42  117  111
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   4552.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5883E-02  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1882E-03  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7482E-05  [K,I,J]   42  117   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   4625.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8062E-02  [K,I,J]   44  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3506E-03  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2352E-04  [K,I,J]   42  117   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2849E-06  [K,I,J]   42  116   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   4729.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1094E-01  [K,I,J]   45  116   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6041E-03  [K,I,J]   42  117   74
# ...
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1306E-02  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4043E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3113E-05  [K,I,J]   51  138   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   23709.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1821E-02  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8222E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8355E-05  [K,I,J]   51  138   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   23725.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2809E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1369E-05  [K,I,J]   51  138   74
#
#  STRESS PERIOD NO.   66
#
#   STRESS PERIOD   66 TIME STEP    1 FROM TIME =   23725.     TO    24090.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   23730.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8815E-04  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5925E-07  [K,I,J]   51  138   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   23737.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1234E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1520E-06  [K,I,J]   51  138   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   23747.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1727E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3810E-06  [K,I,J]   51  138   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   23761.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2416E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9258E-06  [K,I,J]   51  138   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   23780.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3379E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2164E-05  [K,I,J]   51  138   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   23807.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4725E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4822E-05  [K,I,J]   51  138   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   23844.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6604E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1015E-04  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2904E-06  [K,I,J]   51  138   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   23897.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9222E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2002E-04  [K,I,J]   51  138   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9577E-06  [K,I,J]   51  138   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   23971.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1286E-02  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4135E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2840E-05  [K,I,J]   51  138   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   24074.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1790E-02  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8413E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7574E-05  [K,I,J]   52  140   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   24090.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2758E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1268E-05  [K,I,J]   51  138   74
#
#  STRESS PERIOD NO.   67
#
#   STRESS PERIOD   67 TIME STEP    1 FROM TIME =   24090.     TO    24455.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   24095.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8653E-04  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5590E-07  [K,I,J]   55  147   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   24102.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1211E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1409E-06  [K,I,J]   51  138   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   24112.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1694E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3530E-06  [K,I,J]   51  138   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   24126.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2370E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8572E-06  [K,I,J]   51  138   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   24145.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3314E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2002E-05  [K,I,J]   51  138   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   24172.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4632E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4454E-05  [K,I,J]   51  138   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   24209.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6470E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9360E-05  [K,I,J]   51  138   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   24262.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9027E-03  [K,I,J]   61  141   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1956E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8718E-06  [K,I,J]   51  138   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   24336.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1258E-02  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4199E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2569E-05  [K,I,J]   51  138   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   24439.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1754E-02  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8545E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7215E-05  [K,I,J]   56  149   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   24455.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2706E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1172E-05  [K,I,J]   55  147   74
#
#  STRESS PERIOD NO.   68
#
#   STRESS PERIOD   68 TIME STEP    1 FROM TIME =   24455.     TO    24820.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   24460.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8490E-04  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5845E-07  [K,I,J]   55  147   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   24467.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1188E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1457E-06  [K,I,J]   55  147   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   24477.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1663E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3523E-06  [K,I,J]   55  147   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   24491.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2327E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8203E-06  [K,I,J]   55  147   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   24510.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3255E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1840E-05  [K,I,J]   51  138   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   24537.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4552E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4089E-05  [K,I,J]   51  138   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   24574.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6363E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8742E-05  [K,I,J]   53  143   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   24627.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8886E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1971E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8488E-06  [K,I,J]   56  149   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   24701.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1240E-02  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4233E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2595E-05  [K,I,J]   56  149   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   24804.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1726E-02  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8618E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7483E-05  [K,I,J]   56  149   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   24820.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2659E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1213E-05  [K,I,J]   55  147   74
#
#  STRESS PERIOD NO.   69
#
#   STRESS PERIOD   69 TIME STEP    1 FROM TIME =   24820.     TO    25185.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   24825.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8344E-04  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6064E-07  [K,I,J]   55  147   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   24832.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1168E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1511E-06  [K,I,J]   55  147   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   24842.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1634E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3650E-06  [K,I,J]   55  147   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   24856.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2286E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8488E-06  [K,I,J]   55  147   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   24875.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3196E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1888E-05  [K,I,J]   55  147   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   24902.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4468E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4091E-05  [K,I,J]   56  149   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   24939.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6241E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8748E-05  [K,I,J]   53  143   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   24992.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8708E-03  [K,I,J]   62  142   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1973E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8826E-06  [K,I,J]   56  149   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   25066.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1214E-02  [K,I,J]   62  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4239E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2684E-05  [K,I,J]   56  149   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   25169.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1693E-02  [K,I,J]   62  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8631E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7691E-05  [K,I,J]   56  149   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   25185.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2611E-03  [K,I,J]   62  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1251E-05  [K,I,J]   56  149   74
#
#  STRESS PERIOD NO.   70
#
#   STRESS PERIOD   70 TIME STEP    1 FROM TIME =   25185.     TO    25550.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   25190.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8194E-04  [K,I,J]   62  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6243E-07  [K,I,J]   55  147   74
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   25197.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1147E-03  [K,I,J]   62  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1554E-06  [K,I,J]   55  147   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   25207.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1605E-03  [K,I,J]   62  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3752E-06  [K,I,J]   55  147   74
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   25221.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2246E-03  [K,I,J]   62  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8716E-06  [K,I,J]   55  147   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   25240.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3142E-03  [K,I,J]   62  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1978E-05  [K,I,J]   56  149   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   25267.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4393E-03  [K,I,J]   62  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4303E-05  [K,I,J]   56  149   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   25304.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6140E-03  [K,I,J]   62  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8900E-05  [K,I,J]   56  149   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   25357.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8576E-03  [K,I,J]   62  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1962E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9090E-06  [K,I,J]   56  149   74
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   25431.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1196E-02  [K,I,J]   63  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4216E-04  [K,I,J]   53  143   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2751E-05  [K,I,J]   56  149   74
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   25534.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1667E-02  [K,I,J]   63  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8642E-04  [K,I,J]   54  145   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7836E-05  [K,I,J]   56  149   74
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   25550.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2567E-03  [K,I,J]   63  143   74
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1310E-05  [K,I,J]   56  149   74
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2023/10/28  0:12:48
#  Elapsed run time: 21 Minutes,  4.239 Seconds
#
#  Normal termination of SEAWAT
# (True, [])
