# %% [markdown]
# # Import

# %% [markdown]
# - fix shoreline
# - add more septics
# - 1965 images
# - flux

# %%
import flopy
import numpy as np
import matplotlib.pyplot as plt
import shutil
from pathlib import Path

from datetime import datetime
from tempfile import TemporaryDirectory
from tempfile import mkdtemp

import os
import platform
import subprocess
from shapely.geometry import Polygon, Point
from scipy.interpolate import make_interp_spline

# %%
def locate_ground_surface_lay(row=150):
    cross_section = ibound[:,:,0]
    lay = np.where(cross_section[:,row]==1)[0][0]
    return lay

def meter_to_col(col_meter):
    return int(np.round(col_meter/delc,0))

def meter_to_row(row_meter):
    return int(np.round(row_meter/delc,0))

def meter_to_lay(lay_meter):
    return int(np.round((top_elev-lay_meter)/layer_thickness,0))

def col_to_meter(col):
    return col*delc

def row_to_meter(row):
    return row*delc

def lay_to_meter(row):
    return 190.0-row*layer_thickness

# %%
def change_array_within_polygon(array, row_coords, col_coords, value):

    # Create a polygon object from the row and column coordinates
    polygon = Polygon(zip(col_coords, row_coords))

    # Create a boolean mask indicating which points fall within the polygon
    mask = np.zeros_like(array, dtype=bool)
    for row in range(array.shape[0]):
        for col in range(array.shape[1]):
            point = Point(col, row)
            if polygon.contains(point) or polygon.intersects(point):
                mask[row, col] = True

    # Set the values of the array that fall within the polygon to the new value
    array[mask] = value

    return array

# %% [markdown]
# # Workspace

# %%
# Control variable to decide the location of the temp folder
use_d_drive = False  # Set to False to use default temp location

# Define model workspace
myt = datetime.now().strftime('%m%d%H%M%S')
name = 'wasaga'

if use_d_drive:
    temp_dir = 'D:/_T{}_{}_'.format(myt, name)
    os.makedirs(temp_dir, exist_ok=True)
else:
    temp_dir = mkdtemp(prefix='_T{}_{}_'.format(myt, name))

os.makedirs(Path(temp_dir) / '_output', exist_ok=True)

model_ws = temp_dir

def open_file(path):
    if platform.system() == "Windows":
        os.startfile(path)
    elif platform.system() == "Darwin":
        subprocess.Popen(["open", path])
    else:
        subprocess.Popen(["xdg-open", path])

open_file(model_ws)

# %%
model_ws
# Out:
# 'C:\\Users\\swan47\\AppData\\Local\\Temp\\_T0117182556_wasaga_6ocycvka'

# %%
# base
parms= {}
parms['sp1']= 0.0002
parms['hk']= 6.9
parms['al'] = 5
base_parms = parms

# %% [markdown]
# # Model

# %%
# Create a MODFLOW model instance
mf = flopy.modflow.Modflow(modelname="example_model",version='mf2005',
                              exe_name='mf2005', 
                              model_ws=model_ws)

# %%
# # Create a MODFLOW model instance
# model = flopy.seawat.Seawat(modelname="example_model",
#                             exe_name='swtv4', 
#                               model_ws=model_ws)

# %% [markdown]
# # DIS

# %%
# year 1: 1968  (assume houses in 1978 [earilest satellite image] was built 10 years ago ) 
# year 56: (2024 present)
# year 76: (20 years later)
# year 156: (100 years later)
# year 556: (500 years later)

# %%
# Define model dimensions
nlay = int(60 * 2)
nrow = int(220 * 2)
ncol = int(220 * 2)
delr = 2200/nrow  # Cell width along rows (extend 2200 / 220)
delc = 2200/ncol  # Cell width along columns (extend 2200 / 220)

# Define top elevation
layer_thickness = 30.0 / nlay

top_elev = 190.0
botm_elev = [top_elev - (i * layer_thickness) for i in range(1, nlay + 1)]
# Define layer thickness (uniform thickness)


perlen = 365
nper = int(100)
#nper = int(56)
#nper = int(500)
#nper = int(20)

steady = np.append(np.array([True]),np.repeat(False,nper-1))
#steady=[False,False,True]
#steady = True

# Create DIS package

# %%
dis = flopy.modflow.ModflowDis(mf, nlay=nlay, nrow=nrow, ncol=ncol, 
                               delr=delr, delc=delc,top=top_elev, 
                               botm=botm_elev,
                               nper = nper, perlen = perlen,
                               nstp = 1, steady = steady)

# %% [markdown]
# # Ibound

# %%
x = np.array([0, 100, 340, 600, 750, 850, 1100, 1350, 1450, 1530, 1650, 1750, 1850, 2050, 2200])

y_topo = np.array([190,190,187,184,184,184,183,182,179,175.5,175,173.8,173.5,172,171])#topo
#y_topo = np.array([190,190,187,184,184,184,183,182,179+2,175.5+4,175+2,173.8+1,173.5+0,172,171])#topo

y_clay = np.array([185,184,180,175,174,174,173,170,169,168.5,167.5,166.8,166.5,165,164]) #clay


# Interpolate the data using smoothing splines
spl = make_interp_spline(x, y_topo)
x_smooth_topo = np.linspace(x.min(), x.max(), 30)
y_smooth_topo = spl(x_smooth_topo)

col_coords = (x_smooth_topo/delr).round(0)
col_coords_topo = list(col_coords) +[nrow,0]

row_coords = ((top_elev - y_smooth_topo)/layer_thickness).round(0)
row_coords_topo  =  list(row_coords) +[0,0]



# Interpolate the data using smoothing splines
spl = make_interp_spline(x, y_clay)
x_smooth = np.linspace(x.min(), x.max(), 30)
y_smooth = spl(x_smooth)

col_coords = (x_smooth/delr).round(0)
col_coords_clay = list(col_coords) +[nrow,0]
row_coords = ((top_elev - y_smooth)/layer_thickness).round(0)
row_coords_clay  =  list(row_coords) +[nlay,nlay]

# %% [markdown]
# # Ibound & Strt

# %%
# Define ibound and initial conditionsa
ibound = np.ones((nlay, nrow, ncol), dtype=int)
initial_head = np.full((nlay, nrow, ncol), 200.0, dtype=float)
shoreline_distance = 1600

# Set constant head boundary conditions for the first and last rows
array = change_array_within_polygon(ibound, row_coords_topo, col_coords_topo, 0)
plt.scatter(col_coords_topo,row_coords_topo,c='r')


array = change_array_within_polygon(ibound, row_coords_clay, col_coords_clay, 0)
plt.scatter(col_coords,row_coords,c='r')

for c in range(0,2):
    i = np.where(ibound[:,c,-1]==1)[0][-1]
    head = top_elev-i*layer_thickness
    #print('head {}'.format(head))
    
    while head<187:
        ibound[i,c,:] = -1
        #print(i,c)
        #initial_head[i,c,:] = head+0.5
        print(head)
        initial_head[i,c,:] = 187
        head+=layer_thickness
        i-=1


lay = np.where(ibound[:,int(shoreline_distance/delr),-1])[0][0]
elv = lay_to_meter(lay)
head = elv

for c in range(int(shoreline_distance/delr),int(2200/delr)):
    lay = np.where(ibound[:,c,-1]==1)[0][0]
    #print(lay,lay_to_meter(lay))
    ibound[lay,c,:] = -1
    initial_head[lay,c,:] = elv

# Your existing code
im = plt.imshow(ibound[:,:,2], origin='upper', aspect=1)
plt.axvline(x=meter_to_col(shoreline_distance))# shoreline
plt.gcf().set_size_inches(15,10)

# Set the y-axis tick positions and labels
#plt.yticks([0, 10,20, 30,40, 50,60], ['190m (0L)','185m (10L)', '180m (20L)','175m (30L)', '170m (40L)', '165m (50L)','160m (60L)'])
# Add a horizontal colorbar

cbar = plt.colorbar(im, orientation='horizontal')
cbar.ax.tick_params(labelsize=16)
cbar.set_label('Colorbar Label', fontsize=16)

# Display the plot
plt.title('ibound')
plt.grid()
plt.show()


fig, ax = plt.subplots(figsize=(15, 10))
im = ax.imshow(initial_head[:, :, 0], origin='upper')

# Add a horizontal colorbar
cbar = plt.colorbar(im, orientation='horizontal')
cbar.ax.tick_params(labelsize=18)
plt.title('initial head')
plt.show()
# Out:
# 185.25
# 185.5
# 185.75
# 186.0
# 186.25
# 186.5
# 186.75
# 185.0
# 185.25
# 185.5
# 185.75
# 186.0
# 186.25
# 186.5
# 186.75

# %% [markdown]
# # BAS LPF  PCG

# %%
# Create BAS package
bas = flopy.modflow.ModflowBas(mf, ibound=ibound, strt=initial_head)

# Define hydraulic properties
horizontal_k = parms['hk'] # Horizontal hydraulic conductivity (m/day)
vertical_ka = 0.1   # Vertical hydraulic conductivity (m/day)
porosity = 0.25     # Porosity

# Create LPF package (Layer Property Flow package)
lpf = flopy.modflow.ModflowLpf(mf, hk=horizontal_k, 
                               vka=vertical_ka, laytyp=1, 
                               ipakcb=None,ss=0.0002,sy=0.33,
                               laywet=1,iwetit=1,wetfct=0.1,ihdwet=1)

# #ss=0.0002,sy=0.33
# upw = flopy.modflow.ModflowUpw(model, laytyp=1, hk=horizontal_k)

pcg = flopy.modflow.ModflowPcg(mf, hclose=1e-3,npcond=1,
                               relax=0.99,rclose=1e-3,mutpcg=0,nbpol=1,iprpcg=1)

# %% [markdown]
# # Heterogeneity

# %%
# hk_mean = 2.3  # mean hydraulic conductivity
# hk_std = 2  # standard deviation of hydraulic conductivity
# hk= np.random.normal(hk_mean, hk_std, size=[nlay,nrow,ncol])
# hk[np.where(hk<0)]=0.001

# model.lpf.hk = hk

# %%
# hk_mean = np.log10(2.3)  # mean hydraulic conductivity
# hk_std = 0.4  # standard deviation of hydraulic conductivity
# hk= np.random.normal(hk_mean, hk_std, size=[nlay,nrow,ncol])
# hk = 10**hk
# #hk[np.where(hk<0)]=0.001
# hk.mean()
# model.lpf.hk = hk

# %%
# plt.hist(hk.flatten(),bins=np.linspace(0,30,50))
# plt.show()

# plt.imshow(hk[0,:,:])
# plt.show()

# %% [markdown]
# # DRN

# %%
# locate_ground_surface_lay(meter_to_row(160))
# #drn_cell = [(0, 150, 28), -10, 100]
# start_dis = shoreline_distance - 130
# end_dis = shoreline_distance - 70
# beach_drns = np.arange(start_dis,end_dis+1,delr).astype(int)
# river_drns = np.arange(595,605+1,delr).astype(int)
# #beach_drns = []

# drn_list = []
# drn_ys= list(beach_drns)+list(river_drns)

# for y in drn_ys:
   
#    row = meter_to_row(y)
#    lay = locate_ground_surface_lay(row=row)
#    elv = lay_to_meter(lay)
#    print(row)
#    #print(lay)
#    for col in range(ncol):

#       drn_list.append([lay, row, col, elv, 1])
#       #drn_list.append([12*2, meter_to_row(600), col, 184.0-0.5, 100])
      
# drn_cell = {0:drn_list} 

# #drn_cell={0:[[31, 160, 0, 174.5-0.5, 0],[12, 60, 0, 184.0-0.5, 0]]}
# drn = flopy.modflow.ModflowDrn(model=mf, stress_period_data=drn_cell,)

# %%
# Load your model
model = mf
# Plot the ibound array
plt.imshow(model.bas6.ibound.array[:, :, 0], origin='upper', cmap='bone')
# Plot drains for the first stress period if DRN package exists
if model.drn:
    for drn in np.unique(model.drn.stress_period_data[0], axis=0):
        if drn[2] == 0:  # Checks if the drain is in the first layer
            plt.scatter(drn[1], drn[0], c='cyan', s=5, marker='s')

# Customize and display the plot
plt.gcf().set_size_inches(15, 10)
plt.title('Ibound and Drain Cells Visualization')
plt.show()

# %%
# Check if the DRN package exists
if mf.drn is not None:
    # Find unique layers with drain cells
    lays_with_drn = np.unique([i[0] for i in mf.drn.stress_period_data.data[0]])
    
    # Plot drain cells for each layer with drains
    for lay in lays_with_drn:
        pmv = flopy.plot.PlotMapView(model=mf, layer=lay)
        pmv.plot_ibound()  # Optional: Plot ibound for background, comment this line if not needed
        pmv.plot_bc('DRN', color='r')
        plt.title(f'Drain Cells in Layer {lay + 1}')
        plt.show()
else:
    print("No DRN package found in the model, skipping drain cell plotting.")
# Out:
# No DRN package found in the model, skipping drain cell plotting.

# %% [markdown]
# # RCH

# %% [markdown]
# ### Test data

# %%
##2D pers [1]+[30,92,31,212]*25 +[365]*5+[365*5]*5+[365*4]+[185,30,30,120]

# %%
# rch_dict = {}

# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# rch_dict[0] = rch_array

# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# #rch_array[int(nrow/2),int(ncol/2)] = 0.51/delr/delc
# #rch_array[int(nrow/2),int(ncol/3)] = 0.51/delr/delc

# rch_array[int((1700-70)/delr),int(ncol/2)] = 0.51/delr/delc
# rch_array[int((1700-70)/delr),int(ncol/3)] = 0.51/delr/delc
# rch_dict[1] = rch_array 


# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# rch_dict[26] = rch_array


# rch = flopy.modflow.ModflowRch(model = mf, rech = rch_dict)

# %%
# shoreline at 1700m , septic at 1700-60

# %%
def calculate_year_septic_start(df):
    # Ensure the DataFrame is sorted by 'Year'
    df = df.sort_values('Year').reset_index(drop=True)
    
    # Get the unique years and sort them
    unique_years = sorted(df['Year'].unique())
    
    # Initialize the "Year_Septic_Start" list
    year_septic_start = []
    
    # Iterate through the DataFrame rows
    for current_year in df['Year']:
        # Find the index of the current_year in the unique_years list
        current_index = unique_years.index(current_year)
        
        # Determine the previous year (if it's not the first year)
        if current_index == 0:
            #previous_year = 1950  # If it's the first unique year, use 1950
            year_septic_start.append(1950)
        else:
            previous_year = unique_years[current_index - 1]  # Get the previous unique year
        
        # Calculate the "Year_Septic_Start"
            year_septic_start.append((current_year + previous_year) // 2)
    
    # Add the "Year_Septic_Start" as a new column in the DataFrame
    df['Year_Septic_Start'] = year_septic_start
    return df

# %%
import pandas as pd
df = pd.read_csv("wasaga septics placement/septics_transformed.csv")
df = df[~df['Year End'].isna()]
df['Year End'] =df['Year End'].astype(int)
df = calculate_year_septic_start(df)
df['Year_Septic_End'] = df['Sewer_Installation_Period'].apply(lambda x: (int(x.split('-')[1]) + int(x.split('-')[0]))//2)

# %%
# Assuming nrow, ncol, delr, delc, and mf are defined earlier in your code

# Initialize the recharge dictionary
rch_dict = {0: np.full((nrow, ncol), 0.00013, dtype=float)}  # Initial background recharge rate



# Loop through the DataFrame to update rch_dict
for index, row in df.iterrows():
    easting = row['Wasaga Easting']
    northing = row['Wasaga Northing']
    start_year = row['Year_Septic_Start']
    end_year = row['Year_Septic_End']

    # Calculate the indices
    row_index = int(northing / delr)
    col_index = int(easting / delc)

    # Calculate the range of years for each septic source
    start_key = start_year - 1950 + 1
    end_key = end_year - 1950 + 1

    # Loop through each year for the septic source
    for year_key in range(start_key, end_key + 1):
        # Check if the key exists in the dictionary, if not, create a new array with background recharge
        if year_key not in rch_dict:
            rch_dict[year_key] = np.full((nrow, ncol), 0.00013, dtype=float)

        # Update the recharge rate at the septic location
        rch_dict[year_key][row_index, col_index] = 0.51 / delr / delc
    
    # Ensure the septic is turned off after its end year
    # Check if the year after the end_key exists in the dictionary, if not, create a new array with background recharge
    if end_key + 1 not in rch_dict:
        rch_dict[end_key + 1] = np.full((nrow, ncol), 0.00013, dtype=float)
    
    # Set the recharge rate back to the background rate after the septic system's active period
    rch_dict[end_key + 1][row_index, col_index] = 0.00013

# Create the ModflowRch object
rch = flopy.modflow.ModflowRch(model=mf, rech=rch_dict)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calculate and plot in a compact form
kpers, active_septics = zip(*sorted((year_key, np.sum(rech >= 0.51 / delr / delc)) for year_key, rech in rch_dict.items()))

fig, ax1 = plt.subplots(figsize=(10, 6))
bars = ax1.bar(kpers, active_septics, color='dodgerblue', alpha=0.7)

ax1.set(xlabel='kper', ylabel='Number of Active Septic Sources', title='Active Septic Sources Over Time')

ax2 = ax1.twiny().set(xlabel='Year', xlim=[k + 1950 for k in ax1.get_xlim()], xticks=[k + 1950 for k in ax1.get_xticks()],
                      xticklabels=[int(k + 1950) for k in ax1.get_xticks()])
ax1.grid(axis='y', linestyle='--', alpha=0.7)

for bar, val in zip(bars, active_septics):
    if val == 0: ax1.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(val), ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout(); plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming crch_dict is already defined and filled with your data

period = max(rch_dict.keys()) - 30  # Specify the period you want to visualize
if period in rch_dict: 
    crch_array = rch_dict[period]
    plt.imshow(crch_array, cmap='viridis', interpolation='nearest')
    plt.colorbar(label='Concentration');plt.gca().invert_yaxis()
    plt.xlabel('Column Index'); plt.ylabel('Row Index'); plt.title(f'RCH Array Visualization at Period {period}');plt.show()
else: print(f"No data available for period {period}")

# %% [markdown]
# # OC

# %%
# OC
spd = {}
for kper in range(nper):
    for kstp in range(1):
        spd[(kper, kstp)] = [
            "save head",
            "save drawdown",
            "save budget",
            "print head",
            "print budget",
        ]

oc = flopy.modflow.ModflowOc(
    mf,
    stress_period_data= spd,
    compact=True
    ,extension=['oc', 'hds', 'ddn', 'cbc', 'ibo']
)

#oc.reset_budgetunit(budgetunit=1053, fname='test.cbc')
oc.reset_budgetunit(budgetunit=53, fname='example_model.cbc')

# %%
lmt = flopy.modflow.ModflowLmt(mf, output_file_name='mt3d_link.ftl')

# %%
# Write the MODFLOW model input files
mf.write_input()

# %%
# Run the MODFLOW model
success, buff = mf.run_model()
# Out:
# FloPy is using the following executable to run the model: C:\Users\swan47\AppData\Local\flopy\bin\mf2005.EXE
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.12.00 2/3/2017
#
#  Using NAME file: example_model.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2024/01/17 18:27:06
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     2    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     3    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     4    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     5    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     6    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     7    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     8    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     9    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    10    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    11    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    12    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    13    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    14    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    15    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    16    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    17    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    18    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    19    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    20    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    21    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    22    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    23    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    24    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    25    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    26    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    27    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    28    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    29    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    30    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    31    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    32    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    33    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    34    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    35    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    36    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    37    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    38    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    39    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    40    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    41    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    42    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    43    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    44    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    45    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    46    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    47    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    48    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    49    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    50    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    51    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    52    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    53    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    54    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    55    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    56    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    57    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    58    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    59    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    60    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    61    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    62    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    63    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    64    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    65    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    66    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    67    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    68    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    69    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    70    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    71    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    72    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    73    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    74    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    75    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    76    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    77    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    78    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    79    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    80    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    81    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    82    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    83    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    84    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    85    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    86    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    87    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    88    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    89    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    90    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    91    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    92    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    93    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    94    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    95    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    96    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    97    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    98    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    99    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:   100    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2024/01/17 19:43:05
#  Elapsed run time:  1 Hours, 15 Minutes, 59 Seconds
#
#   Normal termination of simulation

# %% [markdown]
# # ---MT3DMS---

# %%
mt = flopy.mt3d.Mt3dms(modflowmodel=mf, modelname='mt', exe_name='mt3dms.exe' ,ftlfilename='mt3d_link.ftl',model_ws=model_ws)

# %% [markdown]
# # ICBUND

# %%
icbund = ibound.copy()
cc = np.where(icbund==-1)
mask = cc[1]>2200/2/delr

cc2 = (cc[0][mask],cc[1][mask],cc[2][mask])
icbund[cc2] = 1
plt.imshow(icbund[:,:,0])

# %% [markdown]
# # BTN ICBOUND

# %%
#icbund = np.full((nlay, nrow, ncol),0, dtype=float)
#
btn = flopy.mt3d.Mt3dBtn(
    mt,
    nprs=5,
    timprs=np.cumsum([200]*7),
    prsity=0.25,
    sconc= 0.01, # starting concentration
    ifmtcn=0, chkmas=False, nprobs=10, nprmas=10,
    dt0=5,  # The user-specified initial 
    ttsmult=1.4,
    mxstrn = 50000,
    icbund = icbund
)

# %%
adv = flopy.mt3d.Mt3dAdv(mt, mixelm=0,percel=0.4,mxpart=50000000,nadvfd=0)
dsp = flopy.mt3d.Mt3dDsp(mt, al=parms['al'], trpt=0.1, 
                        trpv=0.01, 
                        dmcoef=3.7E-10 )  ## !!TRVP change to 0.01
gcg = flopy.mt3d.Mt3dGcg(mt, iter1=50, mxiter=1, isolve=2, cclose= 1e-5)

# %% [markdown]
# # RCH

# %%
# crch_array =  np.full(( nrow, ncol), 0.1, dtype=float)
# crch_dict = {}
# crch_dict[0] = crch_array
# ssm = flopy.mt3d.Mt3dSsm(model, crch=crch_dict)

# rch_dict = {}
# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# rch_dict[0] = rch_array
# rch = flopy.modflow.ModflowRch(model = model, rech = rch_dict)


# ## [row, col, rch(m3), crch, start, end]
# rch_data = [[1100,1100,0.51,5000,1,20]]

# %% [markdown]
# ### Real Septics

# %%
import numpy as np
import pandas as pd
import flopy

# Assuming nrow, ncol, delr, delc, and mt are defined earlier in your code

# Initialize the base concentration array and the dictionary
crch_array_base = np.full((nrow, ncol), 0.01, dtype=float)
crch_dict = {0: crch_array_base.copy()}

# Read the CSV file from the specified path
df = pd.read_csv("wasaga septics placement/septics_transformed.csv")
df = df[~df['Year End'].isna()]
df['Year End'] =df['Year End'].astype(int)

# Loop through the DataFrame to update crch_dict
for index, row in df.iterrows():
    easting = row['Wasaga Easting']
    northing = row['Wasaga Northing']
    start_year = row['Year']
    end_year = row['Year End']

    # Calculate the indices
    row_index = int(northing / delr)  # Using northing for row index
    col_index = int(easting / delc)   # Using easting for column index

    # Calculate the range of years for each septic source
    start_key = start_year - 1968
    end_key = end_year - 1968

    # Loop through each year for the septic source
    for year_key in range(start_key, end_key + 1):
        # Check if the key exists in the dictionary, if not, create a new array
        if year_key not in crch_dict:
            crch_dict[year_key] = crch_array_base.copy()

        # Update the concentration at the specified location
        crch_dict[year_key][row_index, col_index] = 5000  # or any other value you wish to set

# Create the SSM object
ssm = flopy.mt3d.Mt3dSsm(mt, crch=crch_dict)

# %%
import numpy as np
import pandas as pd
import flopy

# Assuming nrow, ncol, delr, delc, and mt are defined earlier in your code
# Also assuming rch_dict is already defined from your MODFLOW recharge setup

# Initialize the base concentration array and the dictionary
crch_array_base = np.full((nrow, ncol), 0.01, dtype=float)  # Background concentration
crch_dict = {}

# Constants for recharge and concentration
background_recharge = 0.00013
septic_recharge = 0.51 / delr / delc
background_concentration = 0.01
septic_concentration = 5000

# Loop through each stress period in rch_dict
for stress_period, rch_array in rch_dict.items():
    # Copy the base concentration array for the current stress period
    crch_array = crch_array_base.copy()
    
    # Find indices where recharge rate indicates a septic source
    septic_indices = np.where(rch_array == septic_recharge)
    
    # Update the concentration array at these indices
    crch_array[septic_indices] = septic_concentration
    
    # Store the updated concentration array in crch_dict for the current stress period
    crch_dict[stress_period] = crch_array

# Create the SSM object using crch_dict
ssm = flopy.mt3d.Mt3dSsm(mt, crch=crch_dict)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Constants for recharge and concentration
septic_concentration = 5000

# Calculate and plot in a compact form
kpers, active_septics = zip(*sorted((year_key, np.sum(crch == septic_concentration)) for year_key, crch in crch_dict.items()))

fig, ax1 = plt.subplots(figsize=(10, 6))
bars = ax1.bar(kpers, active_septics, color='dodgerblue', alpha=0.7)

ax1.set(xlabel='Stress Period (kper)', ylabel='Number of Active Septic Sources', title='Active Septic Sources Over Time')

# Adjust the x-axis to show actual years assuming the first stress period starts in 1950 (change if needed)
start_year = 1950
ax2 = ax1.twiny()
ax2.set(xlabel='Year', xlim=[start_year + kpers[0], start_year + kpers[-1]], xticks=[start_year + k for k in ax1.get_xticks()],
        xticklabels=[int(start_year + k) for k in ax1.get_xticks()])
ax1.grid(axis='y', linestyle='--', alpha=0.7)

# Add text labels on the bars
for bar, val in zip(bars, active_septics):
    if val == 0:
        ax1.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(val), ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming crch_dict is already defined and filled with your data

period = 47  # Specify the period you want to visualize

# Check if the period exists in the dictionary
if period in crch_dict:
    # Extract the array for the specified period
    crch_array = crch_dict[period]

    # Create a heatmap of the array
    plt.imshow(crch_array, cmap='viridis', interpolation='nearest')
    plt.colorbar(label='Concentration')  # Add a color bar to indicate the values

    # Flip the y-axis
    plt.gca().invert_yaxis()

    # Add labels and title
    plt.xlabel('Column Index')
    plt.ylabel('Row Index')
    plt.title(f'CRCH Array Visualization at Period {period}')

    # Show the plot
    plt.show()
else:
    print(f"No data available for period {period}")

# %% [markdown]
# ### Test SSM

# %%
# crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)
# crch_dict = {}
# crch_dict[0] = crch_array

# crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)

# # crch_array[int(nrow/2),int(ncol/2)] =5000
# # crch_array[int(nrow/2),int(ncol/3)] =5000
# crch_array[int((1700-70)/delr),int(ncol/3)] =5000
# crch_array[int((1700-70)/delr),int(ncol/2)] =5000
# spetic_locs = [[int((1700-70)/delr),int(ncol/3)], [int((1700-70)/delr),int(ncol/2)]]

# crch_dict = {}
# crch_dict[1] = crch_array


# crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)
# crch_dict[26] = crch_array

# ssm = flopy.mt3d.Mt3dSsm(mt, crch=crch_dict)

# %% [markdown]
# # RCT

# %%
rct = flopy.mt3d.Mt3dRct(model=mt, isothm=3,sp1=parms['sp1'],sp2=0.0001,igetsc=0,rhob= 1.65E+09)

# %% [markdown]
# # Write and Run

# %%
# Write MODFLOW input files
mt.write_input()

# %%
open_file(model_ws)

# %%
# Run the MODFLOW model
mt.run_model()
# Out:
# FloPy is using the following executable to run the model: C:\Users\swan47\AppData\Local\flopy\bin\mt3dms.exe
#  MT3DMS - Modular 3-D Multi-Species Transport Model [Version 5.30]
#  Developed at University of Alabama for U.S. Department of Defense
#
#  Using NAME File: mt.nam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    365.00
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   5.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2076E-02  [K,I,J]   61  319  438
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]   62  318    2
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   12.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2849E-02  [K,I,J]   61  319  439
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1192E-06  [K,I,J]   62  318    1
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   21.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3881E-02  [K,I,J]   61  319  439
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-06  [K,I,J]   63  319    1
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   35.520
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5233E-02  [K,I,J]   61  319  439
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8345E-06  [K,I,J]   63  320    1
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   54.728
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6959E-02  [K,I,J]   61  319  439
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2742E-05  [K,I,J]   63  320    1
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   81.619
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9089E-02  [K,I,J]   61  319  439
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8345E-05  [K,I,J]   63  320    1
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   119.27
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1160E-01  [K,I,J]   61  319  439
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3040E-04  [K,I,J]   63  321    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7749E-06  [K,I,J]   63  321    1
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   171.97
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1437E-01  [K,I,J]   61  319  439
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9173E-04  [K,I,J]   63  321    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2980E-05  [K,I,J]   63  320    1
#  Transport Step:    9   Step Size:   28.03     Total Elapsed Time:   200.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7094E-02  [K,I,J]   61  319  439
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2146E-04  [K,I,J]   63  321    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2980E-06  [K,I,J]   63  320    1
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   303.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2153E-01  [K,I,J]   61  319  439
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4811E-03  [K,I,J]   63  321    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2736E-04  [K,I,J]   63  321    2
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8345E-06  [K,I,J]   63  322    1
#  Transport Step:   11   Step Size:   61.69     Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1120E-01  [K,I,J]   61  319  439
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1692E-03  [K,I,J]   63  321    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5066E-05  [K,I,J]   63  320    1
#
#  STRESS PERIOD NO.    2
#
#  TIME STEP NO.    1
#  FROM TIME =   365.00     TO    730.00
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   370.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1257E+05  [K,I,J]   47  235  207
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   799.7      [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =   39.89      [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =   1.960      [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1531      [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1196E-01  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.9766E-03  [K,I,J]   47  235  207
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2861E-05  [K,I,J]   14    7  128
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   377.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8348      [K,I,J]   16   20  252
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1262      [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1112E-01  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7873E-03  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8935E-04  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9298E-05  [K,I,J]   48  235  207
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   386.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6129      [K,I,J]   18   28  412
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1300      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1655E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2011E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2676E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3642E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5722E-05  [K,I,J]   17   22   84
#  Transport Step:    4   Step Size:   13.20     Total Elapsed Time:   400.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4752      [K,I,J]   23   50  259
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1286      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2107E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4311E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6092E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1153E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2033E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4351E-05  [K,I,J]   17   22   84
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   419.21
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4063      [K,I,J]   24   54  246
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1351      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2935E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9530E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1729E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4042E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.9638E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2217E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6258E-05  [K,I,J]   17   22   84
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   446.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3509      [K,I,J]   15   14  229
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1292      [K,I,J]   21   39  158
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3864E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1440E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4207E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1016E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3041E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.8690E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2491E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.8702E-05  [K,I,J]   17   22   84
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   483.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3120      [K,I,J]   48  233   89
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1228      [K,I,J]   49  238  331
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5130E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1775E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8193E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2360E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7384E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2714E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.9120E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3040E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1311E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.4530E-05  [K,I,J]   17   22   84
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   536.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2821      [K,I,J]   48  233   89
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1095      [K,I,J]   47  226  255
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6274E-01  [K,I,J]   14    8  176
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2216E-01  [K,I,J]   45  211   69
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1096E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4681E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1584E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5928E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2673E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1092E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3850E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1681E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.7629E-05  [K,I,J]   17   22   84
#  Transport Step:    9   Step Size:   63.55     Total Elapsed Time:   600.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2197      [K,I,J]   48  233   89
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8672E-01  [K,I,J]   47  226  246
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5909E-01  [K,I,J]   51  253  184
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2063E-01  [K,I,J]   56  284  334
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1070E-01  [K,I,J]   15   11  396
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5222E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2100E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9059E-03  [K,I,J]   17   20  406
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3487E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1645E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.6783E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2646E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1287E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.6318E-05  [K,I,J]   17   22   84
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   703.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2162      [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8638E-01  [K,I,J]   44  205  227
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7203E-01  [K,I,J]   49  238  331
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3016E-01  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1499E-01  [K,I,J]   47  226  246
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9149E-02  [K,I,J]   47  226  255
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4605E-02  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1961E-02  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1057E-02  [K,I,J]   42  191  220
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5097E-03  [K,I,J]   42  191  199
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2021E-03  [K,I,J]   24   51  181
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.9811E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.4613E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.2098E-04  [K,I,J]   42  191  199
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1061E-04  [K,I,J]   24   51  181
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.5603E-05  [K,I,J]   17   22   84
#  Transport Step:   11   Step Size:   26.69     Total Elapsed Time:   730.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4519E-01  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2109E-01  [K,I,J]   49  238  331
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8563E-02  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2925E-02  [K,I,J]   42  191  220
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1287E-02  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3707E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1181E-03  [K,I,J]   42  191  199
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4327E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1484E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4828E-05  [K,I,J]   17   22   84
#
#  STRESS PERIOD NO.    3
#
#  TIME STEP NO.    1
#  FROM TIME =   730.00     TO    1095.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   735.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7277      [K,I,J]   46  231  228
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5914E-01  [K,I,J]   48  234    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8052E-02  [K,I,J]   48  235  168
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6640E-04  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1305E-02  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1413E-04  [K,I,J]   48  235  168
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2801E-05  [K,I,J]   48  235  168
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   742.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2348      [K,I,J]   36  151  224
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1788E-01  [K,I,J]   48  235  168
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2560E-02  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3133E-03  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2083E-03  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3552E-04  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4709E-05  [K,I,J]   45  215  161
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   751.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1380      [K,I,J]   44  215  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1388E-01  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2073E-02  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4216E-03  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8720E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2319E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3994E-05  [K,I,J]   47  231  228
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   765.52
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7634E-01  [K,I,J]   44  215  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2019E-01  [K,I,J]   49  243  232
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3557E-02  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1194E-02  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2639E-03  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7361E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2110E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5186E-05  [K,I,J]   47  231  228
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   784.73
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5541E-01  [K,I,J]   46  229  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2750E-01  [K,I,J]   47  229  174
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4896E-02  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2313E-02  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6532E-03  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1855E-03  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6539E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2021E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6080E-05  [K,I,J]   47  231  228
#  Transport Step:    6   Step Size:   15.27     Total Elapsed Time:   800.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3567E-01  [K,I,J]   23   52  252
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1772E-01  [K,I,J]   47  229  174
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3182E-02  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1202E-02  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3058E-03  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7802E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2778E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.7272E-05  [K,I,J]   47  231  228
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   837.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6411E-01  [K,I,J]   47  234  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3978E-01  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1313E-01  [K,I,J]   47  227   54
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4957E-02  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2475E-02  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9506E-03  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3245E-03  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1498E-03  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6026E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2486E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.9239E-05  [K,I,J]   47  231  228
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   890.35
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6615E-01  [K,I,J]   47  234  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3657E-01  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1930E-01  [K,I,J]   47  227   54
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5374E-02  [K,I,J]   43  196  400
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3709E-02  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1480E-02  [K,I,J]   46  222  164
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7274E-03  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2515E-03  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1329E-03  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5460E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2718E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1180E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.5245E-05  [K,I,J]   47  231  228
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   964.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6754E-01  [K,I,J]   47  234  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3072E-01  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2377E-01  [K,I,J]   48  235  168
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7402E-02  [K,I,J]   47  227   54
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4039E-02  [K,I,J]   57  292  339
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2486E-02  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1080E-02  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5023E-03  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2056E-03  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1301E-03  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.5436E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2670E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1299E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.6795E-05  [K,I,J]   47  231  228
#  Transport Step:   10   Step Size:   35.86     Total Elapsed Time:   1000.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2921E-01  [K,I,J]   47  234  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1524E-01  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6806E-02  [K,I,J]   47  227   54
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2176E-02  [K,I,J]   43  196  400
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1107E-02  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4659E-03  [K,I,J]   45  216  117
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1729E-03  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6944E-04  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3010E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1252E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.4947E-05  [K,I,J]   47  231  228
#  Transport Step:   11   Step Size:   95.00     Total Elapsed Time:   1095.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6022E-01  [K,I,J]   47  234  219
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2436E-01  [K,I,J]   37  145  381
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1952E-01  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8595E-02  [K,I,J]   53  266   26
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4700E-02  [K,I,J]   43  196  400
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2317E-02  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1143E-02  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6689E-03  [K,I,J]   45  216  117
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3109E-03  [K,I,J]   45  216  117
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1303E-03  [K,I,J]   45  216  117
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.7665E-04  [K,I,J]   45  215  161
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.4041E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.2182E-04  [K,I,J]   47  231  228
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.9894E-05  [K,I,J]   47  231  228
#
#  STRESS PERIOD NO.    4
#
#  TIME STEP NO.    1
#  FROM TIME =   1095.0     TO    1460.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1100.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6914      [K,I,J]   44  219  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7312E-01  [K,I,J]   49  244  242
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8662E-02  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1101E-02  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1285E-03  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2861E-05  [K,I,J]   50  248  235
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1107.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2333      [K,I,J]   49  250  183
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1803E-01  [K,I,J]   47  231  195
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1800E-02  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2006E-03  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2909E-04  [K,I,J]   49  241  169
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3874E-05  [K,I,J]   45  219  243
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1116.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9647E-01  [K,I,J]   49  250  183
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1269E-01  [K,I,J]   37  155  192
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1903E-02  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3468E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7927E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2062E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4053E-05  [K,I,J]   45  219  243
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1130.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7848E-01  [K,I,J]   48  244  232
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2040E-01  [K,I,J]   44  211  229
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2352E-02  [K,I,J]   46  226  193
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1125E-02  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1928E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7302E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1866E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4649E-05  [K,I,J]   45  219  243
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1149.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7450E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2722E-01  [K,I,J]   42  196  155
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2740E-02  [K,I,J]   46  226  193
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1721E-02  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5571E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1381E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5561E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1800E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4947E-05  [K,I,J]   45  219  243
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1176.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7669E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3002E-01  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4368E-02  [K,I,J]   48  238  170
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1646E-02  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1162E-02  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3245E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1112E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4625E-04  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1752E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5484E-05  [K,I,J]   45  219  243
#  Transport Step:    7   Step Size:   23.38     Total Elapsed Time:   1200.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5220E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2001E-01  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2777E-02  [K,I,J]   48  238  170
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1121E-02  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6641E-03  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1772E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6217E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2468E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.8523E-05  [K,I,J]   45  219  243
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1252.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8246E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2311E-01  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1473E-01  [K,I,J]   51  256  165
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3389E-02  [K,I,J]   60  308   16
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1302E-02  [K,I,J]   46  226  193
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1134E-02  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4639E-03  [K,I,J]   46  226  193
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1938E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.8166E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3916E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1848E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.7868E-05  [K,I,J]   45  219  243
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   1326.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7672E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1646E-01  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1586E-01  [K,I,J]   51  256  165
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6104E-02  [K,I,J]   51  256  165
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1878E-02  [K,I,J]   35  131  193
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9793E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6787E-03  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3532E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1724E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7081E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3600E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1884E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.9298E-05  [K,I,J]   45  219  243
#  Transport Step:   10   Step Size:   73.50     Total Elapsed Time:   1400.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5373E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1116E-01  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1137E-01  [K,I,J]   51  256  165
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4966E-02  [K,I,J]   51  256  165
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1614E-02  [K,I,J]   38  157  385
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7850E-03  [K,I,J]   37  151  224
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5051E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2823E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1412E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5865E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2980E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1580E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.7689E-05  [K,I,J]   45  219  243
#  Transport Step:   11   Step Size:   60.00     Total Elapsed Time:   1460.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3388E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7720E-02  [K,I,J]   50  250  183
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7329E-02  [K,I,J]   51  256  165
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2766E-02  [K,I,J]   51  256  165
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1072E-02  [K,I,J]   38  157  385
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5258E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2993E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1553E-03  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7403E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3105E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1568E-04  [K,I,J]   45  219  243
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.7093E-05  [K,I,J]   45  219  243
#
#  STRESS PERIOD NO.    5
#
#  TIME STEP NO.    1
#  FROM TIME =   1460.0     TO    1825.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1465.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6427      [K,I,J]   36  156   88
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8226E-01  [K,I,J]   48  239  222
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8116E-02  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5282E-03  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1401E-04  [K,I,J]   49  243  232
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3457E-05  [K,I,J]   35  135  208
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1472.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2258      [K,I,J]   34  135  208
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1493E-01  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1179E-02  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9668E-04  [K,I,J]   47  229  146
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4184E-04  [K,I,J]   47  229  146
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6926E-04  [K,I,J]   47  229  146
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1192E-06  [K,I,J]   39  171   32
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1481.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9663E-01  [K,I,J]   50  257  247
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1405E-01  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1342E-02  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2062E-03  [K,I,J]   36  135  208
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4274E-04  [K,I,J]   36  135  208
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1270E-04  [K,I,J]   37  156   88
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1609E-05  [K,I,J]   37  156   88
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1495.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9379E-01  [K,I,J]   50  257  247
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2252E-01  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1655E-02  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7970E-03  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1169E-03  [K,I,J]   37  156   88
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3260E-04  [K,I,J]   37  156   88
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1103E-04  [K,I,J]   37  156   88
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2027E-05  [K,I,J]   37  156   88
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1514.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8389E-01  [K,I,J]   46  232  228
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2836E-01  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1805E-02  [K,I,J]   48  237  298
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1238E-02  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4381E-03  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7117E-04  [K,I,J]   37  156   88
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2527E-04  [K,I,J]   37  156   88
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9239E-05  [K,I,J]   35  135  208
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1541.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7711E-01  [K,I,J]   45  225  184
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2905E-01  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3369E-02  [K,I,J]   45  217   49
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9948E-03  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8600E-03  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2582E-03  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5013E-04  [K,I,J]   48  237  298
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1997E-04  [K,I,J]   48  237  298
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.8047E-05  [K,I,J]   35  135  208
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   1579.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7030E-01  [K,I,J]   44  218  233
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2362E-01  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8378E-02  [K,I,J]   48  239  222
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1365E-02  [K,I,J]   46  226  255
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8256E-03  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5348E-03  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1613E-03  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4202E-04  [K,I,J]   48  237  298
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1824E-04  [K,I,J]   48  237  298
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7927E-05  [K,I,J]   48  237  298
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1632.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5997E-01  [K,I,J]   44  218  233
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1576E-01  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1253E-01  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2902E-02  [K,I,J]   48  239  222
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8447E-03  [K,I,J]   18   27   52
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5421E-03  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3240E-03  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1195E-03  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4143E-04  [K,I,J]   41  189   73
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1800E-04  [K,I,J]   48  237  298
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.7868E-05  [K,I,J]   48  237  298
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   1705.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5002E-01  [K,I,J]   44  218  233
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1016E-01  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1241E-01  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5466E-02  [K,I,J]   48  239  222
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1258E-02  [K,I,J]   38  157  385
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5649E-03  [K,I,J]   48  237  298
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3427E-03  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2289E-03  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.9066E-04  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3672E-04  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1740E-04  [K,I,J]   48  237  298
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.8881E-05  [K,I,J]   48  237  298
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   1809.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4358E-01  [K,I,J]   44  218  233
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7393E-02  [K,I,J]   37  145  381
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9937E-02  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6965E-02  [K,I,J]   48  239  222
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2149E-02  [K,I,J]   28   74   51
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8503E-03  [K,I,J]   40  175  403
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4786E-03  [K,I,J]   37  156   88
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2702E-03  [K,I,J]   37  156   88
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1392E-03  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7206E-04  [K,I,J]   35  135  208
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3314E-04  [K,I,J]   41  189   94
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1603E-04  [K,I,J]   37  156   88
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.8881E-05  [K,I,J]   37  156   88
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   1825.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6660E-02  [K,I,J]   38  172  211
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2416E-02  [K,I,J]   48  239  222
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5628E-03  [K,I,J]   28   74   51
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1330E-03  [K,I,J]   37  156   88
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4977E-04  [K,I,J]   37  156   88
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1502E-04  [K,I,J]   37  156   88
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4590E-05  [K,I,J]   37  156   88
#
#  STRESS PERIOD NO.    6
#
#  TIME STEP NO.    1
#  FROM TIME =   1825.0     TO    2190.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1830.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6472      [K,I,J]   43  213  125
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8487E-01  [K,I,J]   46  225  119
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6552E-02  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3084E-03  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1502E-04  [K,I,J]   44  211  229
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3457E-05  [K,I,J]   46  223  123
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1837.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2230      [K,I,J]   37  166   59
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1458E-01  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8096E-03  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8821E-04  [K,I,J]   46  223  123
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9298E-05  [K,I,J]   39  166   59
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1846.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1102      [K,I,J]   46  233  176
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1403E-01  [K,I,J]   39  176  134
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1393E-02  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2027E-03  [K,I,J]   39  166   59
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5406E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5198E-04  [K,I,J]   38  163   63
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4297E-04  [K,I,J]   46  223  123
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4172E-06  [K,I,J]   43  213  125
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1860.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1070      [K,I,J]   46  233  176
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2284E-01  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1472E-02  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7207E-03  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9692E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3988E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1281E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2265E-05  [K,I,J]   44  213  125
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1879.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9292E-01  [K,I,J]   47  239  239
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2894E-01  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1387E-02  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1068E-02  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3512E-03  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6378E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3105E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1073E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2801E-05  [K,I,J]   44  213  125
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1906.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8421E-01  [K,I,J]   47  239  239
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3072E-01  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2081E-02  [K,I,J]   51  259  219
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8731E-03  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7574E-03  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1664E-03  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5227E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2348E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.9716E-05  [K,I,J]   44  213  125
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   1944.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7424E-01  [K,I,J]   38  174  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2585E-01  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6508E-02  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9882E-03  [K,I,J]   39  171   32
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6933E-03  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4033E-03  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1130E-03  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4649E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2098E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.9656E-05  [K,I,J]   44  213  125
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1997.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6249E-01  [K,I,J]   37  164   67
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1632E-01  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1276E-01  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1887E-02  [K,I,J]   48  240  240
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5743E-03  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4615E-03  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2313E-03  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9847E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4393E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1931E-04  [K,I,J]   44  213  125
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.9537E-05  [K,I,J]   44  213  125
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   2070.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5063E-01  [K,I,J]   37  164   67
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9330E-02  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1320E-01  [K,I,J]   44  211   69
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4670E-02  [K,I,J]   46  225  119
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8334E-03  [K,I,J]   38  163   63
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4261E-03  [K,I,J]   44  213  125
# ...
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1597E-04  [K,I,J]   38  178  213
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1240E-04  [K,I,J]   44  222  243
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1788E-05  [K,I,J]   42  207    4
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   15867.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9312E-01  [K,I,J]   45  233    6
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1102E-01  [K,I,J]   46  234    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1057E-01  [K,I,J]   46  234    6
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1325E-02  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4973E-03  [K,I,J]   44  220  107
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6165E-03  [K,I,J]   34  142  223
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1335E-03  [K,I,J]   35  150  192
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2710E-03  [K,I,J]   44  220  107
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.5484E-04  [K,I,J]   34  139  210
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3105E-04  [K,I,J]   42  207    4
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1037E-04  [K,I,J]   44  220  107
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2861E-05  [K,I,J]   44  222  243
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   15941.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6150E-01  [K,I,J]   45  233    6
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5477E-02  [K,I,J]   46  234    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1056E-01  [K,I,J]   46  234    6
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2996E-02  [K,I,J]   46  234    6
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7771E-03  [K,I,J]   35  150  192
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3627E-03  [K,I,J]   34  139  210
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2611E-03  [K,I,J]   44  222  243
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1061E-03  [K,I,J]   44  222  243
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6843E-04  [K,I,J]   44  222  243
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4035E-04  [K,I,J]   44  222  243
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1502E-04  [K,I,J]   34  139  210
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.9418E-05  [K,I,J]   44  220  107
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   16044.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3299E-01  [K,I,J]   45  233    6
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3244E-02  [K,I,J]   34  142  223
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6788E-02  [K,I,J]   34  142  223
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4705E-02  [K,I,J]   46  234    6
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1106E-02  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6208E-03  [K,I,J]   34  139  210
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3031E-03  [K,I,J]   46  234    6
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1608E-03  [K,I,J]   46  234    6
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.8178E-04  [K,I,J]   34  139  210
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5525E-04  [K,I,J]   44  222  243
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2688E-04  [K,I,J]   44  222  243
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1425E-04  [K,I,J]   44  222  243
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.9358E-05  [K,I,J]   44  222  243
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   16060.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4274E-02  [K,I,J]   38  188  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1609E-02  [K,I,J]   34  142  223
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3064E-03  [K,I,J]   46  234    6
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7820E-04  [K,I,J]   14    7  295
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2944E-04  [K,I,J]   46  234    6
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9954E-05  [K,I,J]   46  234    6
#
#  STRESS PERIOD NO.   45
#
#  TIME STEP NO.    1
#  FROM TIME =   16060.     TO    16425.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   16065.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5820      [K,I,J]   36  173   77
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9513E-01  [K,I,J]   35  155  168
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4488E-02  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1230E-03  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8702E-05  [K,I,J]   42  207    4
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   16072.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1947      [K,I,J]   34  155  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5388E-02  [K,I,J]   43  217  141
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3572E-03  [K,I,J]   36  155  168
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1805E-03  [K,I,J]   36  155  168
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2283E-04  [K,I,J]   42  207    4
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1693E-04  [K,I,J]   42  207    4
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3457E-05  [K,I,J]   44  222  243
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   16082.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1468      [K,I,J]   32  132  193
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1837E-01  [K,I,J]   35  155  168
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9241E-03  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3280E-03  [K,I,J]   36  155  168
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1252E-04  [K,I,J]   39  186  218
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1311E-04  [K,I,J]   37  173   77
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1252E-05  [K,I,J]   35  150  192
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   16096.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1501      [K,I,J]   32  132  193
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2386E-01  [K,I,J]   35  155  168
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1932E-02  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6099E-03  [K,I,J]   36  155  168
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6225E-03  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2152E-04  [K,I,J]   36  155  168
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1001E-04  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2980E-05  [K,I,J]   34  139  210
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   16115.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1242      [K,I,J]   34  154  147
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2544E-01  [K,I,J]   35  155  168
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5961E-03  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1883E-02  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7926E-03  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6515E-04  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1925E-04  [K,I,J]   35  150  192
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9537E-05  [K,I,J]   35  150  192
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   16142.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9494E-01  [K,I,J]   35  163  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2389E-01  [K,I,J]   35  155  168
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1024E-02  [K,I,J]   49  253  235
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1016E-02  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2106E-03  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5567E-03  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3028E-04  [K,I,J]   35  150  192
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2557E-04  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6795E-05  [K,I,J]   34  139  210
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   16179.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8239E-01  [K,I,J]   35  163  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1778E-01  [K,I,J]   44  222   50
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5253E-02  [K,I,J]   46  235  237
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4489E-03  [K,I,J]   44  222  164
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6216E-03  [K,I,J]   44  222  164
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2030E-03  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4290E-03  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3034E-04  [K,I,J]   34  139  210
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3570E-04  [K,I,J]   35  153  147
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5639E-04  [K,I,J]   35  153  147
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.8941E-06  [K,I,J]   36  165  118
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   16232.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7439E-01  [K,I,J]   37  179   34
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9946E-02  [K,I,J]   43  217  141
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1019E-01  [K,I,J]   43  217  141
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1073E-02  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4286E-03  [K,I,J]   44  222  164
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5352E-03  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1902E-03  [K,I,J]   36  165  118
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4342E-03  [K,I,J]   44  222  164
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1841E-03  [K,I,J]   44  222  164
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.9537E-05  [K,I,J]   36  161  104
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   16306.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6210E-01  [K,I,J]   37  179   34
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5247E-02  [K,I,J]   43  217  141
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1033E-01  [K,I,J]   43  217  141
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2451E-02  [K,I,J]   44  222   50
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5868E-03  [K,I,J]   36  161  104
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3178E-03  [K,I,J]   36  162  121
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2277E-03  [K,I,J]   49  253  235
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1001E-03  [K,I,J]   49  253  235
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4363E-04  [K,I,J]   36  162  121
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2408E-04  [K,I,J]   49  253  235
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1240E-04  [K,I,J]   49  253  235
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.4292E-05  [K,I,J]   36  162  121
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   16409.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4498E-01  [K,I,J]   37  179   34
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3340E-02  [K,I,J]   37  179   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7113E-02  [K,I,J]   43  217  141
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4416E-02  [K,I,J]   43  217  141
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8758E-03  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5108E-03  [K,I,J]   36  161  104
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2293E-03  [K,I,J]   49  253  235
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1422E-03  [K,I,J]   49  253  235
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.8148E-04  [K,I,J]   49  253  235
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3880E-04  [K,I,J]   49  253  235
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2038E-04  [K,I,J]   49  253  235
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1353E-04  [K,I,J]   49  253  235
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.6199E-05  [K,I,J]   49  253  235
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   16425.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5996E-02  [K,I,J]   37  179   34
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1522E-02  [K,I,J]   44  222   50
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2275E-03  [K,I,J]   44  222   50
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6431E-04  [K,I,J]   36  162  121
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2629E-04  [K,I,J]   49  253  235
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7629E-05  [K,I,J]   49  253  235
#
#  STRESS PERIOD NO.   46
#
#  TIME STEP NO.    1
#  FROM TIME =   16425.     TO    16790.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   16430.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5461      [K,I,J]   38  189   94
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8636E-01  [K,I,J]   39  189   94
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1092E-02  [K,I,J]   42  200  415
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3546E-04  [K,I,J]   50  253  306
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3934E-05  [K,I,J]   47  235  295
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   16437.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1820      [K,I,J]   38  189   94
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2463E-02  [K,I,J]   42  200  415
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1062E-03  [K,I,J]   40  189   94
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9805E-04  [K,I,J]   55  283  342
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5174E-04  [K,I,J]   55  283  342
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1514E-04  [K,I,J]   55  283  342
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.8285E-05  [K,I,J]   55  283  342
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   16447.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1334      [K,I,J]   37  169  388
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1606E-01  [K,I,J]   39  189   94
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3090E-03  [K,I,J]   40  189   94
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1146E-03  [K,I,J]   42  200  415
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2575E-04  [K,I,J]   42  200  415
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4888E-05  [K,I,J]   36  161  104
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   16461.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1388      [K,I,J]   37  169  388
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2096E-01  [K,I,J]   39  189   94
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4826E-03  [K,I,J]   52  267   34
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2612E-03  [K,I,J]   42  200  415
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1600E-03  [K,I,J]   19   33  116
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2289E-03  [K,I,J]   19   33  116
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1312E-03  [K,I,J]   19   33  116
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1490E-05  [K,I,J]   42  200  415
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   16480.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1196      [K,I,J]   38  187   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2101E-01  [K,I,J]   39  189   94
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2196E-02  [K,I,J]   39  189   94
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2500E-03  [K,I,J]   19   33  116
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8583E-04  [K,I,J]   19   33  116
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1614E-03  [K,I,J]   42  200  415
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5960E-05  [K,I,J]   19   33  116
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   16507.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8804E-01  [K,I,J]   38  187   25

# %%
model_ws
