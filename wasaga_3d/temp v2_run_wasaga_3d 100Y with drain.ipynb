# %% [markdown]
# # Import

# %% [markdown]
# - fix shoreline
# - add more septics
# - 1965 images
# - flux

# %%
import flopy
import numpy as np
import matplotlib.pyplot as plt
import shutil
from pathlib import Path

from datetime import datetime
from tempfile import TemporaryDirectory
from tempfile import mkdtemp

import os
import platform
import subprocess
from shapely.geometry import Polygon, Point
from scipy.interpolate import make_interp_spline
from random_name import generate_random_name

# %%
def locate_ground_surface_lay(row=150):
    cross_section = ibound[:,:,0]
    lay = np.where(cross_section[:,row]==1)[0][0]
    return lay

def meter_to_col(col_meter):
    return int(np.round(col_meter/delc,0))

def meter_to_row(row_meter):
    return int(np.round(row_meter/delc,0))

def meter_to_lay(lay_meter):
    return int(np.round((top_elev-lay_meter)/layer_thickness,0))

def col_to_meter(col):
    return col*delc

def row_to_meter(row):
    return row*delc

def lay_to_meter(row):
    return 190.0-row*layer_thickness

# %%
def change_array_within_polygon(array, row_coords, col_coords, value):

    # Create a polygon object from the row and column coordinates
    polygon = Polygon(zip(col_coords, row_coords))

    # Create a boolean mask indicating which points fall within the polygon
    mask = np.zeros_like(array, dtype=bool)
    for row in range(array.shape[0]):
        for col in range(array.shape[1]):
            point = Point(col, row)
            if polygon.contains(point) or polygon.intersects(point):
                mask[row, col] = True

    # Set the values of the array that fall within the polygon to the new value
    array[mask] = value

    return array

# %% [markdown]
# # Workspace

# %%
# Control variable to decide the location of the temp folder
use_d_drive = True  # Set to False to use default temp location

# Define model workspace
myt = datetime.now().strftime('%m%d%H%M%S')
name = 'wasaga'
adj_non = '_'+generate_random_name()

if use_d_drive:
    temp_dir = 'D:/_T{}_{}'.format(myt, adj_non )
    os.makedirs(temp_dir, exist_ok=True)
else:
    temp_dir = mkdtemp(prefix='_T{}_'.format(myt),suffix=adj_non )

os.makedirs(Path(temp_dir) / '_output', exist_ok=True)

model_ws = temp_dir

def open_file(path):
    if platform.system() == "Windows":
        os.startfile(path)
    elif platform.system() == "Darwin":
        subprocess.Popen(["open", path])
    else:
        subprocess.Popen(["xdg-open", path])

open_file(model_ws)

# %%
model_ws
# Out:
# 'D:/_T0118155450__Dangerous_Mountain'

# %%
# base
parms= {}
parms['sp1']= 0.0002
parms['hk']= 6.9
parms['al'] = 5
base_parms = parms

# %% [markdown]
# # Model

# %%
# Create a MODFLOW model instance
mf = flopy.modflow.Modflow(modelname="example_model",version='mf2005',
                              exe_name='mf2005', 
                              model_ws=model_ws)

# %%
# # Create a MODFLOW model instance
# model = flopy.seawat.Seawat(modelname="example_model",
#                             exe_name='swtv4', 
#                               model_ws=model_ws)

# %% [markdown]
# # DIS

# %%
# year 1: 1968  (assume houses in 1978 [earilest satellite image] was built 10 years ago ) 
# year 56: (2024 present)
# year 76: (20 years later)
# year 156: (100 years later)
# year 556: (500 years later)

# %%
# Define model dimensions
nlay = int(60 * 2)
nrow = int(220 * 2)
ncol = int(220 * 2)
delr = 2200/nrow  # Cell width along rows (extend 2200 / 220)
delc = 2200/ncol  # Cell width along columns (extend 2200 / 220)

# Define top elevation
layer_thickness = 30.0 / nlay

top_elev = 190.0
botm_elev = [top_elev - (i * layer_thickness) for i in range(1, nlay + 1)]
# Define layer thickness (uniform thickness)


perlen = 365
nper = int(100)
#nper = int(56)
#nper = int(500)
#nper = int(20)

steady = np.append(np.array([True]),np.repeat(False,nper-1))
#steady=[False,False,True]
#steady = True

# Create DIS package

# %%
dis = flopy.modflow.ModflowDis(mf, nlay=nlay, nrow=nrow, ncol=ncol, 
                               delr=delr, delc=delc,top=top_elev, 
                               botm=botm_elev,
                               nper = nper, perlen = perlen,
                               nstp = 1, steady = steady)

# %% [markdown]
# # Ibound

# %%
x = np.array([0, 100, 340, 600, 750, 850, 1100, 1350, 1450, 1530, 1650, 1750, 1850, 2050, 2200])

y_topo = np.array([190,190,187,184,184,184,183,182,179,175.5,175,173.8,173.5,172,171])#topo
#y_topo = np.array([190,190,187,184,184,184,183,182,179+2,175.5+4,175+2,173.8+1,173.5+0,172,171])#topo

y_clay = np.array([185,184,180,175,174,174,173,170,169,168.5,167.5,166.8,166.5,165,164]) #clay


# Interpolate the data using smoothing splines
spl = make_interp_spline(x, y_topo)
x_smooth_topo = np.linspace(x.min(), x.max(), 30)
y_smooth_topo = spl(x_smooth_topo)

col_coords = (x_smooth_topo/delr).round(0)
col_coords_topo = list(col_coords) +[nrow,0]

row_coords = ((top_elev - y_smooth_topo)/layer_thickness).round(0)
row_coords_topo  =  list(row_coords) +[0,0]



# Interpolate the data using smoothing splines
spl = make_interp_spline(x, y_clay)
x_smooth = np.linspace(x.min(), x.max(), 30)
y_smooth = spl(x_smooth)

col_coords = (x_smooth/delr).round(0)
col_coords_clay = list(col_coords) +[nrow,0]
row_coords = ((top_elev - y_smooth)/layer_thickness).round(0)
row_coords_clay  =  list(row_coords) +[nlay,nlay]

# %% [markdown]
# # Ibound & Strt

# %%
# Define ibound and initial conditionsa
ibound = np.ones((nlay, nrow, ncol), dtype=int)
initial_head = np.full((nlay, nrow, ncol), 200.0, dtype=float)
shoreline_distance = 1600

# Set constant head boundary conditions for the first and last rows
array = change_array_within_polygon(ibound, row_coords_topo, col_coords_topo, 0)
plt.scatter(col_coords_topo,row_coords_topo,c='r')


array = change_array_within_polygon(ibound, row_coords_clay, col_coords_clay, 0)
plt.scatter(col_coords,row_coords,c='r')

for c in range(0,2):
    i = np.where(ibound[:,c,-1]==1)[0][-1]
    head = top_elev-i*layer_thickness
    #print('head {}'.format(head))
    
    while head<187:
        ibound[i,c,:] = -1
        #print(i,c)
        #initial_head[i,c,:] = head+0.5
        print(head)
        initial_head[i,c,:] = 187
        head+=layer_thickness
        i-=1


lay = np.where(ibound[:,int(shoreline_distance/delr),-1])[0][0]
elv = lay_to_meter(lay)
head = elv

for c in range(int(shoreline_distance/delr),int(2200/delr)):
    lay = np.where(ibound[:,c,-1]==1)[0][0]
    #print(lay,lay_to_meter(lay))
    ibound[lay,c,:] = -1
    initial_head[lay,c,:] = elv

# Your existing code
im = plt.imshow(ibound[:,:,2], origin='upper', aspect=1)
plt.axvline(x=meter_to_col(shoreline_distance))# shoreline
plt.gcf().set_size_inches(15,10)

# Set the y-axis tick positions and labels
#plt.yticks([0, 10,20, 30,40, 50,60], ['190m (0L)','185m (10L)', '180m (20L)','175m (30L)', '170m (40L)', '165m (50L)','160m (60L)'])
# Add a horizontal colorbar

cbar = plt.colorbar(im, orientation='horizontal')
cbar.ax.tick_params(labelsize=16)
cbar.set_label('Colorbar Label', fontsize=16)

# Display the plot
plt.title('ibound')
plt.grid()
plt.show()


fig, ax = plt.subplots(figsize=(15, 10))
im = ax.imshow(initial_head[:, :, 0], origin='upper')

# Add a horizontal colorbar
cbar = plt.colorbar(im, orientation='horizontal')
cbar.ax.tick_params(labelsize=18)
plt.title('initial head')
plt.show()
# Out:
# 185.25
# 185.5
# 185.75
# 186.0
# 186.25
# 186.5
# 186.75
# 185.0
# 185.25
# 185.5
# 185.75
# 186.0
# 186.25
# 186.5
# 186.75

# %% [markdown]
# # BAS LPF  PCG

# %%
# Create BAS package
bas = flopy.modflow.ModflowBas(mf, ibound=ibound, strt=initial_head)

# Define hydraulic properties
horizontal_k = parms['hk'] # Horizontal hydraulic conductivity (m/day)
vertical_ka = 0.1   # Vertical hydraulic conductivity (m/day)
porosity = 0.25     # Porosity

# Create LPF package (Layer Property Flow package)
lpf = flopy.modflow.ModflowLpf(mf, hk=horizontal_k, 
                               vka=vertical_ka, laytyp=1, 
                               ipakcb=None,ss=0.0002,sy=0.33,
                               laywet=1,iwetit=1,wetfct=0.1,ihdwet=1)

# #ss=0.0002,sy=0.33
# upw = flopy.modflow.ModflowUpw(model, laytyp=1, hk=horizontal_k)

pcg = flopy.modflow.ModflowPcg(mf, hclose=1e-3,npcond=1,
                               relax=0.99,rclose=1e-3,mutpcg=0,nbpol=1,iprpcg=1)

# %% [markdown]
# # Heterogeneity

# %%
# hk_mean = 2.3  # mean hydraulic conductivity
# hk_std = 2  # standard deviation of hydraulic conductivity
# hk= np.random.normal(hk_mean, hk_std, size=[nlay,nrow,ncol])
# hk[np.where(hk<0)]=0.001

# model.lpf.hk = hk

# %%
# hk_mean = np.log10(2.3)  # mean hydraulic conductivity
# hk_std = 0.4  # standard deviation of hydraulic conductivity
# hk= np.random.normal(hk_mean, hk_std, size=[nlay,nrow,ncol])
# hk = 10**hk
# #hk[np.where(hk<0)]=0.001
# hk.mean()
# model.lpf.hk = hk

# %%
# plt.hist(hk.flatten(),bins=np.linspace(0,30,50))
# plt.show()

# plt.imshow(hk[0,:,:])
# plt.show()

# %% [markdown]
# # DRN

# %%
locate_ground_surface_lay(meter_to_row(160))
#drn_cell = [(0, 150, 28), -10, 100]
start_dis = shoreline_distance - 25 -20
end_dis = shoreline_distance - 25
beach_drns = np.arange(start_dis,end_dis+1,delr).astype(int)
river_drns = np.arange(595,605+1,delr).astype(int)
#beach_drns = []

drn_list = []
drn_ys= list(beach_drns)+list(river_drns)

for y in drn_ys:
   
   row = meter_to_row(y)
   lay = locate_ground_surface_lay(row=row)
   elv = lay_to_meter(lay)
   #print(row)
   #print(lay)
   for col in range(ncol):

      drn_list.append([lay, row, col, elv, 1.0])
      #drn_list.append([12*2, meter_to_row(600), col, 184.0-0.5, 100])
      
drn_cell = {0:drn_list} 
drn_start_row, drn_end_row = meter_to_row(start_dis), meter_to_row(end_dis)
#drn_cell={0:[[31, 160, 0, 174.5-0.5, 0],[12, 60, 0, 184.0-0.5, 0]]}
drn = flopy.modflow.ModflowDrn(model=mf, stress_period_data=drn_cell,)

# %%
# Load your model
model = mf
# Plot the ibound array
plt.imshow(model.bas6.ibound.array[:, :, 0], origin='upper', cmap='bone')
# Plot drains for the first stress period if DRN package exists
if model.drn:
    for drn in np.unique(model.drn.stress_period_data[0], axis=0):
        if drn[2] == 0:  # Checks if the drain is in the first layer
            plt.scatter(drn[1], drn[0], c='cyan', s=5, marker='s')

# Customize and display the plot
plt.gcf().set_size_inches(15, 10)
plt.title('Ibound and Drain Cells Visualization')
plt.show()

# %% [markdown]
# # RCH

# %% [markdown]
# ### Test data

# %%
##2D pers [1]+[30,92,31,212]*25 +[365]*5+[365*5]*5+[365*4]+[185,30,30,120]

# %%
# rch_dict = {}

# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# rch_dict[0] = rch_array

# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# #rch_array[int(nrow/2),int(ncol/2)] = 0.51/delr/delc
# #rch_array[int(nrow/2),int(ncol/3)] = 0.51/delr/delc

# rch_array[int((1700-70)/delr),int(ncol/2)] = 0.51/delr/delc
# rch_array[int((1700-70)/delr),int(ncol/3)] = 0.51/delr/delc
# rch_dict[1] = rch_array 


# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# rch_dict[26] = rch_array


# rch = flopy.modflow.ModflowRch(model = mf, rech = rch_dict)

# %%
def calculate_year_septic_start(df):
    # Ensure the DataFrame is sorted by 'Year'
    df = df.sort_values('Year').reset_index(drop=True)
    
    # Get the unique years and sort them
    unique_years = sorted(df['Year'].unique())
    
    # Initialize the "Year_Septic_Start" list
    year_septic_start = []
    
    # Iterate through the DataFrame rows
    for current_year in df['Year']:
        # Find the index of the current_year in the unique_years list
        current_index = unique_years.index(current_year)
        
        # Determine the previous year (if it's not the first year)
        if current_index == 0:
            #previous_year = 1950  # If it's the first unique year, use 1950
            year_septic_start.append(1950)
        else:
            previous_year = unique_years[current_index - 1]  # Get the previous unique year
        
        # Calculate the "Year_Septic_Start"
            year_septic_start.append((current_year + previous_year) // 2)
    
    # Add the "Year_Septic_Start" as a new column in the DataFrame
    df['Year_Septic_Start'] = year_septic_start
    return df

# %%
import pandas as pd
df = pd.read_csv("wasaga septics placement/septics_transformed.csv")
df = df[~df['Year End'].isna()]
df['Year End'] =df['Year End'].astype(int)
df = calculate_year_septic_start(df)
df['Year_Septic_End'] = df['Sewer_Installation_Period'].apply(lambda x: (int(x.split('-')[1]) + int(x.split('-')[0]))//2)

# %%
# Assuming nrow, ncol, delr, delc, and mf are defined earlier in your code

# Initialize the recharge dictionary
rch_dict = {0: np.full((nrow, ncol), 0.00013, dtype=float)}  # Initial background recharge rate



# Loop through the DataFrame to update rch_dict
for index, row in df.iterrows():
    easting = row['Wasaga Easting']
    northing = row['Wasaga Northing']
    start_year = row['Year_Septic_Start']
    end_year = row['Year_Septic_End']

    # Calculate the indices
    row_index = int(northing / delr)
    col_index = int(easting / delc)

    # Calculate the range of years for each septic source
    start_key = start_year - 1950 + 1
    end_key = end_year - 1950 + 1

    # Loop through each year for the septic source
    for year_key in range(start_key, end_key + 1):
        # Check if the key exists in the dictionary, if not, create a new array with background recharge
        if year_key not in rch_dict:
            rch_dict[year_key] = np.full((nrow, ncol), 0.00013, dtype=float)

        # Update the recharge rate at the septic location
        rch_dict[year_key][row_index, col_index] = 0.51 / delr / delc
    
    # Ensure the septic is turned off after its end year
    # Check if the year after the end_key exists in the dictionary, if not, create a new array with background recharge
    if end_key + 1 not in rch_dict:
        rch_dict[end_key + 1] = np.full((nrow, ncol), 0.00013, dtype=float)
    
    # Set the recharge rate back to the background rate after the septic system's active period
    rch_dict[end_key + 1][row_index, col_index] = 0.00013

# Create the ModflowRch object
rch = flopy.modflow.ModflowRch(model=mf, rech=rch_dict)

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 8))

# Plot drain coordinates
rows = []
cols = []
for drn in np.unique(model.drn.stress_period_data[0], axis=0):
    rows.append(drn[1])
    cols.append(drn[2])

ax.scatter(cols, rows, c='cyan', marker='s')

# Plot and customize the shoreline as a thicker, dashed line and add annotation
shoreline_y = shoreline_distance / delr
ax.axhline(shoreline_y, color='blue', linestyle='--', linewidth=2, label='Shoreline')
ax.annotate('Shoreline', xy=(0.5, shoreline_y), xytext=(0, 5),
            xycoords=('axes fraction', 'data'), textcoords='offset points',
            ha='center', va='bottom')

# Assuming rch_dict, delr, and delc are already defined
target_value = 0.51 / delr / delc
colors = plt.cm.jet(np.linspace(0, 1, len(rch_dict)))

for (key, array), color in zip(rch_dict.items(), colors):
    rows, cols = np.where(np.isclose(array, target_value))
    if rows.size and cols.size:
        ax.scatter(cols, rows, color=color, label=f'Key: {key}',s=10)

# Set titles and labels
ax.set(title='Drain and Septics', xlabel='Column ', ylabel='Row ')

# Display legend
#ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calculate and plot in a compact form
kpers, active_septics = zip(*sorted((year_key, np.sum(rech >= 0.51 / delr / delc)) for year_key, rech in rch_dict.items()))

fig, ax1 = plt.subplots(figsize=(10, 6))
bars = ax1.bar(kpers, active_septics, color='dodgerblue', alpha=0.7)

ax1.set(xlabel='kper', ylabel='Number of Active Septic Sources', title='Active Septic Sources Over Time')

ax2 = ax1.twiny().set(xlabel='Year', xlim=[k + 1950 for k in ax1.get_xlim()], xticks=[k + 1950 for k in ax1.get_xticks()],
                      xticklabels=[int(k + 1950) for k in ax1.get_xticks()])
ax1.grid(axis='y', linestyle='--', alpha=0.7)

for bar, val in zip(bars, active_septics):
    if val == 0: ax1.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(val), ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout(); plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming crch_dict is already defined and filled with your data

period = max(rch_dict.keys()) - 30  # Specify the period you want to visualize
if period in rch_dict: 
    crch_array = rch_dict[period]
    plt.imshow(crch_array, cmap='viridis', interpolation='nearest')
    plt.colorbar(label='Concentration');plt.gca().invert_yaxis()
    plt.xlabel('Column Index'); plt.ylabel('Row Index'); plt.title(f'RCH Array Visualization at Period {period}');plt.show()
else: print(f"No data available for period {period}")

# %% [markdown]
# # OC

# %%
# OC
spd = {}
for kper in range(nper):
    for kstp in range(1):
        spd[(kper, kstp)] = [
            "save head",
            "save drawdown",
            "save budget",
            "print head",
            "print budget",
        ]

oc = flopy.modflow.ModflowOc(
    mf,
    stress_period_data= spd,
    compact=True
    ,extension=['oc', 'hds', 'ddn', 'cbc', 'ibo']
)

#oc.reset_budgetunit(budgetunit=1053, fname='test.cbc')
oc.reset_budgetunit(budgetunit=53, fname='example_model.cbc')

# %%
lmt = flopy.modflow.ModflowLmt(mf, output_file_name='mt3d_link.ftl')

# %%
# Write the MODFLOW model input files
mf.write_input()

# %%
# Run the MODFLOW model
success, buff = mf.run_model()
# Out:
# FloPy is using the following executable to run the model: C:\Users\swan47\AppData\Local\flopy\bin\mf2005.EXE
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.12.00 2/3/2017
#
#  Using NAME file: example_model.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2024/01/18 18:21:37
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     2    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     3    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     4    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     5    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     6    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     7    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     8    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     9    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    10    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    11    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    12    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    13    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    14    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    15    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    16    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    17    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    18    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    19    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    20    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    21    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    22    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    23    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    24    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    25    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    26    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    27    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    28    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    29    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    30    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    31    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    32    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    33    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    34    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    35    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    36    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    37    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    38    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    39    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    40    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    41    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    42    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    43    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    44    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    45    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    46    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    47    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    48    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    49    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    50    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    51    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    52    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    53    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    54    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    55    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    56    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    57    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    58    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    59    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    60    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    61    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    62    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    63    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    64    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    65    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    66    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    67    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    68    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    69    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    70    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    71    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    72    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    73    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    74    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    75    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    76    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    77    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    78    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    79    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    80    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    81    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    82    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    83    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    84    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    85    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    86    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    87    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    88    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    89    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    90    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    91    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    92    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    93    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    94    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    95    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    96    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    97    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    98    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    99    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:   100    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2024/01/18 19:37:43
#  Elapsed run time:  1 Hours, 16 Minutes,  6 Seconds
#
#   Normal termination of simulation

# %% [markdown]
# #

# %% [markdown]
# # ------MT3DMS------

# %%
mt = flopy.mt3d.Mt3dms(modflowmodel=mf, modelname='mt', exe_name='mt3dms.exe' ,ftlfilename='mt3d_link.ftl',model_ws=model_ws)

# %% [markdown]
# # ICBUND

# %%
icbund = ibound.copy()
cc = np.where(icbund==-1)
mask = cc[1]>2200/2/delr

cc2 = (cc[0][mask],cc[1][mask],cc[2][mask])
icbund[cc2] = 1
plt.imshow(icbund[:,:,0])

# %% [markdown]
# # BTN ICBOUND

# %%
#icbund = np.full((nlay, nrow, ncol),0, dtype=float)
#
btn = flopy.mt3d.Mt3dBtn(
    mt,
    nprs=5,
    timprs=np.cumsum([200]*7),
    prsity=0.25,
    sconc= 0.01, # starting concentration
    ifmtcn=0, chkmas=False, nprobs=10, nprmas=10,
    dt0=5,  # The user-specified initial 
    ttsmult=1.4,
    mxstrn = 50000,
    icbund = icbund
)

# %%
adv = flopy.mt3d.Mt3dAdv(mt, mixelm=0,percel=0.4,mxpart=50000000,nadvfd=0)
dsp = flopy.mt3d.Mt3dDsp(mt, al=parms['al'], trpt=0.1, 
                        trpv=0.01, 
                        dmcoef=3.7E-10 )  ## !!TRVP change to 0.01
gcg = flopy.mt3d.Mt3dGcg(mt, iter1=50, mxiter=1, isolve=2, cclose= 1e-5)

# %% [markdown]
# # RCH

# %%
# crch_array =  np.full(( nrow, ncol), 0.1, dtype=float)
# crch_dict = {}
# crch_dict[0] = crch_array
# ssm = flopy.mt3d.Mt3dSsm(model, crch=crch_dict)

# rch_dict = {}
# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# rch_dict[0] = rch_array
# rch = flopy.modflow.ModflowRch(model = model, rech = rch_dict)


# ## [row, col, rch(m3), crch, start, end]
# rch_data = [[1100,1100,0.51,5000,1,20]]

# %% [markdown]
# ### Real Septics

# %%
import numpy as np
import pandas as pd
import flopy

# Assuming nrow, ncol, delr, delc, and mt are defined earlier in your code

# Initialize the base concentration array and the dictionary
crch_array_base = np.full((nrow, ncol), 0.01, dtype=float)
crch_dict = {0: crch_array_base.copy()}

# Read the CSV file from the specified path
df = pd.read_csv("wasaga septics placement/septics_transformed.csv")
df = df[~df['Year End'].isna()]
df['Year End'] =df['Year End'].astype(int)

# Loop through the DataFrame to update crch_dict
for index, row in df.iterrows():
    easting = row['Wasaga Easting']
    northing = row['Wasaga Northing']
    start_year = row['Year']
    end_year = row['Year End']

    # Calculate the indices
    row_index = int(northing / delr)  # Using northing for row index
    col_index = int(easting / delc)   # Using easting for column index

    # Calculate the range of years for each septic source
    start_key = start_year - 1968
    end_key = end_year - 1968

    # Loop through each year for the septic source
    for year_key in range(start_key, end_key + 1):
        # Check if the key exists in the dictionary, if not, create a new array
        if year_key not in crch_dict:
            crch_dict[year_key] = crch_array_base.copy()

        # Update the concentration at the specified location
        crch_dict[year_key][row_index, col_index] = 5000  # or any other value you wish to set

# Create the SSM object
ssm = flopy.mt3d.Mt3dSsm(mt, crch=crch_dict)

# %%
import numpy as np
import pandas as pd
import flopy

# Assuming nrow, ncol, delr, delc, and mt are defined earlier in your code
# Also assuming rch_dict is already defined from your MODFLOW recharge setup

# Initialize the base concentration array and the dictionary
crch_array_base = np.full((nrow, ncol), 0.01, dtype=float)  # Background concentration
crch_dict = {}

# Constants for recharge and concentration
background_recharge = 0.00013
septic_recharge = 0.51 / delr / delc
background_concentration = 0.01
septic_concentration = 5000

# Loop through each stress period in rch_dict
for stress_period, rch_array in rch_dict.items():
    # Copy the base concentration array for the current stress period
    crch_array = crch_array_base.copy()
    
    # Find indices where recharge rate indicates a septic source
    septic_indices = np.where(rch_array == septic_recharge)
    
    # Update the concentration array at these indices
    crch_array[septic_indices] = septic_concentration
    
    # Store the updated concentration array in crch_dict for the current stress period
    crch_dict[stress_period] = crch_array

# Create the SSM object using crch_dict
ssm = flopy.mt3d.Mt3dSsm(mt, crch=crch_dict)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Constants for recharge and concentration
septic_concentration = 5000

# Calculate and plot in a compact form
kpers, active_septics = zip(*sorted((year_key, np.sum(crch == septic_concentration)) for year_key, crch in crch_dict.items()))

fig, ax1 = plt.subplots(figsize=(10, 6))
bars = ax1.bar(kpers, active_septics, color='dodgerblue', alpha=0.7)

ax1.set(xlabel='Stress Period (kper)', ylabel='Number of Active Septic Sources', title='Active Septic Sources Over Time')

# Adjust the x-axis to show actual years assuming the first stress period starts in 1950 (change if needed)
start_year = 1950
ax2 = ax1.twiny()
ax2.set(xlabel='Year', xlim=[start_year + kpers[0], start_year + kpers[-1]], xticks=[start_year + k for k in ax1.get_xticks()],
        xticklabels=[int(start_year + k) for k in ax1.get_xticks()])
ax1.grid(axis='y', linestyle='--', alpha=0.7)

# Add text labels on the bars
for bar, val in zip(bars, active_septics):
    if val == 0:
        ax1.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(val), ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming crch_dict is already defined and filled with your data

period = 47  # Specify the period you want to visualize

# Check if the period exists in the dictionary
if period in crch_dict:
    # Extract the array for the specified period
    crch_array = crch_dict[period]

    # Create a heatmap of the array
    plt.imshow(crch_array, cmap='viridis', interpolation='nearest')
    plt.colorbar(label='Concentration')  # Add a color bar to indicate the values

    # Flip the y-axis
    plt.gca().invert_yaxis()

    # Add labels and title
    plt.xlabel('Column Index')
    plt.ylabel('Row Index')
    plt.title(f'CRCH Array Visualization at Period {period}')

    # Show the plot
    plt.show()
else:
    print(f"No data available for period {period}")

# %% [markdown]
# ### Test SSM

# %%
# crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)
# crch_dict = {}
# crch_dict[0] = crch_array

# crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)

# # crch_array[int(nrow/2),int(ncol/2)] =5000
# # crch_array[int(nrow/2),int(ncol/3)] =5000
# crch_array[int((1700-70)/delr),int(ncol/3)] =5000
# crch_array[int((1700-70)/delr),int(ncol/2)] =5000
# spetic_locs = [[int((1700-70)/delr),int(ncol/3)], [int((1700-70)/delr),int(ncol/2)]]

# crch_dict = {}
# crch_dict[1] = crch_array


# crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)
# crch_dict[26] = crch_array

# ssm = flopy.mt3d.Mt3dSsm(mt, crch=crch_dict)

# %% [markdown]
# # RCT

# %%
rct = flopy.mt3d.Mt3dRct(model=mt, isothm=3,sp1=parms['sp1'],sp2=0.0001,igetsc=0,rhob= 1.65E+09)

# %% [markdown]
# # Write and Run

# %%
# Write MODFLOW input files
mt.write_input()

# %%
open_file(model_ws)

# %%
# Run the MODFLOW model
mt.run_model()
# Out:
# FloPy is using the following executable to run the model: C:\Users\swan47\AppData\Local\flopy\bin\mt3dms.exe
#  MT3DMS - Modular 3-D Multi-Species Transport Model [Version 5.30]
#  Developed at University of Alabama for U.S. Department of Defense
#
#  Using NAME File: mt.nam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    365.00
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   5.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2062E-02  [K,I,J]   61  319  393
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]   62  318    1
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   12.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2831E-02  [K,I,J]   61  319  393
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1192E-06  [K,I,J]   63  319    1
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   21.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3856E-02  [K,I,J]   61  319   14
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-06  [K,I,J]   63  319    1
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   35.520
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5199E-02  [K,I,J]   61  319   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8345E-06  [K,I,J]   63  320    1
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   54.728
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6914E-02  [K,I,J]   61  319   20
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2682E-05  [K,I,J]   63  320    1
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   81.619
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9030E-02  [K,I,J]   61  319   21
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8166E-05  [K,I,J]   63  320    3
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   119.27
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1152E-01  [K,I,J]   61  319    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2933E-04  [K,I,J]   63  321    5
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7749E-06  [K,I,J]   63  321    1
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   171.97
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1428E-01  [K,I,J]   61  319   20
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8917E-04  [K,I,J]   63  321    8
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2861E-05  [K,I,J]   63  320    1
#  Transport Step:    9   Step Size:   28.03     Total Elapsed Time:   200.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7047E-02  [K,I,J]   61  319    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2086E-04  [K,I,J]   63  321    7
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2980E-06  [K,I,J]   63  320    1
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   303.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2138E-01  [K,I,J]   61  319    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4712E-03  [K,I,J]   63  321   19
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2682E-04  [K,I,J]   63  321    2
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7153E-06  [K,I,J]   63  322    1
#  Transport Step:   11   Step Size:   61.69     Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1113E-01  [K,I,J]   61  319    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1656E-03  [K,I,J]   63  321   13
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4947E-05  [K,I,J]   63  320    4
#
#  STRESS PERIOD NO.    2
#
#  TIME STEP NO.    1
#  FROM TIME =   365.00     TO    730.00
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   370.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1245E+05  [K,I,J]   46  228  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   789.5      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =   51.56      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =   3.100      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2258      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1709E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1221E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2861E-05  [K,I,J]   14    7  128
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   377.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8398      [K,I,J]   16   20  252
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1272      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1318E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1307E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1444E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1395E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1609E-05  [K,I,J]   17   22   84
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   386.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6127      [K,I,J]   19   33  279
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1304      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1845E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3031E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4353E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6002E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.8464E-05  [K,I,J]   17   22   84
#  Transport Step:    4   Step Size:   13.20     Total Elapsed Time:   400.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4729      [K,I,J]   23   50  259
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1277      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2270E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5589E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9735E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1886E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3010E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6139E-05  [K,I,J]   17   22   84
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   419.21
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4043      [K,I,J]   21   41  255
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1329      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3125E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1065E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2588E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6184E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1541E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3195E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.8285E-05  [K,I,J]   17   22   84
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   446.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3494      [K,I,J]   15   14  229
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1261      [K,I,J]   22   43    7
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4065E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1510E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5303E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1511E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4677E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1334E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3541E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1085E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3099E-05  [K,I,J]   17   22   84
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   483.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3131      [K,I,J]   49  241  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1181      [K,I,J]   19   30  251
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5269E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1868E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8754E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3271E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1067E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4114E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1347E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4399E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1585E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.5722E-05  [K,I,J]   17   22   84
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   536.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2825      [K,I,J]   49  241  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1062      [K,I,J]   16   16   87
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6262E-01  [K,I,J]   14    8  176
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2218E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1126E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5382E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2210E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.8417E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4011E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1578E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.5782E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2122E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.9298E-05  [K,I,J]   17   22   84
#  Transport Step:    9   Step Size:   63.55     Total Elapsed Time:   600.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2195      [K,I,J]   49  241  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8474E-01  [K,I,J]   46  219  181
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5817E-01  [K,I,J]   48  233  156
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2108E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1008E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5408E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2690E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1198E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4998E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2439E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.9978E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.3946E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1645E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.7749E-05  [K,I,J]   17   22   84
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   703.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2158      [K,I,J]   47  227  293
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8465E-01  [K,I,J]   42  189   94
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6916E-01  [K,I,J]   44  204   67
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3096E-01  [K,I,J]   51  254  227
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1401E-01  [K,I,J]   44  204   89
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8350E-02  [K,I,J]   45  211  295
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4670E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2429E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1228E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5591E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3058E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1440E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.7236E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.3266E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1478E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.7272E-05  [K,I,J]   17   22   84
#  Transport Step:   11   Step Size:   26.69     Total Elapsed Time:   730.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4508E-01  [K,I,J]   47  227  293
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2030E-01  [K,I,J]   44  204   67
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8700E-02  [K,I,J]   47  228  165
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2880E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1345E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5100E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1689E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6616E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2265E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7331E-05  [K,I,J]   17   22   84
#
#  STRESS PERIOD NO.    3
#
#  TIME STEP NO.    1
#  FROM TIME =   730.00     TO    1095.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   735.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7197      [K,I,J]   45  224  184
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5687E-01  [K,I,J]   49  242  180
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7593E-02  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1170E-02  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1523E-03  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5066E-05  [K,I,J]   46  222  233
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   742.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2398      [K,I,J]   38  169   51
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1831E-01  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2905E-02  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4683E-03  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8899E-04  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3892E-04  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3994E-05  [K,I,J]   48  235  237
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   751.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1396      [K,I,J]   47  235  237
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1378E-01  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2279E-02  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4861E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9531E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1979E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3815E-05  [K,I,J]   46  224  184
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   765.52
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7775E-01  [K,I,J]   47  235  237
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1986E-01  [K,I,J]   46  223  214
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3659E-02  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1363E-02  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3050E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7892E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1878E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4888E-05  [K,I,J]   46  224  184
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   784.73
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5471E-01  [K,I,J]   23   52  252
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2704E-01  [K,I,J]   46  222  192
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4749E-02  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2491E-02  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6840E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2124E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6706E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1734E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.5722E-05  [K,I,J]   46  224  184
#  Transport Step:    6   Step Size:   15.27     Total Elapsed Time:   800.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3604E-01  [K,I,J]   47  234  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1739E-01  [K,I,J]   46  222  192
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2969E-02  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1363E-02  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3265E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9388E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2640E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6258E-05  [K,I,J]   46  224  184
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   837.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6358E-01  [K,I,J]   47  234  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3928E-01  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1284E-01  [K,I,J]   49  242  180
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4787E-02  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2579E-02  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9635E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3695E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1503E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6789E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2092E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.8225E-05  [K,I,J]   46  224  184
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   890.35
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6432E-01  [K,I,J]   50  254  235
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3606E-01  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1955E-01  [K,I,J]   48  233   89
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5422E-02  [K,I,J]   37  145  381
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3827E-02  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1574E-02  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7539E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2883E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1278E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.6461E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2491E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1061E-04  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.5066E-05  [K,I,J]   46  224  184
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   964.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6694E-01  [K,I,J]   48  240  222
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3013E-01  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2477E-01  [K,I,J]   44  208  171
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6978E-02  [K,I,J]   48  233   45
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3906E-02  [K,I,J]   58  299   65
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2717E-02  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1148E-02  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5395E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2306E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1228E-03  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.6676E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2623E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1132E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.6437E-05  [K,I,J]   46  224  184
#  Transport Step:   10   Step Size:   35.86     Total Elapsed Time:   1000.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2911E-01  [K,I,J]   48  240  222
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1501E-01  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6802E-02  [K,I,J]   48  233   89
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2065E-02  [K,I,J]   58  299   65
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1171E-02  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4815E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1925E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.7313E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3588E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1180E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.4292E-05  [K,I,J]   46  224  184
#  Transport Step:   11   Step Size:   95.00     Total Elapsed Time:   1095.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6081E-01  [K,I,J]   48  240  222
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2373E-01  [K,I,J]   39  163  399
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2019E-01  [K,I,J]   44  208  171
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8496E-02  [K,I,J]   48  233   89
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4591E-02  [K,I,J]   37  145  381
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2513E-02  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1145E-02  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6920E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3482E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1386E-03  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.7808E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.5126E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.2217E-04  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.9060E-05  [K,I,J]   46  224  184
#
#  STRESS PERIOD NO.    4
#
#  TIME STEP NO.    1
#  FROM TIME =   1095.0     TO    1460.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1100.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6967      [K,I,J]   46  232  176
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7206E-01  [K,I,J]   50  250  195
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7877E-02  [K,I,J]   51  256  247
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9385E-03  [K,I,J]   51  256  247
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8285E-04  [K,I,J]   51  256  247
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2921E-05  [K,I,J]   46  220  107
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1107.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2320      [K,I,J]   50  256  247
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1796E-01  [K,I,J]   47  230  155
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1608E-02  [K,I,J]   51  256  247
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1630E-03  [K,I,J]   51  256  247
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3207E-04  [K,I,J]   51  254  227
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2682E-05  [K,I,J]   47  232  176
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1116.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9336E-01  [K,I,J]   50  256  247
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1261E-01  [K,I,J]   39  173  166
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1929E-02  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3734E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9334E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2414E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4172E-05  [K,I,J]   47  232  176
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1130.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7679E-01  [K,I,J]   47  237  189
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2043E-01  [K,I,J]   47  231  208
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2362E-02  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1128E-02  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2187E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8893E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2098E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5066E-05  [K,I,J]   47  232  176
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1149.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7485E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2738E-01  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2613E-02  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1630E-02  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5956E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1545E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7224E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1997E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.5543E-05  [K,I,J]   47  232  176
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1176.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7695E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3034E-01  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4398E-02  [K,I,J]   60  308   16
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1595E-02  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1102E-02  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3588E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1270E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5931E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2068E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.6139E-05  [K,I,J]   47  232  176
#  Transport Step:    7   Step Size:   23.38     Total Elapsed Time:   1200.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5241E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2021E-01  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2435E-02  [K,I,J]   48  238  170
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1044E-02  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6565E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1929E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7379E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3070E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1025E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2921E-05  [K,I,J]   47  232  176
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1252.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8256E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2390E-01  [K,I,J]   51  256  247
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1408E-01  [K,I,J]   47  231  208
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3503E-02  [K,I,J]   60  308   16
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1271E-02  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9916E-03  [K,I,J]   51  256  247
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4920E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1953E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.9954E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4673E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2438E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.9298E-05  [K,I,J]   47  232  176
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   1326.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7671E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1684E-01  [K,I,J]   51  256  247
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1580E-01  [K,I,J]   47  231  208
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5597E-02  [K,I,J]   53  269  237
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2005E-02  [K,I,J]   38  161  151
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9300E-03  [K,I,J]   60  308   16
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6391E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3574E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1687E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.8595E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.4005E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2438E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1109E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.4888E-05  [K,I,J]   47  232  176
#  Transport Step:   10   Step Size:   73.50     Total Elapsed Time:   1400.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5371E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1135E-01  [K,I,J]   51  256  247
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1141E-01  [K,I,J]   53  269  237
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4645E-02  [K,I,J]   53  269  237
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1715E-02  [K,I,J]   38  161  151
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7581E-03  [K,I,J]   38  157  385
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4839E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2789E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1338E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.6890E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3237E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1979E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.9060E-05  [K,I,J]   47  232  176
#  Transport Step:   11   Step Size:   60.00     Total Elapsed Time:   1460.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3388E-01  [K,I,J]   59  308   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7915E-02  [K,I,J]   37  145  381
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7316E-02  [K,I,J]   53  269  237
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2610E-02  [K,I,J]   53  269  237
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1062E-02  [K,I,J]   38  161  151
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5180E-03  [K,I,J]   38  157  385
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2911E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1463E-03  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7486E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3600E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1740E-04  [K,I,J]   47  232  176
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.8881E-05  [K,I,J]   47  232  176
#
#  STRESS PERIOD NO.    5
#
#  TIME STEP NO.    1
#  FROM TIME =   1460.0     TO    1825.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1465.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6686      [K,I,J]   40  191  199
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8128E-01  [K,I,J]   46  226  193
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1007E-01  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1195E-02  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1193E-03  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5782E-05  [K,I,J]   37  155  192
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1472.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2305      [K,I,J]   36  155  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1576E-01  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1993E-02  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1762E-03  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1192E-04  [K,I,J]   48  233   45
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1621E-04  [K,I,J]   48  233   45
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5960E-06  [K,I,J]   37  155  168
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1481.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9686E-01  [K,I,J]   44  219  212
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1381E-01  [K,I,J]   37  156  205
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1590E-02  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2428E-03  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6497E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2027E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4053E-05  [K,I,J]   41  191  199
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1495.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9363E-01  [K,I,J]   44  219  212
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2235E-01  [K,I,J]   37  155  192
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2713E-02  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8727E-03  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1646E-03  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5752E-04  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1758E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4470E-05  [K,I,J]   41  191  199
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1514.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8301E-01  [K,I,J]   48  244  252
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2856E-01  [K,I,J]   37  155  192
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2161E-02  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1836E-02  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4148E-03  [K,I,J]   37  155  192
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1097E-03  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5120E-04  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1442E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4232E-05  [K,I,J]   41  191  199
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1541.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7648E-01  [K,I,J]   45  225  184
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2943E-01  [K,I,J]   45  219  181
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3491E-02  [K,I,J]   48  239  222
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1699E-02  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1147E-02  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2553E-03  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7564E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4095E-04  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1293E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3994E-05  [K,I,J]   41  191  199
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   1579.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6988E-01  [K,I,J]   47  234   45
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2426E-01  [K,I,J]   45  219  181
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8478E-02  [K,I,J]   45  219  181
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1504E-02  [K,I,J]   47  233  219
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1270E-02  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6465E-03  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1674E-03  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5645E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2998E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1365E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.4411E-05  [K,I,J]   41  191  199
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1632.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6003E-01  [K,I,J]   47  234   45
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1633E-01  [K,I,J]   37  155  192
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1308E-01  [K,I,J]   45  219  181
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2910E-02  [K,I,J]   46  226  193
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9581E-03  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7634E-03  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3945E-03  [K,I,J]   37  155  192
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1248E-03  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.5096E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2706E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1341E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.4828E-05  [K,I,J]   41  191  199
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   1705.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5066E-01  [K,I,J]   40  187   37
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1073E-01  [K,I,J]   37  155  192
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1292E-01  [K,I,J]   45  219  181
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5462E-02  [K,I,J]   45  219  181
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1310E-02  [K,I,J]   45  217   49
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6556E-03  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4521E-03  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2893E-03  [K,I,J]   37  155  192
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.9739E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4184E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2462E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1496E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.5841E-05  [K,I,J]   41  191  199
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   1809.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4482E-01  [K,I,J]   40  187   37
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7522E-02  [K,I,J]   37  155  192
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1049E-01  [K,I,J]   37  155  192
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7109E-02  [K,I,J]   45  219  181
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2105E-02  [K,I,J]   29   80   55
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8828E-03  [K,I,J]   38  157  385
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5354E-03  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3173E-03  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1782E-03  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.8512E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3994E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2199E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1490E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.7391E-05  [K,I,J]   41  191  199
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   1825.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6851E-02  [K,I,J]   40  187   37
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2457E-02  [K,I,J]   29   80   55
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5476E-03  [K,I,J]   48  239  222
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1487E-03  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6109E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1919E-04  [K,I,J]   41  191  199
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6199E-05  [K,I,J]   41  191  199
#
#  STRESS PERIOD NO.    6
#
#  TIME STEP NO.    1
#  FROM TIME =   1825.0     TO    2190.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1830.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6450      [K,I,J]   45  227  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8359E-01  [K,I,J]   46  225  119
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9565E-02  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9314E-03  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5180E-04  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5186E-05  [K,I,J]   37  157  149
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1837.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2283      [K,I,J]   36  157  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1550E-01  [K,I,J]   39  174   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1670E-02  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9918E-04  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1043E-04  [K,I,J]   38  156   88
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3481E-04  [K,I,J]   38  156   88
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1013E-05  [K,I,J]   37  157  149
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1846.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1127      [K,I,J]   47  239  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1421E-01  [K,I,J]   38  166   59
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1638E-02  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2238E-03  [K,I,J]   38  156   88
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6604E-04  [K,I,J]   46  227  155
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1544E-04  [K,I,J]   37  155  168
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4530E-05  [K,I,J]   38  157  385
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1860.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1080      [K,I,J]   47  239  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2347E-01  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2706E-02  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6645E-03  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1113E-03  [K,I,J]   46  227  155
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5347E-04  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1103E-04  [K,I,J]   46  227  155
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2146E-05  [K,I,J]   46  227  155
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1879.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9574E-01  [K,I,J]   47  239  239
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2975E-01  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2049E-02  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1812E-02  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2775E-03  [K,I,J]   46  227  155
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7689E-04  [K,I,J]   46  227  155
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4315E-04  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9418E-05  [K,I,J]   46  227  155
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1906.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8344E-01  [K,I,J]   44  219  202
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3130E-01  [K,I,J]   39  174   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2106E-02  [K,I,J]   47  233  156
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1796E-02  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1118E-02  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1484E-03  [K,I,J]   46  227  155
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5502E-04  [K,I,J]   46  227  155
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3284E-04  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.9716E-05  [K,I,J]   46  227  155
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   1944.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7351E-01  [K,I,J]   38  172   32
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2643E-01  [K,I,J]   39  174   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5854E-02  [K,I,J]   43  204   67
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1079E-02  [K,I,J]   38  157  385
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1424E-02  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5486E-03  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.9829E-04  [K,I,J]   46  227  155
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4119E-04  [K,I,J]   46  227  155
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2402E-04  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1085E-04  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3397E-05  [K,I,J]   46  227  155
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1997.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6140E-01  [K,I,J]   38  172   32
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1678E-01  [K,I,J]   39  174   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1185E-01  [K,I,J]   43  204   67
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1864E-02  [K,I,J]   48  240  240
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9040E-03  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8440E-03  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3465E-03  [K,I,J]   37  157  149
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.8357E-04  [K,I,J]   46  227  155
# ...
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4873E-03  [K,I,J]   47  240  240
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1985E-03  [K,I,J]   47  240  240
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1131E-03  [K,I,J]   45  227    5
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.8011E-04  [K,I,J]   45  227    5
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3260E-04  [K,I,J]   45  227    5
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2015E-04  [K,I,J]   45  227    5
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1127E-04  [K,I,J]   45  227    5
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.4172E-05  [K,I,J]   45  227    5
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   14949.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3935E-01  [K,I,J]   49  257  227
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8227E-02  [K,I,J]   35  146  212
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7809E-02  [K,I,J]   36  162  121
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7231E-02  [K,I,J]   36  162  121
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2095E-02  [K,I,J]   36  162  121
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1010E-02  [K,I,J]   39  185  160
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7917E-03  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3054E-03  [K,I,J]   50  258  227
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1467E-03  [K,I,J]   39  185  160
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.9066E-04  [K,I,J]   18   28   98
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.5692E-04  [K,I,J]   47  240  240
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2599E-04  [K,I,J]   45  227    5
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1603E-04  [K,I,J]   45  227    5
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1079E-04  [K,I,J]   45  227    5
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.4768E-05  [K,I,J]   45  227    5
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   14965.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5466E-02  [K,I,J]   37  177  101
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2093E-02  [K,I,J]   36  162  121
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6493E-03  [K,I,J]   41  192  410
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1692E-03  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5126E-04  [K,I,J]   47  240  240
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1836E-04  [K,I,J]   47  240  240
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.8345E-05  [K,I,J]   47  240  240
#
#  STRESS PERIOD NO.   42
#
#  TIME STEP NO.    1
#  FROM TIME =   14965.     TO    15330.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   14970.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6118      [K,I,J]   33  143  140
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1007      [K,I,J]   40  194  221
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7530E-02  [K,I,J]   39  186   25
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3877E-03  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3195E-04  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1436E-04  [K,I,J]   48  244  150
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5960E-06  [K,I,J]   48  244  150
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   14977.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2133      [K,I,J]   32  131  193
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7886E-02  [K,I,J]   39  186   25
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5702E-03  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1633E-03  [K,I,J]   36  153  147
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6616E-05  [K,I,J]   34  143  140
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   14987.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1431      [K,I,J]   38  187  139
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1928E-01  [K,I,J]   33  131  193
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1333E-02  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4408E-03  [K,I,J]   34  131  193
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5543E-04  [K,I,J]   34  143  140
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1711E-04  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4768E-05  [K,I,J]   35  150  192
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   15001.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1404      [K,I,J]   38  187  139
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2691E-01  [K,I,J]   33  131  193
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1776E-02  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8111E-03  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1705E-03  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4065E-04  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3886E-04  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1907E-05  [K,I,J]   14    7  295
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   15020.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1293      [K,I,J]   37  177   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2890E-01  [K,I,J]   39  186   25
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1268E-02  [K,I,J]   36  158  196
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2630E-02  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1349E-02  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6693E-03  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3946E-04  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1270E-04  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4351E-05  [K,I,J]   14    7  295
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   15047.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1035      [K,I,J]   39  193  220
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2722E-01  [K,I,J]   39  186   25
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2170E-02  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1319E-02  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1822E-02  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8153E-03  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6336E-04  [K,I,J]   58  300  422
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4011E-04  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6855E-05  [K,I,J]   58  300  422
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   15084.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8576E-01  [K,I,J]   37  178  190
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1843E-01  [K,I,J]   39  186   25
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7818E-02  [K,I,J]   40  194  221
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1196E-02  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1186E-02  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3724E-03  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2296E-03  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9197E-04  [K,I,J]   18   28   98
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.5120E-04  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7081E-04  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.6145E-04  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1872E-04  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.4292E-05  [K,I,J]   35  149  213
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   15137.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6831E-01  [K,I,J]   46  240  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9504E-02  [K,I,J]   39  186   25
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1077E-01  [K,I,J]   35  153  147
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1964E-02  [K,I,J]   40  194  221
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9966E-03  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5138E-03  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2770E-03  [K,I,J]   36  160  227
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1070E-03  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3844E-04  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2027E-04  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.8583E-05  [K,I,J]   47  241  169
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   15211.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4899E-01  [K,I,J]   46  240  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5979E-02  [K,I,J]   36  163  117
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9490E-02  [K,I,J]   36  163  117
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4005E-02  [K,I,J]   36  163  117
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1267E-02  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6093E-03  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3076E-03  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2007E-03  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.8351E-04  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3904E-04  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2187E-04  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.9179E-05  [K,I,J]   47  241  169
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   15314.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3804E-01  [K,I,J]   38  185   37
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5407E-02  [K,I,J]   35  146  212
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7200E-02  [K,I,J]   36  163  117
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6061E-02  [K,I,J]   36  163  117
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1473E-02  [K,I,J]   37  172  154
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9927E-03  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4352E-03  [K,I,J]   35  150  192
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2131E-03  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1417E-03  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7057E-04  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3654E-04  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2086E-04  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.9894E-05  [K,I,J]   47  241  169
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   15330.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5193E-02  [K,I,J]   38  185   37
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1888E-02  [K,I,J]   36  163  117
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4357E-03  [K,I,J]   48  247  181
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1220E-03  [K,I,J]   35  150  192
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4262E-04  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1544E-04  [K,I,J]   47  241  169
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4709E-05  [K,I,J]   47  241  169
#
#  STRESS PERIOD NO.   43
#
#  TIME STEP NO.    1
#  FROM TIME =   15330.     TO    15695.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   15335.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5693      [K,I,J]   38  189  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9641E-01  [K,I,J]   40  196  176
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5436E-02  [K,I,J]   40  196  155
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2648E-03  [K,I,J]   40  196  155
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5984E-04  [K,I,J]   49  249   25
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4160E-04  [K,I,J]   49  249   25
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7153E-06  [K,I,J]   49  249   25
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   15342.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2008      [K,I,J]   39  196  176
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6493E-02  [K,I,J]   40  196  155
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2706E-03  [K,I,J]   40  196  155
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1010E-03  [K,I,J]   41  196  176
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3052E-04  [K,I,J]   36  161  151
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2050E-04  [K,I,J]   49  249   25
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7153E-06  [K,I,J]   36  161  151
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   15352.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1412      [K,I,J]   45  234  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1761E-01  [K,I,J]   40  196  176
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8954E-03  [K,I,J]   21   44   15
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2502E-03  [K,I,J]   41  196  176
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3606E-04  [K,I,J]   35  149  213
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1699E-04  [K,I,J]   21   44   15
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2742E-05  [K,I,J]   21   44   15
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   15366.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1437      [K,I,J]   45  234  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2489E-01  [K,I,J]   40  196  176
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7898E-04  [K,I,J]   40  196  155
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4792E-03  [K,I,J]   42  202   99
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1134E-02  [K,I,J]   40  196  155
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6890E-04  [K,I,J]   41  196  176
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\swan47\Documents\GitHub\wasaga_model\wasaga_3d\temp v2_run_wasaga_3d 100Y with drain.ipynb Cell 105 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/swan47/Documents/GitHub/wasaga_model/wasaga_3d/temp%20v2_run_wasaga_3d%20100Y%20with%20drain.ipynb#Y203sZmlsZQ%3D%3D?line=0'>1</a> # Run the MODFLOW model
# ----> <a href='vscode-notebook-cell:/c%3A/Users/swan47/Documents/GitHub/wasaga_model/wasaga_3d/temp%20v2_run_wasaga_3d%20100Y%20with%20drain.ipynb#Y203sZmlsZQ%3D%3D?line=1'>2</a> mt.run_model()
#
# File c:\Users\swan47\Miniconda3\envs\pht3d\Lib\site-packages\flopy\mbase.py:1373, in BaseModel.run_model(self, silent, pause, report, normal_msg)
#    1342 def run_model(
#    1343     self,
#    1344     silent=False,
#    (...)
#    1347     normal_msg="normal termination",
#    1348 ):
#    1349     """
#    1350     This method will run the model using subprocess.Popen.
#    1351
#    (...)
#    1370
#    1371     """
# -> 1373     return run_model(
#    1374         self.exe_name,
#    1375         self.namefile,
#    1376         model_ws=self.model_ws,
#    1377         silent=silent,
#    1378         pause=pause,
#    1379         report=report,
#    1380         normal_msg=normal_msg,
#    1381     )
#
# File c:\Users\swan47\Miniconda3\envs\pht3d\Lib\site-packages\flopy\mbase.py:1747, in run_model(exe_name, namefile, model_ws, silent, pause, report, normal_msg, use_async, cargs)
#    1745 if not use_async:
#    1746     while True:
# -> 1747         line = proc.stdout.readline().decode("utf-8")
#    1748         if line == "" and proc.poll() is not None:
#    1749             break
#
# KeyboardInterrupt:

# %%
model_ws
# Out:
# 'C:\\Users\\swan47\\AppData\\Local\\Temp\\_T0117182556_wasaga_6ocycvka'
