# %% [markdown]
# # Import

# %% [markdown]
# - fix shoreline
# - add more septics
# - 1965 images
# - flux

# %%
import flopy
import numpy as np
import matplotlib.pyplot as plt
import shutil
from pathlib import Path

from datetime import datetime
from tempfile import TemporaryDirectory
from tempfile import mkdtemp

import os
import platform
import subprocess
from shapely.geometry import Polygon, Point
from scipy.interpolate import make_interp_spline
from random_name import generate_random_name

# %%
def locate_ground_surface_lay(row=150):
    cross_section = ibound[:,:,0]
    lay = np.where(cross_section[:,row]==1)[0][0]
    return lay

def meter_to_col(col_meter):
    return int(np.round(col_meter/delc,0))

def meter_to_row(row_meter):
    return int(np.round(row_meter/delc,0))

def meter_to_lay(lay_meter):
    return int(np.round((top_elev-lay_meter)/layer_thickness,0))

def col_to_meter(col):
    return col*delc

def row_to_meter(row):
    return row*delc

def lay_to_meter(row):
    return 190.0-row*layer_thickness

# %%
def change_array_within_polygon(array, row_coords, col_coords, value):

    # Create a polygon object from the row and column coordinates
    polygon = Polygon(zip(col_coords, row_coords))

    # Create a boolean mask indicating which points fall within the polygon
    mask = np.zeros_like(array, dtype=bool)
    for row in range(array.shape[0]):
        for col in range(array.shape[1]):
            point = Point(col, row)
            if polygon.contains(point) or polygon.intersects(point):
                mask[row, col] = True

    # Set the values of the array that fall within the polygon to the new value
    array[mask] = value

    return array

# %% [markdown]
# # Workspace

# %%
# Control variable to decide the location of the temp folder
use_d_drive = False  # Set to False to use default temp location

# Define model workspace
myt = datetime.now().strftime('%m%d%H%M%S')
name = 'wasaga'
adj_non = '_'+generate_random_name()

if use_d_drive:
    temp_dir = 'D:/_T{}_{}_{}'.format(myt, name,adj_non )
    os.makedirs(temp_dir, exist_ok=True)
else:
    temp_dir = mkdtemp(prefix='_T{}_'.format(myt),suffix=adj_non )

os.makedirs(Path(temp_dir) / '_output', exist_ok=True)

model_ws = temp_dir

def open_file(path):
    if platform.system() == "Windows":
        os.startfile(path)
    elif platform.system() == "Darwin":
        subprocess.Popen(["open", path])
    else:
        subprocess.Popen(["xdg-open", path])

open_file(model_ws)

# %%
mkdtemp(prefix='_T{}_{}'.format(myt, name))
# Out:
# 'C:\\Users\\swan47\\AppData\\Local\\Temp\\_T0124210550_wasagag_h9ka8q'

# %%
# base
parms= {}
parms['sp1']= 0.0002
parms['hk']= 6.9
parms['al'] = 5
base_parms = parms

# %% [markdown]
# # Model

# %%
# Create a MODFLOW model instance
mf = flopy.modflow.Modflow(modelname="example_model",version='mf2005',
                              exe_name='mf2005', 
                              model_ws=model_ws)

# %%
# # Create a MODFLOW model instance
# model = flopy.seawat.Seawat(modelname="example_model",
#                             exe_name='swtv4', 
#                               model_ws=model_ws)

# %% [markdown]
# # DIS

# %%
# year 1: 1968  (assume houses in 1978 [earilest satellite image] was built 10 years ago ) 
# year 56: (2024 present)
# year 76: (20 years later)
# year 156: (100 years later)
# year 556: (500 years later)

# %%
# Define model dimensions
nlay = int(60 * 2)
nrow = int(220 * 2)
ncol = int(220 * 2)
delr = 2200/nrow  # Cell width along rows (extend 2200 / 220)
delc = 2200/ncol  # Cell width along columns (extend 2200 / 220)

# Define top elevation
layer_thickness = 30.0 / nlay

top_elev = 190.0
botm_elev = [top_elev - (i * layer_thickness) for i in range(1, nlay + 1)]
# Define layer thickness (uniform thickness)


perlen = 365
nper = int(10)
#nper = int(56)
#nper = int(500)
#nper = int(20)

steady = np.append(np.array([True]),np.repeat(False,nper-1))
#steady=[False,False,True]
#steady = True

# Create DIS package

# %%
dis = flopy.modflow.ModflowDis(mf, nlay=nlay, nrow=nrow, ncol=ncol, 
                               delr=delr, delc=delc,top=top_elev, 
                               botm=botm_elev,
                               nper = nper, perlen = perlen,
                               nstp = 1, steady = steady)

# %% [markdown]
# # Ibound

# %%
x = np.array([0, 100, 340, 600, 750, 850, 1100, 1350, 1450, 1530, 1650, 1750, 1850, 2050, 2200])

y_topo = np.array([190,190,187,184,184,184,183,182,179,175.5,175,173.8,173.5,172,171])#topo
#y_topo = np.array([190,190,187,184,184,184,183,182,179+2,175.5+4,175+2,173.8+1,173.5+0,172,171])#topo

y_clay = np.array([185,184,180,175,174,174,173,170,169,168.5,167.5,166.8,166.5,165,164]) #clay


# Interpolate the data using smoothing splines
spl = make_interp_spline(x, y_topo)
x_smooth_topo = np.linspace(x.min(), x.max(), 30)
y_smooth_topo = spl(x_smooth_topo)

col_coords = (x_smooth_topo/delr).round(0)
col_coords_topo = list(col_coords) +[nrow,0]

row_coords = ((top_elev - y_smooth_topo)/layer_thickness).round(0)
row_coords_topo  =  list(row_coords) +[0,0]



# Interpolate the data using smoothing splines
spl = make_interp_spline(x, y_clay)
x_smooth = np.linspace(x.min(), x.max(), 30)
y_smooth = spl(x_smooth)

col_coords = (x_smooth/delr).round(0)
col_coords_clay = list(col_coords) +[nrow,0]
row_coords = ((top_elev - y_smooth)/layer_thickness).round(0)
row_coords_clay  =  list(row_coords) +[nlay,nlay]

# %% [markdown]
# # Ibound & Strt

# %%
# Define ibound and initial conditionsa
ibound = np.ones((nlay, nrow, ncol), dtype=int)
initial_head = np.full((nlay, nrow, ncol), 200.0, dtype=float)
shoreline_distance = 1600

# Set constant head boundary conditions for the first and last rows
array = change_array_within_polygon(ibound, row_coords_topo, col_coords_topo, 0)
plt.scatter(col_coords_topo,row_coords_topo,c='r')


array = change_array_within_polygon(ibound, row_coords_clay, col_coords_clay, 0)
plt.scatter(col_coords,row_coords,c='r')

for c in range(0,2):
    i = np.where(ibound[:,c,-1]==1)[0][-1]
    head = top_elev-i*layer_thickness
    #print('head {}'.format(head))
    
    while head<187:
        ibound[i,c,:] = -1
        #print(i,c)
        #initial_head[i,c,:] = head+0.5
        print(head)
        initial_head[i,c,:] = 187
        head+=layer_thickness
        i-=1


lay = np.where(ibound[:,int(shoreline_distance/delr),-1])[0][0]
elv = lay_to_meter(lay)
head = elv

for c in range(int(shoreline_distance/delr),int(2200/delr)):
    lay = np.where(ibound[:,c,-1]==1)[0][0]
    #print(lay,lay_to_meter(lay))
    ibound[lay,c,:] = -1
    initial_head[lay,c,:] = elv

# Your existing code
im = plt.imshow(ibound[:,:,2], origin='upper', aspect=1)
plt.axvline(x=meter_to_col(shoreline_distance))# shoreline
plt.gcf().set_size_inches(15,10)

# Set the y-axis tick positions and labels
#plt.yticks([0, 10,20, 30,40, 50,60], ['190m (0L)','185m (10L)', '180m (20L)','175m (30L)', '170m (40L)', '165m (50L)','160m (60L)'])
# Add a horizontal colorbar

cbar = plt.colorbar(im, orientation='horizontal')
cbar.ax.tick_params(labelsize=16)
cbar.set_label('Colorbar Label', fontsize=16)

# Display the plot
plt.title('ibound')
plt.grid()
plt.show()


fig, ax = plt.subplots(figsize=(15, 10))
im = ax.imshow(initial_head[:, :, 0], origin='upper')

# Add a horizontal colorbar
cbar = plt.colorbar(im, orientation='horizontal')
cbar.ax.tick_params(labelsize=18)
plt.title('initial head')
plt.show()
# Out:
# 185.25
# 185.5
# 185.75
# 186.0
# 186.25
# 186.5
# 186.75
# 185.0
# 185.25
# 185.5
# 185.75
# 186.0
# 186.25
# 186.5
# 186.75

# %% [markdown]
# # BAS LPF  PCG

# %%
# Create BAS package
bas = flopy.modflow.ModflowBas(mf, ibound=ibound, strt=initial_head)

# Define hydraulic properties
horizontal_k = parms['hk'] # Horizontal hydraulic conductivity (m/day)
vertical_ka = 0.1   # Vertical hydraulic conductivity (m/day)
porosity = 0.25     # Porosity

# Create LPF package (Layer Property Flow package)
lpf = flopy.modflow.ModflowLpf(mf, hk=horizontal_k, 
                               vka=vertical_ka, laytyp=1, 
                               ipakcb=None,ss=0.0002,sy=0.33,
                               laywet=1,iwetit=1,wetfct=0.1,ihdwet=1)

# #ss=0.0002,sy=0.33
# upw = flopy.modflow.ModflowUpw(model, laytyp=1, hk=horizontal_k)

pcg = flopy.modflow.ModflowPcg(mf, hclose=1e-3,npcond=1,
                               relax=0.99,rclose=1e-3,mutpcg=0,nbpol=1,iprpcg=1)

# %% [markdown]
# # DRN

# %%
locate_ground_surface_lay(meter_to_row(160))
#drn_cell = [(0, 150, 28), -10, 100]
start_dis = shoreline_distance - 130
end_dis = shoreline_distance - 70
beach_drns = np.arange(start_dis,end_dis+1,delr).astype(int)
river_drns = np.arange(595,605+1,delr).astype(int)
#beach_drns = []

drn_list = []
drn_ys= list(beach_drns)+list(river_drns)

for y in drn_ys:
   
   row = meter_to_row(y)
   lay = locate_ground_surface_lay(row=row)
   elv = lay_to_meter(lay)
   print(row)
   #print(lay)
   for col in range(ncol):

      drn_list.append([lay, row, col, elv, 1])
      #drn_list.append([12*2, meter_to_row(600), col, 184.0-0.5, 100])
      
drn_cell = {0:drn_list} 

#drn_cell={0:[[31, 160, 0, 174.5-0.5, 0],[12, 60, 0, 184.0-0.5, 0]]}
drn = flopy.modflow.ModflowDrn(model=mf, stress_period_data=drn_cell,)
# Out:
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 119
# 120
# 121

# %%
# Load your model
model = mf
# Plot the ibound array
plt.imshow(model.bas6.ibound.array[:, :, 0], origin='upper', cmap='bone')
# Plot drains for the first stress period if DRN package exists
if model.drn:
    for drn in np.unique(model.drn.stress_period_data[0], axis=0):
        if drn[2] == 0:  # Checks if the drain is in the first layer
            plt.scatter(drn[1], drn[0], c='cyan', s=5, marker='s')

# Customize and display the plot
plt.gcf().set_size_inches(15, 10)
plt.title('Ibound and Drain Cells Visualization')
plt.show()

# %% [markdown]
# # RCH

# %% [markdown]
# ### Test data

# %%
##2D pers [1]+[30,92,31,212]*25 +[365]*5+[365*5]*5+[365*4]+[185,30,30,120]

# %%
# rch_dict = {}

# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# rch_dict[0] = rch_array

# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# #rch_array[int(nrow/2),int(ncol/2)] = 0.51/delr/delc
# #rch_array[int(nrow/2),int(ncol/3)] = 0.51/delr/delc

# rch_array[int((1700-70)/delr),int(ncol/2)] = 0.51/delr/delc
# rch_array[int((1700-70)/delr),int(ncol/3)] = 0.51/delr/delc
# rch_dict[1] = rch_array 


# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# rch_dict[26] = rch_array


# rch = flopy.modflow.ModflowRch(model = mf, rech = rch_dict)

# %%
# shoreline at 1700m , septic at 1700-60

# %%
def calculate_year_septic_start(df):
    # Ensure the DataFrame is sorted by 'Year'
    df = df.sort_values('Year').reset_index(drop=True)
    
    # Get the unique years and sort them
    unique_years = sorted(df['Year'].unique())
    
    # Initialize the "Year_Septic_Start" list
    year_septic_start = []
    
    # Iterate through the DataFrame rows
    for current_year in df['Year']:
        # Find the index of the current_year in the unique_years list
        current_index = unique_years.index(current_year)
        
        # Determine the previous year (if it's not the first year)
        if current_index == 0:
            #previous_year = 1950  # If it's the first unique year, use 1950
            year_septic_start.append(1950)
        else:
            previous_year = unique_years[current_index - 1]  # Get the previous unique year
        
        # Calculate the "Year_Septic_Start"
            year_septic_start.append((current_year + previous_year) // 2)
    
    # Add the "Year_Septic_Start" as a new column in the DataFrame
    df['Year_Septic_Start'] = year_septic_start
    return df

# %%
import pandas as pd
df = pd.read_csv("wasaga septics placement/septics_transformed.csv")
df = df[~df['Year End'].isna()]
df['Year End'] =df['Year End'].astype(int)
df = calculate_year_septic_start(df)
df['Year_Septic_End'] = df['Sewer_Installation_Period'].apply(lambda x: (int(x.split('-')[1]) + int(x.split('-')[0]))//2)

# %%
end_dis
# Out:
# 1530

# %%
# Assuming nrow, ncol, delr, delc, and mf are defined earlier in your code

# Initialize the recharge dictionary
rch_dict = {0: np.full((nrow, ncol), 0.00013, dtype=float)}  # Initial background recharge rate


# Loop through the DataFrame to update rch_dict
for index, row in df.iterrows():
    easting = row['Wasaga Easting']
    northing = row['Wasaga Northing']
    start_year = row['Year_Septic_Start']
    end_year = row['Year_Septic_End']

    # Calculate the indices
    row_index = int(northing / delr)
    col_index = int(easting / delc)

    # Calculate the range of years for each septic source
    start_key = start_year - 1950 + 1
    end_key = end_year - 1950 + 1

    # Loop through each year for the septic source
    for year_key in range(start_key, end_key + 1):
        # Check if the key exists in the dictionary, if not, create a new array with background recharge
        if year_key not in rch_dict:
            rch_dict[year_key] = np.full((nrow, ncol), 0.00013, dtype=float)

        # Update the recharge rate at the septic location
        rch_dict[year_key][row_index, col_index] = 0.51 / delr / delc
    
    # Ensure the septic is turned off after its end year
    # Check if the year after the end_key exists in the dictionary, if not, create a new array with background recharge
    if end_key + 1 not in rch_dict:
        rch_dict[end_key + 1] = np.full((nrow, ncol), 0.00013, dtype=float)
    
    # Set the recharge rate back to the background rate after the septic system's active period
    rch_dict[end_key + 1][row_index, col_index] = 0.00013

# Create the ModflowRch object
rch = flopy.modflow.ModflowRch(model=mf, rech=rch_dict)

# %%
import numpy as np
import flopy  # Assuming flopy is already installed and imported

# Assuming nrow, ncol, delr, delc, mf are defined earlier in your code
# Define start_dist, end_dist, and exclude_range
start_dist = start_dis  # Define start distance for exclusion (e.g., 1000 meters)
end_dist = end_dis    # Define end distance for exclusion (e.g., 2000 meters)
exclude_range = True  # Set to True to exclude, False to include

# Convert distances to row indices
start_row_index = int(start_dist / delr)
end_row_index = int(end_dist / delr)

# Initialize the recharge dictionary
rch_dict = {0: np.full((nrow, ncol), 0.00013, dtype=float)}  # Initial background recharge rate

# Loop through the DataFrame to update rch_dict
for index, row in df.iterrows():
    easting = row['Wasaga Easting']
    northing = row['Wasaga Northing']
    start_year = row['Year_Septic_Start']
    end_year = row['Year_Septic_End']

    # Calculate the indices
    row_index = int(northing / delr)
    col_index = int(easting / delc)

    # Check if row index is within the exclusion range and if exclusion is enabled
    if exclude_range and start_row_index <= row_index <= end_row_index:
        continue  # Skip updating for this row index

    # Calculate the range of years for each septic source
    start_key = start_year - 1950 + 1
    end_key = end_year - 1950 + 1

    # Loop through each year for the septic source
    for year_key in range(start_key, end_key + 1):
        # Check if the key exists in the dictionary, if not, create a new array with background recharge
        if year_key not in rch_dict:
            rch_dict[year_key] = np.full((nrow, ncol), 0.00013, dtype=float)

        # Update the recharge rate at the septic location
        rch_dict[year_key][row_index, col_index] = 0.51 / delr / delc
    
    # Ensure the septic is turned off after its end year
    if end_key + 1 not in rch_dict:
        rch_dict[end_key + 1] = np.full((nrow, ncol), 0.00013, dtype=float)

    # Set the recharge rate back to the background rate after the septic system's active period
    rch_dict[end_key + 1][row_index, col_index] = 0.00013

# Create the ModflowRch object
rch = flopy.modflow.ModflowRch(model=mf, rech=rch_dict)

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 8))

# Plot drain coordinates
rows = []
cols = []
for drn in np.unique(model.drn.stress_period_data[0], axis=0):
    rows.append(drn[1])
    cols.append(drn[2])

ax.scatter(cols, rows, c='cyan', marker='s')

# Plot and customize the shoreline as a thicker, dashed line and add annotation
shoreline_y = shoreline_distance / delr
ax.axhline(shoreline_y, color='blue', linestyle='--', linewidth=2, label='Shoreline')
ax.annotate('Shoreline', xy=(0.5, shoreline_y), xytext=(0, 5),
            xycoords=('axes fraction', 'data'), textcoords='offset points',
            ha='center', va='bottom')

# Assuming rch_dict, delr, and delc are already defined
target_value = 0.51 / delr / delc
colors = plt.cm.jet(np.linspace(0, 1, len(rch_dict)))

for (key, array), color in zip(rch_dict.items(), colors):
    rows, cols = np.where(np.isclose(array, target_value))
    if rows.size and cols.size:
        ax.scatter(cols, rows, color=color, label=f'Key: {key}',s=10)

# Set titles and labels
ax.set(title='Drain and Septics', xlabel='Column ', ylabel='Row ')

# Display legend
#ax.legend()
# plt.xlim(0,440)
# plt.ylim(280,320)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calculate and plot in a compact form
kpers, active_septics = zip(*sorted((year_key, np.sum(rech >= 0.51 / delr / delc)) for year_key, rech in rch_dict.items()))

fig, ax1 = plt.subplots(figsize=(10, 6))
bars = ax1.bar(kpers, active_septics, color='dodgerblue', alpha=0.7)

ax1.set(xlabel='kper', ylabel='Number of Active Septic Sources', title='Active Septic Sources Over Time')

ax2 = ax1.twiny().set(xlabel='Year', xlim=[k + 1950 for k in ax1.get_xlim()], xticks=[k + 1950 for k in ax1.get_xticks()],
                      xticklabels=[int(k + 1950) for k in ax1.get_xticks()])
ax1.grid(axis='y', linestyle='--', alpha=0.7)

for bar, val in zip(bars, active_septics):
    if val == 0: ax1.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(val), ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout(); plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming crch_dict is already defined and filled with your data

period = max(rch_dict.keys()) - 30  # Specify the period you want to visualize
if period in rch_dict: 
    crch_array = rch_dict[period]
    plt.imshow(crch_array, cmap='viridis', interpolation='nearest')
    plt.colorbar(label='Concentration');plt.gca().invert_yaxis()
    plt.xlabel('Column Index'); plt.ylabel('Row Index'); plt.title(f'RCH Array Visualization at Period {period}');plt.show()
else: print(f"No data available for period {period}")

# %% [markdown]
# # OC

# %%
# OC
spd = {}
for kper in range(nper):
    for kstp in range(1):
        spd[(kper, kstp)] = [
            "save head",
            "save drawdown",
            "save budget",
            "print head",
            "print budget",
        ]

oc = flopy.modflow.ModflowOc(
    mf,
    stress_period_data= spd,
    compact=True
    ,extension=['oc', 'hds', 'ddn', 'cbc', 'ibo']
)

#oc.reset_budgetunit(budgetunit=1053, fname='test.cbc')
oc.reset_budgetunit(budgetunit=53, fname='example_model.cbc')

# %%
lmt = flopy.modflow.ModflowLmt(mf, output_file_name='mt3d_link.ftl')

# %%
# Write the MODFLOW model input files
mf.write_input()

# %%
# Run the MODFLOW model
success, buff = mf.run_model()
# Out:
# FloPy is using the following executable to run the model: C:\Users\swan47\AppData\Local\flopy\bin\mf2005.EXE
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.12.00 2/3/2017
#
#  Using NAME file: example_model.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2024/01/17 16:26:11
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     2    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     3    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     4    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     5    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     6    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     7    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     8    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:     9    Time step:     1    Ground-Water Flow Eqn.
#  Solving:  Stress period:    10    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2024/01/17 16:36:32
#  Elapsed run time: 10 Minutes, 21.418 Seconds
#
#   Normal termination of simulation

# %% [markdown]
# # ---MT3DMS---

# %%
mt = flopy.mt3d.Mt3dms(modflowmodel=mf, modelname='mt', exe_name='mt3dms.exe' ,ftlfilename='mt3d_link.ftl',model_ws=model_ws)

# %% [markdown]
# # ICBUND

# %%
icbund = ibound.copy()
cc = np.where(icbund==-1)
mask = cc[1]>2200/2/delr

cc2 = (cc[0][mask],cc[1][mask],cc[2][mask])
icbund[cc2] = 1
plt.imshow(icbund[:,:,0])

# %% [markdown]
# # BTN ICBOUND

# %%
#icbund = np.full((nlay, nrow, ncol),0, dtype=float)
#
btn = flopy.mt3d.Mt3dBtn(
    mt,
    nprs=5,
    timprs=np.cumsum([200]*7),
    prsity=0.25,
    sconc= 0.01, # starting concentration
    ifmtcn=0, chkmas=False, nprobs=10, nprmas=10,
    dt0=5,  # The user-specified initial 
    ttsmult=1.4,
    mxstrn = 50000,
    icbund = icbund
)

# %%
adv = flopy.mt3d.Mt3dAdv(mt, mixelm=0,percel=0.4,mxpart=50000000,nadvfd=0)
dsp = flopy.mt3d.Mt3dDsp(mt, al=parms['al'], trpt=0.1, 
                        trpv=0.01, 
                        dmcoef=3.7E-10 )  ## !!TRVP change to 0.01
gcg = flopy.mt3d.Mt3dGcg(mt, iter1=50, mxiter=1, isolve=2, cclose= 1e-5)

# %% [markdown]
# # RCH

# %%
# crch_array =  np.full(( nrow, ncol), 0.1, dtype=float)
# crch_dict = {}
# crch_dict[0] = crch_array
# ssm = flopy.mt3d.Mt3dSsm(model, crch=crch_dict)

# rch_dict = {}
# rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
# rch_dict[0] = rch_array
# rch = flopy.modflow.ModflowRch(model = model, rech = rch_dict)


# ## [row, col, rch(m3), crch, start, end]
# rch_data = [[1100,1100,0.51,5000,1,20]]

# %% [markdown]
# ### Real Septics

# %%
import numpy as np
import pandas as pd
import flopy

# Assuming nrow, ncol, delr, delc, and mt are defined earlier in your code

# Initialize the base concentration array and the dictionary
crch_array_base = np.full((nrow, ncol), 0.01, dtype=float)
crch_dict = {0: crch_array_base.copy()}

# Read the CSV file from the specified path
df = pd.read_csv("wasaga septics placement/septics_transformed.csv")
df = df[~df['Year End'].isna()]
df['Year End'] =df['Year End'].astype(int)

# Loop through the DataFrame to update crch_dict
for index, row in df.iterrows():
    easting = row['Wasaga Easting']
    northing = row['Wasaga Northing']
    start_year = row['Year']
    end_year = row['Year End']

    # Calculate the indices
    row_index = int(northing / delr)  # Using northing for row index
    col_index = int(easting / delc)   # Using easting for column index

    # Calculate the range of years for each septic source
    start_key = start_year - 1968
    end_key = end_year - 1968

    # Loop through each year for the septic source
    for year_key in range(start_key, end_key + 1):
        # Check if the key exists in the dictionary, if not, create a new array
        if year_key not in crch_dict:
            crch_dict[year_key] = crch_array_base.copy()

        # Update the concentration at the specified location
        crch_dict[year_key][row_index, col_index] = 5000  # or any other value you wish to set

# Create the SSM object
ssm = flopy.mt3d.Mt3dSsm(mt, crch=crch_dict)

# %%
import numpy as np
import pandas as pd
import flopy

# Assuming nrow, ncol, delr, delc, and mt are defined earlier in your code
# Also assuming rch_dict is already defined from your MODFLOW recharge setup

# Initialize the base concentration array and the dictionary
crch_array_base = np.full((nrow, ncol), 0.01, dtype=float)  # Background concentration
crch_dict = {}

# Constants for recharge and concentration
background_recharge = 0.00013
septic_recharge = 0.51 / delr / delc
background_concentration = 0.01
septic_concentration = 5000

# Loop through each stress period in rch_dict
for stress_period, rch_array in rch_dict.items():
    # Copy the base concentration array for the current stress period
    crch_array = crch_array_base.copy()
    
    # Find indices where recharge rate indicates a septic source
    septic_indices = np.where(rch_array == septic_recharge)
    
    # Update the concentration array at these indices
    crch_array[septic_indices] = septic_concentration
    
    # Store the updated concentration array in crch_dict for the current stress period
    crch_dict[stress_period] = crch_array

# Create the SSM object using crch_dict
ssm = flopy.mt3d.Mt3dSsm(mt, crch=crch_dict)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Constants for recharge and concentration
septic_concentration = 5000

# Calculate and plot in a compact form
kpers, active_septics = zip(*sorted((year_key, np.sum(crch == septic_concentration)) for year_key, crch in crch_dict.items()))

fig, ax1 = plt.subplots(figsize=(10, 6))
bars = ax1.bar(kpers, active_septics, color='dodgerblue', alpha=0.7)

ax1.set(xlabel='Stress Period (kper)', ylabel='Number of Active Septic Sources', title='Active Septic Sources Over Time')

# Adjust the x-axis to show actual years assuming the first stress period starts in 1950 (change if needed)
start_year = 1950
ax2 = ax1.twiny()
ax2.set(xlabel='Year', xlim=[start_year + kpers[0], start_year + kpers[-1]], xticks=[start_year + k for k in ax1.get_xticks()],
        xticklabels=[int(start_year + k) for k in ax1.get_xticks()])
ax1.grid(axis='y', linestyle='--', alpha=0.7)

# Add text labels on the bars
for bar, val in zip(bars, active_septics):
    if val == 0:
        ax1.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(val), ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming crch_dict is already defined and filled with your data

period = 47  # Specify the period you want to visualize

# Check if the period exists in the dictionary
if period in crch_dict:
    # Extract the array for the specified period
    crch_array = crch_dict[period]

    # Create a heatmap of the array
    plt.imshow(crch_array, cmap='viridis', interpolation='nearest')
    plt.colorbar(label='Concentration')  # Add a color bar to indicate the values

    # Flip the y-axis
    plt.gca().invert_yaxis()

    # Add labels and title
    plt.xlabel('Column Index')
    plt.ylabel('Row Index')
    plt.title(f'CRCH Array Visualization at Period {period}')

    # Show the plot
    plt.show()
else:
    print(f"No data available for period {period}")

# %% [markdown]
# ### Test SSM

# %%
# crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)
# crch_dict = {}
# crch_dict[0] = crch_array

# crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)

# # crch_array[int(nrow/2),int(ncol/2)] =5000
# # crch_array[int(nrow/2),int(ncol/3)] =5000
# crch_array[int((1700-70)/delr),int(ncol/3)] =5000
# crch_array[int((1700-70)/delr),int(ncol/2)] =5000
# spetic_locs = [[int((1700-70)/delr),int(ncol/3)], [int((1700-70)/delr),int(ncol/2)]]

# crch_dict = {}
# crch_dict[1] = crch_array


# crch_array =  np.full(( nrow, ncol), 0.01, dtype=float)
# crch_dict[26] = crch_array

# ssm = flopy.mt3d.Mt3dSsm(mt, crch=crch_dict)

# %%
im = plt.imshow(ibound[:, :, 0], origin='upper')

drns0 = np.unique([i for i in drn.stress_period_data.data[0] if i[2]==0])
for i in drns0:
    plt.scatter(i[1],i[0],c='cyan',s=5,marker='s')


# for i in spetic_locs:

#     plt.scatter([i[0],i[0],i[0],i[0]],[1,2,3,4],c='red',s=6,marker='s')
    


plt.gcf().set_size_inches(15,10)
plt.show()

# %% [markdown]
# # RCT

# %%
rct = flopy.mt3d.Mt3dRct(model=mt, isothm=3,sp1=parms['sp1'],sp2=0.0001,igetsc=0,rhob= 1.65E+09)

# %% [markdown]
# # Write and Run

# %%
# Write MODFLOW input files
mt.write_input()

# %%
open_file(model_ws)

# %%
# Run the MODFLOW model
mt.run_model()
# Out:
# FloPy is using the following executable to run the model: C:\Users\swan47\AppData\Local\flopy\bin\mt3dms.exe
#  MT3DMS - Modular 3-D Multi-Species Transport Model [Version 5.30]
#  Developed at University of Alabama for U.S. Department of Defense
#
#  Using NAME File: mt.nam
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    365.00
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   5.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1742E-02  [K,I,J]   61  319   32
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   12.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2407E-02  [K,I,J]   61  319   31
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]   61  314    1
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   21.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3310E-02  [K,I,J]   61  319  435
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1192E-06  [K,I,J]   61  314    1
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   35.520
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4519E-02  [K,I,J]   61  319  435
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-06  [K,I,J]   61  314    1
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   54.728
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6112E-02  [K,I,J]   61  319  435
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8345E-06  [K,I,J]   61  314    1
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   81.619
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8162E-02  [K,I,J]   61  319  435
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2623E-05  [K,I,J]   65  340    1
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   119.27
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1072E-01  [K,I,J]   61  319  435
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7868E-05  [K,I,J]   65  340    2
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   171.97
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1379E-01  [K,I,J]   61  319  435
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2646E-04  [K,I,J]   65  341    5
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1132E-05  [K,I,J]   65  341    1
#  Transport Step:    9   Step Size:   28.03     Total Elapsed Time:   200.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6946E-02  [K,I,J]   61  319  435
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5722E-05  [K,I,J]   65  341    1
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   303.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2232E-01  [K,I,J]   61  319  435
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1877E-03  [K,I,J]   65  341   16
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1603E-04  [K,I,J]   65  341    7
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1192E-06  [K,I,J]   62  318    1
#  Transport Step:   11   Step Size:   61.69     Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1204E-01  [K,I,J]   61  319  435
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6419E-04  [K,I,J]   65  341   15
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2325E-05  [K,I,J]   65  341    1
#
#  STRESS PERIOD NO.    2
#
#  TIME STEP NO.    1
#  FROM TIME =   365.00     TO    730.00
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   370.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9565E-03  [K,I,J]   61  319  428
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]   65  341    1
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   377.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1325E-02  [K,I,J]   61  319  416
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1788E-06  [K,I,J]   65  341    1
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   386.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1829E-02  [K,I,J]   61  319   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5364E-06  [K,I,J]   65  341    1
#  Transport Step:    4   Step Size:   13.20     Total Elapsed Time:   400.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2418E-02  [K,I,J]   61  319  427
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1252E-05  [K,I,J]   65  341    1
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   419.21
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3425E-02  [K,I,J]   61  319  427
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3755E-05  [K,I,J]   65  341    1
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   446.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4621E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9656E-05  [K,I,J]   65  341    9
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   483.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6153E-02  [K,I,J]   61  319   34
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2348E-04  [K,I,J]   65  341    8
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2980E-06  [K,I,J]   65  341    1
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   536.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8048E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5418E-04  [K,I,J]   65  341   10
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1073E-05  [K,I,J]   65  341    1
#  Transport Step:    9   Step Size:   63.55     Total Elapsed Time:   600.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8957E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8374E-04  [K,I,J]   65  341   10
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2086E-05  [K,I,J]   65  341    1
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   703.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1294E-01  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2328E-03  [K,I,J]   65  341    9
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1222E-04  [K,I,J]   65  341    2
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1192E-06  [K,I,J]   65  340    1
#  Transport Step:   11   Step Size:   26.69     Total Elapsed Time:   730.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3190E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9835E-05  [K,I,J]   65  341   11
#
#  STRESS PERIOD NO.    3
#
#  TIME STEP NO.    1
#  FROM TIME =   730.00     TO    1095.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   735.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5922E-03  [K,I,J]   61  319   11
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1192E-06  [K,I,J]   65  341    1
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   742.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8218E-03  [K,I,J]   61  319   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2384E-06  [K,I,J]   65  341    1
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   751.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1137E-02  [K,I,J]   61  319   37
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6557E-06  [K,I,J]   65  341    1
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   765.52
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1566E-02  [K,I,J]   61  319   24
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1669E-05  [K,I,J]   65  341    1
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   784.73
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2144E-02  [K,I,J]   61  319   24
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4172E-05  [K,I,J]   65  341    1
#  Transport Step:    6   Step Size:   15.27     Total Elapsed Time:   800.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1672E-02  [K,I,J]   61  319   31
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2265E-05  [K,I,J]   65  341    1
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   837.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3958E-02  [K,I,J]   61  319   38
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2372E-04  [K,I,J]   65  341    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1788E-06  [K,I,J]   65  340    1
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   890.35
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5231E-02  [K,I,J]   61  319   38
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5221E-04  [K,I,J]   65  341   16
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7153E-06  [K,I,J]   65  341    1
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   964.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6779E-02  [K,I,J]   61  319   37
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1075E-03  [K,I,J]   65  341    3
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2563E-05  [K,I,J]   65  341    1
#  Transport Step:   10   Step Size:   35.86     Total Elapsed Time:   1000.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3147E-02  [K,I,J]   61  319   38
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1955E-04  [K,I,J]   65  341    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1192E-06  [K,I,J]   61  319    1
#  Transport Step:   11   Step Size:   95.00     Total Elapsed Time:   1095.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7630E-02  [K,I,J]   61  319   39
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1714E-03  [K,I,J]   65  341    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6020E-05  [K,I,J]   65  341    1
#
#  STRESS PERIOD NO.    4
#
#  TIME STEP NO.    1
#  FROM TIME =   1095.0     TO    1460.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1100.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3943E-03  [K,I,J]   61  319   34
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]   65  341    1
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1107.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5478E-03  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2384E-06  [K,I,J]   65  341    1
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1116.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7592E-03  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-06  [K,I,J]   65  341    1
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1130.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1048E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-05  [K,I,J]   65  341    1
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1149.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1438E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3636E-05  [K,I,J]   65  341    1
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1176.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1960E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8762E-05  [K,I,J]   65  341    2
#  Transport Step:    7   Step Size:   23.38     Total Elapsed Time:   1200.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1663E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6020E-05  [K,I,J]   65  341    1
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1252.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3572E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4393E-04  [K,I,J]   65  341   10
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4768E-06  [K,I,J]   65  341    1
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   1326.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4674E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8923E-04  [K,I,J]   65  341   10
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1848E-05  [K,I,J]   65  341    2
#  Transport Step:   10   Step Size:   73.50     Total Elapsed Time:   1400.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4343E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8458E-04  [K,I,J]   65  341    9
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1669E-05  [K,I,J]   65  341    1
#  Transport Step:   11   Step Size:   60.00     Total Elapsed Time:   1460.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3344E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5215E-04  [K,I,J]   65  341    9
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7153E-06  [K,I,J]   65  341    1
#
#  STRESS PERIOD NO.    5
#
#  TIME STEP NO.    1
#  FROM TIME =   1460.0     TO    1825.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1465.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2758E-03  [K,I,J]   61  319   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]   65  341    1
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1472.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3833E-03  [K,I,J]   61  319    6
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1788E-06  [K,I,J]   65  341    1
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1481.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5318E-03  [K,I,J]   61  319   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4768E-06  [K,I,J]   65  341    1
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1495.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7351E-03  [K,I,J]   61  319   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1192E-05  [K,I,J]   65  341    1
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1514.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1011E-02  [K,I,J]   61  319   24
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-05  [K,I,J]   65  341    1
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1541.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1382E-02  [K,I,J]   61  319   32
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7153E-05  [K,I,J]   65  341  437
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   1579.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1873E-02  [K,I,J]   61  319   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1621E-04  [K,I,J]   65  341    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1192E-06  [K,I,J]   61  319    1
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1632.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2508E-02  [K,I,J]   61  319   32
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3499E-04  [K,I,J]   65  341  435
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3576E-06  [K,I,J]   65  341    1
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   1705.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3305E-02  [K,I,J]   61  319   32
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7075E-04  [K,I,J]   65  341    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1371E-05  [K,I,J]   65  341    1
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   1809.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4268E-02  [K,I,J]   61  319   36
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1321E-03  [K,I,J]   65  341    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4649E-05  [K,I,J]   65  341    2
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   1825.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6416E-03  [K,I,J]   61  319   24
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-05  [K,I,J]   65  341    1
#
#  STRESS PERIOD NO.    6
#
#  TIME STEP NO.    1
#  FROM TIME =   1825.0     TO    2190.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   1830.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2006E-03  [K,I,J]   61  319  109
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]   65  341    1
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   1837.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2789E-03  [K,I,J]   61  319    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1192E-06  [K,I,J]   65  341    1
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   1846.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3873E-03  [K,I,J]   61  319    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3576E-06  [K,I,J]   65  341    1
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   1860.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5360E-03  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9537E-06  [K,I,J]   65  341    1
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   1879.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7387E-03  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2384E-05  [K,I,J]   65  341    1
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   1906.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1012E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5603E-05  [K,I,J]   65  341    1
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   1944.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1376E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1281E-04  [K,I,J]   65  341    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5960E-07  [K,I,J]   61  314    1
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   1997.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1850E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2760E-04  [K,I,J]   65  341   10
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2980E-06  [K,I,J]   65  341    1
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   2070.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2453E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5549E-04  [K,I,J]   65  341  439
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1073E-05  [K,I,J]   65  341    1
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   2174.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3192E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1034E-03  [K,I,J]   65  341  439
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3695E-05  [K,I,J]   65  341    2
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   2190.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4808E-03  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1192E-05  [K,I,J]   65  341  439
#
#  STRESS PERIOD NO.    7
#
#  TIME STEP NO.    1
#  FROM TIME =   2190.0     TO    2555.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   2195.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1504E-03  [K,I,J]   61  319    9
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]   65  341    1
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   2202.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2093E-03  [K,I,J]   61  319   16
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1192E-06  [K,I,J]   65  341    1
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   2211.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2907E-03  [K,I,J]   61  319  217
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2980E-06  [K,I,J]   65  341    1
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   2225.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4027E-03  [K,I,J]   61  319   22
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7749E-06  [K,I,J]   65  341    1
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   2244.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5558E-03  [K,I,J]   61  319    6
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1848E-05  [K,I,J]   65  341    1
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   2271.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7631E-03  [K,I,J]   61  319    6
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4411E-05  [K,I,J]   65  341    1
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   2309.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1040E-02  [K,I,J]   61  319   22
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1001E-04  [K,I,J]   65  341  435
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5960E-07  [K,I,J]   61  315    1
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   2362.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1404E-02  [K,I,J]   61  319    5
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2140E-04  [K,I,J]   65  341    3
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2384E-06  [K,I,J]   65  341    1
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   2435.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1871E-02  [K,I,J]   61  319    6
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4286E-04  [K,I,J]   65  341  434
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8345E-06  [K,I,J]   65  341    1
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   2539.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2452E-02  [K,I,J]   61  319    6
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7898E-04  [K,I,J]   65  341  434
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3040E-05  [K,I,J]   65  341    2
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   2555.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3700E-03  [K,I,J]   61  319    6
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8941E-06  [K,I,J]   65  341    1
#
#  STRESS PERIOD NO.    8
#
#  TIME STEP NO.    1
#  FROM TIME =   2555.0     TO    2920.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   2560.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1159E-03  [K,I,J]   61  319   31
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]   65  341    1
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   2567.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1612E-03  [K,I,J]   61  319    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1192E-06  [K,I,J]   65  341    1
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   2576.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2241E-03  [K,I,J]   61  319   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2384E-06  [K,I,J]   65  341    1
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   2590.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3107E-03  [K,I,J]   61  319   22
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-06  [K,I,J]   65  341    1
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   2609.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4294E-03  [K,I,J]   61  319   22
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1431E-05  [K,I,J]   65  341    1
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   2636.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5907E-03  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3397E-05  [K,I,J]   65  341    2
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   2674.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8072E-03  [K,I,J]   61  319   18
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7689E-05  [K,I,J]   65  341  427
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   2727.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1093E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1633E-04  [K,I,J]   65  341    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1788E-06  [K,I,J]   65  341    1
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   2800.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1464E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3266E-04  [K,I,J]   65  341  439
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7153E-06  [K,I,J]   65  341    1
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   2904.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1929E-02  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6008E-04  [K,I,J]   65  341  439
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2563E-05  [K,I,J]   65  341  438
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   2920.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2915E-03  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7153E-06  [K,I,J]   65  341    2
#
#  STRESS PERIOD NO.    9
#
#  TIME STEP NO.    1
#  FROM TIME =   2920.0     TO    3285.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   2925.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9137E-04  [K,I,J]   61  319   34
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   2932.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1272E-03  [K,I,J]   61  319  338
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]   65  341    1
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   2941.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1769E-03  [K,I,J]   61  319   39
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1788E-06  [K,I,J]   65  341    1
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   2955.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2455E-03  [K,I,J]   61  319   18
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4172E-06  [K,I,J]   65  341    1
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   2974.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3397E-03  [K,I,J]   61  319   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1073E-05  [K,I,J]   65  341    1
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   3001.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4680E-03  [K,I,J]   61  319   27
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2563E-05  [K,I,J]   65  341    1
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   3039.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6407E-03  [K,I,J]   61  319   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5841E-05  [K,I,J]   65  341  437
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   3092.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8705E-03  [K,I,J]   61  319  219
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1234E-04  [K,I,J]   65  341  434
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1788E-06  [K,I,J]   65  341    1
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   3165.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1170E-02  [K,I,J]   61  319   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2438E-04  [K,I,J]   65  341  433
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5960E-06  [K,I,J]   65  341    1
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   3269.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1552E-02  [K,I,J]   61  319   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4423E-04  [K,I,J]   65  341  433
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2146E-05  [K,I,J]   65  341    2
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   3285.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2350E-03  [K,I,J]   61  319   22
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5364E-06  [K,I,J]   65  341    1
#
#  STRESS PERIOD NO.   10
#
#  TIME STEP NO.    1
#  FROM TIME =   3285.0     TO    3650.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   3290.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7594E-04  [K,I,J]   50  249  440
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   3297.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1025E-03  [K,I,J]   61  319    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]   65  341    1
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   3306.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1428E-03  [K,I,J]   61  319  325
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1192E-06  [K,I,J]   65  341    1
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   3320.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1982E-03  [K,I,J]   61  319    7
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3576E-06  [K,I,J]   65  341    1
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   3339.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2747E-03  [K,I,J]   61  319  380
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8345E-06  [K,I,J]   65  341    1
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   3366.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3788E-03  [K,I,J]   61  319    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1907E-05  [K,I,J]   65  341    1
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   3404.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5198E-03  [K,I,J]   61  319    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4292E-05  [K,I,J]   65  341    2
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   3457.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7085E-03  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9060E-05  [K,I,J]   65  341    2
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   3530.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9561E-03  [K,I,J]   61  319    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1794E-04  [K,I,J]   65  341  440
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5364E-06  [K,I,J]   65  341    1
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   3634.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1274E-02  [K,I,J]   61  319    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3231E-04  [K,I,J]   65  341  440
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1788E-05  [K,I,J]   65  341    1
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   3650.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1932E-03  [K,I,J]   61  319    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3576E-06  [K,I,J]   65  341    1
#
#  STRESS PERIOD NO.   11
#
#  TIME STEP NO.    1
#  FROM TIME =   3650.0     TO    4015.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   3655.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1049E+05  [K,I,J]   47  235  237
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   657.6      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =   42.58      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =   2.248      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1494      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1025E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7324E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2384E-05  [K,I,J]   14    7  128
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   3662.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8445      [K,I,J]   16   20  252
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1267      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1316E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1214E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1242E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1079E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1132E-05  [K,I,J]   17   22   84
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   3671.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6142      [K,I,J]   18   28  412
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1301      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1842E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2976E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3903E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4959E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6795E-05  [K,I,J]   17   22   84
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   3685.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4880      [K,I,J]   23   50  259
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1336      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2417E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6266E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1028E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1979E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2986E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6080E-05  [K,I,J]   17   22   84
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   3704.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3980      [K,I,J]   24   54  246
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1310      [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3068E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1060E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2507E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5702E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1332E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2670E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6795E-05  [K,I,J]   17   22   84
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   3731.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3455      [K,I,J]   15   14  229
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1248      [K,I,J]   18   26  228
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4019E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1487E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5383E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1422E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4370E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1155E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3016E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.9179E-05  [K,I,J]   17   22   84
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   3769.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3110      [K,I,J]   49  241  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1173      [K,I,J]   19   30  251
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5237E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1836E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8825E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3263E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1010E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3866E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1192E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3767E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1383E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.4768E-05  [K,I,J]   17   22   84
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   3822.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2819      [K,I,J]   49  241  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1058      [K,I,J]   47  226  246
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6233E-01  [K,I,J]   14    8  176
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2202E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1105E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5545E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2172E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.8006E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3772E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1435E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.4923E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1943E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.7629E-05  [K,I,J]   17   22   84
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   3895.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2475      [K,I,J]   49  241  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9280E-01  [K,I,J]   44  204   67
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6853E-01  [K,I,J]   48  233  156
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2623E-01  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1216E-01  [K,I,J]   46  219  252
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6679E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3752E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1704E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6707E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3334E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1508E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.5996E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.2503E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1121E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.4768E-05  [K,I,J]   17   22   84
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   3999.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2068      [K,I,J]   49  240  299
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8065E-01  [K,I,J]   57  291   78
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6616E-01  [K,I,J]   45  211   69
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3009E-01  [K,I,J]   47  228  165
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1347E-01  [K,I,J]   44  205  227
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7746E-02  [K,I,J]   47  226  246
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4537E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2422E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1151E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5206E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2756E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1343E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.6032E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.2718E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1323E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.5603E-05  [K,I,J]   17   22   84
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   4015.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2712E-01  [K,I,J]   40  169   51
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1190E-01  [K,I,J]   52  259  176
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3440E-02  [K,I,J]   48  235  237
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1203E-02  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4126E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1069E-03  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3105E-04  [K,I,J]   17   22   84
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.7689E-05  [K,I,J]   17   22   84
#
#  STRESS PERIOD NO.   12
#
#  TIME STEP NO.    1
#  FROM TIME =   4015.0     TO    4380.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   4020.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7259      [K,I,J]   45  224  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5796E-01  [K,I,J]   48  236  197
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8464E-02  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1332E-02  [K,I,J]   46  222  192
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1485E-03  [K,I,J]   46  222  233
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3576E-05  [K,I,J]   45  215  161
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   4027.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2406      [K,I,J]   45  220  312
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1833E-01  [K,I,J]   48  235  207
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1847E-02  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4341E-03  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1547E-03  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5734E-04  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5186E-05  [K,I,J]   45  215  189
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   4036.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1456      [K,I,J]   44  215  189
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1398E-01  [K,I,J]   46  224  184
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2266E-02  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4126E-03  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7778E-04  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1562E-04  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2623E-05  [K,I,J]   46  224  172
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   4050.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8432E-01  [K,I,J]   44  215  189
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1988E-01  [K,I,J]   48  236  189
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3848E-02  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1282E-02  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2777E-03  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6330E-04  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1574E-04  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3636E-05  [K,I,J]   46  224  172
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   4069.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5474E-01  [K,I,J]   23   52  252
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2697E-01  [K,I,J]   46  222  164
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4995E-02  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2457E-02  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6652E-03  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1834E-03  [K,I,J]   44  208  171
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5555E-04  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1436E-04  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4351E-05  [K,I,J]   46  224  172
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   4096.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5721E-01  [K,I,J]   47  234  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3414E-01  [K,I,J]   46  222  233
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7069E-02  [K,I,J]   49  243  212
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4502E-02  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1325E-02  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4686E-03  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1359E-03  [K,I,J]   46  222  192
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5233E-04  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1544E-04  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5543E-05  [K,I,J]   46  224  172
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   4134.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5953E-01  [K,I,J]   47  234  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3746E-01  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1210E-01  [K,I,J]   48  236  197
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5294E-02  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2312E-02  [K,I,J]   44  208  171
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8913E-03  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3619E-03  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1292E-03  [K,I,J]   46  222  192
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.5233E-04  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1740E-04  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.7272E-05  [K,I,J]   46  222  192
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   4187.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6095E-01  [K,I,J]   50  254  235
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3534E-01  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1827E-01  [K,I,J]   48  233   45
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5273E-02  [K,I,J]   37  145  381
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3995E-02  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1438E-02  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7079E-03  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2889E-03  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1183E-03  [K,I,J]   46  222  192
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4935E-04  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1943E-04  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1019E-04  [K,I,J]   44  208  171
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.3338E-05  [K,I,J]   46  224  172
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   4260.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6404E-01  [K,I,J]   45  219   38
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3032E-01  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2337E-01  [K,I,J]   46  222  233
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6745E-02  [K,I,J]   40  172  418
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4179E-02  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2651E-02  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1074E-02  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5027E-03  [K,I,J]   46  224  172
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2289E-03  [K,I,J]   45  215  189
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1221E-03  [K,I,J]   46  222  192
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.5078E-04  [K,I,J]   46  224  172
# ...
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2789E-04  [K,I,J]   39  170  177
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1407E-04  [K,I,J]   39  170  177
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4053E-05  [K,I,J]   42  192  186
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   19591.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4025E-02  [K,I,J]   39  171  189
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5725E-03  [K,I,J]   40  175  181
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5828E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6303E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2750E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1097E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4423E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2134E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1514E-04  [K,I,J]   39  170  177
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4292E-05  [K,I,J]   40  173  181
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   19694.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5268E-02  [K,I,J]   40  158  183
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7651E-03  [K,I,J]   40  175  181
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7254E-03  [K,I,J]   38  159  173
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5856E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4024E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2335E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5937E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4220E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2247E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1496E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.6080E-05  [K,I,J]   40  173  181
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   19710.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8081E-03  [K,I,J]   40  158  183
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1593E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1225E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2873E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7391E-05  [K,I,J]   39  172  189
#
#  STRESS PERIOD NO.   55
#
#  TIME STEP NO.    1
#  FROM TIME =   19710.     TO    20075.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   19715.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3119E-03  [K,I,J]   40  186  183
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8076E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1037E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1609E-05  [K,I,J]   39  172  189
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   19722.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3931E-03  [K,I,J]   40  185  195
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1082E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2474E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4113E-05  [K,I,J]   39  172  189
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   19732.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5366E-03  [K,I,J]   40  185  195
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1320E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5311E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9060E-05  [K,I,J]   39  172  189
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   19746.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7271E-03  [K,I,J]   40  185  195
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1494E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9537E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2009E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6855E-05  [K,I,J]   39  172  189
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   19765.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9855E-03  [K,I,J]   37  159  184
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1699E-03  [K,I,J]   42  192  186
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1400E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4780E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1329E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6020E-05  [K,I,J]   39  172  189
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   19792.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1331E-02  [K,I,J]   37  159  184
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2292E-03  [K,I,J]   38  159  173
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1755E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1015E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2712E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1216E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4530E-05  [K,I,J]   39  172  189
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   19829.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1828E-02  [K,I,J]   40  158  183
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2956E-03  [K,I,J]   38  159  173
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2045E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1709E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5758E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1830E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1037E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5007E-05  [K,I,J]   39  172  189
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   19882.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2529E-02  [K,I,J]   40  158  183
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4007E-03  [K,I,J]   40  175  181
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2883E-03  [K,I,J]   42  192  186
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2378E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1066E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3058E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1937E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1067E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4292E-05  [K,I,J]   39  172  189
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   19956.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3482E-02  [K,I,J]   40  158  183
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5326E-03  [K,I,J]   40  175  181
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4553E-03  [K,I,J]   38  159  173
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2859E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1601E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7486E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2807E-04  [K,I,J]   42  192  186
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1603E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1335E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3636E-05  [K,I,J]   39  172  189
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   20059.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4760E-02  [K,I,J]   40  158  183
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6968E-03  [K,I,J]   40  175  181
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6634E-03  [K,I,J]   38  159  173
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3316E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2316E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1495E-03  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4280E-04  [K,I,J]   42  192  186
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2891E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1597E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1353E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.5126E-05  [K,I,J]   40  173  181
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   20075.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7310E-03  [K,I,J]   40  158  183
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9519E-04  [K,I,J]   38  159  173
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7123E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2187E-04  [K,I,J]   39  172  189
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6139E-05  [K,I,J]   39  172  189
#
#  STRESS PERIOD NO.   56
#
#  TIME STEP NO.    1
#  FROM TIME =   20075.     TO    20440.
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   20080.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7299E-02  [K,I,J]   41  192  186
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5360E-03  [K,I,J]   42  192  186
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8321E-04  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1252E-04  [K,I,J]   42  191  199
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1669E-05  [K,I,J]   42  191  199
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   20087.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4864E-02  [K,I,J]   39  178  190
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5882E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9871E-04  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1127E-04  [K,I,J]   42  191  199
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3874E-05  [K,I,J]   41  187  185
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   20097.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3868E-02  [K,I,J]   39  178  190
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6698E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3922E-04  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8702E-05  [K,I,J]   41  187  185
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   20111.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2618E-02  [K,I,J]   39  178  190
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9081E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7075E-04  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2235E-04  [K,I,J]   38  160  184
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4768E-05  [K,I,J]   41  187  185
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   20130.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2419E-02  [K,I,J]   39  177  181
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1132E-02  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1590E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3535E-04  [K,I,J]   38  160  184
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9298E-05  [K,I,J]   38  160  184
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   20157.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2523E-02  [K,I,J]   39  177  181
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1065E-02  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5394E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3910E-04  [K,I,J]   40  175  181
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1168E-04  [K,I,J]   38  160  184
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4351E-05  [K,I,J]   38  160  184
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   20194.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2589E-02  [K,I,J]   39  177  181
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7854E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9645E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1917E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2652E-04  [K,I,J]   41  184  183
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1127E-04  [K,I,J]   42  192  186
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5305E-05  [K,I,J]   42  192  186
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   20247.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2944E-02  [K,I,J]   38  159  184
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5984E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1040E-02  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5171E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8148E-04  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2152E-04  [K,I,J]   42  192  186
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1824E-04  [K,I,J]   42  192  186
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3755E-05  [K,I,J]   41  187  185
#  Transport Step:    9   Step Size:   73.79     Total Elapsed Time:   20321.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3842E-02  [K,I,J]   38  159  184
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4900E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9647E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7581E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2013E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7230E-04  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2879E-04  [K,I,J]   42  192  186
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1568E-04  [K,I,J]   42  192  186
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.5186E-05  [K,I,J]   41  187  185
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   20424.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4934E-02  [K,I,J]   38  159  184
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6346E-03  [K,I,J]   40  175  181
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8845E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7804E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3895E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1777E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4101E-04  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3499E-04  [K,I,J]   42  192  186
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1258E-04  [K,I,J]   42  192  186
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.6080E-05  [K,I,J]   41  187  185
#  Transport Step:   11   Step Size:   15.93     Total Elapsed Time:   20440.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7751E-03  [K,I,J]   38  159  184
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1956E-03  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9429E-04  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1425E-04  [K,I,J]   41  186  195
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5186E-05  [K,I,J]   42  192  186
#
#  Program completed.   Total CPU time:  100 minutes 34.656 seconds
# (False, [])

# %%
model_ws
# Out:
# 'C:\\Users\\swan47\\AppData\\Local\\Temp\\_T0109005814_wasaga_8t3rbwo4'
