# %%
import flopy
import numpy as np
import matplotlib.pyplot as plt
import shutil
from pathlib import Path

from datetime import datetime
from tempfile import TemporaryDirectory
from tempfile import mkdtemp

import os
import platform
import subprocess
from shapely.geometry import Polygon, Point
from scipy.interpolate import make_interp_spline

# %%
def locate_ground_surface_lay(row=150):
    cross_section = ibound[:,:,0]
    lay = np.where(cross_section[:,row]==1)[0][0]
    return lay

def meter_to_col(col_meter):
    return int(np.round(col_meter/delc,0))

def meter_to_row(row_meter):
    return int(np.round(row_meter/delc,0))

def meter_to_lay(lay_meter):
    return int(np.round((top_elev-lay_meter)/layer_thickness,0))

def col_to_meter(col):
    return col*delc

def row_to_meter(row):
    return row*delc

def lay_to_meter(row):
    return 190.0-row*layer_thickness

# %%
def change_array_within_polygon(array, row_coords, col_coords, value):

    # Create a polygon object from the row and column coordinates
    polygon = Polygon(zip(col_coords, row_coords))

    # Create a boolean mask indicating which points fall within the polygon
    mask = np.zeros_like(array, dtype=bool)
    for row in range(array.shape[0]):
        for col in range(array.shape[1]):
            point = Point(col, row)
            if polygon.contains(point) or polygon.intersects(point):
                mask[row, col] = True

    # Set the values of the array that fall within the polygon to the new value
    array[mask] = value

    return array

# %% [markdown]
# # Workspace

# %%
# Define model workspace

myt = datetime.now().strftime('%m%d%H%M%S')
name = 'wasaga'
temp_dir = mkdtemp(prefix='_T{}_{}_'.format(myt,name))
os.makedirs(Path(temp_dir) / '_output')

#model_ws = "./modflow_model_2"
model_ws = temp_dir

def open_file(path):
    if platform.system() == "Windows":
        os.startfile(path)
    elif platform.system() == "Darwin":
        subprocess.Popen(["open", path])
    else:
        subprocess.Popen(["xdg-open", path])

open_file(model_ws)

# %% [markdown]
# # Model

# %%
# Create a MODFLOW model instance
model = flopy.modflow.Modflow(modelname="example_model",version='mf2005',
                              exe_name='mf2005', 
                              model_ws=model_ws)

# %%
# Create a MODFLOW model instance
model = flopy.seawat.Seawat(modelname="example_model",
                            exe_name='swtv4', 
                              model_ws=model_ws)

# %% [markdown]
# # DIS

# %%
# Define model dimensions
nlay = int(60 * 2)
nrow = int(220 * 1)
ncol = int(220 * 1)
delr = 2200/nrow  # Cell width along rows (extend 2200 / 220)
delc = 2200/ncol  # Cell width along columns (extend 2200 / 220)

# Define top elevation
layer_thickness = 30.0 / nlay

top_elev = 190.0
botm_elev = [top_elev - (i * layer_thickness) for i in range(1, nlay + 1)]
# Define layer thickness (uniform thickness)


perlen = 365
nper = int(70)

steady = np.append(np.array([True]),np.repeat(False,nper-1))
#steady=[False,False,True]
#steady = True

# Create DIS package

# %%
dis = flopy.modflow.ModflowDis(model, nlay=nlay, nrow=nrow, ncol=ncol, 
                               delr=delr, delc=delc,top=top_elev, 
                               botm=botm_elev,
                               nper = nper, perlen = perlen,
                               nstp = 1, steady = steady)

# %% [markdown]
# # Ibound

# %%
x = np.array([0, 100, 340, 600, 750, 850, 1100, 1350, 1450, 1530, 1650, 1750, 1850, 2050, 2200])
y_topo = np.array([190,190,187,184,184,184,183,182,179,175.5,175,173.8,173.5,172,171])#topo
y_clay = np.array([185,184,180,175,174,174,173,170,169,168.5,167.5,166.8,166.5,165,164]) #clay


# Interpolate the data using smoothing splines
spl = make_interp_spline(x, y_topo)
x_smooth_topo = np.linspace(x.min(), x.max(), 30)
y_smooth_topo = spl(x_smooth_topo)

col_coords = (x_smooth_topo/delr).round(0)
col_coords_topo = list(col_coords) +[nrow,0]

row_coords = ((top_elev - y_smooth_topo)/layer_thickness).round(0)
row_coords_topo  =  list(row_coords) +[0,0]



# Interpolate the data using smoothing splines
spl = make_interp_spline(x, y_clay)
x_smooth = np.linspace(x.min(), x.max(), 30)
y_smooth = spl(x_smooth)

col_coords = (x_smooth/delr).round(0)
col_coords_clay = list(col_coords) +[nrow,0]
row_coords = ((top_elev - y_smooth)/layer_thickness).round(0)
row_coords_clay  =  list(row_coords) +[nlay,nlay]

# %% [markdown]
# # Ibound & Strt

# %%
# Define ibound and initial conditionsa
ibound = np.ones((nlay, nrow, ncol), dtype=int)
initial_head = np.full((nlay, nrow, ncol), 200.0, dtype=float)

# Set constant head boundary conditions for the first and last rows
array = change_array_within_polygon(ibound, row_coords_topo, col_coords_topo, 0)
plt.scatter(col_coords_topo,row_coords_topo,c='r')


array = change_array_within_polygon(ibound, row_coords_clay, col_coords_clay, 0)
plt.scatter(col_coords,row_coords,c='r')

for c in range(0,2):
    i = np.where(ibound[:,c,-1]==1)[0][-1]
    head = top_elev-i*layer_thickness
    #print('head {}'.format(head))
    
    while head<187:
        ibound[i,c,:] = -1
        #print(i,c)
        #initial_head[i,c,:] = head+0.5
        print(head)
        initial_head[i,c,:] = 187
        head+=layer_thickness
        i-=1


lay = np.where(ibound[:,int(1700/delr),-1])[0][0]
elv = lay_to_meter(lay)
head = elv

for c in range(int(1700/delr),int(2200/delr)):
    lay = np.where(ibound[:,c,-1]==1)[0][0]
    #print(lay,lay_to_meter(lay))
    ibound[lay,c,:] = -1
    initial_head[lay,c,:] = elv




# Your existing code
im = plt.imshow(ibound[:,:,2], origin='upper', aspect=1)
plt.axvline(x=meter_to_col(1700))# shoreline
plt.gcf().set_size_inches(15,10)

# Set the y-axis tick positions and labels
#plt.yticks([0, 10,20, 30,40, 50,60], ['190m (0L)','185m (10L)', '180m (20L)','175m (30L)', '170m (40L)', '165m (50L)','160m (60L)'])

# Add a horizontal colorbar
cbar = plt.colorbar(im, orientation='horizontal')
cbar.ax.tick_params(labelsize=16)
cbar.set_label('Colorbar Label', fontsize=16)

# Display the plot
plt.title('ibound')
plt.grid()
plt.show()


fig, ax = plt.subplots(figsize=(15, 10))
im = ax.imshow(initial_head[:, :, 0], origin='upper')

# Add a horizontal colorbar
cbar = plt.colorbar(im, orientation='horizontal')
cbar.ax.tick_params(labelsize=18)
plt.title('initial head')
plt.show()
# Out:
# 185.25
# 185.5
# 185.75
# 186.0
# 186.25
# 186.5
# 186.75
# 185.0
# 185.25
# 185.5
# 185.75
# 186.0
# 186.25
# 186.5
# 186.75

# %% [markdown]
# # BAS LPF  PCG

# %%
# Create BAS package
bas = flopy.modflow.ModflowBas(model, ibound=ibound, strt=initial_head)

# Define hydraulic properties
horizontal_k = 2.3  # Horizontal hydraulic conductivity (m/day)
vertical_ka = 0.1   # Vertical hydraulic conductivity (m/day)
porosity = 0.25     # Porosity

# Create LPF package (Layer Property Flow package)
lpf = flopy.modflow.ModflowLpf(model, hk=horizontal_k, 
                               vka=vertical_ka, laytyp=1, 
                               ipakcb=None,ss=0.0002,sy=0.33,
                               laywet=1,iwetit=1,wetfct=0.1,ihdwet=1)

# #ss=0.0002,sy=0.33
# upw = flopy.modflow.ModflowUpw(model, laytyp=1, hk=horizontal_k)

pcg = flopy.modflow.ModflowPcg(model, hclose=1e-3,npcond=1,
                               relax=0.99,rclose=1e-3,mutpcg=0,nbpol=1,iprpcg=1)

# %% [markdown]
# # Heterogeneity

# %%
hk_mean = 2.3  # mean hydraulic conductivity
hk_std = 2  # standard deviation of hydraulic conductivity
hk= np.random.normal(hk_mean, hk_std, size=[nlay,nrow,ncol])
hk[np.where(hk<0)]=0.001

model.lpf.hk = hk

# %%
hk_mean = np.log10(2.3)  # mean hydraulic conductivity
hk_std = 0.4  # standard deviation of hydraulic conductivity
hk= np.random.normal(hk_mean, hk_std, size=[nlay,nrow,ncol])
hk = 10**hk
#hk[np.where(hk<0)]=0.001
hk.mean()
# Out:
# 3.517465573945923

# %%
plt.hist(hk.flatten(),bins=np.linspace(0,20,50))
plt.show()

plt.imshow(hk[0,:,:])
plt.show()

# %% [markdown]
# # DRN

# %%
locate_ground_surface_lay(meter_to_row(160))
#drn_cell = [(0, 150, 28), -10, 100]

beach_drns = np.arange(1520,1600+1,delr).astype(int)
river_drns = np.arange(595,605+1,delr).astype(int)

drn_list = []
drn_ys= list(beach_drns)+list(river_drns)

for y in drn_ys:
   row = meter_to_row(y)
   lay = locate_ground_surface_lay(row=row)
   elv = lay_to_meter(lay)
   #print(lay)
   for col in range(ncol):

      drn_list.append([lay, row, col, elv, 100])
      #drn_list.append([12*2, meter_to_row(600), col, 184.0-0.5, 100])
      
drn_cell = {0:drn_list} 

#drn_cell={0:[[31, 160, 0, 174.5-0.5, 0],[12, 60, 0, 184.0-0.5, 0]]}
drn = flopy.modflow.ModflowDrn(model=model, stress_period_data=drn_cell,)

# %%
lays_with_drn = np.unique([i[0] for i in drn.stress_period_data.data[0]])
for lay in lays_with_drn:
    pmv = flopy.plot.PlotMapView(model=model, layer=lay)
    pmv.plot_bc('DRN',color='r')

# %% [markdown]
# # BTN ICBOUND

# %%
icbund = np.full((nlay, nrow, ncol),0, dtype=float)
icbund = ibound.copy()

btn = flopy.mt3d.Mt3dBtn(
    model,
    nprs=5,
    timprs=np.cumsum([200]*7),
    prsity=0.25,
    sconc= 0.1, # starting concentration
    ifmtcn=0, chkmas=False, nprobs=10, nprmas=10,
    dt0=5,  # The user-specified initial 
    ttsmult=1.4,
    mxstrn = 50000,
    icbund = icbund
)

# %%
adv = flopy.mt3d.Mt3dAdv(model, mixelm=0,percel=0.4,mxpart=50000000,nadvfd=0)
dsp = flopy.mt3d.Mt3dDsp(model, al=0.2, trpt=0.1, 
                        trpv=0.1, 
                        dmcoef=3.7E-10 )
gcg = flopy.mt3d.Mt3dGcg(model, iter1=50, mxiter=1, isolve=2, cclose= 1e-5)

# %% [markdown]
# # RCH

# %%
crch_array =  np.full(( nrow, ncol), 0.1, dtype=float)
crch_dict = {}
crch_dict[0] = crch_array

crch_array =  np.full(( nrow, ncol), 0.1, dtype=float)
crch_array[int(nrow/2),int(ncol/2)] =5000
crch_array[int(nrow/2),int(ncol/3)] =5000
crch_dict = {}
crch_dict[1] = crch_array

ssm = flopy.mt3d.Mt3dSsm(model, crch=crch_dict)

# %%
rch_dict = {}

rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_dict[0] = rch_array

rch_array = np.full(( nrow, ncol), 0.00013, dtype=float)
rch_array[int(nrow/2),int(ncol/2)] = 0.51/delr/delc
rch_array[int(nrow/2),int(ncol/3)] = 0.51/delr/delc

rch_dict[1] = rch_array
rch = flopy.modflow.ModflowRch(model = model, rech = rch_dict)

# %% [markdown]
# # RCT

# %%
#rct = flopy.mt3d.Mt3dRct(model=model, isothm=3,sp1=0.0001,sp2=0.0001,igetsc=0,rhob= 1.65E+09)

# %% [markdown]
# # OC

# %%
oc = flopy.modflow.ModflowOc(
    model,
    stress_period_data= None,
    compact=True,
    extension=['oc', 'hds', 'ddn', 'cbc', 'ibo']
)

# %% [markdown]
# # Write and Run

# %%
# Write MODFLOW input files
model.write_input()
# Out:
# Util2d rech_1: locat is None, but model does not support free format and how is internal... resetting how = external
# Util2d rech_2: locat is None, but model does not support free format and how is internal... resetting how = external

# %%
model_ws
# Out:
# 'C:\\Users\\swan47\\AppData\\Local\\Temp\\_T1027175925_wasaga_2dkbk_34'

# %%
# Run the MODFLOW model
model.run_model()
# Out:
# FloPy is using the following executable to run the model: ..\..\flopy\bin\swtv4.exe
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: example_model.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2023/10/27 18:15:33
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    365.00
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   5.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3339      [K,I,J]   43  125   10
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7210E-03  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4935E-04  [K,I,J]   57  151   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3080E-05  [K,I,J]   57  151   64
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   12.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1496      [K,I,J]   62  167  217
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1608E-02  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1560E-03  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1319E-04  [K,I,J]   57  151   64
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9860E-06  [K,I,J]   57  151   64
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   21.800
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1018      [K,I,J]   62  167   39
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2747E-02  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3442E-03  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4193E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4019E-05  [K,I,J]   52  142    5
#  Transport Step:    4   Step Size:   13.72     Total Elapsed Time:   35.520
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8283E-01  [K,I,J]   17   29   21
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4115E-02  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6925E-03  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1058E-03  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1437E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1549E-05  [K,I,J]   52  142    5
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   54.728
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9206E-01  [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5551E-02  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1221E-02  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2235E-03  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4176E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6356E-05  [K,I,J]   52  142    5
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   81.619
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1126      [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7966E-02  [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1882E-02  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4307E-03  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9985E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2141E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3729E-05  [K,I,J]   52  142    5
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   119.27
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1345      [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1502E-01  [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2560E-02  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6926E-03  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1974E-03  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5569E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1380E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2972E-05  [K,I,J]   52  142    5
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   171.97
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1564      [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2555E-01  [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3267E-02  [K,I,J]   28   76    8
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9567E-03  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3350E-03  [K,I,J]   45  127   23
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1125E-03  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3444E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9724E-05  [K,I,J]   52  142    5
#  Transport Step:    9   Step Size:   28.03     Total Elapsed Time:   200.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6472E-01  [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6555E-02  [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7952E-03  [K,I,J]   49  136  113
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2105E-03  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5548E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1308E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2494E-05  [K,I,J]   52  142    5
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   303.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2216      [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6177E-01  [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9978E-02  [K,I,J]   23   53  143
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3288E-02  [K,I,J]   25   57   88
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9048E-03  [K,I,J]   45  127   23
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3332E-03  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1399E-03  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5030E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1023E-04  [K,I,J]   55  147  208
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3305E-04  [K,I,J]   55  147  208
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3952E-05  [K,I,J]   52  142    5
#  Transport Step:   11   Step Size:   61.69     Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9433E-01  [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2140E-01  [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3335E-02  [K,I,J]   24   57  178
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6075E-03  [K,I,J]   45  127   23
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2439E-03  [K,I,J]   45  127   23
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8326E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2963E-04  [K,I,J]   52  142    5
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9241E-05  [K,I,J]   52  142    5
#
#  STRESS PERIOD NO.    2
#
#   STRESS PERIOD    2 TIME STEP    1 FROM TIME =   365.00     TO    730.00
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   370.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   9828.      [K,I,J]   37  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   565.9      [K,I,J]   38  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =   22.11      [K,I,J]   38  111  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1495      [K,I,J]   39  111   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1909E-02  [K,I,J]   39  112  111
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7670E-04  [K,I,J]   39  113  111
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3644E-05  [K,I,J]   39  113  111
#  Transport Step:    2   Step Size:   7.000     Total Elapsed Time:   377.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4661      [K,I,J]   37  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4743E-01  [K,I,J]   38  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3800E-02  [K,I,J]   38  111  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1030E-03  [K,I,J]   39  111   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1592E-05  [K,I,J]   40  111   74
#  Transport Step:    3   Step Size:   9.800     Total Elapsed Time:   386.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2651      [K,I,J]   38  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3167E-01  [K,I,J]   38  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2488E-02  [K,I,J]   38  111  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2500E-03  [K,I,J]   38  111  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8724E-05  [K,I,J]   39  111  111
#  Transport Step:    4   Step Size:   13.20     Total Elapsed Time:   400.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2263      [K,I,J]   39  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2807E-01  [K,I,J]   38  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2041E-02  [K,I,J]   38  111   74
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3243E-03  [K,I,J]   38  111  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2508E-04  [K,I,J]   39  111  111
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1253E-05  [K,I,J]   43  112   74
#  Transport Step:    5   Step Size:   19.21     Total Elapsed Time:   419.21
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2078      [K,I,J]   40  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2124E-01  [K,I,J]   38  111   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2753E-02  [K,I,J]   42  111  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4908E-03  [K,I,J]   40  111   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6216E-04  [K,I,J]   42  111  111
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6063E-05  [K,I,J]   43  112   74
#  Transport Step:    6   Step Size:   26.89     Total Elapsed Time:   446.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1974      [K,I,J]   41  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1582E-01  [K,I,J]   43  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3051E-02  [K,I,J]   42  111  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7063E-03  [K,I,J]   40  111   74
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1014E-03  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1625E-04  [K,I,J]   43  112   74
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3993E-05  [K,I,J]   43  113   74
#  Transport Step:    7   Step Size:   37.65     Total Elapsed Time:   483.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1831      [K,I,J]   43  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2181E-01  [K,I,J]   39  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5748E-02  [K,I,J]   39  113  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1052E-02  [K,I,J]   39  113  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2752E-03  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9588E-04  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5626E-04  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3160E-05  [K,I,J]   43  113   74
#  Transport Step:    8   Step Size:   52.71     Total Elapsed Time:   536.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1869      [K,I,J]   44  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3154E-01  [K,I,J]   39  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8053E-02  [K,I,J]   39  113  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3104E-02  [K,I,J]   39  113  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4225E-03  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2256E-03  [K,I,J]   43  113   74
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2966E-04  [K,I,J]   40  114   73
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.8374E-05  [K,I,J]   40  114   73
#  Transport Step:    9   Step Size:   63.55     Total Elapsed Time:   600.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1568      [K,I,J]   45  111  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3279E-01  [K,I,J]   39  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7802E-02  [K,I,J]   39  113  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4002E-02  [K,I,J]   39  113  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3647E-03  [K,I,J]   44  113   74
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2400E-03  [K,I,J]   40  114   73
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4106E-04  [K,I,J]   40  114   73
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1709E-04  [K,I,J]   40  114   73
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2808E-05  [K,I,J]   40  115   73
#  Transport Step:   10   Step Size:   103.3     Total Elapsed Time:   703.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1929      [K,I,J]   42  112  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4570E-01  [K,I,J]   38  112   74
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1178E-01  [K,I,J]   44  112  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5788E-02  [K,I,J]   40  115   73
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2322E-02  [K,I,J]   40  115   73
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8477E-03  [K,I,J]   40  114   73
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.8544E-04  [K,I,J]   48  115  111
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9606E-04  [K,I,J]   48  115  111
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1004E-03  [K,I,J]   40  115   73
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3084E-04  [K,I,J]   40  115   73
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1577E-05  [K,I,J]   47  119  111
#  Transport Step:   11   Step Size:   26.69     Total Elapsed Time:   730.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3907E-01  [K,I,J]   42  112  111
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5874E-02  [K,I,J]   42  112  111
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1221E-02  [K,I,J]   39  113  111
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2710E-03  [K,I,J]   39  113  111
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1571E-04  [K,I,J]   39  113  111
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4124E-05  [K,I,J]   40  115   73
#
#  STRESS PERIOD NO.    3
#
#   STRESS PERIOD    3 TIME STEP    1 FROM TIME =   730.00     TO    1095.0
#
#  Transport Step:    1   Step Size:   5.000     Total Elapsed Time:   735.00
